# %% [markdown]
# # NoSQL (MongoDB) (sesión 4)

# %% [markdown]
# ![Image of MongoDB](https://webassets.mongodb.com/_com_assets/cms/MongoDB-Logo-5c3a7405a85675366beb3a5ec4c032348c390b3f142f5e6dddf1d78e2df5cb5c.png)
#
# Esta hoja muestra cómo acceder a bases de datos MongoDB y también a conectar la salida con Jupyter. Se puede utilizar el *shell* propio de MongoDB en la máquina virtual usando el programa `mongo`. La diferencia es que ese programa espera código Javascript y aquí trabajaremos con Python.
#
# Lo primero que se hará será instalar la versión 3.2 de mongodb. Ésta no viene por defecto en la máquina virtual, y sólo hay que hacerlo una vez, aunque no pasa nada si se repite.

# %%
# Config
port = 27017
# %env DIR=/tmp
# %env MONGOPORT=$port
# Out:
# env: DIR=/tmp
# env: MONGOPORT=27017

# %%
# %%bash
# sudo apt-key adv --keyserver hkp://keyserver.ubuntu.com:80 --recv EA312927
# echo "deb http://repo.mongodb.org/apt/ubuntu xenial/mongodb-org/3.2 multiverse" | sudo tee /etc/apt/sources.list.d/mongodb-org-3.2.list
# sudo apt-get update
# sudo apt-get install -y mongodb-org

# %%
# !sudo service mongod start

# %%
# !mongo -version
# Out:
# MongoDB shell version: 3.2.10

# %%
# !echo 'show log global' | mongo
# Out:
# MongoDB shell version: 3.2.10
# connecting to: test
# 2016-12-09T15:10:50.483+0000 W NETWORK  [thread1] Failed to connect to 127.0.0.1:27017, reason: errno:111 Connection refused
# 2016-12-09T15:10:50.641+0000 E QUERY    [thread1] Error: couldn't connect to server 127.0.0.1:27017, connection attempt failed :
# connect@src/mongo/shell/mongo.js:229:14
# @(connect):1:6
#
# exception: connect failed

# %% [markdown]
# ## OJO: Algunas versiones de pymongo han dado fallos en el retorno de cursores en aggregate. Hay que actualizar a la última versión:

# %%
# !sudo pip2 install --upgrade pymongo
# Out:
# Requirement already up-to-date: pymongo in /usr/local/lib/python2.7/dist-packages
# Cleaning up...

# %%
from pprint import pprint as pp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# Usaremos la librería `pymongo` para python. La cargamos a continuación.

# %%
import pymongo
from pymongo import MongoClient

# %% [markdown]
# La conexión se inicia con `MongoClient`.

# %%
client = MongoClient("localhost", port)
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client.database_names()
# Out:
# [u'local', u'stackoverflow']

# %% [markdown]
#  - Format: 7zipped
#  - Files:
#    - **badges**.xml
#        - UserId, e.g.: "420"
#        - Name, e.g.: "Teacher"
#        - Date, e.g.: "2008-09-15T08:55:03.923"
#    - **comments**.xml
#        - Id
#        - PostId
#        - Score
#        - Text, e.g.: "@Stu Thompson: Seems possible to me - why not try it?"
#        - CreationDate, e.g.:"2008-09-06T08:07:10.730"
#        - UserId
#    - **posts**.xml
#        - Id
#        - PostTypeId
#           - 1: Question
#           - 2: Answer
#        - ParentID (only present if PostTypeId is 2)
#        - AcceptedAnswerId (only present if PostTypeId is 1)
#        - CreationDate
#        - Score
#        - ViewCount
#        - Body
#        - OwnerUserId
#        - LastEditorUserId
#        - LastEditorDisplayName="Jeff Atwood"
#        - LastEditDate="2009-03-05T22:28:34.823"
#        - LastActivityDate="2009-03-11T12:51:01.480"
#        - CommunityOwnedDate="2009-03-11T12:51:01.480"
#        - ClosedDate="2009-03-11T12:51:01.480"
#        - Title=
#        - Tags=
#        - AnswerCount
#        - CommentCount
#        - FavoriteCount
#    - **posthistory**.xml
# 	   - Id
# 	   - PostHistoryTypeId
# 			- 1: Initial Title - The first title a question is asked with.
# 			- 2: Initial Body - The first raw body text a post is submitted with.
# 			- 3: Initial Tags - The first tags a question is asked with.
# 			- 4: Edit Title - A question's title has been changed.
# 			- 5: Edit Body - A post's body has been changed, the raw text is stored here as markdown.
# 			- 6: Edit Tags - A question's tags have been changed.
# 			- 7: Rollback Title - A question's title has reverted to a previous version.
# 			- 8: Rollback Body - A post's body has reverted to a previous version - the raw text is stored here.
# 			- 9: Rollback Tags - A question's tags have reverted to a previous version.
# 			- 10: Post Closed - A post was voted to be closed.
# 			- 11: Post Reopened - A post was voted to be reopened.
# 			- 12: Post Deleted - A post was voted to be removed.
# 			- 13: Post Undeleted - A post was voted to be restored.
# 			- 14: Post Locked - A post was locked by a moderator.
# 			- 15: Post Unlocked - A post was unlocked by a moderator.
# 			- 16: Community Owned - A post has become community owned.
# 			- 17: Post Migrated - A post was migrated.
# 			- 18: Question Merged - A question has had another, deleted question merged into itself.
# 			- 19: Question Protected - A question was protected by a moderator
# 			- 20: Question Unprotected - A question was unprotected by a moderator
# 			- 21: Post Disassociated - An admin removes the OwnerUserId from a post.
# 			- 22: Question Unmerged - A previously merged question has had its answers and votes restored.
# 		- PostId
# 		- RevisionGUID: At times more than one type of history record can be recorded by a single action.  All of these will be grouped using the same RevisionGUID
# 		- CreationDate: "2009-03-05T22:28:34.823"
# 		- UserId
# 		- UserDisplayName: populated if a user has been removed and no longer referenced by user Id
# 		- Comment: This field will contain the comment made by the user who edited a post
# 		- Text: A raw version of the new value for a given revision
# 			- If PostHistoryTypeId = 10, 11, 12, 13, 14, or 15  this column will contain a JSON encoded string with all users who have voted for the PostHistoryTypeId
# 			- If PostHistoryTypeId = 17 this column will contain migration details of either "from <url>" or "to <url>"
# 		- CloseReasonId
# 			- 1: Exact Duplicate - This question covers exactly the same ground as earlier questions on this topic; its answers may be merged with another identical question.
# 			- 2: off-topic
# 			- 3: subjective
# 			- 4: not a real question
# 			- 7: too localized
#    - **postlinks**.xml
#      - Id
#      - CreationDate
#      - PostId
#      - RelatedPostId
#      - PostLinkTypeId
#        - 1: Linked
#        - 3: Duplicate
#    - **users**.xml
#      - Id
#      - Reputation
#      - CreationDate
#      - DisplayName
#      - EmailHash
#      - LastAccessDate
#      - WebsiteUrl
#      - Location
#      - Age
#      - AboutMe
#      - Views
#      - UpVotes
#      - DownVotes
#    - **votes**.xml
#      - Id
#      - PostId
#      - VoteTypeId
#         - ` 1`: AcceptedByOriginator
#         - ` 2`: UpMod
#         - ` 3`: DownMod
#         - ` 4`: Offensive
#         - ` 5`: Favorite - if VoteTypeId = 5 UserId will be populated
#         - ` 6`: Close
#         - ` 7`: Reopen
#         - ` 8`: BountyStart
#         - ` 9`: BountyClose
#         - `10`: Deletion
#         - `11`: Undeletion
#         - `12`: Spam
#         - `13`: InformModerator
#      - CreationDate
#      - UserId (only for VoteTypeId 5)
#      - BountyAmount (only for VoteTypeId 9)

# %%
# %%bash
# (test -e $DIR/Posts.csv && echo "Ya descargado") || (\
# (wget http://neuromancer.inf.um.es:8080/es.stackoverflow/Posts.csv.gz -O - 2>/dev/null | gunzip > $DIR/Posts.csv) \
#   && echo OK)
# Out:
# OK

# %%
# %%bash
# (test -e $DIR/Users.csv && echo "Ya descargado") || (\
# (wget http://neuromancer.inf.um.es:8080/es.stackoverflow/Users.csv.gz -O - 2>/dev/null | gunzip > $DIR/Users.csv) \
#   && echo OK)
# Out:
# OK

# %%
# %%bash
# (test -e $DIR/Tags.csv && echo "Ya descargado") || (\
# (wget http://neuromancer.inf.um.es:8080/es.stackoverflow/Tags.csv.gz -O - 2>/dev/null | gunzip > $DIR/Tags.csv) \
#   && echo OK)
# Out:
# OK

# %%
# %%bash
# (test -e $DIR/Comments.csv && echo "Ya descargado") || (\
# (wget http://neuromancer.inf.um.es:8080/es.stackoverflow/Comments.csv.gz -O - 2>/dev/null | gunzip > $DIR/Comments.csv) \
#   && echo OK)
# Out:
# OK

# %%
# %%bash
# (test -e $DIR/Votes.csv && echo "Ya descargado") || (\
# (wget http://neuromancer.inf.um.es:8080/es.stackoverflow/Votes.csv.gz -O - 2>/dev/null | gunzip > $DIR/Votes.csv) \
#   && echo OK)
# Out:
# OK

# %% [markdown]
# Las bases de datos se crean conforme se nombran. Se puede utilizar la notación punto o la de diccionario. Las colecciones también.

# %%
db = client.stackoverflow
db = client['stackoverflow']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'stackoverflow')

# %% [markdown]
# Las bases de datos están compuestas por un conjunto de **colecciones**. Cada colección aglutina a un conjunto de objetos (documentos) del mismo tipo, aunque como vimos en teoría, cada documento puede tener un conjunto de atributos diferente.

# %%
posts = db.posts
posts
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'stackoverflow'), u'posts')

# %% [markdown]
# Importación de los ficheros CSV. Por ahora creamos una colección diferente para cada uno. Después estudiaremos cómo poder optimizar el acceso usando agregación.

# %%
# %%bash
# mongoimport --db stackoverflow --collection posts --drop --type csv \
#    --headerline --host=127.0.0.1:$MONGOPORT --file $DIR/Posts.csv
# Out:
# 2016-12-09T15:11:42.364+0000	connected to: 127.0.0.1:27017
# 2016-12-09T15:11:42.365+0000	dropping: stackoverflow.posts
# 2016-12-09T15:11:45.321+0000	[###########.............] stackoverflow.posts	14.0MB/29.1MB (48.0%)
# 2016-12-09T15:11:48.321+0000	[###################.....] stackoverflow.posts	23.5MB/29.1MB (80.9%)
# 2016-12-09T15:11:49.303+0000	[########################] stackoverflow.posts	29.1MB/29.1MB (100.0%)
# 2016-12-09T15:11:49.303+0000	imported 17946 documents

# %%
# %%bash
# mongoimport --db stackoverflow --collection users --drop --type csv \
#    --headerline --host=127.0.0.1:$MONGOPORT --file $DIR/Users.csv
# Out:
# 2016-12-09T15:11:49.384+0000	connected to: 127.0.0.1:27017
# 2016-12-09T15:11:49.385+0000	dropping: stackoverflow.users
# 2016-12-09T15:11:50.891+0000	imported 10930 documents

# %%
# %%bash
# mongoimport --db stackoverflow --collection votes --drop --type csv \
#    --headerline --host=127.0.0.1:$MONGOPORT --file $DIR/Votes.csv
# Out:
# 2016-12-09T15:11:50.954+0000	connected to: 127.0.0.1:27017
# 2016-12-09T15:11:50.954+0000	dropping: stackoverflow.votes
# 2016-12-09T15:11:52.893+0000	imported 40655 documents

# %%
# %%bash
# mongoimport --db stackoverflow --collection comments --drop --type csv \
#    --headerline --host=127.0.0.1:$MONGOPORT --file $DIR/Comments.csv
# Out:
# 2016-12-09T15:11:52.945+0000	connected to: 127.0.0.1:27017
# 2016-12-09T15:11:52.945+0000	dropping: stackoverflow.comments
# 2016-12-09T15:11:55.121+0000	imported 25231 documents

# %%
# %%bash
# mongoimport --db stackoverflow --collection tags --drop --type csv \
#    --headerline --host=127.0.0.1:$MONGOPORT --file $DIR/Tags.csv
# Out:
# 2016-12-09T15:11:55.170+0000	connected to: 127.0.0.1:27017
# 2016-12-09T15:11:55.171+0000	dropping: stackoverflow.tags
# 2016-12-09T15:11:55.359+0000	imported 873 documents

# %%
posts.count()
# Out:
# 17946

# %%
def print_respuestas(respuestas):
    for r in respuestas:
        pp(r)

# %% [markdown]
# El API de colección en Python se puede encontrar aquí: https://api.mongodb.com/python/current/api/pymongo/collection.html. La mayoría de libros y referencias muestran el uso de mongo desde Javascript, ya que el *shell* de MongoDB acepta ese lenguaje. La sintaxis con respecto a Python cambia un poco, y se puede seguir en el enlace anterior.

# %%
respuestas = posts.find({ '$and' : [ {"PostTypeId": 2} ,
                                    {"Id" : {'$gte' : 100}} ]}).limit(10)
print_respuestas(respuestas)
# Out:
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<pre><code>$ git reset --soft HEAD~  o $ git reset --soft HEAD~1       #1<br/>// Cambios necesarios //                                    #2<br/>$ git add ...                                               #3<br/>$ git commit ...                                            #4<br/></code></pre><br/><br/><p>Simplemente haces un reset soft, con lo que te quedas con los cambios en local pero deshaces el commit, despu\xe9s haces lo que quieras y vuelves a hacer el commit como quer\xedas la primera vez.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:00:31.680',
#  u'FavoriteCount': u'',
#  u'Id': 102,
#  u'LastActivityDate': u'2015-12-01T19:00:31.680',
#  u'LastEditDate': u'',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': u'',
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 178,
#  u'ParentId': 90,
#  u'PostTypeId': 2,
#  u'Score': 8,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1748e')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Usa m\xe1rgenes laterales autom\xe1ticos.</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.externo {<br/>  border: 1px solid blue;<br/>}<br/>.interno {<br/>  border: 1px dashed goldenrod;<br/>  margin: auto;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/><br/><p>Realmente solo debes de ponerlos en sus valores <code>margin-left</code> y <code>margin-right</code>, pero en tu caso al no requerir margen superior y/o inferior, te valdr\xeda de esa forma, ya que seg\xfan la documentaci\xf3n si se espefica de esa forma ser\xeda igual que hacer:</p><br/><br/><pre><code>.interno {<br/>  margin: 0 auto;<br/>}<br/></code></pre><br/><br/><p>Es decir, el superior e inferior es igual a cero.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 3,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:08:31.660',
#  u'FavoriteCount': u'',
#  u'Id': 105,
#  u'LastActivityDate': u'2015-12-07T18:16:45.097',
#  u'LastEditDate': u'2015-12-07T18:16:45.097',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 280,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 16,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17491')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Pues, no creo que esto sea posible sin recurrir a la altamante no recomendada <code>global</code>. El caso espec\xedfico que muestras aplica perfectamente en la Programaci\xf3n Orientada a Objetos, ser\xeda bueno que expliques la raz\xf3n por la cual est\xe1s tratando de evitarla:</p><br/><br/><pre><code>import serial<br/><br/><br/>class Clase():<br/>    def __init__(self, puerto, baud_rate, buffer) # inicializacion()<br/>        self.puerto = puerto<br/>        self.baud_rate = baud_rate<br/>        self.buffer = buffer<br/>        self.serial = serial.Serial(puerto, baudRate, timeout=1)<br/><br/>    def leer_datos(self):<br/>        # Tu c\xf3digo<br/></code></pre><br/><br/><p>Si estas intentando usar los par\xe1metros de configuraci\xf3n, podr\xedas crear un archivo espec\xedfico el cual ser\xe1 importado a demanda:</p><br/><br/><p><em>settings.py</em></p><br/><br/><pre><code>puerto = \'/dev/ttyACM0\'<br/>baudRate = 115200<br/>buffer = \'\'<br/></code></pre><br/><br/><p><em>main.py</em></p><br/><br/><pre><code>import serial<br/>import settings<br/><br/><br/>def main():<br/>    ser = serial.Serial(settings.puerto, settings.baudRate, timeout=1)<br/>    buffer = settings.buffer + leerDatos(ser)<br/></code></pre><br/><br/><p>Otra opci\xf3n es la mencionada por @Carlangueitor en la cual tu configuraci\xf3n la mueves a un archivo <code>.env</code> dentro de tu proyecto y as\xed evitas exponer la configuraci\xf3n en uno de los archivos. Puedes usar <a href="https://github.com/theskumar/python-dotenv">dotenv</a>.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:07:00.763',
#  u'FavoriteCount': u'',
#  u'Id': 104,
#  u'LastActivityDate': u'2015-12-01T19:07:00.763',
#  u'LastEditDate': u'',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': u'',
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 100,
#  u'ParentId': 87,
#  u'PostTypeId': 2,
#  u'Score': 11,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17492')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Agrega un <code>margin:0 auto;</code> a la clase <code>interno</code> en el CSS para lograr centrarlo horizontalmente dentro del div externo</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.interno {<br/>  background-color: green;<br/>  height: 20px;<br/>  width: 50%;<br/>  margin: 0 auto;/*esto fue lo que se agreg\xf3*/<br/>}<br/>.externo {<br/>  background-color: red;<br/>  width: 200px;<br/>  padding: 20px;<br/>  text-align:center;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:11:46.373',
#  u'FavoriteCount': u'',
#  u'Id': 107,
#  u'LastActivityDate': u'2016-01-05T18:40:20.503',
#  u'LastEditDate': u'2016-01-05T18:40:20.503',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 98,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 98,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 7,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17493')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.interno {<br/>  background-color: green;<br/>  height: 20px;<br/>  width: 50%;<br/>  margin: 0 auto;<br/>}<br/>.externo {<br/>  border: 1px solid blue;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/><br/><p>Simplemente a\xf1adiendo la \xfaltima l\xednea, se centra con respecto a su padre.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:10:09.660',
#  u'FavoriteCount': u'',
#  u'Id': 106,
#  u'LastActivityDate': u'2015-12-07T18:16:48.710',
#  u'LastEditDate': u'2015-12-07T18:16:48.710',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 178,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 2,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17494')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Puedes usar un <a href="https://developer.mozilla.org/es/docs/Web/CSS/CSS_Flexible_Box_Layout/Usando_las_cajas_flexibles_CSS" rel="nofollow">flexbox</a> en el <code>div</code> externo.</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.externo {<br/>  display: flex;<br/>  justify-content: center;<br/>  border: 1px solid blue;<br/>}<br/>.interno {<br/>  border: 1px dashed goldenrod;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:14:47.937',
#  u'FavoriteCount': u'',
#  u'Id': 109,
#  u'LastActivityDate': u'2015-12-07T18:25:51.847',
#  u'LastEditDate': u'2015-12-07T18:25:51.847',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 302,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 3,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17495')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Puedes aplicar este CSS al <code>div</code> interno:</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.interno {<br/>  width: 50%;<br/>  margin: 0 auto;<br/>  border: 1px dashed goldenrod;<br/>}<br/>.externo {<br/>  border: 1px solid blue;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/><br/><p>Por supuesto, no tienes que establecer el ancho al 50%. Cualquier ancho inferior al del <code>div</code> padre funcionar\xe1. El <code>margin: 0 auto</code> es lo que hace el centrado en s\xed.</p><br/><br/><p>Si quieres incluir IE8+, puede que sea mejor usar esto en su lugar:</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.interno {<br/>  display: table;<br/>  margin: 0 auto;<br/>  border: 1px dashed goldenrod;<br/>}<br/>.externo {<br/>  border: 1px solid blue;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/><br/><p>Har\xe1 que el elemento interno se centre horizontalmente, y funciona sin especificar un ancho concreto.</p><br/><br/><p><a href="http://stackoverflow.com/a/114549"><strong>Fuente</strong></a></p><br/><br/><p><a href="https://jsfiddle.net/vLkdgwnv/" rel="nofollow"><strong>JSFiddle</strong></a></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:14:00.683',
#  u'FavoriteCount': u'',
#  u'Id': 108,
#  u'LastActivityDate': u'2015-12-19T06:37:23.277',
#  u'LastEditDate': u'2015-12-19T06:37:23.277',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 149,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 3,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17497')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u"<p>La forma m\xe1s sencilla de lograrlo, es decir sin procedimientos ni cosas complejas, es ejecutar la siguiente consulta:</p><br/><br/><pre><code>SELECT owner, table_name, num_rows, sample_size, last_analyzed <br/>FROM all_tables<br/>WHERE owner = 'nombre_de_tu_esquema';<br/></code></pre><br/><br/><p>La columna <code>num_rows</code> contiene el n\xfamero de filas o registros de cada una de las tablas.</p><br/><br/><hr><br/><br/><p>Actualizaci\xf3n:</p><br/><br/><p>Como destaca @jpertejo: </p><br/><br/><blockquote><br/>  <p>Hay que tener en cuenta que la columna <code>NUM_ROWS</code> de la vista<br/>  <code>ALL_TABLES</code> obtiene la informaci\xf3n de las estad\xedsticas de la tabla.<br/>  Si las estad\xedsticas no est\xe1n actualizadas puede ser que el n\xfamero de<br/>  filas que devuelve el <code>NUM_ROWS</code> no se corresponda con el real. Para<br/>  saber con exactitud en n\xfamero real de filas habr\xeda que hacer un<br/>  <code>COUNT(*)</code>. La consulta del <code>NUM_ROWS</code> es m\xe1s r\xe1pida que el<br/>  <code>COUNT(*)</code>, pero puede no dar datos correctos en algunos casos.</p><br/></blockquote><br/><br/><p>De aqu\xed que en la consulta se incluya la columna <code>last_analyzed</code> cuyo fin es informar la fecha en la que se hizo el m\xe1s reciente an\xe1lisis estad\xedstico para cada tabla.</p><br/>",
#  u'ClosedDate': u'',
#  u'CommentCount': 10,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:15:58.153',
#  u'FavoriteCount': u'',
#  u'Id': 111,
#  u'LastActivityDate': u'2015-12-01T23:57:13.763',
#  u'LastEditDate': u'2015-12-01T23:57:13.763',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 264,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 264,
#  u'ParentId': 110,
#  u'PostTypeId': 2,
#  u'Score': 8,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17498')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Existen muchas formas de centrar elementos con <strong>CSS</strong>, sin embargo una de las que mayor fuerza han tomado en el \xfaltimo a\xf1o es el uso de <strong>Flexbox</strong>.</p><br/><br/><p>Usando Flexbox el contenedor no necesita tener ninguna propiedad especifica para ubicarse en el espacio, sin embargo usando las propiedades de Flexbox para los hijos se puede hacer cosas impensables con el CSS tradicional.</p><br/><br/><p><div class="snippet" data-lang="js" data-hide="false"><br/><div class="snippet-code"><br/><pre class="snippet-code-css lang-css prettyprint-override"><code>.externo {<br/>  border: 1px solid blue;<br/>  align-items: center;<br/>  display: flex;<br/>  justify-content: center;<br/>}<br/>.interno {<br/>  border: 1px dashed goldenrod;<br/>}</code></pre><br/><pre class="snippet-code-html lang-html prettyprint-override"><code><div class="externo"><br/>  <div class="interno"><br/>    Hola<br/>  </div><br/></div></code></pre><br/></div><br/></div><br/></p><br/><br/><p>Para conocer m\xe1s acerca de Flexbox te recomiendo visitar los siguientes enlaces:</p><br/><br/><ul><br/><li><strong>CSS-Tricks</strong> - <a href="https://css-tricks.com/snippets/css/a-guide-to-flexbox/">A Complete Guide to Flexbox</a></li><br/><li><strong>Codrops</strong> - <a href="http://tympanus.net/codrops/css_reference/flexbox/">Flexbox</a></li><br/></ul><br/><br/><hr><br/><br/><p>Si buscas una soluci\xf3n que no incluya Flexbox entonces te recomiendo visitar <a href="https://css-tricks.com/centering-css-complete-guide/">Centering in CSS: A Complete Guide</a>. Esta es la gu\xeda absoluta de como centrar elementos utilizando CSS sin importar el navegador que necesites soportar.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 11,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:16:03.973',
#  u'FavoriteCount': u'',
#  u'Id': 112,
#  u'LastActivityDate': u'2015-12-07T18:15:35.950',
#  u'LastEditDate': u'2015-12-07T18:15:35.950',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 296,
#  u'ParentId': 103,
#  u'PostTypeId': 2,
#  u'Score': 12,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17499')}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Lo que responde Elenasys es correcto. <code>LoginTask</code> es una <code>AsyncTask</code>, con lo cual no es una <code>Activity</code>. No puedes "volver a ella".<br/>Si quieres entender algo m\xe1s sobre el estado de tu <em>stack</em> de activities, puedes correr el siguiente comando de adb:</p><br/><br/><pre><code>adb shell dumpsys activities<br/></code></pre><br/><br/><p>Ah\xed podr\xe1s ver c\xf3mo est\xe1n tus actividades y comprender qu\xe9 pasar\xe1 cuando pulsas "back".</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-01T19:29:43.757',
#  u'FavoriteCount': u'',
#  u'Id': 117,
#  u'LastActivityDate': u'2015-12-04T16:32:07.947',
#  u'LastEditDate': u'2015-12-04T16:32:07.947',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 95,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 309,
#  u'ParentId': 89,
#  u'PostTypeId': 2,
#  u'Score': -1,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1749e')}

# %% [markdown]
# ## Map-Reduce
#
# Mongodb incluye dos APIs para procesar y buscar documentos: el API de Map-Reduce y el API de agregación. Veremos primero el de Map-Reduce. Manual: https://docs.mongodb.com/manual/aggregation/#map-reduce. También el API (en Javascript) de la propia función `mapReduce()` de MongoDB muestra todas las opciones disponibles: https://docs.mongodb.com/manual/reference/command/mapReduce/#dbcmd.mapReduce.
#
# ![imagen](https://docs.mongodb.com/manual/_images/map-reduce.png)

# %%
from bson.code import Code

map = Code("function () {"
           "  emit(this.OwnerUserId, 1);"
           "}")

# %%
reduce = Code("function (key, values) {"
              "  return Array.sum(values);"
              "}")

# %%
results = posts.map_reduce(map, reduce, "posts_by_userid")

# %%
posts_by_userid = db.posts_by_userid
print_respuestas(posts_by_userid.find())
# Out:
# {u'_id': -1.0, u'value': 91.0}
# {u'_id': 20.0, u'value': 110.0}
# {u'_id': 21.0, u'value': 42.0}
# {u'_id': 22.0, u'value': 26.0}
# {u'_id': 23.0, u'value': 31.0}
# {u'_id': 24.0, u'value': 228.0}
# {u'_id': 25.0, u'value': 301.0}
# {u'_id': 26.0, u'value': 18.0}
# {u'_id': 27.0, u'value': 1.0}
# {u'_id': 28.0, u'value': 60.0}
# {u'_id': 29.0, u'value': 3.0}
# {u'_id': 34.0, u'value': 21.0}
# {u'_id': 35.0, u'value': 5.0}
# {u'_id': 36.0, u'value': 1.0}
# {u'_id': 37.0, u'value': 3.0}
# {u'_id': 58.0, u'value': 1.0}
# {u'_id': 65.0, u'value': 40.0}
# {u'_id': 67.0, u'value': 2.0}
# {u'_id': 71.0, u'value': 3.0}
# {u'_id': 73.0, u'value': 275.0}
# {u'_id': 74.0, u'value': 20.0}
# {u'_id': 75.0, u'value': 9.0}
# {u'_id': 77.0, u'value': 1.0}
# {u'_id': 78.0, u'value': 24.0}
# {u'_id': 83.0, u'value': 25.0}
# {u'_id': 87.0, u'value': 10.0}
# {u'_id': 90.0, u'value': 1.0}
# {u'_id': 91.0, u'value': 2.0}
# {u'_id': 92.0, u'value': 3.0}
# {u'_id': 93.0, u'value': 10.0}
# {u'_id': 95.0, u'value': 850.0}
# {u'_id': 98.0, u'value': 3.0}
# {u'_id': 100.0, u'value': 315.0}
# {u'_id': 103.0, u'value': 5.0}
# {u'_id': 105.0, u'value': 9.0}
# {u'_id': 113.0, u'value': 1.0}
# {u'_id': 116.0, u'value': 8.0}
# {u'_id': 120.0, u'value': 12.0}
# {u'_id': 124.0, u'value': 1.0}
# {u'_id': 127.0, u'value': 96.0}
# {u'_id': 129.0, u'value': 1.0}
# {u'_id': 132.0, u'value': 5.0}
# {u'_id': 136.0, u'value': 12.0}
# {u'_id': 137.0, u'value': 4.0}
# {u'_id': 143.0, u'value': 5.0}
# {u'_id': 144.0, u'value': 1.0}
# {u'_id': 148.0, u'value': 1.0}
# {u'_id': 149.0, u'value': 9.0}
# {u'_id': 152.0, u'value': 1.0}
# {u'_id': 154.0, u'value': 33.0}
# {u'_id': 158.0, u'value': 2.0}
# {u'_id': 160.0, u'value': 1.0}
# {u'_id': 166.0, u'value': 39.0}
# {u'_id': 167.0, u'value': 1.0}
# {u'_id': 169.0, u'value': 2.0}
# {u'_id': 170.0, u'value': 1.0}
# {u'_id': 172.0, u'value': 6.0}
# {u'_id': 175.0, u'value': 4.0}
# {u'_id': 178.0, u'value': 6.0}
# {u'_id': 182.0, u'value': 1.0}
# {u'_id': 184.0, u'value': 39.0}
# {u'_id': 187.0, u'value': 20.0}
# {u'_id': 188.0, u'value': 1.0}
# {u'_id': 191.0, u'value': 46.0}
# {u'_id': 195.0, u'value': 1.0}
# {u'_id': 198.0, u'value': 1.0}
# {u'_id': 206.0, u'value': 10.0}
# {u'_id': 211.0, u'value': 1.0}
# {u'_id': 213.0, u'value': 14.0}
# {u'_id': 217.0, u'value': 8.0}
# {u'_id': 218.0, u'value': 1.0}
# {u'_id': 222.0, u'value': 4.0}
# {u'_id': 225.0, u'value': 41.0}
# {u'_id': 227.0, u'value': 245.0}
# {u'_id': 233.0, u'value': 7.0}
# {u'_id': 234.0, u'value': 5.0}
# {u'_id': 236.0, u'value': 2.0}
# {u'_id': 238.0, u'value': 4.0}
# {u'_id': 239.0, u'value': 3.0}
# {u'_id': 241.0, u'value': 2.0}
# {u'_id': 245.0, u'value': 12.0}
# {u'_id': 246.0, u'value': 21.0}
# {u'_id': 248.0, u'value': 1.0}
# {u'_id': 250.0, u'value': 438.0}
# {u'_id': 252.0, u'value': 3.0}
# {u'_id': 258.0, u'value': 3.0}
# {u'_id': 260.0, u'value': 4.0}
# {u'_id': 261.0, u'value': 2.0}
# {u'_id': 262.0, u'value': 1.0}
# {u'_id': 264.0, u'value': 5.0}
# {u'_id': 270.0, u'value': 26.0}
# {u'_id': 271.0, u'value': 53.0}
# {u'_id': 272.0, u'value': 1.0}
# {u'_id': 273.0, u'value': 14.0}
# {u'_id': 274.0, u'value': 1.0}
# {u'_id': 276.0, u'value': 2.0}
# {u'_id': 280.0, u'value': 4.0}
# {u'_id': 282.0, u'value': 1.0}
# {u'_id': 288.0, u'value': 4.0}
# {u'_id': 291.0, u'value': 1.0}
# {u'_id': 292.0, u'value': 13.0}
# {u'_id': 294.0, u'value': 8.0}
# {u'_id': 295.0, u'value': 2.0}
# {u'_id': 296.0, u'value': 2.0}
# {u'_id': 298.0, u'value': 1.0}
# {u'_id': 299.0, u'value': 5.0}
# {u'_id': 301.0, u'value': 56.0}
# {u'_id': 302.0, u'value': 11.0}
# {u'_id': 305.0, u'value': 7.0}
# {u'_id': 306.0, u'value': 1.0}
# {u'_id': 307.0, u'value': 8.0}
# {u'_id': 309.0, u'value': 1.0}
# {u'_id': 315.0, u'value': 1.0}
# {u'_id': 320.0, u'value': 2.0}
# {u'_id': 321.0, u'value': 2.0}
# {u'_id': 325.0, u'value': 1.0}
# {u'_id': 326.0, u'value': 1.0}
# {u'_id': 330.0, u'value': 12.0}
# {u'_id': 334.0, u'value': 1.0}
# {u'_id': 336.0, u'value': 1.0}
# {u'_id': 337.0, u'value': 1.0}
# {u'_id': 341.0, u'value': 1.0}
# {u'_id': 342.0, u'value': 103.0}
# {u'_id': 344.0, u'value': 6.0}
# {u'_id': 345.0, u'value': 4.0}
# {u'_id': 348.0, u'value': 4.0}
# {u'_id': 352.0, u'value': 2.0}
# {u'_id': 353.0, u'value': 46.0}
# {u'_id': 358.0, u'value': 1.0}
# {u'_id': 360.0, u'value': 13.0}
# {u'_id': 362.0, u'value': 3.0}
# {u'_id': 366.0, u'value': 4.0}
# {u'_id': 371.0, u'value': 22.0}
# {u'_id': 376.0, u'value': 6.0}
# {u'_id': 389.0, u'value': 6.0}
# {u'_id': 398.0, u'value': 47.0}
# {u'_id': 399.0, u'value': 38.0}
# {u'_id': 400.0, u'value': 14.0}
# {u'_id': 403.0, u'value': 3.0}
# {u'_id': 404.0, u'value': 2.0}
# {u'_id': 407.0, u'value': 3.0}
# {u'_id': 409.0, u'value': 1.0}
# {u'_id': 415.0, u'value': 1.0}
# {u'_id': 416.0, u'value': 6.0}
# {u'_id': 417.0, u'value': 34.0}
# {u'_id': 430.0, u'value': 15.0}
# {u'_id': 456.0, u'value': 2.0}
# {u'_id': 458.0, u'value': 2.0}
# {u'_id': 463.0, u'value': 86.0}
# {u'_id': 469.0, u'value': 1.0}
# {u'_id': 473.0, u'value': 11.0}
# {u'_id': 478.0, u'value': 1.0}
# {u'_id': 481.0, u'value': 1.0}
# {u'_id': 486.0, u'value': 1.0}
# {u'_id': 500.0, u'value': 3.0}
# {u'_id': 504.0, u'value': 1.0}
# {u'_id': 514.0, u'value': 3.0}
# {u'_id': 515.0, u'value': 1.0}
# {u'_id': 517.0, u'value': 80.0}
# {u'_id': 519.0, u'value': 10.0}
# {u'_id': 529.0, u'value': 6.0}
# {u'_id': 531.0, u'value': 13.0}
# {u'_id': 533.0, u'value': 2.0}
# {u'_id': 534.0, u'value': 2.0}
# {u'_id': 535.0, u'value': 16.0}
# {u'_id': 546.0, u'value': 1.0}
# {u'_id': 547.0, u'value': 21.0}
# {u'_id': 555.0, u'value': 5.0}
# {u'_id': 557.0, u'value': 8.0}
# {u'_id': 561.0, u'value': 1.0}
# {u'_id': 562.0, u'value': 59.0}
# {u'_id': 573.0, u'value': 1.0}
# {u'_id': 575.0, u'value': 3.0}
# {u'_id': 584.0, u'value': 2.0}
# {u'_id': 586.0, u'value': 2.0}
# {u'_id': 594.0, u'value': 6.0}
# {u'_id': 602.0, u'value': 75.0}
# {u'_id': 608.0, u'value': 137.0}
# {u'_id': 610.0, u'value': 13.0}
# {u'_id': 628.0, u'value': 5.0}
# {u'_id': 629.0, u'value': 9.0}
# {u'_id': 630.0, u'value': 75.0}
# {u'_id': 631.0, u'value': 5.0}
# {u'_id': 632.0, u'value': 9.0}
# {u'_id': 634.0, u'value': 41.0}
# {u'_id': 636.0, u'value': 6.0}
# {u'_id': 638.0, u'value': 57.0}
# {u'_id': 643.0, u'value': 1.0}
# {u'_id': 649.0, u'value': 1.0}
# {u'_id': 653.0, u'value': 2.0}
# {u'_id': 659.0, u'value': 2.0}
# {u'_id': 660.0, u'value': 6.0}
# {u'_id': 670.0, u'value': 1.0}
# {u'_id': 676.0, u'value': 5.0}
# {u'_id': 696.0, u'value': 1.0}
# {u'_id': 697.0, u'value': 7.0}
# {u'_id': 700.0, u'value': 1.0}
# {u'_id': 701.0, u'value': 1.0}
# {u'_id': 702.0, u'value': 1.0}
# {u'_id': 704.0, u'value': 1.0}
# {u'_id': 706.0, u'value': 1.0}
# {u'_id': 715.0, u'value': 3.0}
# {u'_id': 716.0, u'value': 2.0}
# {u'_id': 717.0, u'value': 1.0}
# {u'_id': 718.0, u'value': 1.0}
# {u'_id': 719.0, u'value': 4.0}
# {u'_id': 722.0, u'value': 1.0}
# {u'_id': 724.0, u'value': 1.0}
# {u'_id': 725.0, u'value': 1.0}
# {u'_id': 728.0, u'value': 1.0}
# {u'_id': 729.0, u'value': 57.0}
# {u'_id': 731.0, u'value': 3.0}
# {u'_id': 745.0, u'value': 1.0}
# {u'_id': 749.0, u'value': 1.0}
# {u'_id': 758.0, u'value': 1.0}
# {u'_id': 762.0, u'value': 1.0}
# {u'_id': 771.0, u'value': 1.0}
# {u'_id': 776.0, u'value': 1.0}
# {u'_id': 778.0, u'value': 1.0}
# {u'_id': 783.0, u'value': 1.0}
# {u'_id': 785.0, u'value': 2.0}
# {u'_id': 786.0, u'value': 1.0}
# {u'_id': 801.0, u'value': 39.0}
# {u'_id': 807.0, u'value': 2.0}
# {u'_id': 809.0, u'value': 1.0}
# {u'_id': 813.0, u'value': 2.0}
# {u'_id': 816.0, u'value': 4.0}
# {u'_id': 819.0, u'value': 1.0}
# {u'_id': 822.0, u'value': 95.0}
# {u'_id': 823.0, u'value': 1.0}
# {u'_id': 834.0, u'value': 3.0}
# {u'_id': 846.0, u'value': 1.0}
# {u'_id': 864.0, u'value': 1.0}
# {u'_id': 866.0, u'value': 2.0}
# {u'_id': 870.0, u'value': 21.0}
# {u'_id': 872.0, u'value': 2.0}
# {u'_id': 874.0, u'value': 1.0}
# {u'_id': 881.0, u'value': 1.0}
# {u'_id': 883.0, u'value': 2.0}
# {u'_id': 901.0, u'value': 2.0}
# {u'_id': 908.0, u'value': 20.0}
# {u'_id': 917.0, u'value': 1.0}
# {u'_id': 921.0, u'value': 1.0}
# {u'_id': 925.0, u'value': 1.0}
# {u'_id': 929.0, u'value': 2.0}
# {u'_id': 931.0, u'value': 3.0}
# {u'_id': 936.0, u'value': 1.0}
# {u'_id': 950.0, u'value': 1.0}
# {u'_id': 965.0, u'value': 2.0}
# {u'_id': 994.0, u'value': 4.0}
# {u'_id': 1005.0, u'value': 30.0}
# {u'_id': 1007.0, u'value': 1.0}
# {u'_id': 1011.0, u'value': 2.0}
# {u'_id': 1012.0, u'value': 1.0}
# {u'_id': 1021.0, u'value': 1.0}
# {u'_id': 1037.0, u'value': 3.0}
# {u'_id': 1039.0, u'value': 3.0}
# {u'_id': 1055.0, u'value': 1.0}
# {u'_id': 1074.0, u'value': 1.0}
# {u'_id': 1076.0, u'value': 2.0}
# {u'_id': 1092.0, u'value': 28.0}
# {u'_id': 1098.0, u'value': 3.0}
# {u'_id': 1100.0, u'value': 1.0}
# {u'_id': 1103.0, u'value': 4.0}
# {u'_id': 1109.0, u'value': 1.0}
# {u'_id': 1111.0, u'value': 3.0}
# {u'_id': 1117.0, u'value': 1.0}
# {u'_id': 1119.0, u'value': 2.0}
# {u'_id': 1136.0, u'value': 1.0}
# {u'_id': 1144.0, u'value': 3.0}
# {u'_id': 1145.0, u'value': 2.0}
# {u'_id': 1147.0, u'value': 2.0}
# {u'_id': 1155.0, u'value': 1.0}
# {u'_id': 1166.0, u'value': 5.0}
# {u'_id': 1168.0, u'value': 8.0}
# {u'_id': 1171.0, u'value': 7.0}
# {u'_id': 1173.0, u'value': 1.0}
# {u'_id': 1175.0, u'value': 1.0}
# {u'_id': 1184.0, u'value': 21.0}
# {u'_id': 1188.0, u'value': 3.0}
# {u'_id': 1192.0, u'value': 7.0}
# {u'_id': 1201.0, u'value': 1.0}
# {u'_id': 1203.0, u'value': 1.0}
# {u'_id': 1204.0, u'value': 16.0}
# {u'_id': 1219.0, u'value': 2.0}
# {u'_id': 1232.0, u'value': 1.0}
# {u'_id': 1234.0, u'value': 2.0}
# {u'_id': 1246.0, u'value': 1.0}
# {u'_id': 1262.0, u'value': 1.0}
# {u'_id': 1270.0, u'value': 1.0}
# {u'_id': 1274.0, u'value': 5.0}
# {u'_id': 1281.0, u'value': 30.0}
# {u'_id': 1283.0, u'value': 1.0}
# {u'_id': 1288.0, u'value': 1.0}
# {u'_id': 1289.0, u'value': 2.0}
# {u'_id': 1291.0, u'value': 1.0}
# {u'_id': 1303.0, u'value': 1.0}
# {u'_id': 1305.0, u'value': 1.0}
# {u'_id': 1308.0, u'value': 1.0}
# {u'_id': 1330.0, u'value': 1.0}
# {u'_id': 1338.0, u'value': 1.0}
# {u'_id': 1349.0, u'value': 1.0}
# {u'_id': 1357.0, u'value': 2.0}
# {u'_id': 1360.0, u'value': 14.0}
# {u'_id': 1365.0, u'value': 19.0}
# {u'_id': 1368.0, u'value': 2.0}
# {u'_id': 1370.0, u'value': 1.0}
# {u'_id': 1381.0, u'value': 4.0}
# {u'_id': 1389.0, u'value': 7.0}
# {u'_id': 1390.0, u'value': 1.0}
# {u'_id': 1393.0, u'value': 10.0}
# {u'_id': 1399.0, u'value': 23.0}
# {u'_id': 1401.0, u'value': 3.0}
# {u'_id': 1407.0, u'value': 1.0}
# {u'_id': 1415.0, u'value': 1.0}
# {u'_id': 1427.0, u'value': 1.0}
# {u'_id': 1455.0, u'value': 1.0}
# {u'_id': 1459.0, u'value': 1.0}
# {u'_id': 1462.0, u'value': 40.0}
# {u'_id': 1465.0, u'value': 2.0}
# {u'_id': 1466.0, u'value': 37.0}
# {u'_id': 1481.0, u'value': 1.0}
# {u'_id': 1482.0, u'value': 1.0}
# {u'_id': 1487.0, u'value': 1.0}
# {u'_id': 1494.0, u'value': 4.0}
# {u'_id': 1499.0, u'value': 4.0}
# {u'_id': 1500.0, u'value': 1.0}
# {u'_id': 1502.0, u'value': 1.0}
# {u'_id': 1505.0, u'value': 31.0}
# {u'_id': 1507.0, u'value': 1.0}
# {u'_id': 1511.0, u'value': 1.0}
# {u'_id': 1513.0, u'value': 2.0}
# {u'_id': 1521.0, u'value': 1.0}
# {u'_id': 1527.0, u'value': 15.0}
# {u'_id': 1541.0, u'value': 2.0}
# {u'_id': 1543.0, u'value': 1.0}
# {u'_id': 1544.0, u'value': 1.0}
# {u'_id': 1545.0, u'value': 1.0}
# {u'_id': 1547.0, u'value': 1.0}
# {u'_id': 1548.0, u'value': 1.0}
# {u'_id': 1551.0, u'value': 2.0}
# {u'_id': 1553.0, u'value': 9.0}
# {u'_id': 1555.0, u'value': 3.0}
# {u'_id': 1569.0, u'value': 1.0}
# {u'_id': 1571.0, u'value': 1.0}
# {u'_id': 1575.0, u'value': 18.0}
# {u'_id': 1577.0, u'value': 2.0}
# {u'_id': 1579.0, u'value': 1.0}
# {u'_id': 1583.0, u'value': 4.0}
# {u'_id': 1591.0, u'value': 2.0}
# {u'_id': 1592.0, u'value': 5.0}
# {u'_id': 1594.0, u'value': 1.0}
# {u'_id': 1596.0, u'value': 40.0}
# {u'_id': 1599.0, u'value': 8.0}
# {u'_id': 1609.0, u'value': 1.0}
# {u'_id': 1610.0, u'value': 3.0}
# {u'_id': 1612.0, u'value': 2.0}
# {u'_id': 1623.0, u'value': 1.0}
# {u'_id': 1627.0, u'value': 1.0}
# {u'_id': 1631.0, u'value': 2.0}
# {u'_id': 1641.0, u'value': 2.0}
# {u'_id': 1643.0, u'value': 4.0}
# {u'_id': 1651.0, u'value': 1.0}
# {u'_id': 1654.0, u'value': 2.0}
# {u'_id': 1666.0, u'value': 3.0}
# {u'_id': 1675.0, u'value': 1.0}
# {u'_id': 1687.0, u'value': 1.0}
# {u'_id': 1693.0, u'value': 1.0}
# {u'_id': 1719.0, u'value': 1.0}
# {u'_id': 1721.0, u'value': 1.0}
# {u'_id': 1725.0, u'value': 1.0}
# {u'_id': 1733.0, u'value': 1.0}
# {u'_id': 1736.0, u'value': 1.0}
# {u'_id': 1744.0, u'value': 6.0}
# {u'_id': 1746.0, u'value': 3.0}
# {u'_id': 1752.0, u'value': 1.0}
# {u'_id': 1776.0, u'value': 2.0}
# {u'_id': 1777.0, u'value': 1.0}
# {u'_id': 1784.0, u'value': 8.0}
# {u'_id': 1788.0, u'value': 2.0}
# {u'_id': 1792.0, u'value': 8.0}
# {u'_id': 1795.0, u'value': 6.0}
# {u'_id': 1798.0, u'value': 4.0}
# {u'_id': 1803.0, u'value': 1.0}
# {u'_id': 1805.0, u'value': 2.0}
# {u'_id': 1809.0, u'value': 2.0}
# {u'_id': 1812.0, u'value': 1.0}
# {u'_id': 1824.0, u'value': 1.0}
# {u'_id': 1827.0, u'value': 3.0}
# {u'_id': 1839.0, u'value': 27.0}
# {u'_id': 1840.0, u'value': 2.0}
# {u'_id': 1841.0, u'value': 1.0}
# {u'_id': 1859.0, u'value': 1.0}
# {u'_id': 1869.0, u'value': 2.0}
# {u'_id': 1870.0, u'value': 5.0}
# {u'_id': 1881.0, u'value': 3.0}
# {u'_id': 1882.0, u'value': 89.0}
# {u'_id': 1884.0, u'value': 1.0}
# {u'_id': 1898.0, u'value': 2.0}
# {u'_id': 1900.0, u'value': 1.0}
# {u'_id': 1905.0, u'value': 1.0}
# {u'_id': 1913.0, u'value': 2.0}
# {u'_id': 1914.0, u'value': 12.0}
# {u'_id': 1918.0, u'value': 6.0}
# {u'_id': 1921.0, u'value': 2.0}
# {u'_id': 1930.0, u'value': 1.0}
# {u'_id': 1935.0, u'value': 1.0}
# {u'_id': 1940.0, u'value': 3.0}
# {u'_id': 1941.0, u'value': 1.0}
# {u'_id': 1942.0, u'value': 8.0}
# {u'_id': 1943.0, u'value': 30.0}
# {u'_id': 1947.0, u'value': 1.0}
# {u'_id': 1948.0, u'value': 4.0}
# {u'_id': 1949.0, u'value': 1.0}
# {u'_id': 1958.0, u'value': 12.0}
# {u'_id': 1960.0, u'value': 2.0}
# {u'_id': 1962.0, u'value': 4.0}
# {u'_id': 1964.0, u'value': 8.0}
# {u'_id': 1965.0, u'value': 4.0}
# {u'_id': 1972.0, u'value': 1.0}
# {u'_id': 1974.0, u'value': 3.0}
# {u'_id': 1975.0, u'value': 1.0}
# {u'_id': 1980.0, u'value': 6.0}
# {u'_id': 1981.0, u'value': 1.0}
# {u'_id': 1985.0, u'value': 2.0}
# {u'_id': 1986.0, u'value': 1.0}
# {u'_id': 1996.0, u'value': 1.0}
# {u'_id': 1997.0, u'value': 1.0}
# {u'_id': 2000.0, u'value': 1.0}
# {u'_id': 2001.0, u'value': 1.0}
# {u'_id': 2003.0, u'value': 1.0}
# {u'_id': 2004.0, u'value': 58.0}
# {u'_id': 2007.0, u'value': 1.0}
# {u'_id': 2008.0, u'value': 48.0}
# {u'_id': 2013.0, u'value': 8.0}
# {u'_id': 2019.0, u'value': 8.0}
# {u'_id': 2022.0, u'value': 8.0}
# {u'_id': 2025.0, u'value': 1.0}
# {u'_id': 2027.0, u'value': 287.0}
# {u'_id': 2034.0, u'value': 2.0}
# {u'_id': 2036.0, u'value': 4.0}
# {u'_id': 2041.0, u'value': 1.0}
# {u'_id': 2049.0, u'value': 1.0}
# {u'_id': 2059.0, u'value': 5.0}
# {u'_id': 2074.0, u'value': 2.0}
# {u'_id': 2087.0, u'value': 1.0}
# {u'_id': 2092.0, u'value': 1.0}
# {u'_id': 2099.0, u'value': 6.0}
# {u'_id': 2103.0, u'value': 1.0}
# {u'_id': 2109.0, u'value': 2.0}
# {u'_id': 2110.0, u'value': 1.0}
# {u'_id': 2113.0, u'value': 1.0}
# {u'_id': 2114.0, u'value': 1.0}
# {u'_id': 2122.0, u'value': 2.0}
# {u'_id': 2123.0, u'value': 4.0}
# {u'_id': 2133.0, u'value': 9.0}
# {u'_id': 2134.0, u'value': 7.0}
# {u'_id': 2136.0, u'value': 1.0}
# {u'_id': 2137.0, u'value': 1.0}
# {u'_id': 2143.0, u'value': 1.0}
# {u'_id': 2145.0, u'value': 4.0}
# {u'_id': 2151.0, u'value': 1.0}
# {u'_id': 2152.0, u'value': 7.0}
# {u'_id': 2155.0, u'value': 2.0}
# {u'_id': 2156.0, u'value': 1.0}
# {u'_id': 2158.0, u'value': 6.0}
# {u'_id': 2159.0, u'value': 1.0}
# {u'_id': 2162.0, u'value': 15.0}
# {u'_id': 2163.0, u'value': 64.0}
# {u'_id': 2166.0, u'value': 1.0}
# {u'_id': 2169.0, u'value': 1.0}
# {u'_id': 2171.0, u'value': 5.0}
# {u'_id': 2172.0, u'value': 1.0}
# {u'_id': 2176.0, u'value': 4.0}
# {u'_id': 2180.0, u'value': 1.0}
# {u'_id': 2184.0, u'value': 7.0}
# {u'_id': 2186.0, u'value': 19.0}
# {u'_id': 2191.0, u'value': 16.0}
# {u'_id': 2195.0, u'value': 1.0}
# {u'_id': 2198.0, u'value': 1.0}
# {u'_id': 2203.0, u'value': 6.0}
# {u'_id': 2208.0, u'value': 2.0}
# {u'_id': 2222.0, u'value': 1.0}
# {u'_id': 2224.0, u'value': 205.0}
# {u'_id': 2225.0, u'value': 1.0}
# {u'_id': 2228.0, u'value': 1.0}
# {u'_id': 2229.0, u'value': 2.0}
# {u'_id': 2230.0, u'value': 256.0}
# {u'_id': 2234.0, u'value': 1.0}
# {u'_id': 2235.0, u'value': 1.0}
# {u'_id': 2236.0, u'value': 13.0}
# {u'_id': 2238.0, u'value': 5.0}
# {u'_id': 2241.0, u'value': 10.0}
# {u'_id': 2247.0, u'value': 21.0}
# {u'_id': 2256.0, u'value': 5.0}
# {u'_id': 2257.0, u'value': 8.0}
# {u'_id': 2262.0, u'value': 1.0}
# {u'_id': 2267.0, u'value': 1.0}
# {u'_id': 2282.0, u'value': 15.0}
# {u'_id': 2288.0, u'value': 2.0}
# {u'_id': 2293.0, u'value': 1.0}
# {u'_id': 2295.0, u'value': 1.0}
# {u'_id': 2304.0, u'value': 4.0}
# {u'_id': 2325.0, u'value': 1.0}
# {u'_id': 2326.0, u'value': 4.0}
# {u'_id': 2327.0, u'value': 1.0}
# {u'_id': 2335.0, u'value': 4.0}
# {u'_id': 2336.0, u'value': 1.0}
# {u'_id': 2338.0, u'value': 7.0}
# {u'_id': 2345.0, u'value': 1.0}
# {u'_id': 2346.0, u'value': 2.0}
# {u'_id': 2349.0, u'value': 2.0}
# {u'_id': 2351.0, u'value': 1.0}
# {u'_id': 2352.0, u'value': 8.0}
# {u'_id': 2354.0, u'value': 1.0}
# {u'_id': 2357.0, u'value': 3.0}
# {u'_id': 2358.0, u'value': 1.0}
# {u'_id': 2361.0, u'value': 1.0}
# {u'_id': 2364.0, u'value': 1.0}
# {u'_id': 2366.0, u'value': 36.0}
# {u'_id': 2367.0, u'value': 12.0}
# {u'_id': 2370.0, u'value': 1.0}
# {u'_id': 2375.0, u'value': 2.0}
# {u'_id': 2379.0, u'value': 1.0}
# {u'_id': 2380.0, u'value': 1.0}
# {u'_id': 2383.0, u'value': 1.0}
# {u'_id': 2387.0, u'value': 1.0}
# {u'_id': 2392.0, u'value': 2.0}
# {u'_id': 2393.0, u'value': 1.0}
# {u'_id': 2394.0, u'value': 2.0}
# {u'_id': 2397.0, u'value': 1.0}
# {u'_id': 2399.0, u'value': 11.0}
# {u'_id': 2402.0, u'value': 17.0}
# {u'_id': 2408.0, u'value': 4.0}
# {u'_id': 2420.0, u'value': 3.0}
# {u'_id': 2424.0, u'value': 1.0}
# {u'_id': 2429.0, u'value': 180.0}
# {u'_id': 2430.0, u'value': 1.0}
# {u'_id': 2442.0, u'value': 4.0}
# {u'_id': 2448.0, u'value': 4.0}
# {u'_id': 2453.0, u'value': 13.0}
# {u'_id': 2460.0, u'value': 2.0}
# {u'_id': 2467.0, u'value': 1.0}
# {u'_id': 2469.0, u'value': 1.0}
# {u'_id': 2472.0, u'value': 25.0}
# {u'_id': 2475.0, u'value': 18.0}
# {u'_id': 2478.0, u'value': 2.0}
# {u'_id': 2484.0, u'value': 1.0}
# {u'_id': 2488.0, u'value': 1.0}
# {u'_id': 2495.0, u'value': 1.0}
# {u'_id': 2497.0, u'value': 1.0}
# {u'_id': 2500.0, u'value': 2.0}
# {u'_id': 2509.0, u'value': 20.0}
# {u'_id': 2512.0, u'value': 3.0}
# {u'_id': 2518.0, u'value': 1.0}
# {u'_id': 2531.0, u'value': 1.0}
# {u'_id': 2533.0, u'value': 1.0}
# {u'_id': 2539.0, u'value': 15.0}
# {u'_id': 2540.0, u'value': 8.0}
# {u'_id': 2548.0, u'value': 4.0}
# {u'_id': 2549.0, u'value': 1.0}
# {u'_id': 2551.0, u'value': 2.0}
# {u'_id': 2555.0, u'value': 1.0}
# {u'_id': 2558.0, u'value': 1.0}
# {u'_id': 2566.0, u'value': 7.0}
# {u'_id': 2572.0, u'value': 1.0}
# {u'_id': 2580.0, u'value': 5.0}
# {u'_id': 2589.0, u'value': 2.0}
# {u'_id': 2590.0, u'value': 14.0}
# {u'_id': 2592.0, u'value': 2.0}
# {u'_id': 2593.0, u'value': 1.0}
# {u'_id': 2595.0, u'value': 1.0}
# {u'_id': 2596.0, u'value': 9.0}
# {u'_id': 2600.0, u'value': 539.0}
# {u'_id': 2601.0, u'value': 1.0}
# {u'_id': 2605.0, u'value': 3.0}
# {u'_id': 2609.0, u'value': 9.0}
# {u'_id': 2610.0, u'value': 3.0}
# {u'_id': 2624.0, u'value': 3.0}
# {u'_id': 2631.0, u'value': 1.0}
# {u'_id': 2633.0, u'value': 23.0}
# {u'_id': 2636.0, u'value': 4.0}
# {u'_id': 2645.0, u'value': 14.0}
# {u'_id': 2649.0, u'value': 1.0}
# {u'_id': 2652.0, u'value': 4.0}
# {u'_id': 2653.0, u'value': 5.0}
# {u'_id': 2654.0, u'value': 1.0}
# {u'_id': 2659.0, u'value': 29.0}
# {u'_id': 2669.0, u'value': 1.0}
# {u'_id': 2670.0, u'value': 9.0}
# {u'_id': 2673.0, u'value': 2.0}
# {u'_id': 2675.0, u'value': 27.0}
# {u'_id': 2676.0, u'value': 57.0}
# {u'_id': 2681.0, u'value': 6.0}
# {u'_id': 2685.0, u'value': 1.0}
# {u'_id': 2688.0, u'value': 3.0}
# {u'_id': 2690.0, u'value': 1.0}
# {u'_id': 2692.0, u'value': 3.0}
# {u'_id': 2694.0, u'value': 9.0}
# {u'_id': 2698.0, u'value': 1.0}
# {u'_id': 2705.0, u'value': 1.0}
# {u'_id': 2706.0, u'value': 1.0}
# {u'_id': 2708.0, u'value': 1.0}
# {u'_id': 2711.0, u'value': 1.0}
# {u'_id': 2713.0, u'value': 1.0}
# {u'_id': 2718.0, u'value': 11.0}
# {u'_id': 2722.0, u'value': 3.0}
# {u'_id': 2723.0, u'value': 1.0}
# {u'_id': 2724.0, u'value': 3.0}
# {u'_id': 2726.0, u'value': 3.0}
# {u'_id': 2731.0, u'value': 2.0}
# {u'_id': 2732.0, u'value': 1.0}
# {u'_id': 2733.0, u'value': 1.0}
# {u'_id': 2736.0, u'value': 1.0}
# {u'_id': 2742.0, u'value': 115.0}
# {u'_id': 2744.0, u'value': 1.0}
# {u'_id': 2747.0, u'value': 23.0}
# {u'_id': 2755.0, u'value': 1.0}
# {u'_id': 2759.0, u'value': 7.0}
# {u'_id': 2760.0, u'value': 2.0}
# {u'_id': 2762.0, u'value': 1.0}
# {u'_id': 2766.0, u'value': 5.0}
# {u'_id': 2767.0, u'value': 6.0}
# {u'_id': 2768.0, u'value': 1.0}
# {u'_id': 2769.0, u'value': 5.0}
# {u'_id': 2770.0, u'value': 2.0}
# {u'_id': 2771.0, u'value': 1.0}
# {u'_id': 2779.0, u'value': 1.0}
# {u'_id': 2780.0, u'value': 1.0}
# {u'_id': 2784.0, u'value': 1.0}
# {u'_id': 2785.0, u'value': 8.0}
# {u'_id': 2794.0, u'value': 8.0}
# {u'_id': 2795.0, u'value': 1.0}
# {u'_id': 2797.0, u'value': 2.0}
# {u'_id': 2800.0, u'value': 2.0}
# {u'_id': 2802.0, u'value': 7.0}
# {u'_id': 2803.0, u'value': 18.0}
# {u'_id': 2807.0, u'value': 1.0}
# {u'_id': 2808.0, u'value': 1.0}
# {u'_id': 2816.0, u'value': 43.0}
# {u'_id': 2820.0, u'value': 1.0}
# {u'_id': 2822.0, u'value': 1.0}
# {u'_id': 2824.0, u'value': 2.0}
# {u'_id': 2825.0, u'value': 1.0}
# {u'_id': 2826.0, u'value': 9.0}
# {u'_id': 2832.0, u'value': 6.0}
# {u'_id': 2837.0, u'value': 13.0}
# {u'_id': 2838.0, u'value': 8.0}
# {u'_id': 2842.0, u'value': 1.0}
# {u'_id': 2845.0, u'value': 9.0}
# {u'_id': 2848.0, u'value': 21.0}
# {u'_id': 2851.0, u'value': 1.0}
# {u'_id': 2854.0, u'value': 13.0}
# {u'_id': 2856.0, u'value': 4.0}
# {u'_id': 2859.0, u'value': 1.0}
# {u'_id': 2860.0, u'value': 1.0}
# {u'_id': 2862.0, u'value': 6.0}
# {u'_id': 2865.0, u'value': 1.0}
# {u'_id': 2871.0, u'value': 1.0}
# {u'_id': 2878.0, u'value': 5.0}
# {u'_id': 2879.0, u'value': 8.0}
# {u'_id': 2880.0, u'value': 1.0}
# {u'_id': 2883.0, u'value': 2.0}
# {u'_id': 2884.0, u'value': 5.0}
# {u'_id': 2890.0, u'value': 1.0}
# {u'_id': 2894.0, u'value': 3.0}
# {u'_id': 2896.0, u'value': 50.0}
# {u'_id': 2897.0, u'value': 1.0}
# {u'_id': 2904.0, u'value': 1.0}
# {u'_id': 2908.0, u'value': 1.0}
# {u'_id': 2909.0, u'value': 6.0}
# {u'_id': 2910.0, u'value': 1.0}
# {u'_id': 2911.0, u'value': 1.0}
# {u'_id': 2915.0, u'value': 1.0}
# {u'_id': 2917.0, u'value': 2.0}
# {u'_id': 2920.0, u'value': 2.0}
# {u'_id': 2931.0, u'value': 1.0}
# {u'_id': 2932.0, u'value': 1.0}
# {u'_id': 2933.0, u'value': 1.0}
# {u'_id': 2935.0, u'value': 1.0}
# {u'_id': 2937.0, u'value': 66.0}
# {u'_id': 2941.0, u'value': 4.0}
# {u'_id': 2945.0, u'value': 1.0}
# {u'_id': 2946.0, u'value': 1.0}
# {u'_id': 2947.0, u'value': 1.0}
# {u'_id': 2948.0, u'value': 1.0}
# {u'_id': 2950.0, u'value': 1.0}
# {u'_id': 2953.0, u'value': 1.0}
# {u'_id': 2955.0, u'value': 3.0}
# {u'_id': 2957.0, u'value': 6.0}
# {u'_id': 2958.0, u'value': 4.0}
# {u'_id': 2960.0, u'value': 2.0}
# {u'_id': 2965.0, u'value': 1.0}
# {u'_id': 2967.0, u'value': 2.0}
# {u'_id': 2969.0, u'value': 1.0}
# {u'_id': 2973.0, u'value': 1.0}
# {u'_id': 2974.0, u'value': 3.0}
# {u'_id': 2975.0, u'value': 1.0}
# {u'_id': 2980.0, u'value': 10.0}
# {u'_id': 2981.0, u'value': 2.0}
# {u'_id': 2985.0, u'value': 10.0}
# {u'_id': 2989.0, u'value': 1.0}
# {u'_id': 2990.0, u'value': 4.0}
# {u'_id': 2994.0, u'value': 2.0}
# {u'_id': 2995.0, u'value': 2.0}
# {u'_id': 2998.0, u'value': 1.0}
# {u'_id': 3004.0, u'value': 35.0}
# {u'_id': 3008.0, u'value': 8.0}
# {u'_id': 3013.0, u'value': 13.0}
# {u'_id': 3014.0, u'value': 1.0}
# {u'_id': 3021.0, u'value': 3.0}
# {u'_id': 3022.0, u'value': 2.0}
# {u'_id': 3023.0, u'value': 2.0}
# {u'_id': 3038.0, u'value': 5.0}
# {u'_id': 3040.0, u'value': 2.0}
# {u'_id': 3042.0, u'value': 2.0}
# {u'_id': 3043.0, u'value': 1.0}
# {u'_id': 3052.0, u'value': 1.0}
# {u'_id': 3053.0, u'value': 1.0}
# {u'_id': 3054.0, u'value': 1.0}
# {u'_id': 3060.0, u'value': 11.0}
# {u'_id': 3065.0, u'value': 2.0}
# {u'_id': 3067.0, u'value': 1.0}
# {u'_id': 3068.0, u'value': 1.0}
# {u'_id': 3069.0, u'value': 1.0}
# {u'_id': 3073.0, u'value': 8.0}
# {u'_id': 3075.0, u'value': 1.0}
# {u'_id': 3077.0, u'value': 2.0}
# {u'_id': 3080.0, u'value': 4.0}
# {u'_id': 3081.0, u'value': 1.0}
# {u'_id': 3088.0, u'value': 8.0}
# {u'_id': 3089.0, u'value': 3.0}
# {u'_id': 3092.0, u'value': 1.0}
# {u'_id': 3093.0, u'value': 1.0}
# {u'_id': 3094.0, u'value': 10.0}
# {u'_id': 3103.0, u'value': 1.0}
# {u'_id': 3106.0, u'value': 1.0}
# {u'_id': 3110.0, u'value': 1.0}
# {u'_id': 3112.0, u'value': 1.0}
# {u'_id': 3115.0, u'value': 47.0}
# {u'_id': 3116.0, u'value': 1.0}
# {u'_id': 3118.0, u'value': 1.0}
# {u'_id': 3128.0, u'value': 1.0}
# {u'_id': 3130.0, u'value': 18.0}
# {u'_id': 3131.0, u'value': 1.0}
# {u'_id': 3138.0, u'value': 4.0}
# {u'_id': 3142.0, u'value': 1.0}
# {u'_id': 3144.0, u'value': 1.0}
# {u'_id': 3149.0, u'value': 1.0}
# {u'_id': 3151.0, u'value': 1.0}
# {u'_id': 3152.0, u'value': 1.0}
# {u'_id': 3155.0, u'value': 6.0}
# {u'_id': 3158.0, u'value': 3.0}
# {u'_id': 3159.0, u'value': 1.0}
# {u'_id': 3162.0, u'value': 1.0}
# {u'_id': 3165.0, u'value': 1.0}
# {u'_id': 3167.0, u'value': 1.0}
# {u'_id': 3170.0, u'value': 15.0}
# {u'_id': 3181.0, u'value': 1.0}
# {u'_id': 3182.0, u'value': 6.0}
# {u'_id': 3190.0, u'value': 1.0}
# {u'_id': 3199.0, u'value': 2.0}
# {u'_id': 3202.0, u'value': 1.0}
# {u'_id': 3203.0, u'value': 10.0}
# {u'_id': 3204.0, u'value': 1.0}
# {u'_id': 3205.0, u'value': 1.0}
# {u'_id': 3209.0, u'value': 1.0}
# {u'_id': 3216.0, u'value': 3.0}
# {u'_id': 3217.0, u'value': 3.0}
# {u'_id': 3218.0, u'value': 2.0}
# {u'_id': 3221.0, u'value': 1.0}
# {u'_id': 3222.0, u'value': 1.0}
# {u'_id': 3224.0, u'value': 3.0}
# {u'_id': 3228.0, u'value': 2.0}
# {u'_id': 3229.0, u'value': 2.0}
# {u'_id': 3231.0, u'value': 15.0}
# {u'_id': 3234.0, u'value': 17.0}
# {u'_id': 3236.0, u'value': 2.0}
# {u'_id': 3242.0, u'value': 2.0}
# {u'_id': 3243.0, u'value': 2.0}
# {u'_id': 3244.0, u'value': 1.0}
# {u'_id': 3245.0, u'value': 1.0}
# {u'_id': 3247.0, u'value': 1.0}
# {u'_id': 3248.0, u'value': 9.0}
# {u'_id': 3249.0, u'value': 9.0}
# {u'_id': 3250.0, u'value': 2.0}
# {u'_id': 3251.0, u'value': 1.0}
# {u'_id': 3257.0, u'value': 7.0}
# {u'_id': 3258.0, u'value': 1.0}
# {u'_id': 3259.0, u'value': 1.0}
# {u'_id': 3262.0, u'value': 1.0}
# {u'_id': 3265.0, u'value': 1.0}
# {u'_id': 3268.0, u'value': 1.0}
# {u'_id': 3275.0, u'value': 35.0}
# {u'_id': 3278.0, u'value': 1.0}
# {u'_id': 3280.0, u'value': 2.0}
# {u'_id': 3281.0, u'value': 2.0}
# {u'_id': 3283.0, u'value': 2.0}
# {u'_id': 3284.0, u'value': 1.0}
# {u'_id': 3287.0, u'value': 6.0}
# {u'_id': 3290.0, u'value': 1.0}
# {u'_id': 3291.0, u'value': 1.0}
# {u'_id': 3294.0, u'value': 3.0}
# {u'_id': 3304.0, u'value': 1.0}
# {u'_id': 3307.0, u'value': 6.0}
# {u'_id': 3308.0, u'value': 1.0}
# {u'_id': 3311.0, u'value': 1.0}
# {u'_id': 3313.0, u'value': 10.0}
# {u'_id': 3316.0, u'value': 12.0}
# {u'_id': 3320.0, u'value': 5.0}
# {u'_id': 3325.0, u'value': 1.0}
# {u'_id': 3327.0, u'value': 1.0}
# {u'_id': 3330.0, u'value': 1.0}
# {u'_id': 3331.0, u'value': 1.0}
# {u'_id': 3334.0, u'value': 1.0}
# {u'_id': 3336.0, u'value': 1.0}
# {u'_id': 3340.0, u'value': 1.0}
# {u'_id': 3341.0, u'value': 3.0}
# {u'_id': 3342.0, u'value': 1.0}
# {u'_id': 3343.0, u'value': 11.0}
# {u'_id': 3344.0, u'value': 2.0}
# {u'_id': 3345.0, u'value': 1.0}
# {u'_id': 3347.0, u'value': 1.0}
# {u'_id': 3350.0, u'value': 3.0}
# {u'_id': 3357.0, u'value': 1.0}
# {u'_id': 3361.0, u'value': 1.0}
# {u'_id': 3362.0, u'value': 12.0}
# {u'_id': 3365.0, u'value': 1.0}
# {u'_id': 3369.0, u'value': 2.0}
# {u'_id': 3374.0, u'value': 1.0}
# {u'_id': 3376.0, u'value': 2.0}
# {u'_id': 3377.0, u'value': 1.0}
# {u'_id': 3387.0, u'value': 1.0}
# {u'_id': 3390.0, u'value': 1.0}
# {u'_id': 3392.0, u'value': 1.0}
# {u'_id': 3393.0, u'value': 5.0}
# {u'_id': 3394.0, u'value': 1.0}
# {u'_id': 3415.0, u'value': 50.0}
# {u'_id': 3419.0, u'value': 1.0}
# {u'_id': 3423.0, u'value': 1.0}
# {u'_id': 3424.0, u'value': 1.0}
# {u'_id': 3426.0, u'value': 1.0}
# {u'_id': 3436.0, u'value': 1.0}
# {u'_id': 3439.0, u'value': 1.0}
# {u'_id': 3440.0, u'value': 30.0}
# {u'_id': 3443.0, u'value': 3.0}
# {u'_id': 3451.0, u'value': 4.0}
# {u'_id': 3452.0, u'value': 1.0}
# {u'_id': 3456.0, u'value': 2.0}
# {u'_id': 3457.0, u'value': 1.0}
# {u'_id': 3458.0, u'value': 6.0}
# {u'_id': 3459.0, u'value': 1.0}
# {u'_id': 3460.0, u'value': 5.0}
# {u'_id': 3461.0, u'value': 1.0}
# {u'_id': 3468.0, u'value': 2.0}
# {u'_id': 3470.0, u'value': 1.0}
# {u'_id': 3472.0, u'value': 1.0}
# {u'_id': 3480.0, u'value': 5.0}
# {u'_id': 3484.0, u'value': 1.0}
# {u'_id': 3486.0, u'value': 1.0}
# {u'_id': 3488.0, u'value': 4.0}
# {u'_id': 3490.0, u'value': 1.0}
# {u'_id': 3491.0, u'value': 2.0}
# {u'_id': 3492.0, u'value': 1.0}
# {u'_id': 3496.0, u'value': 1.0}
# {u'_id': 3503.0, u'value': 3.0}
# {u'_id': 3507.0, u'value': 1.0}
# {u'_id': 3512.0, u'value': 1.0}
# {u'_id': 3514.0, u'value': 5.0}
# {u'_id': 3517.0, u'value': 2.0}
# {u'_id': 3518.0, u'value': 1.0}
# {u'_id': 3521.0, u'value': 1.0}
# {u'_id': 3522.0, u'value': 2.0}
# {u'_id': 3527.0, u'value': 1.0}
# {u'_id': 3531.0, u'value': 1.0}
# {u'_id': 3533.0, u'value': 31.0}
# {u'_id': 3537.0, u'value': 2.0}
# {u'_id': 3539.0, u'value': 5.0}
# {u'_id': 3541.0, u'value': 2.0}
# {u'_id': 3543.0, u'value': 2.0}
# {u'_id': 3544.0, u'value': 1.0}
# {u'_id': 3545.0, u'value': 1.0}
# {u'_id': 3547.0, u'value': 2.0}
# {u'_id': 3548.0, u'value': 1.0}
# {u'_id': 3550.0, u'value': 5.0}
# {u'_id': 3551.0, u'value': 3.0}
# {u'_id': 3557.0, u'value': 1.0}
# {u'_id': 3559.0, u'value': 9.0}
# {u'_id': 3562.0, u'value': 2.0}
# {u'_id': 3563.0, u'value': 7.0}
# {u'_id': 3570.0, u'value': 1.0}
# {u'_id': 3577.0, u'value': 1.0}
# {u'_id': 3580.0, u'value': 5.0}
# {u'_id': 3581.0, u'value': 3.0}
# {u'_id': 3583.0, u'value': 6.0}
# {u'_id': 3585.0, u'value': 1.0}
# {u'_id': 3587.0, u'value': 1.0}
# {u'_id': 3589.0, u'value': 1.0}
# {u'_id': 3590.0, u'value': 1.0}
# {u'_id': 3592.0, u'value': 2.0}
# {u'_id': 3595.0, u'value': 2.0}
# {u'_id': 3607.0, u'value': 1.0}
# {u'_id': 3610.0, u'value': 6.0}
# {u'_id': 3615.0, u'value': 1.0}
# {u'_id': 3617.0, u'value': 3.0}
# {u'_id': 3618.0, u'value': 2.0}
# {u'_id': 3621.0, u'value': 6.0}
# {u'_id': 3622.0, u'value': 1.0}
# {u'_id': 3626.0, u'value': 2.0}
# {u'_id': 3628.0, u'value': 20.0}
# {u'_id': 3629.0, u'value': 1.0}
# {u'_id': 3633.0, u'value': 1.0}
# {u'_id': 3635.0, u'value': 1.0}
# {u'_id': 3637.0, u'value': 1.0}
# {u'_id': 3642.0, u'value': 3.0}
# {u'_id': 3644.0, u'value': 1.0}
# {u'_id': 3645.0, u'value': 1.0}
# {u'_id': 3648.0, u'value': 1.0}
# {u'_id': 3653.0, u'value': 1.0}
# {u'_id': 3654.0, u'value': 1.0}
# {u'_id': 3656.0, u'value': 3.0}
# {u'_id': 3658.0, u'value': 1.0}
# {u'_id': 3664.0, u'value': 1.0}
# {u'_id': 3665.0, u'value': 11.0}
# {u'_id': 3668.0, u'value': 1.0}
# {u'_id': 3669.0, u'value': 4.0}
# {u'_id': 3675.0, u'value': 1.0}
# {u'_id': 3676.0, u'value': 2.0}
# {u'_id': 3678.0, u'value': 3.0}
# {u'_id': 3682.0, u'value': 3.0}
# {u'_id': 3685.0, u'value': 1.0}
# {u'_id': 3688.0, u'value': 1.0}
# {u'_id': 3691.0, u'value': 3.0}
# {u'_id': 3697.0, u'value': 1.0}
# {u'_id': 3698.0, u'value': 1.0}
# {u'_id': 3700.0, u'value': 2.0}
# {u'_id': 3701.0, u'value': 1.0}
# {u'_id': 3702.0, u'value': 1.0}
# {u'_id': 3705.0, u'value': 1.0}
# {u'_id': 3709.0, u'value': 1.0}
# {u'_id': 3712.0, u'value': 1.0}
# {u'_id': 3715.0, u'value': 1.0}
# {u'_id': 3716.0, u'value': 1.0}
# {u'_id': 3718.0, u'value': 2.0}
# {u'_id': 3723.0, u'value': 1.0}
# {u'_id': 3724.0, u'value': 1.0}
# {u'_id': 3726.0, u'value': 3.0}
# {u'_id': 3727.0, u'value': 4.0}
# {u'_id': 3729.0, u'value': 1.0}
# {u'_id': 3734.0, u'value': 6.0}
# {u'_id': 3743.0, u'value': 1.0}
# {u'_id': 3746.0, u'value': 11.0}
# {u'_id': 3750.0, u'value': 1.0}
# {u'_id': 3751.0, u'value': 1.0}
# {u'_id': 3753.0, u'value': 1.0}
# {u'_id': 3754.0, u'value': 2.0}
# {u'_id': 3755.0, u'value': 1.0}
# {u'_id': 3757.0, u'value': 1.0}
# {u'_id': 3758.0, u'value': 1.0}
# {u'_id': 3759.0, u'value': 2.0}
# {u'_id': 3760.0, u'value': 3.0}
# {u'_id': 3762.0, u'value': 8.0}
# {u'_id': 3763.0, u'value': 4.0}
# {u'_id': 3765.0, u'value': 1.0}
# {u'_id': 3767.0, u'value': 7.0}
# {u'_id': 3770.0, u'value': 2.0}
# {u'_id': 3771.0, u'value': 1.0}
# {u'_id': 3773.0, u'value': 1.0}
# {u'_id': 3782.0, u'value': 1.0}
# {u'_id': 3786.0, u'value': 1.0}
# {u'_id': 3791.0, u'value': 1.0}
# {u'_id': 3797.0, u'value': 1.0}
# {u'_id': 3801.0, u'value': 3.0}
# {u'_id': 3802.0, u'value': 1.0}
# {u'_id': 3809.0, u'value': 3.0}
# {u'_id': 3811.0, u'value': 1.0}
# {u'_id': 3812.0, u'value': 2.0}
# {u'_id': 3813.0, u'value': 1.0}
# {u'_id': 3814.0, u'value': 1.0}
# {u'_id': 3817.0, u'value': 1.0}
# {u'_id': 3821.0, u'value': 1.0}
# {u'_id': 3828.0, u'value': 4.0}
# {u'_id': 3829.0, u'value': 1.0}
# {u'_id': 3834.0, u'value': 37.0}
# {u'_id': 3848.0, u'value': 6.0}
# {u'_id': 3852.0, u'value': 1.0}
# {u'_id': 3855.0, u'value': 1.0}
# {u'_id': 3860.0, u'value': 4.0}
# {u'_id': 3861.0, u'value': 1.0}
# {u'_id': 3865.0, u'value': 1.0}
# {u'_id': 3869.0, u'value': 4.0}
# {u'_id': 3870.0, u'value': 2.0}
# {u'_id': 3871.0, u'value': 1.0}
# {u'_id': 3874.0, u'value': 2.0}
# {u'_id': 3877.0, u'value': 2.0}
# {u'_id': 3878.0, u'value': 13.0}
# {u'_id': 3879.0, u'value': 1.0}
# {u'_id': 3880.0, u'value': 1.0}
# {u'_id': 3884.0, u'value': 1.0}
# {u'_id': 3890.0, u'value': 1.0}
# {u'_id': 3899.0, u'value': 1.0}
# {u'_id': 3901.0, u'value': 1.0}
# {u'_id': 3902.0, u'value': 1.0}
# {u'_id': 3906.0, u'value': 1.0}
# {u'_id': 3907.0, u'value': 1.0}
# {u'_id': 3909.0, u'value': 3.0}
# {u'_id': 3920.0, u'value': 1.0}
# {u'_id': 3924.0, u'value': 8.0}
# {u'_id': 3925.0, u'value': 1.0}
# {u'_id': 3927.0, u'value': 1.0}
# {u'_id': 3930.0, u'value': 1.0}
# {u'_id': 3932.0, u'value': 1.0}
# {u'_id': 3933.0, u'value': 5.0}
# {u'_id': 3935.0, u'value': 2.0}
# {u'_id': 3945.0, u'value': 1.0}
# {u'_id': 3946.0, u'value': 3.0}
# {u'_id': 3947.0, u'value': 2.0}
# {u'_id': 3949.0, u'value': 1.0}
# {u'_id': 3950.0, u'value': 1.0}
# {u'_id': 3952.0, u'value': 6.0}
# {u'_id': 3953.0, u'value': 1.0}
# {u'_id': 3958.0, u'value': 1.0}
# {u'_id': 3961.0, u'value': 1.0}
# {u'_id': 3966.0, u'value': 7.0}
# {u'_id': 3967.0, u'value': 1.0}
# {u'_id': 3974.0, u'value': 2.0}
# {u'_id': 3976.0, u'value': 14.0}
# {u'_id': 3987.0, u'value': 2.0}
# {u'_id': 4000.0, u'value': 1.0}
# {u'_id': 4001.0, u'value': 1.0}
# {u'_id': 4008.0, u'value': 1.0}
# {u'_id': 4012.0, u'value': 1.0}
# {u'_id': 4015.0, u'value': 2.0}
# {u'_id': 4020.0, u'value': 1.0}
# {u'_id': 4021.0, u'value': 11.0}
# {u'_id': 4023.0, u'value': 3.0}
# {u'_id': 4025.0, u'value': 1.0}
# {u'_id': 4026.0, u'value': 9.0}
# {u'_id': 4030.0, u'value': 2.0}
# {u'_id': 4042.0, u'value': 1.0}
# {u'_id': 4046.0, u'value': 1.0}
# {u'_id': 4048.0, u'value': 83.0}
# {u'_id': 4053.0, u'value': 1.0}
# {u'_id': 4059.0, u'value': 1.0}
# {u'_id': 4061.0, u'value': 1.0}
# {u'_id': 4062.0, u'value': 2.0}
# {u'_id': 4068.0, u'value': 1.0}
# {u'_id': 4071.0, u'value': 1.0}
# {u'_id': 4083.0, u'value': 6.0}
# {u'_id': 4085.0, u'value': 10.0}
# {u'_id': 4087.0, u'value': 2.0}
# {u'_id': 4088.0, u'value': 1.0}
# {u'_id': 4090.0, u'value': 1.0}
# {u'_id': 4093.0, u'value': 1.0}
# {u'_id': 4096.0, u'value': 1.0}
# {u'_id': 4098.0, u'value': 4.0}
# {u'_id': 4100.0, u'value': 1.0}
# {u'_id': 4105.0, u'value': 1.0}
# {u'_id': 4111.0, u'value': 9.0}
# {u'_id': 4115.0, u'value': 2.0}
# {u'_id': 4116.0, u'value': 1.0}
# {u'_id': 4117.0, u'value': 3.0}
# {u'_id': 4137.0, u'value': 1.0}
# {u'_id': 4140.0, u'value': 1.0}
# {u'_id': 4142.0, u'value': 11.0}
# {u'_id': 4150.0, u'value': 2.0}
# {u'_id': 4155.0, u'value': 1.0}
# {u'_id': 4156.0, u'value': 13.0}
# {u'_id': 4163.0, u'value': 6.0}
# {u'_id': 4164.0, u'value': 2.0}
# {u'_id': 4181.0, u'value': 1.0}
# {u'_id': 4187.0, u'value': 1.0}
# {u'_id': 4191.0, u'value': 1.0}
# {u'_id': 4192.0, u'value': 1.0}
# {u'_id': 4198.0, u'value': 2.0}
# {u'_id': 4208.0, u'value': 1.0}
# {u'_id': 4215.0, u'value': 1.0}
# {u'_id': 4222.0, u'value': 1.0}
# {u'_id': 4225.0, u'value': 1.0}
# {u'_id': 4227.0, u'value': 4.0}
# {u'_id': 4229.0, u'value': 11.0}
# {u'_id': 4231.0, u'value': 34.0}
# {u'_id': 4243.0, u'value': 1.0}
# {u'_id': 4244.0, u'value': 1.0}
# {u'_id': 4246.0, u'value': 2.0}
# {u'_id': 4253.0, u'value': 5.0}
# {u'_id': 4263.0, u'value': 1.0}
# {u'_id': 4264.0, u'value': 1.0}
# {u'_id': 4265.0, u'value': 17.0}
# {u'_id': 4266.0, u'value': 1.0}
# {u'_id': 4271.0, u'value': 1.0}
# {u'_id': 4273.0, u'value': 3.0}
# {u'_id': 4274.0, u'value': 5.0}
# {u'_id': 4279.0, u'value': 1.0}
# {u'_id': 4288.0, u'value': 1.0}
# {u'_id': 4298.0, u'value': 1.0}
# {u'_id': 4300.0, u'value': 1.0}
# {u'_id': 4306.0, u'value': 2.0}
# {u'_id': 4312.0, u'value': 2.0}
# {u'_id': 4316.0, u'value': 2.0}
# {u'_id': 4317.0, u'value': 1.0}
# {u'_id': 4321.0, u'value': 8.0}
# {u'_id': 4325.0, u'value': 13.0}
# {u'_id': 4326.0, u'value': 2.0}
# {u'_id': 4328.0, u'value': 12.0}
# {u'_id': 4330.0, u'value': 1.0}
# {u'_id': 4336.0, u'value': 1.0}
# {u'_id': 4347.0, u'value': 1.0}
# {u'_id': 4348.0, u'value': 1.0}
# {u'_id': 4351.0, u'value': 1.0}
# {u'_id': 4355.0, u'value': 3.0}
# {u'_id': 4357.0, u'value': 1.0}
# {u'_id': 4360.0, u'value': 1.0}
# {u'_id': 4361.0, u'value': 40.0}
# {u'_id': 4362.0, u'value': 1.0}
# {u'_id': 4365.0, u'value': 2.0}
# {u'_id': 4366.0, u'value': 1.0}
# {u'_id': 4367.0, u'value': 7.0}
# {u'_id': 4369.0, u'value': 1.0}
# {u'_id': 4370.0, u'value': 2.0}
# {u'_id': 4371.0, u'value': 2.0}
# {u'_id': 4377.0, u'value': 1.0}
# {u'_id': 4380.0, u'value': 1.0}
# {u'_id': 4381.0, u'value': 21.0}
# {u'_id': 4382.0, u'value': 1.0}
# {u'_id': 4383.0, u'value': 1.0}
# {u'_id': 4384.0, u'value': 5.0}
# {u'_id': 4388.0, u'value': 1.0}
# {u'_id': 4389.0, u'value': 1.0}
# {u'_id': 4392.0, u'value': 1.0}
# {u'_id': 4394.0, u'value': 2.0}
# {u'_id': 4396.0, u'value': 1.0}
# {u'_id': 4402.0, u'value': 1.0}
# {u'_id': 4403.0, u'value': 1.0}
# {u'_id': 4404.0, u'value': 1.0}
# {u'_id': 4410.0, u'value': 2.0}
# {u'_id': 4414.0, u'value': 1.0}
# {u'_id': 4418.0, u'value': 16.0}
# {u'_id': 4420.0, u'value': 1.0}
# {u'_id': 4421.0, u'value': 1.0}
# {u'_id': 4423.0, u'value': 1.0}
# {u'_id': 4430.0, u'value': 1.0}
# {u'_id': 4432.0, u'value': 1.0}
# {u'_id': 4439.0, u'value': 1.0}
# {u'_id': 4440.0, u'value': 1.0}
# {u'_id': 4446.0, u'value': 4.0}
# {u'_id': 4447.0, u'value': 1.0}
# {u'_id': 4451.0, u'value': 6.0}
# {u'_id': 4453.0, u'value': 1.0}
# {u'_id': 4455.0, u'value': 1.0}
# {u'_id': 4456.0, u'value': 22.0}
# {u'_id': 4458.0, u'value': 1.0}
# {u'_id': 4465.0, u'value': 1.0}
# {u'_id': 4466.0, u'value': 1.0}
# {u'_id': 4468.0, u'value': 1.0}
# {u'_id': 4474.0, u'value': 1.0}
# {u'_id': 4476.0, u'value': 1.0}
# {u'_id': 4479.0, u'value': 3.0}
# {u'_id': 4482.0, u'value': 1.0}
# {u'_id': 4486.0, u'value': 1.0}
# {u'_id': 4487.0, u'value': 32.0}
# {u'_id': 4494.0, u'value': 1.0}
# {u'_id': 4495.0, u'value': 3.0}
# {u'_id': 4499.0, u'value': 63.0}
# {u'_id': 4507.0, u'value': 1.0}
# {u'_id': 4508.0, u'value': 8.0}
# {u'_id': 4514.0, u'value': 1.0}
# {u'_id': 4516.0, u'value': 1.0}
# {u'_id': 4520.0, u'value': 5.0}
# {u'_id': 4528.0, u'value': 33.0}
# {u'_id': 4529.0, u'value': 2.0}
# {u'_id': 4530.0, u'value': 3.0}
# {u'_id': 4532.0, u'value': 12.0}
# {u'_id': 4537.0, u'value': 2.0}
# {u'_id': 4538.0, u'value': 3.0}
# {u'_id': 4541.0, u'value': 1.0}
# {u'_id': 4544.0, u'value': 1.0}
# {u'_id': 4545.0, u'value': 2.0}
# {u'_id': 4548.0, u'value': 7.0}
# {u'_id': 4562.0, u'value': 1.0}
# {u'_id': 4563.0, u'value': 2.0}
# {u'_id': 4564.0, u'value': 1.0}
# {u'_id': 4566.0, u'value': 47.0}
# {u'_id': 4568.0, u'value': 9.0}
# {u'_id': 4571.0, u'value': 1.0}
# {u'_id': 4574.0, u'value': 1.0}
# {u'_id': 4577.0, u'value': 1.0}
# {u'_id': 4580.0, u'value': 5.0}
# {u'_id': 4582.0, u'value': 1.0}
# {u'_id': 4583.0, u'value': 1.0}
# {u'_id': 4584.0, u'value': 5.0}
# {u'_id': 4594.0, u'value': 1.0}
# {u'_id': 4595.0, u'value': 20.0}
# {u'_id': 4598.0, u'value': 3.0}
# {u'_id': 4603.0, u'value': 1.0}
# {u'_id': 4610.0, u'value': 34.0}
# {u'_id': 4612.0, u'value': 18.0}
# {u'_id': 4613.0, u'value': 2.0}
# {u'_id': 4617.0, u'value': 6.0}
# {u'_id': 4620.0, u'value': 2.0}
# {u'_id': 4624.0, u'value': 1.0}
# {u'_id': 4627.0, u'value': 1.0}
# {u'_id': 4629.0, u'value': 1.0}
# {u'_id': 4632.0, u'value': 9.0}
# {u'_id': 4633.0, u'value': 4.0}
# {u'_id': 4634.0, u'value': 2.0}
# {u'_id': 4635.0, u'value': 2.0}
# {u'_id': 4637.0, u'value': 1.0}
# {u'_id': 4641.0, u'value': 1.0}
# {u'_id': 4646.0, u'value': 2.0}
# {u'_id': 4650.0, u'value': 1.0}
# {u'_id': 4654.0, u'value': 6.0}
# {u'_id': 4656.0, u'value': 1.0}
# {u'_id': 4661.0, u'value': 5.0}
# {u'_id': 4663.0, u'value': 1.0}
# {u'_id': 4669.0, u'value': 1.0}
# {u'_id': 4671.0, u'value': 1.0}
# {u'_id': 4673.0, u'value': 3.0}
# {u'_id': 4674.0, u'value': 1.0}
# {u'_id': 4675.0, u'value': 1.0}
# {u'_id': 4676.0, u'value': 6.0}
# {u'_id': 4677.0, u'value': 6.0}
# {u'_id': 4678.0, u'value': 1.0}
# {u'_id': 4680.0, u'value': 23.0}
# {u'_id': 4684.0, u'value': 34.0}
# {u'_id': 4688.0, u'value': 1.0}
# {u'_id': 4695.0, u'value': 2.0}
# {u'_id': 4696.0, u'value': 2.0}
# {u'_id': 4697.0, u'value': 1.0}
# {u'_id': 4700.0, u'value': 1.0}
# {u'_id': 4704.0, u'value': 1.0}
# {u'_id': 4708.0, u'value': 4.0}
# {u'_id': 4710.0, u'value': 2.0}
# {u'_id': 4712.0, u'value': 2.0}
# {u'_id': 4715.0, u'value': 2.0}
# {u'_id': 4717.0, u'value': 13.0}
# {u'_id': 4718.0, u'value': 23.0}
# {u'_id': 4723.0, u'value': 4.0}
# {u'_id': 4725.0, u'value': 16.0}
# {u'_id': 4726.0, u'value': 3.0}
# {u'_id': 4729.0, u'value': 3.0}
# {u'_id': 4730.0, u'value': 1.0}
# {u'_id': 4736.0, u'value': 3.0}
# {u'_id': 4738.0, u'value': 1.0}
# {u'_id': 4748.0, u'value': 9.0}
# {u'_id': 4751.0, u'value': 1.0}
# {u'_id': 4753.0, u'value': 7.0}
# {u'_id': 4754.0, u'value': 1.0}
# {u'_id': 4756.0, u'value': 1.0}
# {u'_id': 4757.0, u'value': 1.0}
# {u'_id': 4764.0, u'value': 3.0}
# {u'_id': 4766.0, u'value': 1.0}
# {u'_id': 4770.0, u'value': 17.0}
# {u'_id': 4771.0, u'value': 3.0}
# {u'_id': 4775.0, u'value': 7.0}
# {u'_id': 4777.0, u'value': 1.0}
# {u'_id': 4778.0, u'value': 1.0}
# {u'_id': 4779.0, u'value': 19.0}
# {u'_id': 4780.0, u'value': 1.0}
# {u'_id': 4781.0, u'value': 1.0}
# {u'_id': 4782.0, u'value': 7.0}
# {u'_id': 4783.0, u'value': 1.0}
# {u'_id': 4786.0, u'value': 2.0}
# {u'_id': 4787.0, u'value': 1.0}
# {u'_id': 4788.0, u'value': 1.0}
# {u'_id': 4790.0, u'value': 2.0}
# {u'_id': 4791.0, u'value': 1.0}
# {u'_id': 4794.0, u'value': 2.0}
# {u'_id': 4798.0, u'value': 1.0}
# {u'_id': 4799.0, u'value': 1.0}
# {u'_id': 4804.0, u'value': 46.0}
# {u'_id': 4805.0, u'value': 2.0}
# {u'_id': 4810.0, u'value': 2.0}
# {u'_id': 4811.0, u'value': 20.0}
# {u'_id': 4813.0, u'value': 1.0}
# {u'_id': 4814.0, u'value': 1.0}
# {u'_id': 4815.0, u'value': 5.0}
# {u'_id': 4819.0, u'value': 3.0}
# {u'_id': 4822.0, u'value': 1.0}
# {u'_id': 4823.0, u'value': 2.0}
# {u'_id': 4830.0, u'value': 1.0}
# {u'_id': 4834.0, u'value': 2.0}
# {u'_id': 4836.0, u'value': 4.0}
# {u'_id': 4839.0, u'value': 2.0}
# {u'_id': 4840.0, u'value': 1.0}
# {u'_id': 4845.0, u'value': 4.0}
# {u'_id': 4846.0, u'value': 1.0}
# {u'_id': 4858.0, u'value': 19.0}
# {u'_id': 4859.0, u'value': 1.0}
# {u'_id': 4861.0, u'value': 1.0}
# {u'_id': 4866.0, u'value': 4.0}
# {u'_id': 4870.0, u'value': 1.0}
# {u'_id': 4871.0, u'value': 1.0}
# {u'_id': 4872.0, u'value': 3.0}
# {u'_id': 4874.0, u'value': 37.0}
# {u'_id': 4878.0, u'value': 4.0}
# {u'_id': 4879.0, u'value': 4.0}
# {u'_id': 4880.0, u'value': 1.0}
# {u'_id': 4881.0, u'value': 1.0}
# {u'_id': 4883.0, u'value': 6.0}
# {u'_id': 4886.0, u'value': 1.0}
# {u'_id': 4892.0, u'value': 1.0}
# {u'_id': 4894.0, u'value': 2.0}
# {u'_id': 4897.0, u'value': 1.0}
# {u'_id': 4898.0, u'value': 2.0}
# {u'_id': 4899.0, u'value': 1.0}
# {u'_id': 4907.0, u'value': 2.0}
# {u'_id': 4910.0, u'value': 1.0}
# {u'_id': 4914.0, u'value': 2.0}
# {u'_id': 4916.0, u'value': 1.0}
# {u'_id': 4918.0, u'value': 3.0}
# {u'_id': 4919.0, u'value': 2.0}
# {u'_id': 4923.0, u'value': 8.0}
# {u'_id': 4924.0, u'value': 4.0}
# {u'_id': 4926.0, u'value': 7.0}
# {u'_id': 4930.0, u'value': 1.0}
# {u'_id': 4932.0, u'value': 1.0}
# {u'_id': 4934.0, u'value': 6.0}
# {u'_id': 4937.0, u'value': 2.0}
# {u'_id': 4939.0, u'value': 1.0}
# {u'_id': 4943.0, u'value': 2.0}
# {u'_id': 4948.0, u'value': 2.0}
# {u'_id': 4949.0, u'value': 1.0}
# {u'_id': 4950.0, u'value': 2.0}
# {u'_id': 4951.0, u'value': 1.0}
# {u'_id': 4958.0, u'value': 1.0}
# {u'_id': 4959.0, u'value': 1.0}
# {u'_id': 4961.0, u'value': 5.0}
# {u'_id': 4970.0, u'value': 4.0}
# {u'_id': 4983.0, u'value': 1.0}
# {u'_id': 4984.0, u'value': 1.0}
# {u'_id': 4985.0, u'value': 1.0}
# {u'_id': 4986.0, u'value': 4.0}
# {u'_id': 4987.0, u'value': 1.0}
# {u'_id': 4989.0, u'value': 4.0}
# {u'_id': 4991.0, u'value': 3.0}
# {u'_id': 5002.0, u'value': 3.0}
# {u'_id': 5004.0, u'value': 9.0}
# {u'_id': 5005.0, u'value': 18.0}
# {u'_id': 5012.0, u'value': 1.0}
# {u'_id': 5019.0, u'value': 1.0}
# {u'_id': 5023.0, u'value': 2.0}
# {u'_id': 5024.0, u'value': 1.0}
# {u'_id': 5027.0, u'value': 1.0}
# {u'_id': 5032.0, u'value': 1.0}
# {u'_id': 5034.0, u'value': 2.0}
# {u'_id': 5036.0, u'value': 1.0}
# {u'_id': 5048.0, u'value': 3.0}
# {u'_id': 5049.0, u'value': 2.0}
# {u'_id': 5056.0, u'value': 1.0}
# {u'_id': 5066.0, u'value': 1.0}
# {u'_id': 5069.0, u'value': 2.0}
# {u'_id': 5071.0, u'value': 1.0}
# {u'_id': 5075.0, u'value': 2.0}
# {u'_id': 5076.0, u'value': 1.0}
# {u'_id': 5080.0, u'value': 1.0}
# {u'_id': 5081.0, u'value': 1.0}
# {u'_id': 5087.0, u'value': 2.0}
# {u'_id': 5090.0, u'value': 1.0}
# {u'_id': 5094.0, u'value': 1.0}
# {u'_id': 5095.0, u'value': 1.0}
# {u'_id': 5098.0, u'value': 1.0}
# {u'_id': 5105.0, u'value': 1.0}
# {u'_id': 5107.0, u'value': 1.0}
# {u'_id': 5109.0, u'value': 1.0}
# {u'_id': 5111.0, u'value': 1.0}
# {u'_id': 5114.0, u'value': 2.0}
# {u'_id': 5118.0, u'value': 1.0}
# {u'_id': 5126.0, u'value': 1.0}
# {u'_id': 5127.0, u'value': 1.0}
# {u'_id': 5130.0, u'value': 1.0}
# {u'_id': 5131.0, u'value': 2.0}
# {u'_id': 5133.0, u'value': 1.0}
# {u'_id': 5137.0, u'value': 1.0}
# {u'_id': 5145.0, u'value': 1.0}
# {u'_id': 5147.0, u'value': 4.0}
# {u'_id': 5157.0, u'value': 1.0}
# {u'_id': 5159.0, u'value': 1.0}
# {u'_id': 5161.0, u'value': 1.0}
# {u'_id': 5164.0, u'value': 1.0}
# {u'_id': 5174.0, u'value': 1.0}
# {u'_id': 5175.0, u'value': 1.0}
# {u'_id': 5176.0, u'value': 1.0}
# {u'_id': 5179.0, u'value': 1.0}
# {u'_id': 5180.0, u'value': 4.0}
# {u'_id': 5187.0, u'value': 1.0}
# {u'_id': 5193.0, u'value': 2.0}
# {u'_id': 5194.0, u'value': 1.0}
# {u'_id': 5197.0, u'value': 2.0}
# {u'_id': 5199.0, u'value': 1.0}
# {u'_id': 5200.0, u'value': 1.0}
# {u'_id': 5206.0, u'value': 4.0}
# {u'_id': 5215.0, u'value': 1.0}
# {u'_id': 5217.0, u'value': 1.0}
# {u'_id': 5218.0, u'value': 1.0}
# {u'_id': 5219.0, u'value': 10.0}
# {u'_id': 5231.0, u'value': 2.0}
# {u'_id': 5233.0, u'value': 1.0}
# {u'_id': 5236.0, u'value': 2.0}
# {u'_id': 5238.0, u'value': 6.0}
# {u'_id': 5239.0, u'value': 4.0}
# {u'_id': 5240.0, u'value': 1.0}
# {u'_id': 5242.0, u'value': 2.0}
# {u'_id': 5243.0, u'value': 1.0}
# {u'_id': 5244.0, u'value': 1.0}
# {u'_id': 5247.0, u'value': 1.0}
# {u'_id': 5248.0, u'value': 5.0}
# {u'_id': 5253.0, u'value': 2.0}
# {u'_id': 5257.0, u'value': 2.0}
# {u'_id': 5259.0, u'value': 4.0}
# {u'_id': 5262.0, u'value': 1.0}
# {u'_id': 5263.0, u'value': 7.0}
# {u'_id': 5265.0, u'value': 3.0}
# {u'_id': 5267.0, u'value': 1.0}
# {u'_id': 5268.0, u'value': 1.0}
# {u'_id': 5271.0, u'value': 4.0}
# {u'_id': 5272.0, u'value': 11.0}
# {u'_id': 5274.0, u'value': 3.0}
# {u'_id': 5278.0, u'value': 1.0}
# {u'_id': 5283.0, u'value': 10.0}
# {u'_id': 5287.0, u'value': 1.0}
# {u'_id': 5292.0, u'value': 1.0}
# {u'_id': 5295.0, u'value': 2.0}
# {u'_id': 5296.0, u'value': 1.0}
# {u'_id': 5297.0, u'value': 1.0}
# {u'_id': 5301.0, u'value': 1.0}
# {u'_id': 5307.0, u'value': 1.0}
# {u'_id': 5311.0, u'value': 2.0}
# {u'_id': 5320.0, u'value': 2.0}
# {u'_id': 5324.0, u'value': 1.0}
# {u'_id': 5327.0, u'value': 2.0}
# {u'_id': 5328.0, u'value': 1.0}
# {u'_id': 5329.0, u'value': 3.0}
# {u'_id': 5339.0, u'value': 10.0}
# {u'_id': 5342.0, u'value': 1.0}
# {u'_id': 5344.0, u'value': 1.0}
# {u'_id': 5350.0, u'value': 3.0}
# {u'_id': 5351.0, u'value': 1.0}
# {u'_id': 5356.0, u'value': 1.0}
# {u'_id': 5358.0, u'value': 1.0}
# {u'_id': 5365.0, u'value': 1.0}
# {u'_id': 5368.0, u'value': 4.0}
# {u'_id': 5370.0, u'value': 43.0}
# {u'_id': 5376.0, u'value': 1.0}
# {u'_id': 5378.0, u'value': 1.0}
# {u'_id': 5380.0, u'value': 3.0}
# {u'_id': 5381.0, u'value': 1.0}
# {u'_id': 5385.0, u'value': 1.0}
# {u'_id': 5389.0, u'value': 7.0}
# {u'_id': 5396.0, u'value': 1.0}
# {u'_id': 5399.0, u'value': 1.0}
# {u'_id': 5403.0, u'value': 7.0}
# {u'_id': 5406.0, u'value': 2.0}
# {u'_id': 5407.0, u'value': 1.0}
# {u'_id': 5408.0, u'value': 1.0}
# {u'_id': 5409.0, u'value': 2.0}
# {u'_id': 5421.0, u'value': 6.0}
# {u'_id': 5422.0, u'value': 7.0}
# {u'_id': 5423.0, u'value': 1.0}
# {u'_id': 5427.0, u'value': 1.0}
# {u'_id': 5429.0, u'value': 1.0}
# {u'_id': 5431.0, u'value': 2.0}
# {u'_id': 5432.0, u'value': 2.0}
# {u'_id': 5438.0, u'value': 15.0}
# {u'_id': 5441.0, u'value': 3.0}
# {u'_id': 5449.0, u'value': 1.0}
# {u'_id': 5456.0, u'value': 1.0}
# {u'_id': 5458.0, u'value': 2.0}
# {u'_id': 5461.0, u'value': 8.0}
# {u'_id': 5464.0, u'value': 4.0}
# {u'_id': 5465.0, u'value': 5.0}
# {u'_id': 5467.0, u'value': 1.0}
# {u'_id': 5469.0, u'value': 1.0}
# {u'_id': 5472.0, u'value': 1.0}
# {u'_id': 5478.0, u'value': 9.0}
# {u'_id': 5480.0, u'value': 1.0}
# {u'_id': 5481.0, u'value': 1.0}
# {u'_id': 5483.0, u'value': 1.0}
# {u'_id': 5487.0, u'value': 3.0}
# {u'_id': 5492.0, u'value': 2.0}
# {u'_id': 5493.0, u'value': 2.0}
# {u'_id': 5497.0, u'value': 1.0}
# {u'_id': 5505.0, u'value': 1.0}
# {u'_id': 5506.0, u'value': 1.0}
# {u'_id': 5516.0, u'value': 2.0}
# {u'_id': 5517.0, u'value': 1.0}
# {u'_id': 5519.0, u'value': 5.0}
# {u'_id': 5521.0, u'value': 1.0}
# {u'_id': 5523.0, u'value': 1.0}
# {u'_id': 5525.0, u'value': 1.0}
# {u'_id': 5530.0, u'value': 1.0}
# {u'_id': 5532.0, u'value': 1.0}
# {u'_id': 5534.0, u'value': 1.0}
# {u'_id': 5538.0, u'value': 2.0}
# {u'_id': 5541.0, u'value': 1.0}
# {u'_id': 5550.0, u'value': 1.0}
# {u'_id': 5552.0, u'value': 2.0}
# {u'_id': 5558.0, u'value': 6.0}
# {u'_id': 5562.0, u'value': 1.0}
# {u'_id': 5563.0, u'value': 1.0}
# {u'_id': 5566.0, u'value': 5.0}
# {u'_id': 5569.0, u'value': 2.0}
# ...
# {u'_id': 11168.0, u'value': 1.0}
# {u'_id': 11173.0, u'value': 1.0}
# {u'_id': 11179.0, u'value': 1.0}
# {u'_id': 11180.0, u'value': 2.0}
# {u'_id': 11181.0, u'value': 2.0}
# {u'_id': 11183.0, u'value': 1.0}
# {u'_id': 11184.0, u'value': 1.0}
# {u'_id': 11187.0, u'value': 2.0}
# {u'_id': 11203.0, u'value': 2.0}
# {u'_id': 11213.0, u'value': 1.0}
# {u'_id': 11214.0, u'value': 1.0}
# {u'_id': 11216.0, u'value': 1.0}
# {u'_id': 11223.0, u'value': 4.0}
# {u'_id': 11231.0, u'value': 1.0}
# {u'_id': 11232.0, u'value': 1.0}
# {u'_id': 11237.0, u'value': 1.0}
# {u'_id': 11238.0, u'value': 1.0}
# {u'_id': 11242.0, u'value': 1.0}
# {u'_id': 11249.0, u'value': 1.0}
# {u'_id': 11254.0, u'value': 3.0}
# {u'_id': 11259.0, u'value': 2.0}
# {u'_id': 11261.0, u'value': 14.0}
# {u'_id': 11263.0, u'value': 3.0}
# {u'_id': 11265.0, u'value': 1.0}
# {u'_id': 11266.0, u'value': 1.0}
# {u'_id': 11274.0, u'value': 1.0}
# {u'_id': 11278.0, u'value': 1.0}
# {u'_id': 11279.0, u'value': 1.0}
# {u'_id': 11287.0, u'value': 1.0}
# {u'_id': 11288.0, u'value': 2.0}
# {u'_id': 11289.0, u'value': 1.0}
# {u'_id': 11292.0, u'value': 1.0}
# {u'_id': 11294.0, u'value': 5.0}
# {u'_id': 11295.0, u'value': 1.0}
# {u'_id': 11300.0, u'value': 1.0}
# {u'_id': 11302.0, u'value': 1.0}
# {u'_id': 11303.0, u'value': 2.0}
# {u'_id': 11305.0, u'value': 1.0}
# {u'_id': 11308.0, u'value': 1.0}
# {u'_id': 11309.0, u'value': 8.0}
# {u'_id': 11313.0, u'value': 16.0}
# {u'_id': 11320.0, u'value': 4.0}
# {u'_id': 11322.0, u'value': 1.0}
# {u'_id': 11323.0, u'value': 1.0}
# {u'_id': 11325.0, u'value': 3.0}
# {u'_id': 11337.0, u'value': 1.0}
# {u'_id': 11340.0, u'value': 2.0}
# {u'_id': 11342.0, u'value': 8.0}
# {u'_id': 11343.0, u'value': 1.0}
# {u'_id': 11344.0, u'value': 1.0}
# {u'_id': 11346.0, u'value': 1.0}
# {u'_id': 11349.0, u'value': 1.0}
# {u'_id': 11353.0, u'value': 2.0}
# {u'_id': 11354.0, u'value': 2.0}
# {u'_id': 11361.0, u'value': 1.0}
# {u'_id': 11367.0, u'value': 1.0}
# {u'_id': 11370.0, u'value': 2.0}
# {u'_id': 11376.0, u'value': 4.0}
# {u'_id': 11380.0, u'value': 2.0}
# {u'_id': 11381.0, u'value': 1.0}
# {u'_id': 11382.0, u'value': 1.0}
# {u'_id': 11385.0, u'value': 1.0}
# {u'_id': 11389.0, u'value': 1.0}
# {u'_id': 11394.0, u'value': 1.0}
# {u'_id': 11395.0, u'value': 9.0}
# {u'_id': 11397.0, u'value': 2.0}
# {u'_id': 11398.0, u'value': 3.0}
# {u'_id': 11403.0, u'value': 1.0}
# {u'_id': 11406.0, u'value': 1.0}
# {u'_id': 12415.0, u'value': 1.0}
# {u'_id': 12418.0, u'value': 1.0}
# {u'_id': 12424.0, u'value': 5.0}
# {u'_id': 12428.0, u'value': 2.0}
# {u'_id': 12431.0, u'value': 10.0}
# {u'_id': 12434.0, u'value': 1.0}
# {u'_id': 12435.0, u'value': 2.0}
# {u'_id': 12436.0, u'value': 1.0}
# {u'_id': 12441.0, u'value': 1.0}
# {u'_id': 12446.0, u'value': 7.0}
# {u'_id': 12455.0, u'value': 1.0}
# {u'_id': 12458.0, u'value': 3.0}
# {u'_id': 12459.0, u'value': 4.0}
# {u'_id': 12467.0, u'value': 3.0}
# {u'_id': 12468.0, u'value': 3.0}
# {u'_id': 12470.0, u'value': 2.0}
# {u'_id': 12472.0, u'value': 1.0}
# {u'_id': 12474.0, u'value': 1.0}
# {u'_id': 12475.0, u'value': 1.0}
# {u'_id': 12476.0, u'value': 2.0}
# {u'_id': 12478.0, u'value': 1.0}
# {u'_id': 12483.0, u'value': 5.0}
# {u'_id': 12486.0, u'value': 1.0}
# {u'_id': 12492.0, u'value': 1.0}
# {u'_id': 12494.0, u'value': 1.0}
# {u'_id': 12496.0, u'value': 1.0}
# {u'_id': 12497.0, u'value': 3.0}
# {u'_id': 12498.0, u'value': 1.0}
# {u'_id': 12510.0, u'value': 3.0}
# {u'_id': 12511.0, u'value': 4.0}
# {u'_id': 12517.0, u'value': 1.0}
# {u'_id': 12524.0, u'value': 1.0}
# {u'_id': 12525.0, u'value': 1.0}
# {u'_id': 12530.0, u'value': 1.0}
# {u'_id': 12531.0, u'value': 2.0}
# {u'_id': 12535.0, u'value': 1.0}
# {u'_id': 12540.0, u'value': 1.0}
# {u'_id': 12545.0, u'value': 1.0}
# {u'_id': 12550.0, u'value': 1.0}
# {u'_id': 12551.0, u'value': 1.0}
# {u'_id': 12554.0, u'value': 1.0}
# {u'_id': 12555.0, u'value': 1.0}
# {u'_id': 12557.0, u'value': 1.0}
# {u'_id': 12565.0, u'value': 1.0}
# {u'_id': 12567.0, u'value': 1.0}
# {u'_id': 12570.0, u'value': 1.0}
# {u'_id': 12575.0, u'value': 3.0}
# {u'_id': 12578.0, u'value': 5.0}
# {u'_id': 12586.0, u'value': 1.0}
# {u'_id': 12591.0, u'value': 9.0}
# {u'_id': 12600.0, u'value': 1.0}
# {u'_id': 12604.0, u'value': 2.0}
# {u'_id': 12605.0, u'value': 7.0}
# {u'_id': 12606.0, u'value': 2.0}
# {u'_id': 12608.0, u'value': 1.0}
# {u'_id': 12609.0, u'value': 1.0}
# {u'_id': 12611.0, u'value': 1.0}
# {u'_id': 12613.0, u'value': 3.0}
# {u'_id': 12615.0, u'value': 1.0}
# {u'_id': 12616.0, u'value': 5.0}
# {u'_id': 12618.0, u'value': 2.0}
# {u'_id': 12619.0, u'value': 1.0}
# {u'_id': 12621.0, u'value': 1.0}
# {u'_id': 12622.0, u'value': 1.0}
# {u'_id': 12623.0, u'value': 1.0}
# {u'_id': 12625.0, u'value': 31.0}
# {u'_id': 12628.0, u'value': 1.0}
# {u'_id': 12629.0, u'value': 3.0}
# {u'_id': 12631.0, u'value': 1.0}
# {u'_id': 12632.0, u'value': 2.0}
# {u'_id': 12634.0, u'value': 1.0}
# {u'_id': 12635.0, u'value': 2.0}
# {u'_id': 12640.0, u'value': 1.0}
# {u'_id': 12641.0, u'value': 1.0}
# {u'_id': 12644.0, u'value': 1.0}
# {u'_id': 12645.0, u'value': 1.0}
# {u'_id': 12654.0, u'value': 2.0}
# {u'_id': 12655.0, u'value': 2.0}
# {u'_id': 12657.0, u'value': 11.0}
# {u'_id': 12672.0, u'value': 1.0}
# {u'_id': 12677.0, u'value': 1.0}
# {u'_id': 12680.0, u'value': 1.0}
# {u'_id': 12681.0, u'value': 2.0}
# {u'_id': 12685.0, u'value': 1.0}
# {u'_id': 12686.0, u'value': 2.0}
# {u'_id': 12690.0, u'value': 1.0}
# {u'_id': 12698.0, u'value': 1.0}
# {u'_id': 12700.0, u'value': 1.0}
# {u'_id': 12708.0, u'value': 9.0}
# {u'_id': 12709.0, u'value': 1.0}
# {u'_id': 12710.0, u'value': 1.0}
# {u'_id': 12717.0, u'value': 2.0}
# {u'_id': 12720.0, u'value': 1.0}
# {u'_id': 12723.0, u'value': 2.0}
# {u'_id': 12724.0, u'value': 3.0}
# {u'_id': 12725.0, u'value': 1.0}
# {u'_id': 12727.0, u'value': 1.0}
# {u'_id': 12729.0, u'value': 1.0}
# {u'_id': 12737.0, u'value': 1.0}
# {u'_id': 12740.0, u'value': 1.0}
# {u'_id': 12745.0, u'value': 1.0}
# {u'_id': 12750.0, u'value': 1.0}
# {u'_id': 12753.0, u'value': 1.0}
# {u'_id': 12754.0, u'value': 1.0}
# {u'_id': 12755.0, u'value': 1.0}
# {u'_id': 12758.0, u'value': 1.0}
# {u'_id': 12760.0, u'value': 3.0}
# {u'_id': 12761.0, u'value': 1.0}
# {u'_id': 12766.0, u'value': 1.0}
# {u'_id': 12772.0, u'value': 1.0}
# {u'_id': 12773.0, u'value': 2.0}
# {u'_id': 12774.0, u'value': 1.0}
# {u'_id': 12775.0, u'value': 1.0}
# {u'_id': 12781.0, u'value': 5.0}
# {u'_id': 12790.0, u'value': 2.0}
# {u'_id': 12795.0, u'value': 1.0}
# {u'_id': 12797.0, u'value': 1.0}
# {u'_id': 12798.0, u'value': 1.0}
# {u'_id': 12804.0, u'value': 1.0}
# {u'_id': 12805.0, u'value': 1.0}
# {u'_id': 12807.0, u'value': 1.0}
# {u'_id': 12808.0, u'value': 3.0}
# {u'_id': 12809.0, u'value': 1.0}
# {u'_id': 12811.0, u'value': 1.0}
# {u'_id': 12816.0, u'value': 1.0}
# {u'_id': 12817.0, u'value': 2.0}
# {u'_id': 12822.0, u'value': 1.0}
# {u'_id': 12825.0, u'value': 1.0}
# {u'_id': 12826.0, u'value': 5.0}
# {u'_id': 12829.0, u'value': 1.0}
# {u'_id': 12830.0, u'value': 1.0}
# {u'_id': 12831.0, u'value': 1.0}
# {u'_id': 12843.0, u'value': 2.0}
# {u'_id': 12844.0, u'value': 3.0}
# {u'_id': 12845.0, u'value': 21.0}
# {u'_id': 12851.0, u'value': 1.0}
# {u'_id': 12854.0, u'value': 2.0}
# {u'_id': 12855.0, u'value': 1.0}
# {u'_id': 12859.0, u'value': 1.0}
# {u'_id': 12865.0, u'value': 1.0}
# {u'_id': 12866.0, u'value': 1.0}
# {u'_id': 12869.0, u'value': 1.0}
# {u'_id': 12870.0, u'value': 4.0}
# {u'_id': 12873.0, u'value': 1.0}
# {u'_id': 12876.0, u'value': 1.0}
# {u'_id': 12878.0, u'value': 7.0}
# {u'_id': 12886.0, u'value': 2.0}
# {u'_id': 12889.0, u'value': 1.0}
# {u'_id': 12891.0, u'value': 2.0}
# {u'_id': 12894.0, u'value': 1.0}
# {u'_id': 12895.0, u'value': 5.0}
# {u'_id': 12898.0, u'value': 1.0}
# {u'_id': 12899.0, u'value': 1.0}
# {u'_id': 12901.0, u'value': 1.0}
# {u'_id': 12902.0, u'value': 1.0}
# {u'_id': 12903.0, u'value': 3.0}
# {u'_id': 12904.0, u'value': 3.0}
# {u'_id': 12906.0, u'value': 1.0}
# {u'_id': 12908.0, u'value': 1.0}
# {u'_id': 12912.0, u'value': 1.0}
# {u'_id': 12913.0, u'value': 2.0}
# {u'_id': 12914.0, u'value': 1.0}
# {u'_id': 12917.0, u'value': 1.0}
# {u'_id': 12919.0, u'value': 1.0}
# {u'_id': 12924.0, u'value': 1.0}
# {u'_id': 12930.0, u'value': 1.0}
# {u'_id': 12932.0, u'value': 1.0}
# {u'_id': 12933.0, u'value': 1.0}
# {u'_id': 12935.0, u'value': 2.0}
# {u'_id': 12936.0, u'value': 1.0}
# {u'_id': 12937.0, u'value': 1.0}
# {u'_id': 12940.0, u'value': 1.0}
# {u'_id': 12942.0, u'value': 1.0}
# {u'_id': 12945.0, u'value': 2.0}
# {u'_id': 12948.0, u'value': 1.0}
# {u'_id': 12951.0, u'value': 1.0}
# {u'_id': 12952.0, u'value': 1.0}
# {u'_id': 12958.0, u'value': 1.0}
# {u'_id': 12964.0, u'value': 3.0}
# {u'_id': 12967.0, u'value': 1.0}
# {u'_id': 12968.0, u'value': 1.0}
# {u'_id': 12972.0, u'value': 5.0}
# {u'_id': 12975.0, u'value': 3.0}
# {u'_id': 12980.0, u'value': 1.0}
# {u'_id': 12982.0, u'value': 1.0}
# {u'_id': 12987.0, u'value': 1.0}
# {u'_id': 12988.0, u'value': 1.0}
# {u'_id': 12991.0, u'value': 4.0}
# {u'_id': 12994.0, u'value': 2.0}
# {u'_id': 12995.0, u'value': 1.0}
# {u'_id': 12999.0, u'value': 1.0}
# {u'_id': 13001.0, u'value': 1.0}
# {u'_id': 13003.0, u'value': 1.0}
# {u'_id': 13005.0, u'value': 1.0}
# {u'_id': 13009.0, u'value': 1.0}
# {u'_id': 13011.0, u'value': 1.0}
# {u'_id': 13016.0, u'value': 1.0}
# {u'_id': 13023.0, u'value': 1.0}
# {u'_id': 13039.0, u'value': 2.0}
# {u'_id': 13042.0, u'value': 6.0}
# {u'_id': 13043.0, u'value': 1.0}
# {u'_id': 13047.0, u'value': 5.0}
# {u'_id': 13049.0, u'value': 1.0}
# {u'_id': 13053.0, u'value': 2.0}
# {u'_id': 13061.0, u'value': 3.0}
# {u'_id': 13062.0, u'value': 1.0}
# {u'_id': 13063.0, u'value': 3.0}
# {u'_id': 13064.0, u'value': 2.0}
# {u'_id': 13076.0, u'value': 1.0}
# {u'_id': 13077.0, u'value': 2.0}
# {u'_id': 13080.0, u'value': 1.0}
# {u'_id': 13083.0, u'value': 1.0}
# {u'_id': 13085.0, u'value': 1.0}
# {u'_id': 13095.0, u'value': 1.0}
# {u'_id': 13099.0, u'value': 1.0}
# {u'_id': 13100.0, u'value': 1.0}
# {u'_id': 13104.0, u'value': 1.0}
# {u'_id': 13106.0, u'value': 1.0}
# {u'_id': 13108.0, u'value': 3.0}
# {u'_id': 13112.0, u'value': 1.0}
# {u'_id': 13115.0, u'value': 2.0}
# {u'_id': 13116.0, u'value': 2.0}
# {u'_id': 13124.0, u'value': 1.0}
# {u'_id': 13131.0, u'value': 1.0}
# {u'_id': 13146.0, u'value': 1.0}
# {u'_id': 13147.0, u'value': 6.0}
# {u'_id': 13148.0, u'value': 1.0}
# {u'_id': 13151.0, u'value': 2.0}
# {u'_id': 13156.0, u'value': 1.0}
# {u'_id': 13158.0, u'value': 1.0}
# {u'_id': 13160.0, u'value': 1.0}
# {u'_id': 13165.0, u'value': 1.0}
# {u'_id': 13169.0, u'value': 1.0}
# {u'_id': 13173.0, u'value': 1.0}
# {u'_id': 13177.0, u'value': 3.0}
# {u'_id': 13178.0, u'value': 2.0}
# {u'_id': 13180.0, u'value': 2.0}
# {u'_id': 13184.0, u'value': 1.0}
# {u'_id': 13192.0, u'value': 1.0}
# {u'_id': 13194.0, u'value': 1.0}
# {u'_id': 13199.0, u'value': 2.0}
# {u'_id': 13200.0, u'value': 1.0}
# {u'_id': 13203.0, u'value': 2.0}
# {u'_id': 13209.0, u'value': 3.0}
# {u'_id': 13211.0, u'value': 1.0}
# {u'_id': 13213.0, u'value': 1.0}
# {u'_id': 13222.0, u'value': 3.0}
# {u'_id': 13225.0, u'value': 1.0}
# {u'_id': 13226.0, u'value': 1.0}
# {u'_id': 13227.0, u'value': 1.0}
# {u'_id': 13234.0, u'value': 1.0}
# {u'_id': 13235.0, u'value': 1.0}
# {u'_id': 13237.0, u'value': 6.0}
# {u'_id': 13239.0, u'value': 1.0}
# {u'_id': 13240.0, u'value': 1.0}
# {u'_id': 13245.0, u'value': 1.0}
# {u'_id': 13250.0, u'value': 1.0}
# {u'_id': 13251.0, u'value': 2.0}
# {u'_id': 13258.0, u'value': 2.0}
# {u'_id': 13266.0, u'value': 1.0}
# {u'_id': 13267.0, u'value': 1.0}
# {u'_id': 13269.0, u'value': 2.0}
# {u'_id': 13273.0, u'value': 4.0}
# {u'_id': 13275.0, u'value': 1.0}
# {u'_id': 13277.0, u'value': 1.0}
# {u'_id': 13278.0, u'value': 1.0}
# {u'_id': 13282.0, u'value': 2.0}
# {u'_id': 13299.0, u'value': 1.0}
# {u'_id': 13303.0, u'value': 1.0}
# {u'_id': 13304.0, u'value': 1.0}
# {u'_id': 13310.0, u'value': 1.0}
# {u'_id': 13316.0, u'value': 1.0}
# {u'_id': 13325.0, u'value': 1.0}
# {u'_id': 13326.0, u'value': 3.0}
# {u'_id': 13335.0, u'value': 1.0}
# {u'_id': 13339.0, u'value': 1.0}
# {u'_id': 13341.0, u'value': 1.0}
# {u'_id': 13342.0, u'value': 2.0}
# {u'_id': 13343.0, u'value': 2.0}
# {u'_id': 13347.0, u'value': 1.0}
# {u'_id': 13349.0, u'value': 4.0}
# {u'_id': 13350.0, u'value': 1.0}
# {u'_id': 13354.0, u'value': 2.0}
# {u'_id': 13357.0, u'value': 1.0}
# {u'_id': 13358.0, u'value': 2.0}
# {u'_id': 13362.0, u'value': 1.0}
# {u'_id': 13372.0, u'value': 2.0}
# {u'_id': 13377.0, u'value': 1.0}
# {u'_id': 13380.0, u'value': 1.0}
# {u'_id': 13383.0, u'value': 1.0}
# {u'_id': 13389.0, u'value': 3.0}
# {u'_id': 13393.0, u'value': 1.0}
# {u'_id': 13405.0, u'value': 7.0}
# {u'_id': 13407.0, u'value': 1.0}
# {u'_id': 13410.0, u'value': 1.0}
# {u'_id': 13414.0, u'value': 1.0}
# {u'_id': 13420.0, u'value': 2.0}
# {u'_id': 13425.0, u'value': 2.0}
# {u'_id': 13429.0, u'value': 1.0}
# {u'_id': 13432.0, u'value': 2.0}
# {u'_id': 13433.0, u'value': 1.0}
# {u'_id': 13437.0, u'value': 1.0}
# {u'_id': 13440.0, u'value': 2.0}
# {u'_id': 13443.0, u'value': 1.0}
# {u'_id': 13450.0, u'value': 1.0}
# {u'_id': 13451.0, u'value': 1.0}
# {u'_id': 13454.0, u'value': 1.0}
# {u'_id': 13455.0, u'value': 1.0}
# {u'_id': 13460.0, u'value': 6.0}
# {u'_id': 13462.0, u'value': 3.0}
# {u'_id': 13464.0, u'value': 1.0}
# {u'_id': 13466.0, u'value': 1.0}
# {u'_id': 13470.0, u'value': 1.0}
# {u'_id': 13474.0, u'value': 1.0}
# {u'_id': 13480.0, u'value': 1.0}
# {u'_id': 13483.0, u'value': 1.0}
# {u'_id': 13485.0, u'value': 1.0}
# {u'_id': 13489.0, u'value': 5.0}
# {u'_id': 13490.0, u'value': 2.0}
# {u'_id': 13491.0, u'value': 1.0}
# {u'_id': 13493.0, u'value': 1.0}
# {u'_id': 13495.0, u'value': 1.0}
# {u'_id': 13498.0, u'value': 2.0}
# {u'_id': 13506.0, u'value': 1.0}
# {u'_id': 13513.0, u'value': 1.0}
# {u'_id': 13518.0, u'value': 1.0}
# {u'_id': 13522.0, u'value': 1.0}
# {u'_id': 13525.0, u'value': 2.0}
# {u'_id': 13538.0, u'value': 1.0}
# {u'_id': 13539.0, u'value': 1.0}
# {u'_id': 13544.0, u'value': 1.0}
# {u'_id': 13546.0, u'value': 2.0}
# {u'_id': 13547.0, u'value': 2.0}
# {u'_id': 13550.0, u'value': 1.0}
# {u'_id': 13552.0, u'value': 1.0}
# {u'_id': 13554.0, u'value': 3.0}
# {u'_id': 13557.0, u'value': 2.0}
# {u'_id': 13560.0, u'value': 1.0}
# {u'_id': 13566.0, u'value': 1.0}
# {u'_id': 13567.0, u'value': 2.0}
# {u'_id': 13569.0, u'value': 1.0}
# {u'_id': 13571.0, u'value': 2.0}
# {u'_id': 13574.0, u'value': 1.0}
# {u'_id': 13575.0, u'value': 1.0}
# {u'_id': 13576.0, u'value': 1.0}
# {u'_id': 13577.0, u'value': 1.0}
# {u'_id': 13580.0, u'value': 2.0}
# {u'_id': 13587.0, u'value': 1.0}
# {u'_id': 13590.0, u'value': 2.0}
# {u'_id': 13591.0, u'value': 1.0}
# {u'_id': 13592.0, u'value': 1.0}
# {u'_id': 13601.0, u'value': 1.0}
# {u'_id': 13603.0, u'value': 1.0}
# {u'_id': 13608.0, u'value': 2.0}
# {u'_id': 13610.0, u'value': 1.0}
# {u'_id': 13612.0, u'value': 2.0}
# {u'_id': 13626.0, u'value': 1.0}
# {u'_id': 13635.0, u'value': 1.0}
# {u'_id': 13637.0, u'value': 7.0}
# {u'_id': 13638.0, u'value': 1.0}
# {u'_id': 13646.0, u'value': 3.0}
# {u'_id': 13647.0, u'value': 1.0}
# {u'_id': 13648.0, u'value': 1.0}
# {u'_id': 13651.0, u'value': 1.0}
# {u'_id': 13652.0, u'value': 1.0}
# {u'_id': 13655.0, u'value': 1.0}
# {u'_id': 13658.0, u'value': 1.0}
# {u'_id': 13661.0, u'value': 3.0}
# {u'_id': 13664.0, u'value': 1.0}
# {u'_id': 13670.0, u'value': 1.0}
# {u'_id': 13675.0, u'value': 1.0}
# {u'_id': 13677.0, u'value': 1.0}
# {u'_id': 13681.0, u'value': 2.0}
# {u'_id': 13682.0, u'value': 1.0}
# {u'_id': 13691.0, u'value': 1.0}
# {u'_id': 13693.0, u'value': 2.0}
# {u'_id': 13696.0, u'value': 2.0}
# {u'_id': 13701.0, u'value': 1.0}
# {u'_id': 13709.0, u'value': 1.0}
# {u'_id': 13711.0, u'value': 1.0}
# {u'_id': 13714.0, u'value': 1.0}
# {u'_id': 13722.0, u'value': 2.0}
# {u'_id': 13723.0, u'value': 1.0}
# {u'_id': 13724.0, u'value': 1.0}
# {u'_id': 13725.0, u'value': 1.0}
# {u'_id': 13726.0, u'value': 2.0}
# {u'_id': 13730.0, u'value': 1.0}
# {u'_id': 13731.0, u'value': 1.0}
# {u'_id': 13737.0, u'value': 1.0}
# {u'_id': 13744.0, u'value': 1.0}
# {u'_id': 13746.0, u'value': 1.0}
# {u'_id': 13750.0, u'value': 1.0}
# {u'_id': 13756.0, u'value': 1.0}
# {u'_id': 13758.0, u'value': 2.0}
# {u'_id': 13759.0, u'value': 1.0}
# {u'_id': 13764.0, u'value': 1.0}
# {u'_id': 13766.0, u'value': 1.0}
# {u'_id': 13767.0, u'value': 1.0}
# {u'_id': 13773.0, u'value': 2.0}
# {u'_id': 13775.0, u'value': 1.0}
# {u'_id': 13776.0, u'value': 1.0}
# {u'_id': 13778.0, u'value': 1.0}
# {u'_id': 13781.0, u'value': 1.0}
# {u'_id': 13787.0, u'value': 2.0}
# {u'_id': 13788.0, u'value': 1.0}
# {u'_id': 13789.0, u'value': 1.0}
# {u'_id': 13790.0, u'value': 1.0}
# {u'_id': 13792.0, u'value': 1.0}
# {u'_id': 13797.0, u'value': 1.0}
# {u'_id': 13798.0, u'value': 1.0}
# {u'_id': 13800.0, u'value': 2.0}
# {u'_id': 13809.0, u'value': 1.0}
# {u'_id': 13811.0, u'value': 1.0}
# {u'_id': 13818.0, u'value': 1.0}
# {u'_id': u'', u'value': 12.0}

# %% [markdown]
# Se le puede añadir una etiqueta para especificar sobre qué elementos queremos trabajar (`query`):

# %% [markdown]
# La función `map_reduce` puede llevar añadida una serie de *keywords*, los mismos especificados en la documentación:
#
# - `query`: Restringe los datos que se tratan
# - `sort`: Ordena los documentos de entrada por alguna clave
# - `limit`: Limita el número de resultados
# - `out`: Especifica la colección de salida y otras opciones. Lo veremos después.
# - etc.

# %%
# %%timeit
results = posts.map_reduce(map, reduce, "myresults", query={"Score": {'$gt' : 20}}, sort={'OwnerUserId': 1})
r = list(results.find())
# Out:
# 10 loops, best of 3: 38.3 ms per loop

# %%
# %%timeit
results = posts.map_reduce(map, reduce, "myresults", query={"Score": {'$gt' : 20}})
r = list(results.find())
# Out:
# 10 loops, best of 3: 48.1 ms per loop

# %% [markdown]
# En el parámetro `out` se puede especificar en qué colección se quedarán los datos resultado del map-reduce. Por defecto, en la colección origen. (Todos los parámetros aquí: https://docs.mongodb.com/manual/reference/command/mapReduce/#mapreduce-out-cmd). En la operación `map_reduce()`  podemos especificar la colección de salida, pero también podemos añadir un parámetro final `out={...}`.
#
# Hay varias posibilidades para `out`:
#
# - `replace`: Sustituye la colección, si la hubiera, con la especificada (p. ej.: `out={ "replace" : "coll" }`.
# - `merge`: Mezcla la colección existente, sustituyendo los documentos que existan por los generados.
# - `reduce`: Si existe un documento con el mismo \_id en la colección, se aplica la función `reduce` para *fusionar* ambos documentos y producir un nuevo documento.
#
# Veremos a continuación, al resolver el ejercicio de crear `post_comments` con map-reduce cómo se utilizan estas posibilidades.

# %% [markdown]
# ## Framework de Agregación
#
# Framework de agregación: https://docs.mongodb.com/manual/reference/operator/aggregation/. Y aquí una presentación interesante sobre el tema: https://www.mongodb.com/presentations/aggregation-framework-0?jmp=docs&_ga=1.223708571.1466850754.1477658152
#
# ![agragación](https://docs.mongodb.com/manual/_images/aggregation-pipeline.png)

# %%
respuestas = posts.aggregate( [ {'$project' : { 'Id' : 1 }}, {'$limit': 20} ])
print_respuestas(respuestas)
# Out:
# {u'Id': 2, u'_id': ObjectId('584ac9ae0b09c35439b17442')}
# {u'Id': 3, u'_id': ObjectId('584ac9ae0b09c35439b17443')}
# {u'Id': 5, u'_id': ObjectId('584ac9ae0b09c35439b17444')}
# {u'Id': 15, u'_id': ObjectId('584ac9ae0b09c35439b1744d')}
# {u'Id': 219, u'_id': ObjectId('584ac9ae0b09c35439b174f8')}
# {u'Id': 1, u'_id': ObjectId('584ac9ae0b09c35439b17441')}
# {u'Id': 6, u'_id': ObjectId('584ac9ae0b09c35439b17445')}
# {u'Id': 4, u'_id': ObjectId('584ac9ae0b09c35439b17446')}
# {u'Id': 7, u'_id': ObjectId('584ac9ae0b09c35439b17447')}
# {u'Id': 8, u'_id': ObjectId('584ac9ae0b09c35439b17448')}
# {u'Id': 10, u'_id': ObjectId('584ac9ae0b09c35439b17449')}
# {u'Id': 9, u'_id': ObjectId('584ac9ae0b09c35439b1744a')}
# {u'Id': 11, u'_id': ObjectId('584ac9ae0b09c35439b1744b')}
# {u'Id': 12, u'_id': ObjectId('584ac9ae0b09c35439b1744c')}
# {u'Id': 16, u'_id': ObjectId('584ac9ae0b09c35439b1744e')}
# {u'Id': 17, u'_id': ObjectId('584ac9ae0b09c35439b1744f')}
# {u'Id': 18, u'_id': ObjectId('584ac9ae0b09c35439b17450')}
# {u'Id': 14, u'_id': ObjectId('584ac9ae0b09c35439b17451')}
# {u'Id': 19, u'_id': ObjectId('584ac9ae0b09c35439b17452')}
# {u'Id': 20, u'_id': ObjectId('584ac9ae0b09c35439b17453')}

# %%
respuestas = posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 40}}},
        {'$lookup': {
            'from': "users", 
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"}
        }
        ])
print_respuestas(respuestas)
# Out:
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Asumiendo que se est\xe1 haciendo un <code>join</code> de columnas sin duplicados, lo cu\xe1l es un caso com\xfan:</p><br/><br/><ul><br/><li><p>Un <strong>inner join</strong> de A y B entregar\xe1 el resultado de la intersecci\xf3n de los conjuntos A y B. En otras lapabras, la parte <em>interna</em> \u2013intersecci\xf3n\u2013 en un diagrama de Venn.</p></li><br/><li><p>Un <strong>full outer join</strong> entre A y B entregar\xe1 el resultado de la uni\xf3n de A y B. En otras palabras, la parte <em>externa</em> \u2013uni\xf3n\u2013 en un diagrama de Venn .</p></li><br/></ul><br/><br/><h1>Ejemplos:</h1><br/><br/><p>Supongamos que tenemos dos tablas, con una sola columna cada una y los siguientes datos:</p><br/><br/><pre><code>A    B<br/>-    -<br/>1    3<br/>2    4<br/>3    5<br/>4    6<br/></code></pre><br/><br/><p>Nota que (1,2) solo se encuentran en A, (3,4) son comunes y (5,6) solamente se encuentran en B.</p><br/><br/><h1>Inner Join</h1><br/><br/><p>Un inner join \u2013utilizando cualquiera de las sintaxis de consulta equivalente\u2013 te entrega la intersecci\xf3n de ambas tablas, es decir, las filas que ambas tablas tienen en com\xfan.</p><br/><br/><pre><code>select * from a INNER JOIN b on a.a = b.b;<br/>select a.*, b.*  from a, b where a.a = b.b;<br/><br/>a | b<br/>--+--<br/>3 | 3<br/>4 | 4<br/></code></pre><br/><br/><h1>Left outer join</h1><br/><br/><p>Un <code>outer join</code> por la izquierda, te dar\xe1 todas las filas de A, incluyendo las filas comunes entre A y B.</p><br/><br/><pre><code>select * from a LEFT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a = b.b(+);<br/><br/>a |  b<br/>--+-----<br/>1 | null<br/>2 | null<br/>3 |    3<br/>4 |    4<br/></code></pre><br/><br/><h1>Right outer join</h1><br/><br/><p>Un <code>outer join</code> por la derecha te dar\xe1 todas las filas de B, incluyendo las filas comunes con A.</p><br/><br/><pre><code>select * from a RIGHT OUTER JOIN b on a.a = b.b;<br/>select a.*,b.*  from a,b where a.a(+) = b.b;<br/><br/>a    |  b<br/>-----+----<br/>3    |  3<br/>4    |  4<br/>null |  5<br/>null |  6<br/></code></pre><br/><br/><h1>Full outer join</h1><br/><br/><p>Un <code>outer join</code> completo (full) te entregar\xe1 la uni\xf3n de A y B; es decir, todas las filas de A y todas las filas de B. Si una fila en A no tiene una fila correspondiente en B, la porci\xf3n de B es null, y vice versa.</p><br/><br/><pre><code>select * from a FULL OUTER JOIN b on a.a = b.b;<br/><br/> a   |  b<br/>-----+-----<br/>   1 | null<br/>   2 | null<br/>   3 |    3<br/>   4 |    4<br/>null |    5<br/>null |    6<br/></code></pre><br/><br/><h1>Diagramas de Venn</h1><br/><br/><p>Esto mismo, podemos verlo con diagramas de Venn:</p><br/><br/><p><img src="https://upload.wikimedia.org/wikipedia/commons/9/9d/SQL_Joins.svg" alt="Explicaci\xf3n visual de joins"><br/>Imagen <a href="https://commons.wikimedia.org/wiki/File:SQL_Joins.svg" rel="nofollow">SQL Joins.svg</a> de <a href="https://commons.wikimedia.org/wiki/User:Arbeck" rel="nofollow">Arbeck</a>, compartida bajo licencia <a href="https://creativecommons.org/licenses/by/3.0/deed.en" rel="nofollow">CC BY 3.0</a>.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 7,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-11-02T17:08:19.893',
#  u'FavoriteCount': u'',
#  u'Id': 40,
#  u'LastActivityDate': u'2016-08-31T13:44:37.070',
#  u'LastEditDate': u'2016-08-31T13:44:37.070',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 21,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 21,
#  u'ParentId': 36,
#  u'PostTypeId': 2,
#  u'Score': 55,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17465'),
#  u'owner': [{u'AboutMe': u'<p>Entrepreneur, software developer and traveler. :)</p><br/><br/><p>\xbfTe gustar\xeda que existiera <strong><a href="http://area51.stackexchange.com/proposals/42810/stackoverflow-in-spanish?referrer=UCvpq888Myc9zlsUrCq6xg2">StackOverflow en Espa\xf1ol</a></strong>? </p><br/><br/><p><strong>Unete</strong> a la <a href="http://area51.stackexchange.com/proposals/42810/stackoverflow-in-spanish?referrer=UCvpq888Myc9zlsUrCq6xg2">propuesta para que exista</a> aqu\xed en Area51.</p><br/>',
#              u'AccountId': 93263,
#              u'Age': 41,
#              u'CreationDate': u'2015-10-29T13:46:46.317',
#              u'DisplayName': u'jachguate',
#              u'DownVotes': 8,
#              u'Id': 21,
#              u'LastAccessDate': u'2016-09-02T22:37:41.520',
#              u'Location': u'Guatemala',
#              u'ProfileImageUrl': u'',
#              u'Reputation': 1814,
#              u'UpVotes': 191,
#              u'Views': 118,
#              u'WebsiteUrl': u'http://jachguate.wordpress.com',
#              u'_id': ObjectId('584ac9b50b09c35439b1ba70')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>El problema viene de la limitaci\xf3n que los ordenadores tienen para representar n\xfameros de <a href="https://es.wikipedia.org/wiki/Coma_flotante">coma flotante</a> usando un n\xfamero finito de bits.</p><br/><br/><p><a href="http://www.exploringbinary.com/why-0-point-1-does-not-exist-in-floating-point">En este art\xedculo en ingl\xe9s</a> hay una muy buena explicaci\xf3n. B\xe1sicamente, para representar el n\xfamero 0.1 en coma flotante necesitamos un n\xfamero infinito de d\xedgitos binarios:</p><br/><br/><p><a href="http://i.stack.imgur.com/e5fNJ.png"><img src="http://i.stack.imgur.com/e5fNJ.png" alt="Dividiendo 1 entre 10 en binario"></a></p><br/><br/><p><em>Dividiendo 1 entre 10 en binario</em></p><br/><br/><p><a href="http://i.stack.imgur.com/rvPPD.png"><img src="http://i.stack.imgur.com/rvPPD.png" alt="1/10 en binario (primeros 1369 d\xedgitos)"></a></p><br/><br/><p><em>1/10 en binario (primeros 1369 d\xedgitos)</em></p><br/><br/><p>Si suponemos que nuestro ordenador es capaz de almacenar hasta 53 d\xedgitos, una vez truncado nuestro 0.1 queda representado en binario como:</p><br/><br/><p>0.0001100110011001100110011001100110011001100110011001101</p><br/><br/><p>...que en decimal es</p><br/><br/><p>0.1000000000000000055511151231257827021181583404541015625</p><br/><br/><p>Para este problema hay b\xe1sicamente dos soluciones:</p><br/><br/><ul><br/><li>Usar un tipo decimal exacto en vez de coma flotante. Hay lenguajes que proporcionan estos tipos nativamente (por ejemplo, .NET tiene el tipo <a href="https://msdn.microsoft.com/en-us/library/364x0z75.aspx">decimal</a>); para los que no, suele haber librer\xedas especializadas para ello (por ejemplo <a href="https://github.com/MikeMcl/decimal.js">decimal.js</a> para Javascript).</li><br/><li>Si el n\xfamero de decimales se conoce por adelantado (por ejemplo al tratar con valores monetarios), los valores se pueden representar como enteros. As\xed, 123.45\u20ac se representar\xeda como 12345 c\xe9ntimos. El punto decimal se a\xf1adir\xeda al final, a la hora de mostrar el valor al usuario.</li><br/></ul><br/><br/><p>Un buen sitio con m\xe1s informaci\xf3n sobre este tema: <a href="http://puntoflotante.org">http://puntoflotante.org</a></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 5,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-02T07:43:50.070',
#  u'FavoriteCount': u'',
#  u'Id': 204,
#  u'LastActivityDate': u'2015-12-02T09:56:34.630',
#  u'LastEditDate': u'2015-12-02T09:56:34.630',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 23,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 23,
#  u'ParentId': 197,
#  u'PostTypeId': 2,
#  u'Score': 58,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b174ea'),
#  u'owner': [{u'AboutMe': u'<p><strong><em>Desarrollador en Stack Overflow</em></strong></p><br/><br/><p>Empecemos por lo importante: me encantan los <a href="http://en.wikipedia.org/wiki/MSX" rel="nofollow">ordenadores MSX</a> y el <a href="https://en.wikipedia.org/wiki/Renault_Twingo#Twingo_I_.281993.E2.80.932007.29" rel="nofollow">Renault Twingo cl\xe1sico</a> (s\xf3lo el modelo 1993-2007; los modelos m\xe1s nuevos son tan aburridos como cualquier otro coche).<br/></p><br/><br/><p>Y ahora la parte aburrida. Soy ingeniero de telecomunicaciones pero trabajo como programador, principalmente en C#. He hecho mucho desarrollo en Windows Forms en el pasado, tambi\xe9n WPF y Silverlight, pero ahora estoy m\xe1s metido en el desarrollo web (al principio s\xf3lo backend, pero ahora estoy en el mundo del frontend tambi\xe9n).<br/></p><br/><br/><p><del>Cuando tengo tiempo libre me gusta</del> Cuando <em>ten\xeda</em> tiempo libre me gustaba programar mi MSX Turbo-R en ensamblador de Z80. De hecho he desarrollado incluso <a href="http://konamiman.com/msx/msx-s.html#inl" rel="nofollow">una pila TCP/IP completa para MSX</a> (<a href="https://bitbucket.org/konamiman/msx/src/cf8fc0cc652e1ff79b1a2fc657b2f10d4e0c72fb/SRC/INL/?at=default" rel="nofollow">las fuentes est\xe1n disponibles</a>, \xa1\xe9chales un ojo!), que present\xe9 como mi proyecto de final de carrera en la universidad, con muy buenos resultados.</p><br/><br/><p>Puedes ver mis proyectos de software aqu\xed:<br/><br/><a href="http://www.konamiman.com" rel="nofollow">http://www.konamiman.com</a><br/><br/><a href="http://bitbucket.org/konamiman" rel="nofollow">http://bitbucket.org/konamiman</a></p><br/><br/><p>Y si quieres puedes escribirme: konamiman@stackoverflow.com</p><br/>',
#              u'AccountId': 3201,
#              u'Age': 42,
#              u'CreationDate': u'2015-10-29T14:53:36.233',
#              u'DisplayName': u'Konamiman',
#              u'DownVotes': 4,
#              u'Id': 23,
#              u'LastAccessDate': u'2016-09-03T16:45:09.773',
#              u'Location': u'Palma de Mallorca, Spain',
#              u'ProfileImageUrl': u'https://i.stack.imgur.com/iqUR6.jpg?s=128&g=1',
#              u'Reputation': 1725,
#              u'UpVotes': 357,
#              u'Views': 234,
#              u'WebsiteUrl': u'http://www.konamiman.com',
#              u'_id': ObjectId('584ac9b50b09c35439b1ba71')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>En <code>Java</code> solo los tipos primitivos (Descritos en el <a href="https://docs.oracle.com/javase/specs/jls/se7/html/jls-4.html#jls-4.2">JLS (\xa74.2)</a>, por ejemplo <code>int</code> o <code>char</code>) se comparan con <code>==</code>, los <code>String</code>s (y los demas objetos) en <code>Java</code> se comparan entre ellos con el metodo <code>equals</code>.</p><br/><br/><p><a href="http://docs.oracle.com/javase/7/docs/api/java/lang/String.html#equals(java.lang.Object)"><code>String#equals(Object)</code></a></p><br/><br/><blockquote><br/>  <p>Compara este <code>String</code> con el objeto especificado. El resultado es <code>true</code> si, y solo si el argumento no es <code>null</code> y es un objeto del tipo <code>String</code> que representa la misma secuencia de caracteres que este objecto.</p><br/></blockquote><br/><br/><hr><br/><br/><ul><br/><li><a href="https://docs.oracle.com/javase/specs/jls/se8/html/jls-15.html#jls-15.21.3">JLS (\xa715.21.3)</a> Si bien puede utilizarse <code>==</code> para comparar referencias de tipo <code>String</code>, una prueba de igualdad <strong>determina si los dos operandos refieren al mismo objeto <code>String</code></strong>. El resultado es <code>false</code> si los operandos son distintos objetos String, incluso si contienen la misma secuencia de caracteres.</li><br/></ul><br/><br/><hr><br/><br/><p>Por lo tanto tu comparacion debe ser:</p><br/><br/><pre><code>if(miNombre.equals(intento)) {<br/></code></pre><br/><br/><p><strong>SALIDA:</strong></p><br/><br/><pre><code>Adivina mi nombre: <br/>manuel<br/>Intentalo de nuevo!<br/>Jordi<br/>Acertaste!<br/></code></pre><br/><br/><p><strong>ACLARACIONES:</strong></p><br/><br/><ul><br/><li><p>He puesto la variable <code>miNombre</code> al principio de la comparaci\xf3n para evitar una <a href="http://docs.oracle.com/javase/7/docs/api/java/lang/NullPointerException.html"><code>NullPointerException</code></a> si <code>intento == null</code>  (si, las comparaciones con <code>null</code> tambien se hacen con <code>==</code>).</p><br/><br/><p><strong>Como extra:</strong> si <code>null</code> es un valor v\xe1lido en la representaci\xf3n (y por tanto queremos evitar una <a href="http://docs.oracle.com/javase/7/docs/api/java/lang/NullPointerException.html"><code>NPE</code></a>), <code>Objects.equals</code> est\xe1 disponible a partir de <code>Java 7</code> y se encarga de devolver true si ambas son <code>null</code> o <code>false</code> si s\xf3lo lo es una. </p></li><br/></ul><br/><br/><p></p><br/><br/><ul><br/><li><p>En este caso se puede usar el metodo <a href="http://docs.oracle.com/javase/7/docs/api/java/lang/String.html#equalsIgnoreCase(java.lang.String)"><code>String#equalsIgnoreCase(Object)</code></a> que ignorara <code>MAYUSCULAS</code> o <code>MINUSCULAS</code> al hacer la comparacion:</p><br/><br/><pre><code>if(miNombre.equalsIgnoreCase(intento)) {       <br/></code></pre></li><br/><li><p><a href="https://docs.oracle.com/javase/specs/jls/se8/html/jls-15.html#jls-15.21">JLS (\xa715.21)</a> Los operadores de igualdad (<code>==</code> y <code>!=</code>) se pueden utilizar para comparar dos operandos que son convertibles (\xa75.1.8) de tipo num\xe9rico, o los dos operandos de tipo <code>boolean</code> o <code>Boolean</code> o dos operandos que <code>></code> son de tipo de referencia o el tipo <code>null</code>. Todos los dem\xe1s casos causan un error en tiempo de compilaci\xf3n.</p></li><br/></ul><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 3,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-02T12:35:37.430',
#  u'FavoriteCount': u'',
#  u'Id': 226,
#  u'LastActivityDate': u'2015-12-16T08:07:07.077',
#  u'LastEditDate': u'2015-12-16T08:07:07.077',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 517,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 517,
#  u'ParentId': 225,
#  u'PostTypeId': 2,
#  u'Score': 44,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b174ff'),
#  u'owner': [{u'AboutMe': u'<p>Beer and programming freak.</p><br/><br/><p><a href="http://www.greenardo.cat" rel="nofollow">http://www.greenardo.cat</a><br><br><br/><a href="http://www.ibeernalia.com" rel="nofollow">http://www.ibeernalia.com</a></p><br/>',
#              u'AccountId': 4763924,
#              u'Age': 35,
#              u'CreationDate': u'2015-12-02T12:07:58.183',
#              u'DisplayName': u'Jordi Castilla',
#              u'DownVotes': 131,
#              u'Id': 517,
#              u'LastAccessDate': u'2016-09-02T05:39:45.730',
#              u'Location': u'Barcelona',
#              u'ProfileImageUrl': u'https://graph.facebook.com/100007829376909/picture?type=large',
#              u'Reputation': 2377,
#              u'UpVotes': 378,
#              u'Views': 129,
#              u'WebsiteUrl': u'http://www.ibeernalia.com',
#              u'_id': ObjectId('584ac9b50b09c35439b1bc33')}]}

# %%
respuestas = posts.aggregate( [
        {'$match': { 'Score' : {'$gte': 40}}},
        {'$lookup': {
            'from': "users",
            'localField': "OwnerUserId",
            'foreignField': "Id",
            'as': "owner"}
        },
        { '$project' :
        {
            'Id' : True,
            'Score' : True,
            'username' : {'$arrayElemAt' : ['$owner.DisplayName', 0]},
            'owner.DisplayName'  : True
        }}
        ])
print_respuestas(respuestas)
# Out:
# {u'Id': 40,
#  u'Score': 55,
#  u'_id': ObjectId('584ac9ae0b09c35439b17465'),
#  u'owner': [{u'DisplayName': u'jachguate'}],
#  u'username': u'jachguate'}
# {u'Id': 204,
#  u'Score': 58,
#  u'_id': ObjectId('584ac9ae0b09c35439b174ea'),
#  u'owner': [{u'DisplayName': u'Konamiman'}],
#  u'username': u'Konamiman'}
# {u'Id': 226,
#  u'Score': 44,
#  u'_id': ObjectId('584ac9ae0b09c35439b174ff'),
#  u'owner': [{u'DisplayName': u'Jordi Castilla'}],
#  u'username': u'Jordi Castilla'}

# %% [markdown]
# ## EJERCICIO: Construir, con el API de agregación, una colección 'post_comments', donde se añade el campo 'Comments' a cada Post con la lista de todos los comentarios referidos a un Post.

# %%
posts_comments = posts.aggregate( [
        {'$limit': 20},
        {'$lookup': {
            'from': "comments", 
            'localField': "Id",
            'foreignField': "PostId",
            'as': "comments"}
        }
        ])
print_respuestas(posts_comments)
# Out:
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>He encontrado la soluci\xf3n.</p><br/><br/><p>Resulta que las rutas tienen asignada una <strong>precedencia</strong> num\xe9rica asignada, que el motor de enrutamiento de WebApi usa para decidir qu\xe9 ruta usar en caso de conflicto. Las rutas creadas autom\xe1ticamente para una misma acci\xf3n siempre tienen una precedencia distinta, \xa1pero la ruta que yo estaba creando manualmente ten\xeda la misma precedencia que la ya existente!</p><br/><br/><p>As\xed pues la soluci\xf3n es a\xf1adir lo siguiente a <code>GetActionDirectRoutes</code>, inmediatamente despu\xe9s de <code>new RouteEntry</code>:</p><br/><br/><pre><code>entry.Route.DataTokens["precedence"] = <br/>    ((decimal)route.Route.DataTokens["precedence"]) - 0.1M;<br/></code></pre><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-29T19:14:23.673',
#  u'FavoriteCount': u'',
#  u'Id': 2,
#  u'LastActivityDate': u'2015-10-29T19:14:23.673',
#  u'LastEditDate': u'',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': u'',
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 23,
#  u'ParentId': 1,
#  u'PostTypeId': 2,
#  u'Score': 7,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17442'),
#  u'comments': [{u'CreationDate': u'2015-10-29T19:14:50.617',
#                 u'Id': 3,
#                 u'PostId': 2,
#                 u'Score': 0,
#                 u'Text': u'...y aqu\xed tenemos nuestra primera respuesta. :-)',
#                 u'UserDisplayName': u'',
#                 u'UserId': 23,
#                 u'_id': ObjectId('584ac9b90b09c35439b283de')}]}
# {u'AcceptedAnswerId': 9,
#  u'AnswerCount': 3,
#  u'Body': u"<p>Luego de ver cierto c\xf3digo, me he dado cuenta que utilizan este estilo:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').Text;<br/></code></pre><br/><br/><p>Parece trabajar bien, pero yo hab\xeda utilizado hasta ahora:</p><br/><br/><pre><code>aStr:=tblAcct.FieldByName('Name').AsString;<br/></code></pre><br/><br/><p>He utilizado ambos al cargar un TMemo y no parece haber diferencia alguna.</p><br/><br/><pre><code>aMemo.Lines.Text:=tblAcct.FieldByName('History').Text;<br/>aMemo.Lines.Text:=tblAcct.FieldByName('History').AsString;<br/></code></pre><br/><br/><p>\xbfHay alguna raz\xf3n por la que deba utilizar una y no la otra? \xbfCu\xe1l es esa raz\xf3n?</p><br/><br/><p>Normalmente, para un memo, utilizo:</p><br/><br/><pre><code>aMemo.Lines.Assign(tblAcct.FieldByName('History'))<br/></code></pre><br/><br/><p>Y esto trabaja bien tambi\xe9n.</p><br/>",
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-29T23:54:31.947',
#  u'FavoriteCount': u'',
#  u'Id': 3,
#  u'LastActivityDate': u'2015-12-18T20:19:25.133',
#  u'LastEditDate': u'2015-12-03T16:24:56.370',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 20,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 21,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 7,
#  u'Tags': u'<delphi>',
#  u'Title': u'\xbfEs igual utilizar .AsString que .Text para obtener el valor de un campo de un DataSet?',
#  u'ViewCount': 142,
#  u'_id': ObjectId('584ac9ae0b09c35439b17443'),
#  u'comments': [{u'CreationDate': u'2015-10-30T07:08:56.507',
#                 u'Id': 4,
#                 u'PostId': 3,
#                 u'Score': 0,
#                 u'Text': u'Ante dos alternativas iguales para hacer lo mismo, utiliza siempre la m\xe1s legible.',
#                 u'UserDisplayName': u'',
#                 u'UserId': 23,
#                 u'_id': ObjectId('584ac9b90b09c35439b283df')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': 6,
#  u'Body': u'<p>Cu\xe1l es la forma m\xe1s eficiente de separar un string en <code>c++</code> como el que se muestra en el c\xf3digo, el cual contiene espacios entre las palabras, este es el m\xe9todo que yo estoy usando actualmente.</p><br/><br/><pre><code>#include <iostream><br/>#include <sstream><br/><br/>int main(int argc, char** argv){<br/><br/>    std::string str("Texto para dividir");<br/>    std::istringstream isstream(str);<br/><br/>    while(!isstream.eof()){<br/><br/>        std::string tempStr;<br/><br/>        isstream >> tempStr;<br/><br/>        std::cout << tempStr << std::endl;<br/>    }<br/><br/>    return 0;<br/>}<br/></code></pre><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 5,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T01:15:27.267',
#  u'FavoriteCount': u'',
#  u'Id': 5,
#  u'LastActivityDate': u'2016-01-14T22:50:57.000',
#  u'LastEditDate': u'2015-12-14T00:58:59.270',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 25,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 11,
#  u'Tags': u'<c++><string>',
#  u'Title': u"\xbfC\xf3mo separar las palabras que contiene un string en C++? ' Split '",
#  u'ViewCount': 1209,
#  u'_id': ObjectId('584ac9ae0b09c35439b17444'),
#  u'comments': [{u'CreationDate': u'2015-10-30T14:03:12.927',
#                 u'Id': 5,
#                 u'PostId': 5,
#                 u'Score': 1,
#                 u'Text': u'Creo que no se puede preguntar por lo m\xe1s elegante, ya que esto usualmente es subjetivo.',
#                 u'UserDisplayName': u'',
#                 u'UserId': 21,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e0')},
#                {u'CreationDate': u'2015-12-02T11:55:06.800',
#                 u'Id': 242,
#                 u'PostId': 5,
#                 u'Score': 1,
#                 u'Text': u'Angel, yo sugeriria que edites la palabra "elegante" de tu pregunta porque no se corresponde con las reglas de los sitios de SE. Elegante como dice @jachguate es subjetivo y por ende preguntas enfocandose en ese aspecto deber\xedan ser cerradas como "primarily opinion based" o "se basa principalmente en opiniones"',
#                 u'UserDisplayName': u'',
#                 u'UserId': 92,
#                 u'_id': ObjectId('584ac9b90b09c35439b2848d')},
#                {u'CreationDate': u'2015-12-02T17:09:52.673',
#                 u'Id': 351,
#                 u'PostId': 5,
#                 u'Score': 0,
#                 u'Text': u'@Dzyann lo tendre en cuenta para futuras pregunta ahora no creo que sea bueno pues hay preguntas que hacen referencia a eso saludos',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b284dd')},
#                {u'CreationDate': u'2015-12-04T18:51:28.980',
#                 u'Id': 824,
#                 u'PostId': 5,
#                 u'Score': 1,
#                 u'Text': u'Voto para cerrar porque esto de "elegancia" es basado en la opini\xf3n de cada qui\xe9n.',
#                 u'UserDisplayName': u'',
#                 u'UserId': 670,
#                 u'_id': ObjectId('584ac9b90b09c35439b2861d')},
#                {u'CreationDate': u'2015-12-10T16:34:36.243',
#                 u'Id': 1477,
#                 u'PostId': 5,
#                 u'Score': 2,
#                 u'Text': u'Cuidado con usar espacios para separar palabras, hay varios idiomas (como chino) que no usan espacios. Incluso en idiomas con caracteres latinos hay palabras como parlez-vous francais? en el que no se usa el espacio como separador. ICU tiene una libreria genial para todos los casos. http://userguide.icu-project.org/boundaryanalysis',
#                 u'UserDisplayName': u'',
#                 u'UserId': 718,
#                 u'_id': ObjectId('584ac9b90b09c35439b287e8')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'C ++ es un lenguaje de programaci\xf3n de prop\xf3sito general de nivel intermedio basado en C. Use esta etiqueta para preguntas acerca de c\xf3digo para ser compilado con el compilador de C ++.',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T16:53:47.187',
#  u'FavoriteCount': u'',
#  u'Id': 15,
#  u'LastActivityDate': u'2015-12-05T20:51:37.347',
#  u'LastEditDate': u'2015-12-05T20:51:37.347',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 24,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 4,
#  u'Score': 0,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1744d'),
#  u'comments': []}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-12-02T10:31:43.837',
#  u'FavoriteCount': u'',
#  u'Id': 219,
#  u'LastActivityDate': u'2015-12-02T10:31:43.837',
#  u'LastEditDate': u'2015-12-02T10:31:43.837',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': -1,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': -1,
#  u'ParentId': u'',
#  u'PostTypeId': 4,
#  u'Score': 0,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b174f8'),
#  u'comments': []}
# {u'AcceptedAnswerId': 2,
#  u'AnswerCount': 1,
#  u'Body': u'<p>Estoy creando un servicio usando ASP.NET WebApi. Quiero a\xf1adir soporte para negociaci\xf3n del tipo de contenido basado en extensiones en el URI, as\xed que he a\xf1adido lo siguiente al c\xf3digo de inicializaci\xf3n del servicio:</p><br/><br/><pre><code>public static class WebApiConfig<br/>{<br/>  public static void Register(HttpConfiguration config)<br/>  {<br/>    config.Formatters.JsonFormatter.AddUriPathExtensionMapping("json", "application/json");<br/>    config.Formatters.XmlFormatter.AddUriPathExtensionMapping("xml", "application/xml");<br/>  }<br/>}<br/></code></pre><br/><br/><p>Para que esto funcione necesito crear dos rutas para cada acci\xf3n del controlador (estoy usando exclusivamente enrutamiento basado en atributos):</p><br/><br/><pre><code>[Route("item/{id}/details")]<br/>[Route("item/{id}/details.{ext}")]<br/>[HttpGet]<br/>public ItemDetail[] GetItemDetails(int id)<br/>{<br/>  return itemsService.GetItemDetails(id);<br/>}<br/><br/>[Route("item/{name}")]<br/>[Route("item/{name}.{ext}")]<br/>[HttpPost]<br/>public int CreateItem(string name)<br/>{<br/>  return itemsService.Create(name);<br/>}<br/></code></pre><br/><br/><p>Esto queda feo y hace que el c\xf3digo sea innecesariamente largo, as\xed que investigu\xe9 una forma de a\xf1adir la ruta con la extensi\xf3n autom\xe1ticamente cuando se crea la ruta normal. Como resultado desarroll\xe9 una implementaci\xf3n personalizada de <code>IDirectRouteProvider</code> que puedo usar al registrar los atributos de ruta:</p><br/><br/><pre><code>config.MapHttpAttributeRoutes(new AutomaticExtensionRouteProvider());<br/></code></pre><br/><br/><p>El c\xf3digo del proveedor personalizado es:</p><br/><br/><pre><code>public class AutomaticExtensionRouteProvider : DefaultDirectRouteProvider<br/>{<br/>    protected override IReadOnlyList<RouteEntry> GetActionDirectRoutes(<br/>      HttpActionDescriptor actionDescriptor,<br/>      IReadOnlyList<IDirectRouteFactory> factories,<br/>      IInlineConstraintResolver constraintResolver)<br/>    {<br/>        var result = base.GetActionDirectRoutes(actionDescriptor, factories, constraintResolver);<br/>        var list = new List<RouteEntry>(result);<br/>        foreach(var route in result.Where(r => !r.Route.RouteTemplate.EndsWith(".{ext}")))<br/>        {<br/>            var newTemplate = route.Route.RouteTemplate + ".{ext}";<br/>            if (!result.Any(r => r.Route.RouteTemplate == newTemplate))<br/>            {<br/>                var entry = new RouteEntry(null, new HttpRoute(newTemplate,<br/>                    new HttpRouteValueDictionary(route.Route.Defaults),<br/>                    new HttpRouteValueDictionary(route.Route.Constraints),<br/>                    new HttpRouteValueDictionary(route.Route.DataTokens)));<br/>                list.Add(entry);<br/>            }<br/>        }<br/>        return list.AsReadOnly();<br/>    }<br/>}<br/></code></pre><br/><br/><p>El problema es que esto funciona bien... pero falla en un caso: <strong>cuando la \xfaltima parte de la ruta es un par\xe1metro sin restricciones</strong>. As\xed pues, en el ejemplo anterior la creaci\xf3n de rutas para <code>GetItemDetails</code> funciona, pero para <code>CreateItem</code> lanza lo siguiente:</p><br/><br/><pre><code>System.InvalidOperationException: Multiple actions were found that match the request: <br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>CreateItem on type FooBar.Api.Controllers.ItemsController<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.ActionSelectorCacheItem.SelectAction(HttpControllerContext controllerContext)<br/>   at System.Web.Http.Controllers.ApiControllerActionSelector.SelectAction(HttpControllerContext controllerContext)<br/></code></pre><br/><br/><p>Me imagino de d\xf3nde puede venir el problema: una cadena arbitraria cumple los patrones <code>{name}</code> y <code>{name}.{ext}</code>, por lo que el motor de WebApi se atraganta al intentar seleccionar la ruta adecua ...
#  u'ClosedDate': u'',
#  u'CommentCount': 2,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-29T15:56:52.933',
#  u'FavoriteCount': u'',
#  u'Id': 1,
#  u'LastActivityDate': u'2015-11-02T17:02:47.503',
#  u'LastEditDate': u'2015-11-02T17:02:47.503',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 21,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 23,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 6,
#  u'Tags': u'<.net><asp.net-web-api><asp.net>',
#  u'Title': u'La creaci\xf3n manual de un alias de ruta con un DirectRouteProvider personalizado causa un error "Multiple actions were found that match the request"',
#  u'ViewCount': 102,
#  u'_id': ObjectId('584ac9ae0b09c35439b17441'),
#  u'comments': [{u'CreationDate': u'2015-10-29T16:31:36.090',
#                 u'Id': 1,
#                 u'PostId': 1,
#                 u'Score': 0,
#                 u'Text': u'M\xe1s tarde a\xf1adir\xe9 la respuesta, pero si alguien quiere hacer los honores antes...',
#                 u'UserDisplayName': u'',
#                 u'UserId': 23,
#                 u'_id': ObjectId('584ac9b90b09c35439b283dc')},
#                {u'CreationDate': u'2015-10-29T18:03:06.780',
#                 u'Id': 2,
#                 u'PostId': 1,
#                 u'Score': 1,
#                 u'Text': u'\xa1Excelente! Nuestra primera pregunta. :)',
#                 u'UserDisplayName': u'',
#                 u'UserId': 4,
#                 u'_id': ObjectId('584ac9b90b09c35439b283dd')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': 2,
#  u'Body': u'<p>\xbfC\xf3mo estar seguro o qu\xe9 pautas seguir a la hora de usar los moldes expl\xedcitos  en <code>C++</code>?</p><br/><br/><p>Por lo que entiendo al usar los <code>moldes</code> le estamos pidiendo al compilador que pase de la comprobaci\xf3n de tipos, y eso no creo que sea muy bueno si uno no sabe exactamente qu\xe9 molde usar. Por eso quer\xeda saber qu\xe9 gu\xedas usan o cosas a tener en cuenta para decidirse por un tipo de molde u otro a la hora de modelar los datos, para determinadas situaciones, y as\xed saber cu\xe1ndo es seguro usar uno u otro.</p><br/><br/><ol><br/><li><code>const_cast</code></li><br/><li><code>static_cast</code></li><br/><li><code>dynamic_cast</code></li><br/><li><code>reinterpret_cast</code></li><br/></ol><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 8,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T01:36:21.210',
#  u'FavoriteCount': u'',
#  u'Id': 6,
#  u'LastActivityDate': u'2015-12-14T01:05:54.117',
#  u'LastEditDate': u'2015-12-14T01:05:54.117',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 100,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 3,
#  u'Tags': u'<c++><casting>',
#  u'Title': u'\xbfCu\xe1ndo usar y es seguro emplear const_cast, static_cast, dynamic_cast, reinterpret_cast?',
#  u'ViewCount': 181,
#  u'_id': ObjectId('584ac9ae0b09c35439b17445'),
#  u'comments': [{u'CreationDate': u'2015-12-02T12:27:45.953',
#                 u'Id': 247,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'Si vas a copiar una pregunta de SO por favor agrega una referencia a la original [When should static_cast, dynamic_cast, const_cast and reinterpret_cast be used?](http://stackoverflow.com/a/332086/4574)',
#                 u'UserDisplayName': u'',
#                 u'UserId': 92,
#                 u'_id': ObjectId('584ac9b90b09c35439b28492')},
#                {u'CreationDate': u'2015-12-02T16:05:32.273',
#                 u'Id': 312,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'la pregunta no es una copia, como muchas que eh visto ultimamente, si es cierto que mirando el link que pones, puede parecerlo pero no lo es, por otro lado si te refieres por lo que se esta haciendo estos dias fijate que la respuesta no es mia, por otro lado esta fue de las primeras preguntas del sitio y era para testear espero aclarar tu insinuaci\xf3n saludos',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b284c2')},
#                {u'CreationDate': u'2015-12-02T20:10:05.240',
#                 u'Id': 407,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'Yo no he insinuado nada, simplemente aclare que si vas a copiar, pongas la referencia. Clara y concisamente, no se a que te referies con insinuacion.',
#                 u'UserDisplayName': u'',
#                 u'UserId': 92,
#                 u'_id': ObjectId('584ac9b90b09c35439b284fb')},
#                {u'CreationDate': u'2015-12-02T20:15:38.427',
#                 u'Id': 411,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'Angel, exacto, dije si vas a copiar, porque no se si es copia o no, y vos aclaras que no es copia. Igual, una pregunta tan basica mas que seguro que ya existia en SO. Tengo entendido que estos posts estan antes de que la beta se haya abierto para mas personas?',
#                 u'UserDisplayName': u'',
#                 u'UserId': 92,
#                 u'_id': ObjectId('584ac9b90b09c35439b284fd')},
#                {u'CreationDate': u'2015-12-02T20:13:22.607',
#                 u'Id': 409,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'quizas lo interprete mas pero usted dijo -> Si vas a copiar una pregunta de SO por favor agrega..... y yo aclaro que esto no es una copia',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b284fe')},
#                {u'CreationDate': u'2015-12-02T20:21:26.597',
#                 u'Id': 415,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'ahora te entiendo pero, ponte en mi lugar yo leo tu primer comentario, y parece que mes lo esta diciendo de forma afirmativa. Que no hay mal rollo por mi parte quizas fuera que se mal interpretaron los comentarios, tambien puede que influyera el tema que estoy viendo estos dia que se estan copiando y auto respondiendo en cuestion de segundo y me lo tome por ese lado pues esa practica yo no la comparto, y quizas por eso me tome tu comentario como acusacion, pues si te pones en mi lugar y lees eso creo que es comprensible que crea que me lo estas insinuando',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b28500')},
#                {u'CreationDate': u'2015-12-02T20:22:49.967',
#                 u'Id': 417,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'si este post es de hace un mes o mas',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b28501')},
#                {u'CreationDate': u'2015-12-02T20:42:56.333',
#                 u'Id': 420,
#                 u'PostId': 6,
#                 u'Score': 0,
#                 u'Text': u'Respecto a eso, he posteado una pregunta aqui [Paremos el acaparamiento de puntos](http://meta.es.stackoverflow.com/questions/103/paremos-el-acaparamiento-de-puntos)',
#                 u'UserDisplayName': u'',
#                 u'UserId': 92,
#                 u'_id': ObjectId('584ac9b90b09c35439b28502')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p><code>.AsString</code> devuelve el mismo "<em>string</em>" que la propiedad <code>.Text</code> si no existe ning\xfan controlador de eventos "Event Handler", <code>OnGetText</code>, pero de existir uno puede darse el caso de ser diferente, o quiz\xe1s un descendiente en <code>TField</code> que no sea el est\xe1ndar podr\xeda ocasionar que fuera diferente.</p><br/><br/><p>Saludos y espero ayude.</p><br/><br/><p>P.D: Sobre si hay una raz\xf3n para usar una u otra no sabr\xeda decirle con total certeza eso depender\xeda del uso que tenga previsto para el valor de retorno.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T00:45:47.640',
#  u'FavoriteCount': u'',
#  u'Id': 4,
#  u'LastActivityDate': u'2015-12-14T00:58:15.613',
#  u'LastEditDate': u'2015-12-14T00:58:15.613',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 25,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': 3,
#  u'PostTypeId': 2,
#  u'Score': 2,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17446'),
#  u'comments': []}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Lo de elegancia es algo dif\xedcil de decir, es cuesti\xf3n de gustos. Pero la legibilidad del c\xf3digo siempre es importante. Por eso, este c\xf3digo se puede simplificar as\xed: (a mi me parece mas legible)</p><br/><br/><pre><code>std::string tempStr;<br/>while(isstream >> tempStr) {<br/>    std::cout << tempStr << std::endl;<br/>}<br/></code></pre><br/><br/><p>Con lo cual, metiendo todo en una funci\xf3n quedar\xeda algo as\xed:</p><br/><br/><pre><code>std::vector<std::string> split_istringstream(std::string str) {<br/>    std::vector<std::string> resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(isstream >> palabra){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Otra alternativa, que incluso permite definir el delimitador (el operador >> de <code>istringstream</code> solo divide la cadena por los espacios - ASCII 32) es utilizar <a href="http://es.cppreference.com/w/cpp/string/basic_string/getline">std::getline</a>. </p><br/><br/><pre><code>std::vector<std::string> split_getline(std::string str, char delim) {<br/>    std::vector<std::string> resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(std::getline(isstream, palabra, delim)){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Aqu\xed abajo te dejo una comparativa entre ambas opciones, son pr\xe1cticamente iguales en eficiencia, dejando de un lado los vectores, reservan pr\xe1cticamente la misma memoria.</p><br/><br/><p><a href="http://cpp.sh/3jtw">http://cpp.sh/3jtw</a></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T05:30:50.993',
#  u'FavoriteCount': u'',
#  u'Id': 7,
#  u'LastActivityDate': u'2015-10-30T05:30:50.993',
#  u'LastEditDate': u'',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': u'',
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 25,
#  u'ParentId': 5,
#  u'PostTypeId': 2,
#  u'Score': 11,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17447'),
#  u'comments': []}
# {u'AcceptedAnswerId': 442,
#  u'AnswerCount': 1,
#  u'Body': u'<p>Para un proyecto web en el que estoy participando usamos el componente <a href="http://angular-ui.github.io/angular-google-maps" rel="nofollow">Angular Google Maps</a>. Este es el c\xf3digo <code>JavaScript</code> que hace referencia al componente y lo inicializa:</p><br/><br/><pre><code>var configureGoogleMaps = function(uiGmapGoogleMapApiProvider) {<br/>    uiGmapGoogleMapApiProvider.configure({<br/>        libraries: \'geometry,visualization\'<br/>    });<br/>}<br/>configureGoogleMaps.$inject = [\'uiGmapGoogleMapApiProvider\'];<br/><br/>angular<br/>    .module(\'shTools.Map\', [\'uiGmapgoogle-maps\'])<br/>    .directive(\'map\', mapDirective)<br/>    .config(configureGoogleMaps);<br/></code></pre><br/><br/><p>donde <code>mapDirective</code> define un elemento HTML que contiene el componente de Google Maps.</p><br/><br/><p>Esto est\xe1 funcionando como se espera. El problema es que cuando ejecuto un simple test usando <code>Jasmine</code> con <code>Karma</code>, obtengo el error <code>Unknown provider: uiGmapGoogleMapApiProvider</code>. Por alguna raz\xf3n no est\xe1 siendo capaz de encontrar el proveedor.</p><br/><br/><p>He intentado crear un <code>mock</code> para forzar la creaci\xf3n de un proveedor con ese nombre, pero no ha funcionado:</p><br/><br/><pre><code>angular.module(\'uiGmapgoogle-maps\', [])<br/>    .value(\'uiGmapGoogleMapApiProvider\', {<br/>        configure: function() {}<br/>    });<br/></code></pre><br/><br/><p>\xbfQu\xe9 podr\xeda estar pasando aqu\xed?</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T10:26:44.223',
#  u'FavoriteCount': 1,
#  u'Id': 8,
#  u'LastActivityDate': u'2016-01-16T04:02:40.000',
#  u'LastEditDate': u'2015-12-03T15:38:34.307',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 95,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 23,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 6,
#  u'Tags': u'<google-maps><angularjs><jasmine><karma-jasmine>',
#  u'Title': u'"Unknown provider: uiGmapGoogleMapApiProvider" al probar con Jasmine c\xf3digo que usa el componente de Google Maps para AngularJS',
#  u'ViewCount': 149,
#  u'_id': ObjectId('584ac9ae0b09c35439b17448'),
#  u'comments': [{u'CreationDate': u'2015-12-01T17:02:33.213',
#                 u'Id': 61,
#                 u'PostId': 8,
#                 u'Score': 0,
#                 u'Text': u"Quiz\xe1s olvidaste incluir el js en la configuraci\xf3n de karma (karma.config.js)? Ej:    files: [<br/>      '../bower_components/angular/angular.js',<br/>      '../bower_components/angular-mocks/angular-mocks.js',<br/>      '../src/*.js',<br/>      './*.js'<br/>    ],",
#                 u'UserDisplayName': u'',
#                 u'UserId': 114,
#                 u'_id': ObjectId('584ac9b90b09c35439b283fd')}]}
# {u'AcceptedAnswerId': 11,
#  u'AnswerCount': 1,
#  u'Body': u'<p>Dado el siguiente c\xf3digo en TypeScript</p><br/><br/><pre><code>class Persona {<br/>    constructor(public nombre: string, public apellido: string) {<br/>    }<br/><br/>    nombreCompleto1 = () => {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/><br/>    nombreCompleto2() {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/>}<br/><br/>var p = new Persona("Juan", "P\xe9rez");<br/><br/>console.log(p.nombreCompleto1());<br/>console.log(p.nombreCompleto2());<br/></code></pre><br/><br/><p>Como se puede ver los m\xe9todos <code>nombreCompleto1</code> y <code>nombreCompleto2</code> hacen lo mismo pero est\xe1n declarados ligeramente diferente.</p><br/><br/><p>Al ejecutarlo en los dos casos se obtiene el resultado esperado:</p><br/><br/><pre><br/>Juan P\xe9rez<br/>Juan P\xe9rez<br/></pre><br/><br/><p>\xbfCu\xe1l es la diferencia entre las dos declaraciones si los dos hacen los mismo y cu\xe1l es la forma adecuada de declararlo?</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 2,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T14:33:50.523',
#  u'FavoriteCount': 1,
#  u'Id': 10,
#  u'LastActivityDate': u'2015-12-14T01:05:34.960',
#  u'LastEditDate': u'2015-12-09T18:18:51.863',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 342,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 20,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 7,
#  u'Tags': u'<typescript>',
#  u'Title': u'\xbfC\xf3mo definir m\xe9todos correctamente en TypeScript?',
#  u'ViewCount': 159,
#  u'_id': ObjectId('584ac9ae0b09c35439b17449'),
#  u'comments': [{u'CreationDate': u'2015-12-06T05:47:50.147',
#                 u'Id': 998,
#                 u'PostId': 10,
#                 u'Score': 0,
#                 u'Text': u'Y ahora porque el voto en contra?',
#                 u'UserDisplayName': u'',
#                 u'UserId': 20,
#                 u'_id': ObjectId('584ac9b90b09c35439b28681')},
#                {u'CreationDate': u'2015-12-09T18:50:57.613',
#                 u'Id': 1407,
#                 u'PostId': 10,
#                 u'Score': 0,
#                 u'Text': u'Seguro alguien quer\xeda su medallita de C\xedtrico',
#                 u'UserDisplayName': u'',
#                 u'UserId': 100,
#                 u'_id': ObjectId('584ac9b90b09c35439b287a9')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Antes de responder directamente la respuesta, hablaremos de las propiedades relevantes de TField y sus descendientes.</p><br/><br/><h1><code>Text</code>/<code>DisplayText</code></h1><br/><br/><p>Ambas propiedades sirven para obtener una representaci\xf3n textual del valor del campo para su uso en la Interfaz de Usuario. <br/>El prop\xf3sito de la propiedad <code>Text</code> es el de obtener una representaci\xf3n textual del campo cu\xe1ndo est\xe1 siendo editado en un control asociado a datos (Data Aware), en contraste con la propiedad <code>DisplayText</code> que proporciona el valor del campo con formato de visualizaci\xf3n para el usuario, por ejemplo, puede contener caracteres de puntuaci\xf3n u otra decoraci\xf3n al valor plano. (1234.50 en contraste con 1,234.50).</p><br/><br/><p>En otras palabras, un <code>TdbEdit</code> o controles similares, mostrar\xe1n el valor de <code>DisplayText</code> cu\xe1ndo no est\xe1n siendo editados, y al recibir el foco, cambiar\xe1n el valor al de la propiedad <code>Text</code> y es este valor el que el usuario "edita". Un TdbLabel solamente tira de la propiedad <code>DisplayText</code>, ya que no es editable.</p><br/><br/><p>La documentaci\xf3n para <code>Text</code> dice:</p><br/><br/><blockquote><br/>  <p>Contains the string to display in a data-aware control when the field is in edit mode</p><br/></blockquote><br/><br/><p>Un ejemplo t\xedpico es un <code>TFloatField</code> con la propiedad <code>Currency</code> establecida a <code>True</code>. La propiedad DisplayText te devuelve el string con el n\xfamero conteniendo separadores de miles, el separador decimal y el s\xedmbolo de la moneda. La propiedad Text, te devuelve una cadena que no contiene separadores de miles ni s\xedmbolo de moneda.</p><br/><br/><pre><code>begin<br/>  MyFloatField.Currency := True;<br/>  MyFloatField.AsFloat := 1234.56;<br/>  A := MyFloatField.Text; //\'1234.56\'<br/>  B := MyFloatField.DisplayText; //\'$1,234.56\', depends on your locale<br/>  ShowMessage(A + #13 + B);<br/>end;<br/></code></pre><br/><br/><p>El comportamiento de ambas propiedades puede ser personalizado escribiendo un manejador de eventos para <code>OnGetText</code>, d\xf3nde se puede escribir la l\xf3gica para convertir el valor del campo en una de ambas representaciones textuales. El par\xe1metro booleano <code>DisplayText</code> indica si la cadena solicitada es para representar el valor en la interfaz de usuario o para edici\xf3n. </p><br/><br/><p>De esta manera, podemos lograr que la representaci\xf3n en la interfaz de usuario para un campo entero con valor 1 sea \'uno\', y su valor para edici\xf3n sea \'one\'</p><br/><br/><h1><code>AsString</code></h1><br/><br/><p>Por otro lado, la propiedad AsString utiliza una conversi\xf3n plana entre el tipo de dato base del campo y una cadena de caracteres. Cada descendiente de <code>TField</code> implementa el m\xe9todo virtual <code>GetAsString</code> que t\xedpicamente utiliza funciones de la RTL para realizar la conversi\xf3n. Siguiendo con el ejemplo de TFloatField, esta clase llama a la funci\xf3n FloatToStr() para realizar la conversi\xf3n.</p><br/><br/><h1>La respuesta</h1><br/><br/><p>Dicho todo esto, la respuesta a la pregunta ser\xeda:</p><br/><br/><p>AsString retorna usualmente el mismo valor que retorna la propiedad Text, siempre que no haya un manejador de evento para OnGetText, pero la representaci\xf3n podr\xeda ser diferente si hubiese un manejador de evento o un descendiente no est\xe1ndar de TField.</p><br/><br/><p>Con la informaci\xf3n dada, no puede decirse cu\xe1l es m\xe1s apropiado, ya que esto depende de cu\xe1l es el uso que se le dar\xe1 al valor retornado. Si se est\xe1 utilizando para mostrar valores en la Interfaz de usuario, como se muestra en los ejemplos de c\xf3digo proporcionados, mi consejo es que utilices la propiedad <code>DisplayText</code>.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T13:59:47.113',
#  u'FavoriteCount': u'',
#  u'Id': 9,
#  u'LastActivityDate': u'2015-10-30T13:59:47.113',
#  u'LastEditDate': u'',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': u'',
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 21,
#  u'ParentId': 3,
#  u'PostTypeId': 2,
#  u'Score': 5,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1744a'),
#  u'comments': [{u'CreationDate': u'2015-10-30T14:54:20.307',
#                 u'Id': 6,
#                 u'PostId': 9,
#                 u'Score': 1,
#                 u'Text': u'guau creo que esta es muy buena respuesta',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e1')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>En el primer caso:</p><br/><br/><pre><code>nombreCompleto1 = () => {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>est\xe1s creando un <em>m\xe9todo de instancia</em>, es equivalente a ejecutar <code>this.nombreCompleto1 = function() {...}</code> en JavaScript.</p><br/><br/><p>En el segundo caso:</p><br/><br/><pre><code>nombreCompleto2() {<br/>    return this.nombre + " " + this.apellido;<br/>}<br/></code></pre><br/><br/><p>est\xe1s creando un <em>m\xe9todo de prototipo</em>, es equivalente a <code>Persona.prototype.nombreCompleto2 = function() {...}</code> en JavaScript.</p><br/><br/><p>En general es preferible crear m\xe9todos de prototipo: en tal caso el m\xe9todo se define una sola vez, mientras que los m\xe9todos de instancia se crean una vez por instancia, consumiendo m\xe1s memoria.</p><br/><br/><p>M\xe1s informaci\xf3n: <a href="http://www.johnpapa.net/typescriptpost3" rel="nofollow">TypeScript Classes and Interfaces</a></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 2,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T14:43:43.737',
#  u'FavoriteCount': u'',
#  u'Id': 11,
#  u'LastActivityDate': u'2015-12-14T01:05:34.960',
#  u'LastEditDate': u'2015-12-14T01:05:34.960',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 25,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 23,
#  u'ParentId': 10,
#  u'PostTypeId': 2,
#  u'Score': 10,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1744b'),
#  u'comments': [{u'CreationDate': u'2015-11-01T21:47:24.230',
#                 u'Id': 15,
#                 u'PostId': 11,
#                 u'Score': 1,
#                 u'Text': u'Y cu\xe1l de los dos es el recomendable y porque?... (para completar la respuesta)',
#                 u'UserDisplayName': u'',
#                 u'UserId': 20,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e4')},
#                {u'CreationDate': u'2015-11-02T08:25:12.210',
#                 u'Id': 17,
#                 u'PostId': 11,
#                 u'Score': 1,
#                 u'Text': u'Cierto. \xa1A\xf1adido!',
#                 u'UserDisplayName': u'',
#                 u'UserId': 23,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e6')}]}
# {u'AcceptedAnswerId': 18,
#  u'AnswerCount': 2,
#  u'Body': u'<p>Hoy, en mi trabajo, escrib\xed algo as\xed, en Perl:</p><br/><br/><pre><code>my @x = qw( 1 2 3 4 5 );<br/>splice(@x, 10);<br/></code></pre><br/><br/><p>y produjo el error:</p><br/><br/><blockquote><br/>  <p>splice() offset past end of array at ./x line X.</p><br/></blockquote><br/><br/><p>Pero en mi laptop personal, no hay ning\xfan error as\xed. Ya s\xe9 que <a href="http://stackoverflow.com/a/3346640/13860">es f\xe1cil suprimir el mensaje (en Ingl\xe9s)</a> con <code>no warnings \'misc\';</code>, pero mi pregunta es:</p><br/><br/><p>\xbfPor qu\xe9 la diferencia entre las versiones de Perl?</p><br/><br/><p>En el trabajo, veo el mensaje con Perl 5.14, y en mi equipo personal no lo veo con Perl 5.20.  \xbfCuando lo cambi\xf3, y por qu\xe9?</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T15:37:40.450',
#  u'FavoriteCount': u'',
#  u'Id': 12,
#  u'LastActivityDate': u'2016-08-30T13:52:11.543',
#  u'LastEditDate': u'2016-08-30T13:52:11.543',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 5465,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 22,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 11,
#  u'Tags': u'<array><perl>',
#  u'Title': u'"splice() offset past end of array" en diferentes versiones de Perl',
#  u'ViewCount': 132,
#  u'_id': ObjectId('584ac9ae0b09c35439b1744c'),
#  u'comments': [{u'CreationDate': u'2015-10-30T16:30:45.820',
#                 u'Id': 7,
#                 u'PostId': 12,
#                 u'Score': 0,
#                 u'Text': u'yo no manejo Perl pero quizas esto le ayude http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html creo que eso  ocurre entre la .14 y .16 en algunos sistemas https://rt.perl.org/Public/Bug/Display.html?id=117729',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e2')}]}
# {u'AcceptedAnswerId': 17,
#  u'AnswerCount': 1,
#  u'Body': u'<p>Estoy tratando de descargar el simulador de <code>iOS 8.4</code> en <code>Xcode 7</code> y me devuelve este error: </p><br/><br/><blockquote><br/>  <p>Could not download and install ios 8.4. Authorization is required to install the packages.</p><br/></blockquote><br/><br/><p>Antes de eso ingres\xe9 mi password de usuario.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T19:42:29.823',
#  u'FavoriteCount': u'',
#  u'Id': 16,
#  u'LastActivityDate': u'2015-12-29T12:25:29.713',
#  u'LastEditDate': u'2015-12-29T12:25:29.713',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 100,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 37,
#  u'ParentId': u'',
#  u'PostTypeId': 1,
#  u'Score': 4,
#  u'Tags': u'<ios><xcode>',
#  u'Title': u'Error ios 8.4 simulator en xcode 7',
#  u'ViewCount': 93,
#  u'_id': ObjectId('584ac9ae0b09c35439b1744e'),
#  u'comments': [{u'CreationDate': u'2015-10-30T20:47:56.377',
#                 u'Id': 8,
#                 u'PostId': 16,
#                 u'Score': 0,
#                 u'Text': u'Bienvenido a StackOverflow quizas quiera echar un vistazo a esta pagina http://es.stackoverflow.com/tour',
#                 u'UserDisplayName': u'',
#                 u'UserId': 24,
#                 u'_id': ObjectId('584ac9b90b09c35439b283e3')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Para realizar esta operaci\xf3n, ejecuta <code>Xcode</code> como <code>root</code> con el comando <a href="https://es.wikipedia.org/wiki/Sudo" rel="nofollow"><code>sudo</code></a> e instala dentro de esa sesi\xf3n:</p><br/><br/><pre><code>sudo /Applications/Xcode.app/Contents/MacOS/Xcode<br/></code></pre><br/><br/><p>Una vez hayas instalados debes salir e iniciar normalmente.</p><br/><br/><p>Debes tener precauci\xf3n si tienes proyectos abiertos cuando usas sudo para lanzar Xcode.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T20:36:12.323',
#  u'FavoriteCount': u'',
#  u'Id': 17,
#  u'LastActivityDate': u'2015-11-02T17:08:36.167',
#  u'LastEditDate': u'2015-11-02T17:08:36.167',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 21,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': 16,
#  u'PostTypeId': 2,
#  u'Score': 2,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b1744f'),
#  u'comments': []}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Como ya mencion\xe9 yo no uso Perl, pero mirando la documentaci\xf3n en una parte de ella dice lo siguiente:</p><br/><br/><blockquote><br/>  <p>"Si el desplazamiento es m\xe1s all\xe1 del final de la matriz, Perl emite<br/>  una advertencia, y (Perl) empalma/splice en el extremo de la matriz."</p><br/></blockquote><br/><br/><p><em>...If OFFSET is past the end of the array, Perl issues a warning, and splices at the end of the array.</em></p><br/><br/><p>De echo he revisado en varias versiones y es lo mismo por lo menos la documentaci\xf3n advierten sobre el <em>warning</em>.</p><br/><br/><p>Aqu\xed le dejo los links (en Ingl\xe9s); </p><br/><br/><ul><br/><li><p><a href="http://perldoc.perl.org/5.16.2/functions/splice.html" rel="nofollow" title="http://perldoc.perl.org/5.16.2/functions/splice.html">Perl v 5.16.2</a></p></li><br/><li><p><a href="http://perldoc.perl.org/5.20.0/functions/splice.html" rel="nofollow" title="http://perldoc.perl.org/5.20.0/functions/splice.html">Perl v 5.20.0</a></p></li><br/><li><p><a href="http://perldoc.perl.org/functions/splice.html" rel="nofollow" title="http://perldoc.perl.org/functions/splice.html">Perl v 5.22</a></p></li><br/></ul><br/><br/><p>Seg\xfan lo anterior lo normal es el <em>warning</em>, pero por lo que se puede ver en el siguiente link, no en todas las versiones es as\xed y tambi\xe9n depende del OS.</p><br/><br/><p><a href="http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html" rel="nofollow">http://www.nntp.perl.org/group/perl.perl5.porters/2013/04/msg201134.html</a></p><br/><br/><p>Creo que eso ocurre entre la <code>5.14</code> y <code>5.16</code> en algunos sistemas, aqu\xed puede ver la notificaci\xf3n de bug pero quiz\xe1s tambi\xe9n le suceda a usted en la <code>5.20</code> debido a su OS y no es que haya cambiado algo. </p><br/><br/><p><a href="https://rt.perl.org/Public/Bug/Display.html?id=117729" rel="nofollow">https://rt.perl.org/Public/Bug/Display.html?id=117729</a></p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 1,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-31T01:15:02.047',
#  u'FavoriteCount': u'',
#  u'Id': 18,
#  u'LastActivityDate': u'2015-12-15T22:22:22.080',
#  u'LastEditDate': u'2015-12-15T22:22:22.080',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 264,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': 12,
#  u'PostTypeId': 2,
#  u'Score': 8,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17450'),
#  u'comments': [{u'CreationDate': u'2015-12-05T15:14:45.093',
#                 u'Id': 929,
#                 u'PostId': 18,
#                 u'Score': 1,
#                 u'Text': u'Tienes raz\xf3n que la advertencia en este caso espec\xedfico desapareci\xf3 enter 5.14 y 5.16, y que esto fue una decisi\xf3n  deliberada para quitarla y no un nuevo bug. La \xfanica raz\xf3n que la versi\xf3n del sistema operativo tiene algo que ver aqu\xed es porque las personas que **no** instalan sus propio perls van a tener cualquier versi\xf3n que les d\xe9 su OS.',
#                 u'UserDisplayName': u'',
#                 u'UserId': 288,
#                 u'_id': ObjectId('584ac9b90b09c35439b28652')}]}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p><strong>\xbfQu\xe9 es C ++?</strong></p><br/><br/><p>C ++ es de tipado est\xe1tico (statically typed), (por lo general) compilado, multi-paradigma, que no debe confundirse con C o C ++ / CLI. Se desarroll\xf3 en la d\xe9cada de 1980 por Bjarne Stroustrup, inicialmente como un conjunto de extensiones para el lenguaje de programaci\xf3n C. Bas\xe1ndose en C, C ++ ha mejorado la seguridad de tipos y ha a\xf1adido soporte para la gesti\xf3n autom\xe1tica de recursos, la orientaci\xf3n a objetos, programaci\xf3n gen\xe9rica, y el manejo de excepciones, entre otras caracter\xedsticas.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-30T16:53:47.187',
#  u'FavoriteCount': u'',
#  u'Id': 14,
#  u'LastActivityDate': u'2016-03-31T20:32:49.003',
#  u'LastEditDate': u'2016-03-31T20:32:49.003',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 4595,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 5,
#  u'Score': 0,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17451'),
#  u'comments': []}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'<p>Delphi es un lenguaje de prop\xf3sito general para el desarrollo r\xe1pido de nativo de Windows, OS X, iOS y aplicaciones Android.</p><br/><br/><p>El nombre utilizado para referirse a la lengua es Delphi, pero los desarrolladores decidier\xf3n regresar el nombre original al lenguaje, Object Pascal, restringiendo el nombre al IDE, que se utiliza para ayudar a editar y depurar proyectos de Delphi de manera m\xe1s eficiente. Es desarrollado por Embarcadero Technologies, y se vende, ya sea como un producto independiente o como parte de RAD Studio, que incluye otros idiomas tambi\xe9n.</p><br/><br/><p>Delphi es una mejora del lenguaje de Niklaus Wirth Pascal (y Object Pascal).</p><br/><br/><p>Delphi se origin\xf3 en 1995 en Borland, evolucionando desde Turbo Pascal, y es la segunda mayor plataforma de desarrollo de Windows despu\xe9s de .NET de Microsoft.</p><br/>',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-31T01:47:38.807',
#  u'FavoriteCount': u'',
#  u'Id': 19,
#  u'LastActivityDate': u'2015-12-06T18:28:40.030',
#  u'LastEditDate': u'2015-12-06T18:28:40.030',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 24,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 5,
#  u'Score': 0,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17452'),
#  u'comments': []}
# {u'AcceptedAnswerId': u'',
#  u'AnswerCount': u'',
#  u'Body': u'Delphi es un lenguaje para el desarrollo r\xe1pido de nativo en Windows, OS X, iOS, y aplicaciones de Android a trav\xe9s del uso de Object Pascal. El nombre hace referencia al lenguaje Delphi, as\xed como su IDE, que se utiliza para ayudar a editar y depurar proyectos de Delphi.',
#  u'ClosedDate': u'',
#  u'CommentCount': 0,
#  u'CommunityOwnedDate': u'',
#  u'CreationDate': u'2015-10-31T01:47:38.807',
#  u'FavoriteCount': u'',
#  u'Id': 20,
#  u'LastActivityDate': u'2015-12-06T04:14:11.190',
#  u'LastEditDate': u'2015-12-06T04:14:11.190',
#  u'LastEditorDisplayName': u'',
#  u'LastEditorUserId': 24,
#  u'OwnerDisplayName': u'',
#  u'OwnerUserId': 24,
#  u'ParentId': u'',
#  u'PostTypeId': 4,
#  u'Score': 0,
#  u'Tags': u'',
#  u'Title': u'',
#  u'ViewCount': u'',
#  u'_id': ObjectId('584ac9ae0b09c35439b17453'),
#  u'comments': []}

# %% [markdown]
# ## EJERCICIO: Construir, con el API de Map-Reduce, una colección 'post_comments', donde se añade el campo 'Comments' a cada Post con la lista de todos los comentarios referidos a un Post.

# %% [markdown]
# Veremos la resolución de este ejercicio para que haga de ejemplo para los siguientes a implementar. En primer lugar, una operación map/reduce sólo se puede ejecutar sobre una colección, así que sólo puede contener resultados de la misma. Por lo tanto, con sólo una operación map/reduce no va a ser posible realizar todo el ejercicio.
#
# Así, en primer lugar, parece interesante agrupar todos los comentarios que se han producido de un Post en particular. En cada comentario, el atributo `PostId` marca una referencia al Post al que se refiere.
#
# Es importante cómo se construyen las operaciones `map()` y `reduce()`. Primero, la función `map()` se ejecutará para todos los documentos (o para todos los que cumplan la condición si se utiliza el modificador `query=`). Sin embargo, la función `reduce()` no se ejecutará a no ser que haya más de un elemento asociado a la misma clave.
#
# Por lo tanto, la salida de la función `map()` debe ser la misma que la de la función `reduce()`. En nuestro caso, es un objeto JSON de la forma:
#
#     { type: 'comment', comments: [ {comentario1, comentario2} ] }
#
# En el caso de que sólo se ejecute la función `map()`, nótese cómo el objeto tiene la misma composición, pero con un array de sólo un elemento (comentario): sí mismo.

# %%
from bson.code import Code

comments_map = Code("function () {"
           "  emit(this.PostId, { type: 'comment', comments: [this]});"
           "}")

comments_reduce = Code("function (key, values) {"
                       "  comments = [];"
                       "  for (i = 0, len = values.length; i < len; ++i) {"
                       "    if ('comments' in values[i])"
                       "      comments = comments.concat(values[i].comments);"
                       "  }"
                       "  return { type: 'comment', comments: comments };"
                       "}")

db.comments.map_reduce(comments_map, comments_reduce, "post_comments")
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'stackoverflow'), u'post_comments')

# %%
r = list(db.post_comments.find())
r[:10]
# Out:
# [{u'_id': 1.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-10-29T16:31:36.090',
#      u'Id': 1,
#      u'PostId': 1,
#      u'Score': 0,
#      u'Text': u'M\xe1s tarde a\xf1adir\xe9 la respuesta, pero si alguien quiere hacer los honores antes...',
#      u'UserDisplayName': u'',
#      u'UserId': 23,
#      u'_id': ObjectId('584ac9b90b09c35439b283dc')},
#     {u'CreationDate': u'2015-10-29T18:03:06.780',
#      u'Id': 2,
#      u'PostId': 1,
#      u'Score': 1,
#      u'Text': u'\xa1Excelente! Nuestra primera pregunta. :)',
#      u'UserDisplayName': u'',
#      u'UserId': 4,
#      u'_id': ObjectId('584ac9b90b09c35439b283dd')}],
#    u'type': u'comment'}},
#  {u'_id': 2.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-10-29T19:14:50.617',
#      u'Id': 3,
#      u'PostId': 2,
#      u'Score': 0,
#      u'Text': u'...y aqu\xed tenemos nuestra primera respuesta. :-)',
#      u'UserDisplayName': u'',
#      u'UserId': 23,
#      u'_id': ObjectId('584ac9b90b09c35439b283de')}],
#    u'type': u'comment'}},
#  {u'_id': 3.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-10-30T07:08:56.507',
#      u'Id': 4,
#      u'PostId': 3,
#      u'Score': 0,
#      u'Text': u'Ante dos alternativas iguales para hacer lo mismo, utiliza siempre la m\xe1s legible.',
#      u'UserDisplayName': u'',
#      u'UserId': 23,
#      u'_id': ObjectId('584ac9b90b09c35439b283df')}],
#    u'type': u'comment'}},
#  {u'_id': 5.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-10-30T14:03:12.927',
#      u'Id': 5,
#      u'PostId': 5,
#      u'Score': 1,
#      u'Text': u'Creo que no se puede preguntar por lo m\xe1s elegante, ya que esto usualmente es subjetivo.',
#      u'UserDisplayName': u'',
#      u'UserId': 21,
#      u'_id': ObjectId('584ac9b90b09c35439b283e0')},
#     {u'CreationDate': u'2015-12-02T11:55:06.800',
#      u'Id': 242,
#      u'PostId': 5,
#      u'Score': 1,
#      u'Text': u'Angel, yo sugeriria que edites la palabra "elegante" de tu pregunta porque no se corresponde con las reglas de los sitios de SE. Elegante como dice @jachguate es subjetivo y por ende preguntas enfocandose en ese aspecto deber\xedan ser cerradas como "primarily opinion based" o "se basa principalmente en opiniones"',
#      u'UserDisplayName': u'',
#      u'UserId': 92,
#      u'_id': ObjectId('584ac9b90b09c35439b2848d')},
#     {u'CreationDate': u'2015-12-02T17:09:52.673',
#      u'Id': 351,
#      u'PostId': 5,
#      u'Score': 0,
#      u'Text': u'@Dzyann lo tendre en cuenta para futuras pregunta ahora no creo que sea bueno pues hay preguntas que hacen referencia a eso saludos',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b284dd')},
#     {u'CreationDate': u'2015-12-04T18:51:28.980',
#      u'Id': 824,
#      u'PostId': 5,
#      u'Score': 1,
#      u'Text': u'Voto para cerrar porque esto de "elegancia" es basado en la opini\xf3n de cada qui\xe9n.',
#      u'UserDisplayName': u'',
#      u'UserId': 670,
#      u'_id': ObjectId('584ac9b90b09c35439b2861d')},
#     {u'CreationDate': u'2015-12-10T16:34:36.243',
#      u'Id': 1477,
#      u'PostId': 5,
#      u'Score': 2,
#      u'Text': u'Cuidado con usar espacios para separar palabras, hay varios idiomas (como chino) que no usan espacios. Incluso en idiomas con caracteres latinos hay palabras como parlez-vous francais? en el que no se usa el espacio como separador. ICU tiene una libreria genial para todos los casos. http://userguide.icu-project.org/boundaryanalysis',
#      u'UserDisplayName': u'',
#      u'UserId': 718,
#      u'_id': ObjectId('584ac9b90b09c35439b287e8')}],
#    u'type': u'comment'}},
#  {u'_id': 6.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-12-02T12:27:45.953',
#      u'Id': 247,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'Si vas a copiar una pregunta de SO por favor agrega una referencia a la original [When should static_cast, dynamic_cast, const_cast and reinterpret_cast be used?](http://stackoverflow.com/a/332086/4574)',
#      u'UserDisplayName': u'',
#      u'UserId': 92,
#      u'_id': ObjectId('584ac9b90b09c35439b28492')},
#     {u'CreationDate': u'2015-12-02T16:05:32.273',
#      u'Id': 312,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'la pregunta no es una copia, como muchas que eh visto ultimamente, si es cierto que mirando el link que pones, puede parecerlo pero no lo es, por otro lado si te refieres por lo que se esta haciendo estos dias fijate que la respuesta no es mia, por otro lado esta fue de las primeras preguntas del sitio y era para testear espero aclarar tu insinuaci\xf3n saludos',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b284c2')},
#     {u'CreationDate': u'2015-12-02T20:10:05.240',
#      u'Id': 407,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'Yo no he insinuado nada, simplemente aclare que si vas a copiar, pongas la referencia. Clara y concisamente, no se a que te referies con insinuacion.',
#      u'UserDisplayName': u'',
#      u'UserId': 92,
#      u'_id': ObjectId('584ac9b90b09c35439b284fb')},
#     {u'CreationDate': u'2015-12-02T20:15:38.427',
#      u'Id': 411,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'Angel, exacto, dije si vas a copiar, porque no se si es copia o no, y vos aclaras que no es copia. Igual, una pregunta tan basica mas que seguro que ya existia en SO. Tengo entendido que estos posts estan antes de que la beta se haya abierto para mas personas?',
#      u'UserDisplayName': u'',
#      u'UserId': 92,
#      u'_id': ObjectId('584ac9b90b09c35439b284fd')},
#     {u'CreationDate': u'2015-12-02T20:13:22.607',
#      u'Id': 409,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'quizas lo interprete mas pero usted dijo -> Si vas a copiar una pregunta de SO por favor agrega..... y yo aclaro que esto no es una copia',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b284fe')},
#     {u'CreationDate': u'2015-12-02T20:21:26.597',
#      u'Id': 415,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'ahora te entiendo pero, ponte en mi lugar yo leo tu primer comentario, y parece que mes lo esta diciendo de forma afirmativa. Que no hay mal rollo por mi parte quizas fuera que se mal interpretaron los comentarios, tambien puede que influyera el tema que estoy viendo estos dia que se estan copiando y auto respondiendo en cuestion de segundo y me lo tome por ese lado pues esa practica yo no la comparto, y quizas por eso me tome tu comentario como acusacion, pues si te pones en mi lugar y lees eso creo que es comprensible que crea que me lo estas insinuando',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b28500')},
#     {u'CreationDate': u'2015-12-02T20:22:49.967',
#      u'Id': 417,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'si este post es de hace un mes o mas',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b28501')},
#     {u'CreationDate': u'2015-12-02T20:42:56.333',
#      u'Id': 420,
#      u'PostId': 6,
#      u'Score': 0,
#      u'Text': u'Respecto a eso, he posteado una pregunta aqui [Paremos el acaparamiento de puntos](http://meta.es.stackoverflow.com/questions/103/paremos-el-acaparamiento-de-puntos)',
#      u'UserDisplayName': u'',
#      u'UserId': 92,
#      u'_id': ObjectId('584ac9b90b09c35439b28502')}],
#    u'type': u'comment'}},
#  {u'_id': 266.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-12-03T03:11:40.730',
#      u'Id': 466,
#      u'PostId': 266,
#      u'Score': 0,
#      u'Text': u"Curiosa palabra: 'comitear'.",
#      u'UserDisplayName': u'',
#      u'UserId': 417,
#      u'_id': ObjectId('584ac9b90b09c35439b28520')}],
#    u'type': u'comment'}},
#  {u'_id': 8.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-12-01T17:02:33.213',
#      u'Id': 61,
#      u'PostId': 8,
#      u'Score': 0,
#      u'Text': u"Quiz\xe1s olvidaste incluir el js en la configuraci\xf3n de karma (karma.config.js)? Ej:    files: [<br/>      '../bower_components/angular/angular.js',<br/>      '../bower_components/angular-mocks/angular-mocks.js',<br/>      '../src/*.js',<br/>      './*.js'<br/>    ],",
#      u'UserDisplayName': u'',
#      u'UserId': 114,
#      u'_id': ObjectId('584ac9b90b09c35439b283fd')}],
#    u'type': u'comment'}},
#  {u'_id': 9.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-10-30T14:54:20.307',
#      u'Id': 6,
#      u'PostId': 9,
#      u'Score': 1,
#      u'Text': u'guau creo que esta es muy buena respuesta',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b283e1')}],
#    u'type': u'comment'}},
#  {u'_id': 10.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-12-06T05:47:50.147',
#      u'Id': 998,
#      u'PostId': 10,
#      u'Score': 0,
#      u'Text': u'Y ahora porque el voto en contra?',
#      u'UserDisplayName': u'',
#      u'UserId': 20,
#      u'_id': ObjectId('584ac9b90b09c35439b28681')},
#     {u'CreationDate': u'2015-12-09T18:50:57.613',
#      u'Id': 1407,
#      u'PostId': 10,
#      u'Score': 0,
#      u'Text': u'Seguro alguien quer\xeda su medallita de C\xedtrico',
#      u'UserDisplayName': u'',
#      u'UserId': 100,
#      u'_id': ObjectId('584ac9b90b09c35439b287a9')}],
#    u'type': u'comment'}},
#  {u'_id': 11.0,
#   u'value': {u'comments': [{u'CreationDate': u'2015-11-01T21:47:24.230',
#      u'Id': 15,
#      u'PostId': 11,
#      u'Score': 1,
#      u'Text': u'Y cu\xe1l de los dos es el recomendable y porque?... (para completar la respuesta)',
#      u'UserDisplayName': u'',
#      u'UserId': 20,
#      u'_id': ObjectId('584ac9b90b09c35439b283e4')},
#     {u'CreationDate': u'2015-11-02T08:25:12.210',
#      u'Id': 17,
#      u'PostId': 11,
#      u'Score': 1,
#      u'Text': u'Cierto. \xa1A\xf1adido!',
#      u'UserDisplayName': u'',
#      u'UserId': 23,
#      u'_id': ObjectId('584ac9b90b09c35439b283e6')}],
#    u'type': u'comment'}}]

# %% [markdown]
# Después del primer paso de map/reduce, tenemos que construir la colección final que asocia cada Post con sus comentarios. Como hemos construido antes la colección `post_comments` indizada por el `Id` del Post, podemos utilizar ahora una ejecución de map/reduce que *mezcle* los datos en `post_comments` con los datos en `posts`.
#
# La segunda ejecución de map/reduce la haremos sobre `posts`, para que el resultado sea completo, incluso para los Posts que no aparecen en comentarios, y por lo tanto tendrán el atributo `comments` vacío.
#
# En este caso, debemos hacer que la función `map()` produzca una salida de documentos que también están indizados con el atributo `Id`, y, como sólo hay uno para cada `Id`, la función `reduce()` no se ejecutará. **Tan sólo se ejecutará para mezclar ambas colecciones**, así que la función `reduce()` tendrá que estar preparada para mezclar objetos de tipo "comment" y Posts. En cualquier caso, como se puede ver, es válida también aunque sólo se llame con un objeto de tipo Post. Finalmente, la función `map()` prepara a cada objeto Post, inicialmente, con una lista de comentarios vacíos

# %%
posts_map = Code("""
function () {
  obj = this;
  obj.comments = [];
  emit(this.Id, obj);
}
""")

posts_reduce = Code("""
function (key, values) {
  comments = []; // The set of comments
  obj = {}; // The object to return
  
  for (i = 0, len = values.length; i < len; ++i) {
    if ('type' in values[i] && values[i].type === 'comment')
      comments = comments.concat(values[i].comments);
    else // Object
    {
      obj = values[i];
      // obj.comments will always be there because of the map() operation
      comments = comments.concat(obj.comments);
    }
  }
  
  // Finalize: Add the comments to the object to return
  obj.comments = comments;
  return obj;
}
""")

db.posts.map_reduce(posts_map, posts_reduce, out={'reduce' : 'post_comments'})
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'stackoverflow'), u'post_comments')

# %%
r = list(db.post_comments.find())
r[:10]
# Out:
# [{u'_id': 7.0,
#   u'value': {u'AcceptedAnswerId': u'',
#    u'AnswerCount': u'',
#    u'Body': u'<p>Lo de elegancia es algo dif\xedcil de decir, es cuesti\xf3n de gustos. Pero la legibilidad del c\xf3digo siempre es importante. Por eso, este c\xf3digo se puede simplificar as\xed: (a mi me parece mas legible)</p><br/><br/><pre><code>std::string tempStr;<br/>while(isstream >> tempStr) {<br/>    std::cout << tempStr << std::endl;<br/>}<br/></code></pre><br/><br/><p>Con lo cual, metiendo todo en una funci\xf3n quedar\xeda algo as\xed:</p><br/><br/><pre><code>std::vector<std::string> split_istringstream(std::string str) {<br/>    std::vector<std::string> resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(isstream >> palabra){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Otra alternativa, que incluso permite definir el delimitador (el operador >> de <code>istringstream</code> solo divide la cadena por los espacios - ASCII 32) es utilizar <a href="http://es.cppreference.com/w/cpp/string/basic_string/getline">std::getline</a>. </p><br/><br/><pre><code>std::vector<std::string> split_getline(std::string str, char delim) {<br/>    std::vector<std::string> resultado;<br/>    std::istringstream isstream(str);<br/>    std::string palabra;<br/><br/>    while(std::getline(isstream, palabra, delim)){<br/>        resultado.push_back(palabra);<br/>    }<br/><br/>    return resultado;<br/>}<br/></code></pre><br/><br/><p>Aqu\xed abajo te dejo una comparativa entre ambas opciones, son pr\xe1cticamente iguales en eficiencia, dejando de un lado los vectores, reservan pr\xe1cticamente la misma memoria.</p><br/><br/><p><a href="http://cpp.sh/3jtw">http://cpp.sh/3jtw</a></p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 0,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-10-30T05:30:50.993',
#    u'FavoriteCount': u'',
#    u'Id': 7,
#    u'LastActivityDate': u'2015-10-30T05:30:50.993',
#    u'LastEditDate': u'',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': u'',
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 25,
#    u'ParentId': 5,
#    u'PostTypeId': 2,
#    u'Score': 11,
#    u'Tags': u'',
#    u'Title': u'',
#    u'ViewCount': u'',
#    u'_id': ObjectId('584ac9ae0b09c35439b17447'),
#    u'comments': []}},
#  {u'_id': 10.0,
#   u'value': {u'AcceptedAnswerId': 11,
#    u'AnswerCount': 1,
#    u'Body': u'<p>Dado el siguiente c\xf3digo en TypeScript</p><br/><br/><pre><code>class Persona {<br/>    constructor(public nombre: string, public apellido: string) {<br/>    }<br/><br/>    nombreCompleto1 = () => {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/><br/>    nombreCompleto2() {<br/>        return this.nombre + " " + this.apellido;<br/>    }<br/>}<br/><br/>var p = new Persona("Juan", "P\xe9rez");<br/><br/>console.log(p.nombreCompleto1());<br/>console.log(p.nombreCompleto2());<br/></code></pre><br/><br/><p>Como se puede ver los m\xe9todos <code>nombreCompleto1</code> y <code>nombreCompleto2</code> hacen lo mismo pero est\xe1n declarados ligeramente diferente.</p><br/><br/><p>Al ejecutarlo en los dos casos se obtiene el resultado esperado:</p><br/><br/><pre><br/>Juan P\xe9rez<br/>Juan P\xe9rez<br/></pre><br/><br/><p>\xbfCu\xe1l es la diferencia entre las dos declaraciones si los dos hacen los mismo y cu\xe1l es la forma adecuada de declararlo?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 2,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-10-30T14:33:50.523',
#    u'FavoriteCount': 1,
#    u'Id': 10,
#    u'LastActivityDate': u'2015-12-14T01:05:34.960',
#    u'LastEditDate': u'2015-12-09T18:18:51.863',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 342,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 20,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 7,
#    u'Tags': u'<typescript>',
#    u'Title': u'\xbfC\xf3mo definir m\xe9todos correctamente en TypeScript?',
#    u'ViewCount': 159,
#    u'comments': [{u'CreationDate': u'2015-12-06T05:47:50.147',
#      u'Id': 998,
#      u'PostId': 10,
#      u'Score': 0,
#      u'Text': u'Y ahora porque el voto en contra?',
#      u'UserDisplayName': u'',
#      u'UserId': 20,
#      u'_id': ObjectId('584ac9b90b09c35439b28681')},
#     {u'CreationDate': u'2015-12-09T18:50:57.613',
#      u'Id': 1407,
#      u'PostId': 10,
#      u'Score': 0,
#      u'Text': u'Seguro alguien quer\xeda su medallita de C\xedtrico',
#      u'UserDisplayName': u'',
#      u'UserId': 100,
#      u'_id': ObjectId('584ac9b90b09c35439b287a9')}]}},
#  {u'_id': 20.0,
#   u'value': {u'AcceptedAnswerId': u'',
#    u'AnswerCount': u'',
#    u'Body': u'Delphi es un lenguaje para el desarrollo r\xe1pido de nativo en Windows, OS X, iOS, y aplicaciones de Android a trav\xe9s del uso de Object Pascal. El nombre hace referencia al lenguaje Delphi, as\xed como su IDE, que se utiliza para ayudar a editar y depurar proyectos de Delphi.',
#    u'ClosedDate': u'',
#    u'CommentCount': 0,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-10-31T01:47:38.807',
#    u'FavoriteCount': u'',
#    u'Id': 20,
#    u'LastActivityDate': u'2015-12-06T04:14:11.190',
#    u'LastEditDate': u'2015-12-06T04:14:11.190',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 24,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 24,
#    u'ParentId': u'',
#    u'PostTypeId': 4,
#    u'Score': 0,
#    u'Tags': u'',
#    u'Title': u'',
#    u'ViewCount': u'',
#    u'_id': ObjectId('584ac9ae0b09c35439b17453'),
#    u'comments': []}},
#  {u'_id': 33.0,
#   u'value': {u'AcceptedAnswerId': 852,
#    u'AnswerCount': 5,
#    u'Body': u'<p>Ya que en jQuery es posible cambiar la visibilidad de un elemento, \xbfc\xf3mo puedo saber si un elemento est\xe1 visible o no en tiempo de ejecuci\xf3n?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 0,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-02T15:20:04.967',
#    u'FavoriteCount': 2,
#    u'Id': 33,
#    u'LastActivityDate': u'2016-01-14T02:58:37.123',
#    u'LastEditDate': u'',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': u'',
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 21,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 23,
#    u'Tags': u'<javascript><jquery>',
#    u'Title': u'\xbfC\xf3mo puedo saber si un elemento est\xe1 visible con jQuery?',
#    u'ViewCount': 1232,
#    u'_id': ObjectId('584ac9ae0b09c35439b1745f'),
#    u'comments': []}},
#  {u'_id': 34.0,
#   u'value': {u'AcceptedAnswerId': 91,
#    u'AnswerCount': 1,
#    u'Body': u'<p>Estoy realizando una aplicaci\xf3n en la que me gustar\xeda recibir la temperatura a trav\xe9s de un Arduino. Creo que utilizar Sockets es una excelente forma de comunicaci\xf3n, pero no tengo idea de c\xf3mo utilizar Sockets en una aplicaci\xf3n Android hecha con Delphi. </p><br/><br/><p>\xbfEs diferente de c\xf3mo se utiliza en Delphi compilado para Windows?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 3,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-02T15:23:51.607',
#    u'FavoriteCount': u'',
#    u'Id': 34,
#    u'LastActivityDate': u'2016-06-03T22:33:03.410',
#    u'LastEditDate': u'2016-06-03T22:33:03.410',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 227,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 21,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 8,
#    u'Tags': u'<delphi><android><socket><tcpip><tcp>',
#    u'Title': u'\xbfC\xf3mo usar Sockets en Android con Delphi?',
#    u'ViewCount': 178,
#    u'comments': [{u'CreationDate': u'2015-12-01T18:13:00.677',
#      u'Id': 79,
#      u'PostId': 34,
#      u'Score': 0,
#      u'Text': u'Te recomendar\xeda que revises el framework de [Google Cloud Messaging](https://developers.google.com/cloud-messaging/) para android por sobre abrir sockets directamente. Te va a ahorrar varios dolores de cabeza.',
#      u'UserDisplayName': u'',
#      u'UserId': 245,
#      u'_id': ObjectId('584ac9b90b09c35439b2840b')},
#     {u'CreationDate': u'2015-12-01T19:39:53.883',
#      u'Id': 111,
#      u'PostId': 34,
#      u'Score': 0,
#      u'Text': u'@jachguate, \xbfC\xf3mo quieres realizar la comunicaci\xf3n? \xbfBluetooth? \xbfUn servidor que maneje peticiones?',
#      u'UserDisplayName': u'',
#      u'UserId': 309,
#      u'_id': ObjectId('584ac9b90b09c35439b28426')},
#     {u'CreationDate': u'2015-12-02T01:56:42.060',
#      u'Id': 203,
#      u'PostId': 34,
#      u'Score': 0,
#      u'Text': u'@Jaime, la comunicaci\xf3n es TCP/IP a un socket en un servidor accesible v\xeda lan/wan',
#      u'UserDisplayName': u'',
#      u'UserId': 21,
#      u'_id': ObjectId('584ac9b90b09c35439b2846f')}]}},
#  {u'_id': 36.0,
#   u'value': {u'AcceptedAnswerId': 40,
#    u'AnswerCount': 1,
#    u'Body': u'<p>\xbfCu\xe1l es la diferencia entre un inner y un outer join?</p><br/><br/><p>Y \xbfcu\xe1l es la funci\xf3n de los modificadores <code>left</code>, <code>right</code> o <code>full</code>?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 0,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-02T15:31:51.453',
#    u'FavoriteCount': 8,
#    u'Id': 36,
#    u'LastActivityDate': u'2016-08-31T13:44:37.070',
#    u'LastEditDate': u'2015-12-14T16:41:53.950',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 95,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 21,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 27,
#    u'Tags': u'<mysql><sql><inner-join><join>',
#    u'Title': u'\xbfCu\xe1l es la diferencia entre un inner y un outer join?',
#    u'ViewCount': 1066,
#    u'_id': ObjectId('584ac9ae0b09c35439b17461'),
#    u'comments': []}},
#  {u'_id': 37.0,
#   u'value': {u'AcceptedAnswerId': 39,
#    u'AnswerCount': 1,
#    u'Body': u'<p>Tengo una tabla con varias columnas, por ejemplo, <code>ID</code>, <code>Nombre</code>, <code>Edad</code>y <code>Pais</code>. De estas, he marcado la columna <code>Edad</code> como <em><code>unused</code></em> con la  sentencia siguiente:</p><br/><br/><pre><code>alter table Persona set unused column AGE;<br/></code></pre><br/><br/><p>Ahora, quiero utilizar la columna <code>Edad</code> de nuevo, \xbfC\xf3mo puedo hacerlo en Oracle (10g)?</p><br/><br/><p>Adem\xe1s, \xbfqu\xe9 es mejor, borrar una columna, o establecerla como <strong>no utilizada</strong> (<em>unused</em>)?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 0,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-02T15:41:11.333',
#    u'FavoriteCount': u'',
#    u'Id': 37,
#    u'LastActivityDate': u'2015-11-02T16:46:25.517',
#    u'LastEditDate': u'2015-11-02T16:32:49.907',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 21,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 21,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 9,
#    u'Tags': u'<sql><oracle><oracle-10g>',
#    u'Title': u'\xbfC\xf3mo reutilizar una columna marcada como "unused" en Oracle?',
#    u'ViewCount': 115,
#    u'_id': ObjectId('584ac9ae0b09c35439b17462'),
#    u'comments': []}},
#  {u'_id': 41.0,
#   u'value': {u'AcceptedAnswerId': 42,
#    u'AnswerCount': 2,
#    u'Body': u'<p>Estoy creando un proyecto asp net mvc 5 empty, y estoy agregando manualmente mis referencias de JavaScript.</p><br/><br/><p>He agregado esta linea:</p><br/><br/><pre><code><script src="./bower_components/angular/angular.min.js"></script><br/></code></pre><br/><br/><p>Ahora mis preguntas son: \xbfC\xf3mo se descargan esos paquetes si no he agregado bower al proyecto? \xbfC\xf3mo lo puedo agregar?</p><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 1,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-02T17:16:43.263',
#    u'FavoriteCount': u'',
#    u'Id': 41,
#    u'LastActivityDate': u'2015-12-02T15:16:09.120',
#    u'LastEditDate': u'2015-12-02T15:16:09.120',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 83,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 35,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 5,
#    u'Tags': u'<asp.net><bower>',
#    u'Title': u'Agregar bower a una aplicaci\xf3n asp net empty',
#    u'ViewCount': 134,
#    u'comments': [{u'CreationDate': u'2015-11-02T18:14:17.603',
#      u'Id': 23,
#      u'PostId': 41,
#      u'Score': 1,
#      u'Text': u'Bienvenido a StackOverflow quiz\xe1s quiera echar un vistazo a esta pagina http://es.stackoverflow.com/tour',
#      u'UserDisplayName': u'',
#      u'UserId': 24,
#      u'_id': ObjectId('584ac9b90b09c35439b283ec')}]}},
#  {u'_id': 45.0,
#   u'value': {u'AcceptedAnswerId': u'',
#    u'AnswerCount': u'',
#    u'Body': u"<p>Pod\xe9s usar lo siguiente </p><br/><br/><pre><code>if($('#elemento').css('display') == 'none'){<br/>   // Acci\xf3n si el elemento no es visible<br/>}else{<br/>   // Acci\xf3n si el elemento es visible<br/>}<br/></code></pre><br/><br/><p>en el caso de que tambien queramos chequear la opacidad hacemos: </p><br/><br/><pre><code>if($('#elemento').css('display') == 'none' || $('#elemento').css('opacity') == 0){<br/>       // Acci\xf3n si el elemento no es visible<br/>}else{<br/>       // Acci\xf3n si el elemento es visible<br/>}<br/></code></pre><br/>",
#    u'ClosedDate': u'',
#    u'CommentCount': 1,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-03T20:00:54.010',
#    u'FavoriteCount': u'',
#    u'Id': 45,
#    u'LastActivityDate': u'2015-11-26T13:14:32.687',
#    u'LastEditDate': u'2015-11-26T13:14:32.687',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 58,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 58,
#    u'ParentId': 33,
#    u'PostTypeId': 2,
#    u'Score': -1,
#    u'Tags': u'',
#    u'Title': u'',
#    u'ViewCount': u'',
#    u'comments': [{u'CreationDate': u'2015-12-01T18:40:14.330',
#      u'Id': 88,
#      u'PostId': 45,
#      u'Score': 0,
#      u'Text': u'Tambi\xe9n habr\xeda que mirar el valor de `visibility`',
#      u'UserDisplayName': u'',
#      u'UserId': 250,
#      u'_id': ObjectId('584ac9b90b09c35439b28413')}]}},
#  {u'_id': 46.0,
#   u'value': {u'AcceptedAnswerId': 130,
#    u'AnswerCount': 2,
#    u'Body': u'<p>Estaba practicando con lambdas y me encontr\xe9 con el siguiente c\xf3digo:</p><br/><br/><pre><code>auto make_fibo() <br/>{<br/>  return [](int n) {<br/>    std::function<int(int)> recurse;<br/>    recurse = [&](int n){ <br/>       return (n<=2)? 1 : recurse(n-1) + recurse(n-2); <br/>    }; <br/>    return recurse(n);<br/>  };<br/>}<br/></code></pre><br/><br/><p>Yo no sabia que era <code>function</code> ni como trabajaba despu\xe9s de buscar y leer varios textos por ejemplo el siguiente:</p><br/><br/><p><a href="http://www.cplusplus.com/reference/functional/function/" rel="nofollow">http://www.cplusplus.com/reference/functional/function/</a></p><br/><br/><p>Mi pregunta es si, <code>std::function</code> es similar a lo siguiente por ejemplo:</p><br/><br/><pre><code>typedef  int (*FredMemFn)(int i);<br/></code></pre><br/>',
#    u'ClosedDate': u'',
#    u'CommentCount': 2,
#    u'CommunityOwnedDate': u'',
#    u'CreationDate': u'2015-11-05T00:26:45.847',
#    u'FavoriteCount': 2,
#    u'Id': 46,
#    u'LastActivityDate': u'2015-12-07T11:57:18.943',
#    u'LastEditDate': u'2015-12-07T11:57:18.943',
#    u'LastEditorDisplayName': u'',
#    u'LastEditorUserId': 22,
#    u'OwnerDisplayName': u'',
#    u'OwnerUserId': 24,
#    u'ParentId': u'',
#    u'PostTypeId': 1,
#    u'Score': 7,
#    u'Tags': u'<c++><c++11>',
#    u'Title': u'\xbfEs std::function equivalente a un puntero?',
#    u'ViewCount': 176,
#    u'comments': [{u'CreationDate': u'2015-11-05T07:27:30.143',
#      u'Id': 33,
#      u'PostId': 46,
#      u'Score': 6,
#      u'Text': u'Sugerencia: edita el t\xedtulo para que sea m\xe1s autocontenido: Por ejemplo: "\xbfEs std::function equivalente a un puntero?" (o a un typedef, o lo que sea m\xe1s apropiado)',
#      u'UserDisplayName': u'',
#      u'UserId': 23,
#      u'_id': ObjectId('584ac9b90b09c35439b28404')},
#     {u'CreationDate': u'2015-12-01T17:18:20.450',
#      u'Id': 72,
#      u'PostId': 46,
#      u'Score': 0,
#      u'Text': u'La pregunta es si `std::function` es similar a un puntero a funci\xf3n, o a un `typedef` de un puntero a funci\xf3n?',
#      u'UserDisplayName': u'',
#      u'UserId': 93,
#      u'_id': ObjectId('584ac9b90b09c35439b28406')}]}}]

# %% [markdown]
# ## EJERCICIO: Relacionar en un scatterplot el 'Score' de una pregunta o respuesta con respecto al número de comentarios ('CommentCount')

# %%
scores = []
commentcounts = []
for post in posts.find():
    scores.append(post['Score'])
    commentcounts.append(post['CommentCount'])

# %%
import matplotlib.pyplot as plt

x = list(scores)
y = list(commentcounts)

plt.scatter(x, y, alpha=0.5)
plt.show()

# %% [markdown]
# ## Índices

# %% [markdown]
# Se pueden crear más índices, de tipos `ASCENDING`, `DESCENDING`, `HASHED`, y otros geoespaciales. https://api.mongodb.com/python/current/api/pymongo/collection.html#pymongo.collection.Collection.create_index

# %%
# %%timeit
res = posts.find({'OwnerUserId' :  22},projection={'Id' :1, 'OwnerUserId': 1})
r = list(res)
# Out:
# 10 loops, best of 3: 17.4 ms per loop

# %%
posts.create_index([('OwnerUserId', pymongo.HASHED)])
# Out:
# u'OwnerUserId_hashed'

# %%
# %%timeit
res = posts.find({'OwnerUserId' :  22},projection={'Id' :1, 'OwnerUserId': 1})
r = list(res)
# Out:
# The slowest run took 5.57 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 3: 525 µs per loop

# %% [markdown]
# ## Esquemas: Monothon
#
# El siguiente comando instala la librería python `monothon`, que no viene instalada en la máquina virtual. Esta librería nos permite definir esquemas por los que se regirán los datos de las colecciones. Está basada en la librería para Javascript `mongoose`.

# %%
# !sudo pip install --upgrade git+https://github.com/dsevilla/mongothon.git@patch-2
# Out:
# Downloading/unpacking git+https://github.com/dsevilla/mongothon.git@patch-2
#   Cloning https://github.com/dsevilla/mongothon.git (to patch-2) to /tmp/pip-RQEl_M-build
#   Running setup.py (path:/tmp/pip-RQEl_M-build/setup.py) egg_info for package from git+https://github.com/dsevilla/mongothon.git@patch-2
#
# Downloading/unpacking pymongo<3.0.0,>=2.5.0 (from Mongothon==0.7.20)
#   Downloading pymongo-2.9.4.tar.gz (442kB): 442kB downloaded
#   Running setup.py (path:/tmp/pip-build-Tun8MW/pymongo/setup.py) egg_info for package pymongo
#
# Requirement already up-to-date: inflection==0.2.0 in /usr/local/lib/python2.7/dist-packages (from Mongothon==0.7.20)
# Requirement already up-to-date: schemer<0.3.0,>=0.2.0 in /usr/local/lib/python2.7/dist-packages (from Mongothon==0.7.20)
# Installing collected packages: pymongo, Mongothon
#   Found existing installation: pymongo 3.4.0
#     Uninstalling pymongo:
#       Successfully uninstalled pymongo
#   Running setup.py install for pymongo
#     building 'bson._cbson' extension
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c bson/_cbsonmodule.c -o build/temp.linux-x86_64-2.7/bson/_cbsonmodule.o
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c bson/time64.c -o build/temp.linux-x86_64-2.7/bson/time64.o
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c bson/buffer.c -o build/temp.linux-x86_64-2.7/bson/buffer.o
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c bson/encoding_helpers.c -o build/temp.linux-x86_64-2.7/bson/encoding_helpers.o
#     x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wl,-Bsymbolic-functions -Wl,-z,relro -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security build/temp.linux-x86_64-2.7/bson/_cbsonmodule.o build/temp.linux-x86_64-2.7/bson/time64.o build/temp.linux-x86_64-2.7/bson/buffer.o build/temp.linux-x86_64-2.7/bson/encoding_helpers.o -o build/lib.linux-x86_64-2.7/bson/_cbson.so
#     building 'pymongo._cmessage' extension
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c pymongo/_cmessagemodule.c -o build/temp.linux-x86_64-2.7/pymongo/_cmessagemodule.o
#     x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -fno-strict-aliasing -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -fPIC -Ibson -I/usr/include/python2.7 -c bson/buffer.c -o build/temp.linux-x86_64-2.7/bson/buffer.o
#     x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wl,-Bsymbolic-functions -Wl,-z,relro -D_FORTIFY_SOURCE=2 -g -fstack-protector-strong -Wformat -Werror=format-security build/temp.linux-x86_64-2.7/pymongo/_cmessagemodule.o build/temp.linux-x86_64-2.7/bson/buffer.o -o build/lib.linux-x86_64-2.7/pymongo/_cmessage.so
#
#   Could not find .egg-info directory in install record for pymongo<3.0.0,>=2.5.0 (from Mongothon==0.7.20)
#   Found existing installation: Mongothon 0.7.20
#     Uninstalling Mongothon:
#       Successfully uninstalled Mongothon
#   Running setup.py install for Mongothon
#
#   Could not find .egg-info directory in install record for Mongothon==0.7.20 from git+https://github.com/dsevilla/mongothon.git@patch-2 in /usr/local/lib/python2.7/dist-packages
# Successfully installed pymongo Mongothon
# Cleaning up...

# %% [markdown]
#    - **votes**.xml
#      - Id
#      - PostId
#      - VoteTypeId
#         - ` 1`: AcceptedByOriginator
#         - ` 2`: UpMod
#         - ` 3`: DownMod
#         - ` 4`: Offensive
#         - ` 5`: Favorite - if VoteTypeId = 5 UserId will be populated
#         - ` 6`: Close
#         - ` 7`: Reopen
#         - ` 8`: BountyStart
#         - ` 9`: BountyClose
#         - `10`: Deletion
#         - `11`: Undeletion
#         - `12`: Spam
#         - `13`: InformModerator
#      - CreationDate
#      - UserId (only for VoteTypeId 5)
#      - BountyAmount (only for VoteTypeId 9)

# %%
from mongothon import Schema, create_model
from datetime import datetime

votes_schema = Schema({
            "Id":         {"type": int, "required": True},
            "PostId":        {"type": int, "required": True},
            "VoteTypeId":   {"type": int }, # Podría hacerse un enum con "validates": one_of("AcceptedByOriginator", "UpMod", etc.)
            "CreationDate": {"type": datetime},
            "UserId" : { "type" : int},
            "BountyAmount" : {"type": int}
        })

Votes = create_model(votes_schema, db.votes)

# %%
# Crear un nuevo voto
vote1 = Votes({'Id': 1000000, 'PostId': 1, 'VoteTypeId': 1})

# Guardarlo en la Base de datos
vote1.save()

# Encontrarlo por su _id
vote2 = Votes.find_by_id(vote1['_id'])
vote2
# Out:
# {u'Id': 1000000,
#  u'PostId': 1,
#  u'VoteTypeId': 1,
#  u'_id': ObjectId('584ac9fb6252f606af346867')}

# %%
# Se comprueba que el voto se ha añadido a la colección con las funciones estándar de pymongo:
result = db.votes.find({'Id' : 1000000})
print list(result)
# Out:
# [{u'VoteTypeId': 1, u'PostId': 1, u'_id': ObjectId('584ac9fb6252f606af346867'), u'Id': 1000000}]

# %% [markdown]
# ## EJERCICIO: Con Map-Reduce y con el Framework de Agregación, mostrar las consultas RQ1 y RQ2 de la sesión 2

# %% [markdown]
# En SQL RQ1 era
# %%sql
# SELECT OwnerUserId AS Autor, count(*) AS Preguntas FROM Posts WHERE PostTypeId = 1 AND OwnerUserId IS NOT NULL GROUP BY OwnerUserId ORDER BY Preguntas DESC;

# %%
RQ1 = posts.aggregate( [
        {'$match': { 'PostTypeId' : {'$eq': 1}}},
        {
            '$project' : {'OwnerUserId': True}
        },
        {
            "$group":{"_id":"$OwnerUserId", "Preguntas":{"$sum":1}}    
        },
        { 
            "$sort": {"Preguntas": -1} 
        }
    ])
print_respuestas(RQ1)
# Out:
# {u'Preguntas': 116, u'_id': 2230}
# {u'Preguntas': 68, u'_id': 4048}
# {u'Preguntas': 52, u'_id': 9099}
# {u'Preguntas': 46, u'_id': 342}
# {u'Preguntas': 45, u'_id': 3115}
# {u'Preguntas': 43, u'_id': 3415}
# {u'Preguntas': 43, u'_id': 5370}
# {u'Preguntas': 37, u'_id': 2896}
# {u'Preguntas': 35, u'_id': 4361}
# {u'Preguntas': 33, u'_id': 517}
# {u'Preguntas': 33, u'_id': 6399}
# {u'Preguntas': 32, u'_id': 4231}
# {u'Preguntas': 32, u'_id': 2366}
# {u'Preguntas': 32, u'_id': 4528}
# {u'Preguntas': 30, u'_id': 4874}
# {u'Preguntas': 30, u'_id': 4487}
# {u'Preguntas': 30, u'_id': 250}
# {u'Preguntas': 29, u'_id': 3004}
# {u'Preguntas': 28, u'_id': 4610}
# {u'Preguntas': 27, u'_id': 1505}
# {u'Preguntas': 27, u'_id': 100}
# {u'Preguntas': 27, u'_id': 2676}
# {u'Preguntas': 26, u'_id': 1092}
# {u'Preguntas': 23, u'_id': 4718}
# {u'Preguntas': 23, u'_id': 2675}
# {u'Preguntas': 23, u'_id': 1005}
# {u'Preguntas': 23, u'_id': 729}
# {u'Preguntas': 22, u'_id': 4680}
# {u'Preguntas': 22, u'_id': 4499}
# {u'Preguntas': 22, u'_id': 4456}
# {u'Preguntas': 22, u'_id': 2429}
# {u'Preguntas': 22, u'_id': 371}
# {u'Preguntas': 22, u'_id': 6044}
# {u'Preguntas': 21, u'_id': 1281}
# {u'Preguntas': 21, u'_id': 870}
# {u'Preguntas': 20, u'_id': 5972}
# {u'Preguntas': 20, u'_id': 10019}
# {u'Preguntas': 20, u'_id': 2633}
# {u'Preguntas': 20, u'_id': 24}
# {u'Preguntas': 20, u'_id': 3275}
# {u'Preguntas': 20, u'_id': 5997}
# {u'Preguntas': 20, u'_id': 3628}
# {u'Preguntas': 19, u'_id': 4381}
# {u'Preguntas': 19, u'_id': 6646}
# {u'Preguntas': 18, u'_id': 353}
# {u'Preguntas': 18, u'_id': 4811}
# {u'Preguntas': 18, u'_id': 1839}
# {u'Preguntas': 18, u'_id': 6943}
# {u'Preguntas': 18, u'_id': 908}
# {u'Preguntas': 18, u'_id': 5005}
# {u'Preguntas': 17, u'_id': 9897}
# {u'Preguntas': 17, u'_id': 9539}
# {u'Preguntas': 17, u'_id': 4770}
# {u'Preguntas': 17, u'_id': 399}
# {u'Preguntas': 17, u'_id': 6560}
# {u'Preguntas': 17, u'_id': 608}
# {u'Preguntas': 17, u'_id': 801}
# {u'Preguntas': 17, u'_id': 4779}
# {u'Preguntas': 16, u'_id': 10097}
# {u'Preguntas': 16, u'_id': 4418}
# {u'Preguntas': 16, u'_id': 6046}
# {u'Preguntas': 16, u'_id': 4612}
# {u'Preguntas': 16, u'_id': 4725}
# {u'Preguntas': 16, u'_id': 2004}
# {u'Preguntas': 16, u'_id': 4595}
# {u'Preguntas': 16, u'_id': 7384}
# {u'Preguntas': 15, u'_id': 9484}
# {u'Preguntas': 15, u'_id': 2247}
# {u'Preguntas': 15, u'_id': 1184}
# {u'Preguntas': 15, u'_id': 638}
# {u'Preguntas': 15, u'_id': 2747}
# {u'Preguntas': 15, u'_id': 5710}
# {u'Preguntas': 15, u'_id': 2539}
# {u'Preguntas': 14, u'_id': 301}
# {u'Preguntas': 14, u'_id': 1204}
# {u'Preguntas': 14, u'_id': 65}
# {u'Preguntas': 14, u'_id': 2163}
# {u'Preguntas': 14, u'_id': 1360}
# {u'Preguntas': 14, u'_id': 22}
# {u'Preguntas': 14, u'_id': 2645}
# {u'Preguntas': 13, u'_id': 2236}
# {u'Preguntas': 13, u'_id': 3231}
# {u'Preguntas': 13, u'_id': 417}
# {u'Preguntas': 13, u'_id': 7254}
# {u'Preguntas': 12, u'_id': 2659}
# {u'Preguntas': 12, u'_id': 4532}
# {u'Preguntas': 12, u'_id': 3234}
# {u'Preguntas': 12, u'_id': 21}
# {u'Preguntas': 12, u'_id': 3976}
# {u'Preguntas': 12, u'_id': 7615}
# {u'Preguntas': 12, u'_id': 25}
# {u'Preguntas': 12, u'_id': 4684}
# {u'Preguntas': 12, u'_id': 2282}
# {u'Preguntas': 12, u'_id': 3013}
# {u'Preguntas': 12, u'_id': 78}
# {u'Preguntas': 12, u'_id': 2854}
# {u'Preguntas': 12, u'_id': 6534}
# {u'Preguntas': 12, u'_id': 9205}
# {u'Preguntas': 12, u'_id': u''}
# {u'Preguntas': 12, u'_id': 1914}
# {u'Preguntas': 12, u'_id': 400}
# {u'Preguntas': 11, u'_id': 10930}
# {u'Preguntas': 11, u'_id': 3665}
# {u'Preguntas': 11, u'_id': 3746}
# {u'Preguntas': 11, u'_id': 3316}
# {u'Preguntas': 11, u'_id': 4328}
# {u'Preguntas': 11, u'_id': 4229}
# {u'Preguntas': 11, u'_id': 6635}
# {u'Preguntas': 10, u'_id': 10428}
# {u'Preguntas': 10, u'_id': 10422}
# {u'Preguntas': 10, u'_id': 4156}
# {u'Preguntas': 10, u'_id': 4021}
# {u'Preguntas': 10, u'_id': 7280}
# {u'Preguntas': 10, u'_id': 7142}
# {u'Preguntas': 10, u'_id': 8958}
# {u'Preguntas': 10, u'_id': 6173}
# {u'Preguntas': 10, u'_id': 2224}
# {u'Preguntas': 10, u'_id': 2241}
# {u'Preguntas': 10, u'_id': 1575}
# {u'Preguntas': 10, u'_id': 1527}
# {u'Preguntas': 10, u'_id': 271}
# {u'Preguntas': 10, u'_id': 7621}
# {u'Preguntas': 10, u'_id': 1958}
# {u'Preguntas': 10, u'_id': 3130}
# {u'Preguntas': 10, u'_id': 5283}
# {u'Preguntas': 10, u'_id': 8930}
# {u'Preguntas': 10, u'_id': 535}
# {u'Preguntas': 10, u'_id': 7358}
# {u'Preguntas': 9, u'_id': 11261}
# {u'Preguntas': 9, u'_id': 10552}
# {u'Preguntas': 9, u'_id': 9958}
# {u'Preguntas': 9, u'_id': 2985}
# {u'Preguntas': 9, u'_id': 191}
# {u'Preguntas': 9, u'_id': 2718}
# {u'Preguntas': 9, u'_id': 2399}
# {u'Preguntas': 9, u'_id': 2596}
# {u'Preguntas': 9, u'_id': 2453}
# {u'Preguntas': 9, u'_id': 4748}
# {u'Preguntas': 9, u'_id': 227}
# {u'Preguntas': 9, u'_id': 5729}
# {u'Preguntas': 9, u'_id': 3170}
# {u'Preguntas': 9, u'_id': 2837}
# {u'Preguntas': 9, u'_id': 6489}
# {u'Preguntas': 9, u'_id': 2980}
# {u'Preguntas': 9, u'_id': 6495}
# {u'Preguntas': 9, u'_id': 4632}
# {u'Preguntas': 9, u'_id': 2670}
# {u'Preguntas': 9, u'_id': 2826}
# {u'Preguntas': 9, u'_id': 2402}
# {u'Preguntas': 9, u'_id': 292}
# {u'Preguntas': 9, u'_id': 5272}
# {u'Preguntas': 9, u'_id': 6974}
# {u'Preguntas': 9, u'_id': 4568}
# {u'Preguntas': 9, u'_id': 6549}
# {u'Preguntas': 9, u'_id': 5004}
# {u'Preguntas': 9, u'_id': 5339}
# {u'Preguntas': 9, u'_id': 7541}
# {u'Preguntas': 8, u'_id': 11395}
# {u'Preguntas': 8, u'_id': 11342}
# {u'Preguntas': 8, u'_id': 10388}
# {u'Preguntas': 8, u'_id': 7242}
# {u'Preguntas': 8, u'_id': 4325}
# {u'Preguntas': 8, u'_id': 4142}
# {u'Preguntas': 8, u'_id': 4085}
# {u'Preguntas': 8, u'_id': 1943}
# {u'Preguntas': 8, u'_id': 3343}
# {u'Preguntas': 8, u'_id': 3249}
# {u'Preguntas': 8, u'_id': 187}
# {u'Preguntas': 8, u'_id': 2352}
# {u'Preguntas': 8, u'_id': 3203}
# {u'Preguntas': 8, u'_id': 3248}
# {u'Preguntas': 8, u'_id': 3094}
# {u'Preguntas': 8, u'_id': 6020}
# {u'Preguntas': 8, u'_id': 9669}
# {u'Preguntas': 8, u'_id': 10452}
# {u'Preguntas': 8, u'_id': 5894}
# {u'Preguntas': 8, u'_id': 4321}
# {u'Preguntas': 8, u'_id': 5219}
# {u'Preguntas': 8, u'_id': 7591}
# {u'Preguntas': 7, u'_id': 12657}
# {u'Preguntas': 7, u'_id': 12431}
# {u'Preguntas': 7, u'_id': 10688}
# {u'Preguntas': 7, u'_id': 7064}
# {u'Preguntas': 7, u'_id': 12625}
# {u'Preguntas': 7, u'_id': 3966}
# {u'Preguntas': 7, u'_id': 3834}
# {u'Preguntas': 7, u'_id': 9130}
# {u'Preguntas': 7, u'_id': 3767}
# {u'Preguntas': 7, u'_id': 1168}
# {u'Preguntas': 7, u'_id': 5422}
# {u'Preguntas': 7, u'_id': 7694}
# {u'Preguntas': 7, u'_id': 3533}
# {u'Preguntas': 7, u'_id': 2338}
# {u'Preguntas': 7, u'_id': 2509}
# {u'Preguntas': 7, u'_id': 5263}
# {u'Preguntas': 7, u'_id': 4753}
# {u'Preguntas': 7, u'_id': 547}
# {u'Preguntas': 7, u'_id': 23}
# {u'Preguntas': 7, u'_id': 4111}
# {u'Preguntas': 7, u'_id': 10744}
# {u'Preguntas': 7, u'_id': 1792}
# {u'Preguntas': 7, u'_id': 1389}
# {u'Preguntas': 7, u'_id': 4548}
# {u'Preguntas': 7, u'_id': 9885}
# {u'Preguntas': 7, u'_id': 5389}
# {u'Preguntas': 7, u'_id': 5438}
# {u'Preguntas': 7, u'_id': 166}
# {u'Preguntas': 7, u'_id': 3008}
# {u'Preguntas': 7, u'_id': 233}
# {u'Preguntas': 7, u'_id': 7490}
# {u'Preguntas': 7, u'_id': 5826}
# {u'Preguntas': 7, u'_id': 9458}
# {u'Preguntas': 7, u'_id': 7137}
# {u'Preguntas': 7, u'_id': 2152}
# {u'Preguntas': 7, u'_id': 6363}
# {u'Preguntas': 7, u'_id': 7165}
# {u'Preguntas': 7, u'_id': 9168}
# {u'Preguntas': 6, u'_id': 10903}
# {u'Preguntas': 6, u'_id': 12878}
# {u'Preguntas': 6, u'_id': 10870}
# {u'Preguntas': 6, u'_id': 11313}
# {u'Preguntas': 6, u'_id': 10848}
# {u'Preguntas': 6, u'_id': 10577}
# {u'Preguntas': 6, u'_id': 10399}
# {u'Preguntas': 6, u'_id': 10379}
# {u'Preguntas': 6, u'_id': 9991}
# {u'Preguntas': 6, u'_id': 9905}
# {u'Preguntas': 6, u'_id': 9883}
# {u'Preguntas': 6, u'_id': 9610}
# {u'Preguntas': 6, u'_id': 9277}
# {u'Preguntas': 6, u'_id': 4083}
# {u'Preguntas': 6, u'_id': 6564}
# {u'Preguntas': 6, u'_id': 2133}
# {u'Preguntas': 6, u'_id': 7301}
# {u'Preguntas': 6, u'_id': 302}
# {u'Preguntas': 6, u'_id': 3621}
# {u'Preguntas': 6, u'_id': 3583}
# {u'Preguntas': 6, u'_id': 4026}
# {u'Preguntas': 6, u'_id': 3257}
# {u'Preguntas': 6, u'_id': 2257}
# {u'Preguntas': 6, u'_id': 12591}
# {u'Preguntas': 6, u'_id': 2019}
# {u'Preguntas': 6, u'_id': 6881}
# {u'Preguntas': 6, u'_id': 1399}
# {u'Preguntas': 6, u'_id': 4451}
# {u'Preguntas': 6, u'_id': 83}
# {u'Preguntas': 6, u'_id': 10777}
# {u'Preguntas': 6, u'_id': 225}
# {u'Preguntas': 6, u'_id': 9427}
# {u'Preguntas': 6, u'_id': 1795}
# {u'Preguntas': 6, u'_id': 1466}
# {u'Preguntas': 6, u'_id': 6612}
# {u'Preguntas': 6, u'_id': 2367}
# {u'Preguntas': 6, u'_id': 430}
# {u'Preguntas': 6, u'_id': 3182}
# {u'Preguntas': 6, u'_id': 2472}
# {u'Preguntas': 6, u'_id': 2879}
# {u'Preguntas': 6, u'_id': 5674}
# {u'Preguntas': 6, u'_id': 8907}
# {u'Preguntas': 6, u'_id': 9182}
# {u'Preguntas': 6, u'_id': 2909}
# {u'Preguntas': 6, u'_id': 5421}
# {u'Preguntas': 6, u'_id': 3060}
# {u'Preguntas': 6, u'_id': 120}
# {u'Preguntas': 6, u'_id': 5663}
# {u'Preguntas': 6, u'_id': 4923}
# {u'Preguntas': 6, u'_id': 463}
# {u'Preguntas': 6, u'_id': 6406}
# {u'Preguntas': 6, u'_id': 6677}
# {u'Preguntas': 6, u'_id': 7192}
# {u'Preguntas': 6, u'_id': 6170}
# {u'Preguntas': 6, u'_id': 8728}
# {u'Preguntas': 6, u'_id': 9434}
# {u'Preguntas': 5, u'_id': 12446}
# {u'Preguntas': 5, u'_id': 11294}
# {u'Preguntas': 5, u'_id': 10786}
# {u'Preguntas': 5, u'_id': 10451}
# {u'Preguntas': 5, u'_id': 9912}
# {u'Preguntas': 5, u'_id': 6095}
# {u'Preguntas': 5, u'_id': 9788}
# {u'Preguntas': 5, u'_id': 9524}
# {u'Preguntas': 5, u'_id': 6497}
# {u'Preguntas': 5, u'_id': 4676}
# {u'Preguntas': 5, u'_id': 3539}
# {u'Preguntas': 5, u'_id': 6762}
# {u'Preguntas': 5, u'_id': 4961}
# {u'Preguntas': 5, u'_id': 3460}
# {u'Preguntas': 5, u'_id': 9179}
# {u'Preguntas': 5, u'_id': 6270}
# {u'Preguntas': 5, u'_id': 2238}
# {u'Preguntas': 5, u'_id': 676}
# {u'Preguntas': 5, u'_id': 11001}
# {u'Preguntas': 5, u'_id': 12578}
# {u'Preguntas': 5, u'_id': 2957}
# {u'Preguntas': 5, u'_id': 5558}
# {u'Preguntas': 5, u'_id': 2862}
# {u'Preguntas': 5, u'_id': 6851}
# {u'Preguntas': 5, u'_id': 2013}
# {u'Preguntas': 5, u'_id': 6811}
# {u'Preguntas': 5, u'_id': 2838}
# {u'Preguntas': 5, u'_id': 1166}
# {u'Preguntas': 5, u'_id': 4661}
# {u'Preguntas': 5, u'_id': 206}
# {u'Preguntas': 5, u'_id': 7166}
# {u'Preguntas': 5, u'_id': 4274}
# {u'Preguntas': 5, u'_id': 2256}
# {u'Preguntas': 5, u'_id': 6215}
# {u'Preguntas': 5, u'_id': 154}
# {u'Preguntas': 5, u'_id': 4584}
# {u'Preguntas': 5, u'_id': 2769}
# {u'Preguntas': 5, u'_id': 7347}
# {u'Preguntas': 5, u'_id': 6764}
# {u'Preguntas': 5, u'_id': 12483}
# {u'Preguntas': 5, u'_id': 5461}
# {u'Preguntas': 5, u'_id': 5566}
# {u'Preguntas': 5, u'_id': 3038}
# {u'Preguntas': 5, u'_id': 5988}
# {u'Preguntas': 5, u'_id': 9261}
# {u'Preguntas': 5, u'_id': 3287}
# {u'Preguntas': 5, u'_id': 6603}
# {u'Preguntas': 5, u'_id': 6833}
# {u'Preguntas': 5, u'_id': 3762}
# {u'Preguntas': 5, u'_id': 7520}
# {u'Preguntas': 5, u'_id': 7529}
# {u'Preguntas': 5, u'_id': 9159}
# {u'Preguntas': 5, u'_id': 9010}
# {u'Preguntas': 5, u'_id': 531}
# {u'Preguntas': 4, u'_id': 13489}
# {u'Preguntas': 4, u'_id': 12708}
# {u'Preguntas': 4, u'_id': 12616}
# {u'Preguntas': 4, u'_id': 11110}
# {u'Preguntas': 4, u'_id': 10454}
# {u'Preguntas': 4, u'_id': 10439}
# {u'Preguntas': 4, u'_id': 9886}
# {u'Preguntas': 4, u'_id': 4866}
# {u'Preguntas': 4, u'_id': 4708}
# {u'Preguntas': 4, u'_id': 4446}
# {u'Preguntas': 4, u'_id': 6187}
# {u'Preguntas': 4, u'_id': 389}
# {u'Preguntas': 4, u'_id': 3869}
# {u'Preguntas': 4, u'_id': 660}
# {u'Preguntas': 4, u'_id': 5147}
# {u'Preguntas': 4, u'_id': 13047}
# {u'Preguntas': 4, u'_id': 3451}
# {u'Preguntas': 4, u'_id': 9185}
# {u'Preguntas': 4, u'_id': 6172}
# {u'Preguntas': 4, u'_id': 75}
# {u'Preguntas': 4, u'_id': 10740}
# {u'Preguntas': 4, u'_id': 10832}
# {u'Preguntas': 4, u'_id': 2027}
# {u'Preguntas': 4, u'_id': 1274}
# {u'Preguntas': 4, u'_id': 2990}
# {u'Preguntas': 4, u'_id': 636}
# {u'Preguntas': 4, u'_id': 4815}
# {u'Preguntas': 4, u'_id': 2652}
# {u'Preguntas': 4, u'_id': 13637}
# {u'Preguntas': 4, u'_id': 9313}
# {u'Preguntas': 4, u'_id': 5206}
# {u'Preguntas': 4, u'_id': 360}
# {u'Preguntas': 4, u'_id': 4098}
# {u'Preguntas': 4, u'_id': 9396}
# {u'Preguntas': 4, u'_id': 13042}
# {u'Preguntas': 4, u'_id': 5248}
# {u'Preguntas': 4, u'_id': 816}
# {u'Preguntas': 4, u'_id': 8771}
# {u'Preguntas': 4, u'_id': 95}
# {u'Preguntas': 4, u'_id': 5723}
# {u'Preguntas': 4, u'_id': 4654}
# {u'Preguntas': 4, u'_id': 2802}
# {u'Preguntas': 4, u'_id': 5403}
# {u'Preguntas': 4, u'_id': 1499}
# {u'Preguntas': 4, u'_id': 9920}
# {u'Preguntas': 4, u'_id': 5703}
# {u'Preguntas': 4, u'_id': 7518}
# {u'Preguntas': 4, u'_id': 5855}
# {u'Preguntas': 4, u'_id': 5911}
# {u'Preguntas': 4, u'_id': 4723}
# {u'Preguntas': 4, u'_id': 2540}
# {u'Preguntas': 4, u'_id': 4775}
# {u'Preguntas': 4, u'_id': 8847}
# {u'Preguntas': 4, u'_id': 6882}
# {u'Preguntas': 4, u'_id': 2878}
# {u'Preguntas': 4, u'_id': 3727}
# {u'Preguntas': 4, u'_id': 10491}
# {u'Preguntas': 4, u'_id': 5465}
# {u'Preguntas': 4, u'_id': 3088}
# {u'Preguntas': 4, u'_id': 5902}
# {u'Preguntas': 4, u'_id': 5938}
# {u'Preguntas': 4, u'_id': 2653}
# {u'Preguntas': 4, u'_id': 2742}
# {u'Preguntas': 4, u'_id': 2134}
# {u'Preguntas': 4, u'_id': 5368}
# {u'Preguntas': 4, u'_id': 9517}
# {u'Preguntas': 4, u'_id': 632}
# {u'Preguntas': 4, u'_id': 7210}
# {u'Preguntas': 4, u'_id': 8898}
# {u'Preguntas': 4, u'_id': 9474}
# {u'Preguntas': 4, u'_id': 2036}
# {u'Preguntas': 4, u'_id': 2681}
# {u'Preguntas': 4, u'_id': 10648}
# {u'Preguntas': 4, u'_id': 3073}
# {u'Preguntas': 4, u'_id': 5851}
# {u'Preguntas': 4, u'_id': 5921}
# {u'Preguntas': 4, u'_id': 11124}
# {u'Preguntas': 4, u'_id': 3138}
# {u'Preguntas': 4, u'_id': 9119}
# {u'Preguntas': 4, u'_id': 8873}
# {u'Preguntas': 4, u'_id': 6137}
# {u'Preguntas': 4, u'_id': 3320}
# {u'Preguntas': 4, u'_id': 6461}
# {u'Preguntas': 4, u'_id': 6535}
# {u'Preguntas': 4, u'_id': 3480}
# {u'Preguntas': 4, u'_id': 6789}
# {u'Preguntas': 4, u'_id': 4924}
# {u'Preguntas': 4, u'_id': 7141}
# {u'Preguntas': 4, u'_id': 3933}
# {u'Preguntas': 4, u'_id': 7291}
# {u'Preguntas': 4, u'_id': 7349}
# {u'Preguntas': 4, u'_id': 3878}
# {u'Preguntas': 4, u'_id': 7399}
# {u'Preguntas': 4, u'_id': 5808}
# {u'Preguntas': 4, u'_id': 8899}
# {u'Preguntas': 4, u'_id': 8983}
# {u'Preguntas': 4, u'_id': 3550}
# {u'Preguntas': 4, u'_id': 2636}
# {u'Preguntas': 4, u'_id': 9348}
# {u'Preguntas': 4, u'_id': 529}
# {u'Preguntas': 3, u'_id': 13222}
# {u'Preguntas': 3, u'_id': 13063}
# {u'Preguntas': 3, u'_id': 13108}
# {u'Preguntas': 3, u'_id': 12844}
# {u'Preguntas': 3, u'_id': 2162}
# {u'Preguntas': 3, u'_id': 12629}
# {u'Preguntas': 3, u'_id': 10835}
# {u'Preguntas': 3, u'_id': 12459}
# {u'Preguntas': 3, u'_id': 9023}
# {u'Preguntas': 3, u'_id': 11320}
# {u'Preguntas': 3, u'_id': 11223}
# {u'Preguntas': 3, u'_id': 11095}
# {u'Preguntas': 3, u'_id': 11013}
# {u'Preguntas': 3, u'_id': 10952}
# {u'Preguntas': 3, u'_id': 10921}
# {u'Preguntas': 3, u'_id': 6206}
# {u'Preguntas': 3, u'_id': 7555}
# {u'Preguntas': 3, u'_id': 10636}
# {u'Preguntas': 3, u'_id': 9174}
# {u'Preguntas': 3, u'_id': 10301}
# {u'Preguntas': 3, u'_id': 10080}
# {u'Preguntas': 3, u'_id': 9939}
# {u'Preguntas': 3, u'_id': 9928}
# {u'Preguntas': 3, u'_id': 9420}
# {u'Preguntas': 3, u'_id': 9583}
# {u'Preguntas': 3, u'_id': 9594}
# {u'Preguntas': 3, u'_id': 4530}
# {u'Preguntas': 3, u'_id': 1111}
# {u'Preguntas': 3, u'_id': 3828}
# {u'Preguntas': 3, u'_id': 11325}
# {u'Preguntas': 3, u'_id': 4117}
# {u'Preguntas': 3, u'_id': 1948}
# {u'Preguntas': 3, u'_id': 5619}
# {u'Preguntas': 3, u'_id': 13209}
# {u'Preguntas': 3, u'_id': 4858}
# {u'Preguntas': 3, u'_id': 12904}
# {u'Preguntas': 3, u'_id': 3581}
# {u'Preguntas': 3, u'_id': 1962}
# {u'Preguntas': 3, u'_id': 3617}
# {u'Preguntas': 3, u'_id': 3488}
# {u'Preguntas': 3, u'_id': 3443}
# {u'Preguntas': 3, u'_id': 3393}
# {u'Preguntas': 3, u'_id': 555}
# {u'Preguntas': 3, u'_id': 3341}
# {u'Preguntas': 3, u'_id': 1746}
# {u'Preguntas': 3, u'_id': 5002}
# {u'Preguntas': 3, u'_id': 629}
# {u'Preguntas': 3, u'_id': 5271}
# {u'Preguntas': 3, u'_id': 1965}
# {u'Preguntas': 3, u'_id': 3440}
# {u'Preguntas': 3, u'_id': 8839}
# {u'Preguntas': 3, u'_id': 3642}
# {u'Preguntas': 3, u'_id': 5239}
# {u'Preguntas': 3, u'_id': 2974}
# {u'Preguntas': 3, u'_id': 1365}
# {u'Preguntas': 3, u'_id': 10626}
# {u'Preguntas': 3, u'_id': 6897}
# {u'Preguntas': 3, u'_id': 631}
# {u'Preguntas': 3, u'_id': 7231}
# {u'Preguntas': 3, u'_id': 398}
# {u'Preguntas': 3, u'_id': 2766}
# {u'Preguntas': 3, u'_id': 4918}
# {u'Preguntas': 3, u'_id': 9471}
# {u'Preguntas': 3, u'_id': 4736}
# {u'Preguntas': 3, u'_id': 6878}
# {u'Preguntas': 3, u'_id': 4265}
# {u'Preguntas': 3, u'_id': 2123}
# {u'Preguntas': 3, u'_id': 4253}
# {u'Preguntas': 3, u'_id': 822}
# {u'Preguntas': 3, u'_id': 2512}
# {u'Preguntas': 3, u'_id': 4023}
# {u'Preguntas': 3, u'_id': 12510}
# {u'Preguntas': 3, u'_id': 2894}
# {u'Preguntas': 3, u'_id': 5180}
# {u'Preguntas': 3, u'_id': 3809}
# {u'Preguntas': 3, u'_id': 9859}
# {u'Preguntas': 3, u'_id': 127}
# {u'Preguntas': 3, u'_id': 630}
# {u'Preguntas': 3, u'_id': 2832}
# {u'Preguntas': 3, u'_id': 3726}
# {u'Preguntas': 3, u'_id': 149}
# {u'Preguntas': 3, u'_id': 3682}
# {u'Preguntas': 3, u'_id': 2304}
# {u'Preguntas': 3, u'_id': 35}
# {u'Preguntas': 3, u'_id': 3909}
# {u'Preguntas': 3, u'_id': 12575}
# {u'Preguntas': 3, u'_id': 4845}
# {u'Preguntas': 3, u'_id': 2724}
# {u'Preguntas': 3, u'_id': 2767}
# {u'Preguntas': 3, u'_id': 1171}
# {u'Preguntas': 3, u'_id': 238}
# {u'Preguntas': 3, u'_id': 9384}
# {u'Preguntas': 3, u'_id': 3021}
# {u'Preguntas': 3, u'_id': 4677}
# {u'Preguntas': 3, u'_id': 5690}
# {u'Preguntas': 3, u'_id': 2958}
# {u'Preguntas': 3, u'_id': 2335}
# {u'Preguntas': 3, u'_id': 3158}
# {u'Preguntas': 3, u'_id': 4633}
# {u'Preguntas': 3, u'_id': 93}
# {u'Preguntas': 3, u'_id': 5646}
# {u'Preguntas': 3, u'_id': 4771}
# {u'Preguntas': 3, u'_id': 4782}
# {u'Preguntas': 3, u'_id': 4726}
# {u'Preguntas': 3, u'_id': 73}
# {u'Preguntas': 3, u'_id': 8990}
# {u'Preguntas': 3, u'_id': 12991}
# {u'Preguntas': 3, u'_id': 6984}
# {u'Preguntas': 3, u'_id': 5274}
# {u'Preguntas': 3, u'_id': 294}
# {u'Preguntas': 3, u'_id': 5350}
# {u'Preguntas': 3, u'_id': 5259}
# {u'Preguntas': 3, u'_id': 5380}
# {u'Preguntas': 3, u'_id': 9807}
# {u'Preguntas': 3, u'_id': 1401}
# {u'Preguntas': 3, u'_id': 2171}
# {u'Preguntas': 3, u'_id': 5487}
# {u'Preguntas': 3, u'_id': 2941}
# {u'Preguntas': 3, u'_id': 7266}
# {u'Preguntas': 3, u'_id': 7293}
# {u'Preguntas': 3, u'_id': 1592}
# {u'Preguntas': 3, u'_id': 5654}
# {u'Preguntas': 3, u'_id': 5700}
# {u'Preguntas': 3, u'_id': 7441}
# {u'Preguntas': 3, u'_id': 5743}
# {u'Preguntas': 3, u'_id': 5681}
# {u'Preguntas': 3, u'_id': 4991}
# {u'Preguntas': 3, u'_id': 5932}
# {u'Preguntas': 3, u'_id': 5989}
# {u'Preguntas': 3, u'_id': 11398}
# {u'Preguntas': 3, u'_id': 9305}
# {u'Preguntas': 3, u'_id': 132}
# {u'Preguntas': 3, u'_id': 3294}
# {u'Preguntas': 3, u'_id': 260}
# {u'Preguntas': 3, u'_id': 12468}
# {u'Preguntas': 3, u'_id': 6774}
# {u'Preguntas': 3, u'_id': 6955}
# {u'Preguntas': 3, u'_id': 9232}
# {u'Preguntas': 3, u'_id': 6992}
# {u'Preguntas': 3, u'_id': 7101}
# {u'Preguntas': 3, u'_id': 10253}
# {u'Preguntas': 3, u'_id': 1098}
# {u'Preguntas': 3, u'_id': 6585}
# {u'Preguntas': 3, u'_id': 92}
# {u'Preguntas': 3, u'_id': 7393}
# {u'Preguntas': 3, u'_id': 10587}
# {u'Preguntas': 3, u'_id': 7542}
# {u'Preguntas': 3, u'_id': 7554}
# {u'Preguntas': 3, u'_id': 6568}
# {u'Preguntas': 3, u'_id': 10757}
# {u'Preguntas': 3, u'_id': 5772}
# {u'Preguntas': 3, u'_id': 7288}
# {u'Preguntas': 3, u'_id': 7703}
# {u'Preguntas': 3, u'_id': 12467}
# {u'Preguntas': 3, u'_id': 6316}
# {u'Preguntas': 3, u'_id': 8994}
# {u'Preguntas': 3, u'_id': 4878}
# {u'Preguntas': 3, u'_id': 4879}
# {u'Preguntas': 3, u'_id': 12903}
# {u'Preguntas': 3, u'_id': 9164}
# {u'Preguntas': 3, u'_id': 9194}
# {u'Preguntas': 3, u'_id': 9230}
# {u'Preguntas': 3, u'_id': 4989}
# {u'Preguntas': 3, u'_id': 9282}
# {u'Preguntas': 3, u'_id': 9454}
# {u'Preguntas': 2, u'_id': 13696}
# {u'Preguntas': 2, u'_id': 13693}
# {u'Preguntas': 2, u'_id': 13571}
# {u'Preguntas': 2, u'_id': 13557}
# {u'Preguntas': 2, u'_id': 13490}
# {u'Preguntas': 2, u'_id': 13354}
# {u'Preguntas': 2, u'_id': 13273}
# {u'Preguntas': 2, u'_id': 13203}
# {u'Preguntas': 2, u'_id': 12945}
# {u'Preguntas': 2, u'_id': 13061}
# {u'Preguntas': 2, u'_id': 13039}
# {u'Preguntas': 2, u'_id': 12935}
# {u'Preguntas': 2, u'_id': 12845}
# {u'Preguntas': 2, u'_id': 12870}
# {u'Preguntas': 2, u'_id': 12817}
# {u'Preguntas': 2, u'_id': 11103}
# {u'Preguntas': 2, u'_id': 9874}
# {u'Preguntas': 2, u'_id': 10559}
# {u'Preguntas': 2, u'_id': 10647}
# {u'Preguntas': 2, u'_id': 12723}
# {u'Preguntas': 2, u'_id': 11164}
# {u'Preguntas': 2, u'_id': 12613}
# {u'Preguntas': 2, u'_id': 12606}
# {u'Preguntas': 2, u'_id': 12476}
# {u'Preguntas': 2, u'_id': 12458}
# {u'Preguntas': 2, u'_id': 11376}
# {u'Preguntas': 2, u'_id': 11340}
# {u'Preguntas': 2, u'_id': 6353}
# {u'Preguntas': 2, u'_id': 11203}
# {u'Preguntas': 2, u'_id': 11187}
# {u'Preguntas': 2, u'_id': 10574}
# {u'Preguntas': 2, u'_id': 6317}
# {u'Preguntas': 2, u'_id': 11053}
# {u'Preguntas': 2, u'_id': 10863}
# {u'Preguntas': 2, u'_id': 10173}
# {u'Preguntas': 2, u'_id': 10807}
# {u'Preguntas': 2, u'_id': 10850}
# {u'Preguntas': 2, u'_id': 10845}
# {u'Preguntas': 2, u'_id': 10796}
# {u'Preguntas': 2, u'_id': 10787}
# {u'Preguntas': 2, u'_id': 10769}
# {u'Preguntas': 2, u'_id': 10731}
# {u'Preguntas': 2, u'_id': 10582}
# {u'Preguntas': 2, u'_id': 10556}
# {u'Preguntas': 2, u'_id': 8756}
# {u'Preguntas': 2, u'_id': 10520}
# {u'Preguntas': 2, u'_id': 10475}
# {u'Preguntas': 2, u'_id': 10426}
# {u'Preguntas': 2, u'_id': 7004}
# {u'Preguntas': 2, u'_id': 10374}
# {u'Preguntas': 2, u'_id': 10367}
# {u'Preguntas': 2, u'_id': 10348}
# {u'Preguntas': 2, u'_id': 10297}
# {u'Preguntas': 2, u'_id': 10225}
# {u'Preguntas': 2, u'_id': 13722}
# {u'Preguntas': 2, u'_id': 10206}
# {u'Preguntas': 2, u'_id': 10180}
# {u'Preguntas': 2, u'_id': 9363}
# {u'Preguntas': 2, u'_id': 10049}
# {u'Preguntas': 2, u'_id': 10032}
# {u'Preguntas': 2, u'_id': 10004}
# {u'Preguntas': 2, u'_id': 9978}
# {u'Preguntas': 2, u'_id': 4872}
# {u'Preguntas': 2, u'_id': 9910}
# {u'Preguntas': 2, u'_id': 9713}
# {u'Preguntas': 2, u'_id': 9840}
# {u'Preguntas': 2, u'_id': 13547}
# {u'Preguntas': 2, u'_id': 13525}
# {u'Preguntas': 2, u'_id': 9762}
# {u'Preguntas': 2, u'_id': 9754}
# {u'Preguntas': 2, u'_id': 9675}
# {u'Preguntas': 2, u'_id': 9645}
# {u'Preguntas': 2, u'_id': 13349}
# {u'Preguntas': 2, u'_id': 13269}
# {u'Preguntas': 2, u'_id': 9529}
# {u'Preguntas': 2, u'_id': 9521}
# {u'Preguntas': 2, u'_id': 9505}
# {u'Preguntas': 2, u'_id': 6551}
# {u'Preguntas': 2, u'_id': 1940}
# {u'Preguntas': 2, u'_id': 6467}
# {u'Preguntas': 2, u'_id': 4715}
# {u'Preguntas': 2, u'_id': 6449}
# {u'Preguntas': 2, u'_id': 4326}
# {u'Preguntas': 2, u'_id': 4696}
# {u'Preguntas': 2, u'_id': 4646}
# {u'Preguntas': 2, u'_id': 4635}
# {u'Preguntas': 2, u'_id': 4620}
# {u'Preguntas': 2, u'_id': 4598}
# {u'Preguntas': 2, u'_id': 6838}
# {u'Preguntas': 2, u'_id': 10685}
# {u'Preguntas': 2, u'_id': 8886}
# {u'Preguntas': 2, u'_id': 10083}
# {u'Preguntas': 2, u'_id': 575}
# {u'Preguntas': 2, u'_id': 6323}
# {u'Preguntas': 2, u'_id': 9253}
# {u'Preguntas': 2, u'_id': 4355}
# {u'Preguntas': 2, u'_id': 5852}
# {u'Preguntas': 2, u'_id': 4312}
# {u'Preguntas': 2, u'_id': 4306}
# {u'Preguntas': 2, u'_id': 514}
# {u'Preguntas': 2, u'_id': 4246}
# {u'Preguntas': 2, u'_id': 4150}
# {u'Preguntas': 2, u'_id': 4823}
# {u'Preguntas': 2, u'_id': 11025}
# {u'Preguntas': 2, u'_id': 7389}
# {u'Preguntas': 2, u'_id': 37}
# {u'Preguntas': 2, u'_id': 2208}
# {u'Preguntas': 2, u'_id': 10621}
# {u'Preguntas': 2, u'_id': 3947}
# {u'Preguntas': 2, u'_id': 2184}
# {u'Preguntas': 2, u'_id': 13758}
# {u'Preguntas': 2, u'_id': 4529}
# {u'Preguntas': 2, u'_id': 10329}
# {u'Preguntas': 2, u'_id': 7096}
# {u'Preguntas': 2, u'_id': 6910}
# {u'Preguntas': 2, u'_id': 4227}
# {u'Preguntas': 2, u'_id': 1964}
# {u'Preguntas': 2, u'_id': 13432}
# {u'Preguntas': 2, u'_id': 5069}
# {u'Preguntas': 2, u'_id': 3676}
# {u'Preguntas': 2, u'_id': 1039}
# {u'Preguntas': 2, u'_id': 9308}
# {u'Preguntas': 2, u'_id': 13554}
# {u'Preguntas': 2, u'_id': 3551}
# {u'Preguntas': 2, u'_id': 2785}
# {u'Preguntas': 2, u'_id': 9191}
# {u'Preguntas': 2, u'_id': 3344}
# {u'Preguntas': 2, u'_id': 3243}
# {u'Preguntas': 2, u'_id': 4538}
# {u'Preguntas': 2, u'_id': 12843}
# {u'Preguntas': 2, u'_id': 6393}
# {u'Preguntas': 2, u'_id': 7116}
# {u'Preguntas': 2, u'_id': 3042}
# {u'Preguntas': 2, u'_id': 3065}
# {u'Preguntas': 2, u'_id': 5516}
# {u'Preguntas': 2, u'_id': 11263}
# {u'Preguntas': 2, u'_id': 11004}
# {u'Preguntas': 2, u'_id': 1610}
# {u'Preguntas': 2, u'_id': 2551}
# {u'Preguntas': 2, u'_id': 4819}
# {u'Preguntas': 2, u'_id': 1870}
# {u'Preguntas': 2, u'_id': 6672}
# {u'Preguntas': 2, u'_id': 1513}
# {u'Preguntas': 2, u'_id': 4710}
# {u'Preguntas': 2, u'_id': 2408}
# {u'Preguntas': 2, u'_id': 3718}
# {u'Preguntas': 2, u'_id': 7340}
# {u'Preguntas': 2, u'_id': 12654}
# {u'Preguntas': 2, u'_id': 217}
# {u'Preguntas': 2, u'_id': 872}
# {u'Preguntas': 2, u'_id': 11181}
# {u'Preguntas': 2, u'_id': 2346}
# {u'Preguntas': 2, u'_id': 1827}
# {u'Preguntas': 2, u'_id': 5034}
# {u'Preguntas': 2, u'_id': 9698}
# {u'Preguntas': 2, u'_id': 2994}
# {u'Preguntas': 2, u'_id': 4115}
# {u'Preguntas': 2, u'_id': 74}
# {u'Preguntas': 2, u'_id': 10020}
# {u'Preguntas': 2, u'_id': 6962}
# {u'Preguntas': 2, u'_id': 2770}
# {u'Preguntas': 2, u'_id': 7661}
# {u'Preguntas': 2, u'_id': 3759}
# {u'Preguntas': 2, u'_id': 3754}
# {u'Preguntas': 2, u'_id': 11353}
# {u'Preguntas': 2, u'_id': 4164}
# {u'Preguntas': 2, u'_id': 4394}
# {u'Preguntas': 2, u'_id': 5908}
# {u'Preguntas': 2, u'_id': 5431}
# {u'Preguntas': 2, u'_id': 4479}
# {u'Preguntas': 2, u'_id': 5492}
# {u'Preguntas': 2, u'_id': 2981}
# {u'Preguntas': 2, u'_id': 4613}
# {u'Preguntas': 2, u'_id': 6921}
# {u'Preguntas': 2, u'_id': 12531}
# {u'Preguntas': 2, u'_id': 965}
# {u'Preguntas': 2, u'_id': 731}
# {u'Preguntas': 2, u'_id': 11354}
# {u'Preguntas': 2, u'_id': 2917}
# {u'Preguntas': 2, u'_id': 6771}
# {u'Preguntas': 2, u'_id': 4786}
# {u'Preguntas': 2, u'_id': 4673}
# {u'Preguntas': 2, u'_id': 1776}
# {u'Preguntas': 2, u'_id': 3362}
# {u'Preguntas': 2, u'_id': 4790}
# {u'Preguntas': 2, u'_id': 1188}
# {u'Preguntas': 2, u'_id': 5265}
# {u'Preguntas': 2, u'_id': 299}
# {u'Preguntas': 2, u'_id': 2955}
# {u'Preguntas': 2, u'_id': 1631}
# {u'Preguntas': 2, u'_id': 9780}
# {u'Preguntas': 2, u'_id': 305}
# {u'Preguntas': 2, u'_id': 7380}
# {u'Preguntas': 2, u'_id': 3281}
# {u'Preguntas': 2, u'_id': 458}
# {u'Preguntas': 2, u'_id': 6613}
# {u'Preguntas': 2, u'_id': 5577}
# {u'Preguntas': 2, u'_id': 5320}
# {u'Preguntas': 2, u'_id': 1809}
# {u'Preguntas': 2, u'_id': 6007}
# {u'Preguntas': 2, u'_id': 5720}
# {u'Preguntas': 2, u'_id': 4371}
# {u'Preguntas': 2, u'_id': 2392}
# {u'Preguntas': 2, u'_id': 8853}
# {u'Preguntas': 2, u'_id': 3217}
# {u'Preguntas': 2, u'_id': 2394}
# {u'Preguntas': 2, u'_id': 12435}
# {u'Preguntas': 2, u'_id': 2566}
# {u'Preguntas': 2, u'_id': 3280}
# {u'Preguntas': 2, u'_id': 8923}
# {u'Preguntas': 2, u'_id': 9449}
# {u'Preguntas': 2, u'_id': 13612}
# {u'Preguntas': 2, u'_id': 3547}
# {u'Preguntas': 2, u'_id': 5881}
# {u'Preguntas': 2, u'_id': 13178}
# {u'Preguntas': 2, u'_id': 6946}
# {u'Preguntas': 2, u'_id': 3592}
# {u'Preguntas': 2, u'_id': 9680}
# {u'Preguntas': 2, u'_id': 5197}
# {u'Preguntas': 2, u'_id': 3541}
# {u'Preguntas': 2, u'_id': 5737}
# {u'Preguntas': 2, u'_id': 9741}
# {u'Preguntas': 2, u'_id': 11254}
# {u'Preguntas': 2, u'_id': 8999}
# {u'Preguntas': 2, u'_id': 5049}
# {u'Preguntas': 2, u'_id': 9039}
# {u'Preguntas': 2, u'_id': 416}
# {u'Preguntas': 2, u'_id': 2122}
# {u'Preguntas': 2, u'_id': 3763}
# {u'Preguntas': 2, u'_id': 3077}
# {u'Preguntas': 2, u'_id': 3700}
# {u'Preguntas': 2, u'_id': 9376}
# {u'Preguntas': 2, u'_id': 1654}
# {u'Preguntas': 2, u'_id': 288}
# {u'Preguntas': 2, u'_id': 7538}
# {u'Preguntas': 2, u'_id': 1788}
# {u'Preguntas': 2, u'_id': 3250}
# {u'Preguntas': 2, u'_id': 4898}
# {u'Preguntas': 2, u'_id': 4914}
# {u'Preguntas': 2, u'_id': 4937}
# {u'Preguntas': 2, u'_id': 4943}
# {u'Preguntas': 2, u'_id': 6589}
# {u'Preguntas': 2, u'_id': 8738}
# {u'Preguntas': 2, u'_id': 4545}
# {u'Preguntas': 2, u'_id': 4729}
# {u'Preguntas': 2, u'_id': 6269}
# {u'Preguntas': 2, u'_id': 1599}
# {u'Preguntas': 2, u'_id': 6765}
# {u'Preguntas': 2, u'_id': 2722}
# {u'Preguntas': 2, u'_id': 4695}
# {u'Preguntas': 2, u'_id': 6436}
# {u'Preguntas': 2, u'_id': 6831}
# {u'Preguntas': 2, u'_id': 2759}
# {u'Preguntas': 2, u'_id': 6836}
# {u'Preguntas': 2, u'_id': 2800}
# {u'Preguntas': 2, u'_id': 9258}
# {u'Preguntas': 2, u'_id': 5253}
# {u'Preguntas': 2, u'_id': 1494}
# {u'Preguntas': 2, u'_id': 9834}
# {u'Preguntas': 2, u'_id': 9320}
# {u'Preguntas': 2, u'_id': 5327}
# {u'Preguntas': 2, u'_id': 5242}
# {u'Preguntas': 2, u'_id': 7013}
# {u'Preguntas': 2, u'_id': 4894}
# {u'Preguntas': 2, u'_id': 13546}
# {u'Preguntas': 2, u'_id': 5406}
# {u'Preguntas': 2, u'_id': 2883}
# {u'Preguntas': 2, u'_id': 5441}
# {u'Preguntas': 2, u'_id': 5478}
# {u'Preguntas': 2, u'_id': 2920}
# {u'Preguntas': 2, u'_id': 5458}
# {u'Preguntas': 2, u'_id': 5763}
# {u'Preguntas': 2, u'_id': 5519}
# {u'Preguntas': 2, u'_id': 9238}
# {u'Preguntas': 2, u'_id': 5552}
# {u'Preguntas': 2, u'_id': 5569}
# {u'Preguntas': 2, u'_id': 7322}
# {u'Preguntas': 2, u'_id': 5601}
# {u'Preguntas': 2, u'_id': 5602}
# {u'Preguntas': 2, u'_id': 10724}
# {u'Preguntas': 2, u'_id': 29}
# {u'Preguntas': 2, u'_id': 5583}
# {u'Preguntas': 2, u'_id': 5655}
# {u'Preguntas': 2, u'_id': 5659}
# {u'Preguntas': 2, u'_id': 7404}
# {u'Preguntas': 2, u'_id': 10628}
# {u'Preguntas': 2, u'_id': 10806}
# {u'Preguntas': 2, u'_id': 7501}
# {u'Preguntas': 2, u'_id': 2420}
# {u'Preguntas': 2, u'_id': 5870}
# {u'Preguntas': 2, u'_id': 5877}
# {u'Preguntas': 2, u'_id': 5907}
# {u'Preguntas': 2, u'_id': 5990}
# {u'Preguntas': 2, u'_id': 9011}
# {u'Preguntas': 2, u'_id': 1147}
# {u'Preguntas': 2, u'_id': 6842}
# {u'Preguntas': 2, u'_id': 3199}
# {u'Preguntas': 2, u'_id': 6056}
# {u'Preguntas': 2, u'_id': 3224}
# {u'Preguntas': 2, u'_id': 901}
# {u'Preguntas': 2, u'_id': 6031}
# {u'Preguntas': 2, u'_id': 6212}
# {u'Preguntas': 2, u'_id': 11370}
# {u'Preguntas': 2, u'_id': 5493}
# {u'Preguntas': 2, u'_id': 6265}
# {u'Preguntas': 2, u'_id': 6305}
# {u'Preguntas': 2, u'_id': 6360}
# {u'Preguntas': 2, u'_id': 6386}
# {u'Preguntas': 2, u'_id': 5977}
# {u'Preguntas': 2, u'_id': 6407}
# {u'Preguntas': 2, u'_id': 6469}
# {u'Preguntas': 2, u'_id': 6502}
# {u'Preguntas': 2, u'_id': 1805}
# {u'Preguntas': 2, u'_id': 6506}
# {u'Preguntas': 2, u'_id': 264}
# {u'Preguntas': 2, u'_id': 6088}
# {u'Preguntas': 2, u'_id': 3491}
# {u'Preguntas': 2, u'_id': 6654}
# {u'Preguntas': 2, u'_id': 12618}
# {u'Preguntas': 2, u'_id': 3522}
# {u'Preguntas': 2, u'_id': 3517}
# {u'Preguntas': 2, u'_id': 6741}
# {u'Preguntas': 2, u'_id': 6751}
# {u'Preguntas': 2, u'_id': 4810}
# {u'Preguntas': 2, u'_id': 8906}
# {u'Preguntas': 2, u'_id': 12681}
# {u'Preguntas': 2, u'_id': 6829}
# {u'Preguntas': 2, u'_id': 3595}
# {u'Preguntas': 2, u'_id': 6898}
# {u'Preguntas': 2, u'_id': 9134}
# {u'Preguntas': 2, u'_id': 4950}
# {u'Preguntas': 2, u'_id': 7084}
# {u'Preguntas': 2, u'_id': 5845}
# {u'Preguntas': 2, u'_id': 7216}
# {u'Preguntas': 2, u'_id': 7238}
# {u'Preguntas': 2, u'_id': 7255}
# {u'Preguntas': 2, u'_id': 7132}
# {u'Preguntas': 2, u'_id': 10605}
# {u'Preguntas': 2, u'_id': 7519}
# {u'Preguntas': 2, u'_id': 1145}
# {u'Preguntas': 2, u'_id': 7601}
# {u'Preguntas': 2, u'_id': 5257}
# {u'Preguntas': 2, u'_id': 6634}
# {u'Preguntas': 2, u'_id': 4030}
# {u'Preguntas': 2, u'_id': 5231}
# {u'Preguntas': 2, u'_id': 8827}
# {u'Preguntas': 2, u'_id': 3022}
# {u'Preguntas': 2, u'_id': 8931}
# {u'Preguntas': 2, u'_id': 2610}
# {u'Preguntas': 2, u'_id': 9012}
# {u'Preguntas': 2, u'_id': 6656}
# {u'Preguntas': 2, u'_id': 8859}
# {u'Preguntas': 2, u'_id': 9121}
# {u'Preguntas': 2, u'_id': 9129}
# {u'Preguntas': 2, u'_id': 12891}
# {u'Preguntas': 2, u'_id': 13425}
# {u'Preguntas': 2, u'_id': 9390}
# {u'Preguntas': 2, u'_id': 9397}
# {u'Preguntas': 2, u'_id': 533}
# {u'Preguntas': 2, u'_id': 5075}
# {u'Preguntas': 1, u'_id': 13800}
# {u'Preguntas': 1, u'_id': 13809}
# {u'Preguntas': 1, u'_id': 13744}
# {u'Preguntas': 1, u'_id': 13792}
# {u'Preguntas': 1, u'_id': 13789}
# {u'Preguntas': 1, u'_id': 13781}
# {u'Preguntas': 1, u'_id': 13443}
# {u'Preguntas': 1, u'_id': 13767}
# {u'Preguntas': 1, u'_id': 13766}
# {u'Preguntas': 1, u'_id': 13764}
# {u'Preguntas': 1, u'_id': 13726}
# {u'Preguntas': 1, u'_id': 12851}
# {u'Preguntas': 1, u'_id': 13756}
# {u'Preguntas': 1, u'_id': 13750}
# {u'Preguntas': 1, u'_id': 13746}
# {u'Preguntas': 1, u'_id': 13237}
# {u'Preguntas': 1, u'_id': 13723}
# {u'Preguntas': 1, u'_id': 13724}
# {u'Preguntas': 1, u'_id': 13714}
# {u'Preguntas': 1, u'_id': 12424}
# {u'Preguntas': 1, u'_id': 6704}
# {u'Preguntas': 1, u'_id': 13635}
# {u'Preguntas': 1, u'_id': 13626}
# {u'Preguntas': 1, u'_id': 4222}
# {u'Preguntas': 1, u'_id': 13580}
# {u'Preguntas': 1, u'_id': 13610}
# {u'Preguntas': 1, u'_id': 13603}
# {u'Preguntas': 1, u'_id': 13601}
# {u'Preguntas': 1, u'_id': 13587}
# {u'Preguntas': 1, u'_id': 11153}
# {u'Preguntas': 1, u'_id': 13575}
# {u'Preguntas': 1, u'_id': 13574}
# {u'Preguntas': 1, u'_id': 13566}
# {u'Preguntas': 1, u'_id': 1201}
# {u'Preguntas': 1, u'_id': 12727}
# {u'Preguntas': 1, u'_id': 10950}
# {u'Preguntas': 1, u'_id': 11288}
# {u'Preguntas': 1, u'_id': 13506}
# {u'Preguntas': 1, u'_id': 13498}
# {u'Preguntas': 1, u'_id': 13485}
# {u'Preguntas': 1, u'_id': 13483}
# {u'Preguntas': 1, u'_id': 13470}
# {u'Preguntas': 1, u'_id': 13462}
# {u'Preguntas': 1, u'_id': 13466}
# {u'Preguntas': 1, u'_id': 13405}
# {u'Preguntas': 1, u'_id': 13180}
# {u'Preguntas': 1, u'_id': 13450}
# {u'Preguntas': 1, u'_id': 9785}
# {u'Preguntas': 1, u'_id': 5199}
# {u'Preguntas': 1, u'_id': 13433}
# {u'Preguntas': 1, u'_id': 13393}
# {u'Preguntas': 1, u'_id': 11061}
# {u'Preguntas': 1, u'_id': 13350}
# {u'Preguntas': 1, u'_id': 13342}
# {u'Preguntas': 1, u'_id': 13341}
# {u'Preguntas': 1, u'_id': 13339}
# {u'Preguntas': 1, u'_id': 13335}
# {u'Preguntas': 1, u'_id': 9281}
# {u'Preguntas': 1, u'_id': 13326}
# {u'Preguntas': 1, u'_id': 13304}
# {u'Preguntas': 1, u'_id': 13310}
# {u'Preguntas': 1, u'_id': 12774}
# {u'Preguntas': 1, u'_id': 13267}
# {u'Preguntas': 1, u'_id': 13266}
# {u'Preguntas': 1, u'_id': 5847}
# {u'Preguntas': 1, u'_id': 10506}
# {u'Preguntas': 1, u'_id': 6730}
# {u'Preguntas': 1, u'_id': 13251}
# {u'Preguntas': 1, u'_id': 13250}
# {u'Preguntas': 1, u'_id': 13245}
# {u'Preguntas': 1, u'_id': 12994}
# {u'Preguntas': 1, u'_id': 13240}
# {u'Preguntas': 1, u'_id': 13077}
# {u'Preguntas': 1, u'_id': 13194}
# {u'Preguntas': 1, u'_id': 13192}
# {u'Preguntas': 1, u'_id': 13146}
# {u'Preguntas': 1, u'_id': 12754}
# {u'Preguntas': 1, u'_id': 6192}
# {u'Preguntas': 1, u'_id': 13131}
# {u'Preguntas': 1, u'_id': 13100}
# {u'Preguntas': 1, u'_id': 13116}
# {u'Preguntas': 1, u'_id': 12790}
# {u'Preguntas': 1, u'_id': 13112}
# {u'Preguntas': 1, u'_id': 13099}
# {u'Preguntas': 1, u'_id': 13095}
# {u'Preguntas': 1, u'_id': 13085}
# {u'Preguntas': 1, u'_id': 13083}
# {u'Preguntas': 1, u'_id': 13064}
# {u'Preguntas': 1, u'_id': 13062}
# {u'Preguntas': 1, u'_id': 13811}
# {u'Preguntas': 1, u'_id': 10072}
# {u'Preguntas': 1, u'_id': 13023}
# {u'Preguntas': 1, u'_id': 7597}
# {u'Preguntas': 1, u'_id': 10076}
# {u'Preguntas': 1, u'_id': 13005}
# {u'Preguntas': 1, u'_id': 12987}
# {u'Preguntas': 1, u'_id': 12982}
# {u'Preguntas': 1, u'_id': 12968}
# {u'Preguntas': 1, u'_id': 12886}
# {u'Preguntas': 1, u'_id': 12914}
# {u'Preguntas': 1, u'_id': 5365}
# {u'Preguntas': 1, u'_id': 12901}
# {u'Preguntas': 1, u'_id': 12866}
# {u'Preguntas': 1, u'_id': 12865}
# {u'Preguntas': 1, u'_id': 12859}
# {u'Preguntas': 1, u'_id': 12854}
# {u'Preguntas': 1, u'_id': 5324}
# {u'Preguntas': 1, u'_id': 12831}
# {u'Preguntas': 1, u'_id': 12830}
# {u'Preguntas': 1, u'_id': 12829}
# {u'Preguntas': 1, u'_id': 12825}
# {u'Preguntas': 1, u'_id': 7582}
# {u'Preguntas': 1, u'_id': 12804}
# {u'Preguntas': 1, u'_id': 12811}
# {u'Preguntas': 1, u'_id': 12807}
# {u'Preguntas': 1, u'_id': 12798}
# {u'Preguntas': 1, u'_id': 12795}
# {u'Preguntas': 1, u'_id': 12775}
# {u'Preguntas': 1, u'_id': 12755}
# {u'Preguntas': 1, u'_id': 12745}
# {u'Preguntas': 1, u'_id': 12737}
# {u'Preguntas': 1, u'_id': 10062}
# {u'Preguntas': 1, u'_id': 12710}
# {u'Preguntas': 1, u'_id': 8784}
# {u'Preguntas': 1, u'_id': 12700}
# {u'Preguntas': 1, u'_id': 12698}
# {u'Preguntas': 1, u'_id': 12690}
# {u'Preguntas': 1, u'_id': 12677}
# {u'Preguntas': 1, u'_id': 12672}
# {u'Preguntas': 1, u'_id': 12632}
# {u'Preguntas': 1, u'_id': 12631}
# {u'Preguntas': 1, u'_id': 10674}
# {u'Preguntas': 1, u'_id': 12622}
# {u'Preguntas': 1, u'_id': 12611}
# {u'Preguntas': 1, u'_id': 12608}
# {u'Preguntas': 1, u'_id': 9327}
# {u'Preguntas': 1, u'_id': 3291}
# {u'Preguntas': 1, u'_id': 12604}
# {u'Preguntas': 1, u'_id': 12555}
# {u'Preguntas': 1, u'_id': 12550}
# {u'Preguntas': 1, u'_id': 12551}
# {u'Preguntas': 1, u'_id': 12545}
# {u'Preguntas': 1, u'_id': 12535}
# {u'Preguntas': 1, u'_id': 12530}
# {u'Preguntas': 1, u'_id': 12525}
# {u'Preguntas': 1, u'_id': 9953}
# {u'Preguntas': 1, u'_id': 12511}
# {u'Preguntas': 1, u'_id': 12498}
# {u'Preguntas': 1, u'_id': 12496}
# {u'Preguntas': 1, u'_id': 11135}
# {u'Preguntas': 1, u'_id': 12478}
# {u'Preguntas': 1, u'_id': 12472}
# {u'Preguntas': 1, u'_id': 12436}
# {u'Preguntas': 1, u'_id': 12434}
# {u'Preguntas': 1, u'_id': 3390}
# {u'Preguntas': 1, u'_id': 11406}
# {u'Preguntas': 1, u'_id': 11403}
# {u'Preguntas': 1, u'_id': 11397}
# {u'Preguntas': 1, u'_id': 11394}
# {u'Preguntas': 1, u'_id': 11389}
# {u'Preguntas': 1, u'_id': 11381}
# {u'Preguntas': 1, u'_id': 11349}
# {u'Preguntas': 1, u'_id': 11346}
# {u'Preguntas': 1, u'_id': 11343}
# {u'Preguntas': 1, u'_id': 11344}
# {u'Preguntas': 1, u'_id': 11323}
# {u'Preguntas': 1, u'_id': 11308}
# {u'Preguntas': 1, u'_id': 11302}
# {u'Preguntas': 1, u'_id': 10775}
# {u'Preguntas': 1, u'_id': 11295}
# {u'Preguntas': 1, u'_id': 11289}
# {u'Preguntas': 1, u'_id': 11279}
# {u'Preguntas': 1, u'_id': 11278}
# {u'Preguntas': 1, u'_id': 11274}
# {u'Preguntas': 1, u'_id': 11242}
# {u'Preguntas': 1, u'_id': 6296}
# {u'Preguntas': 1, u'_id': 11216}
# {u'Preguntas': 1, u'_id': 11214}
# {u'Preguntas': 1, u'_id': 11213}
# {u'Preguntas': 1, u'_id': 11183}
# {u'Preguntas': 1, u'_id': 11184}
# {u'Preguntas': 1, u'_id': 11179}
# {u'Preguntas': 1, u'_id': 11168}
# {u'Preguntas': 1, u'_id': 11156}
# {u'Preguntas': 1, u'_id': 11155}
# {u'Preguntas': 1, u'_id': 11154}
# {u'Preguntas': 1, u'_id': 13049}
# {u'Preguntas': 1, u'_id': 5012}
# {u'Preguntas': 1, u'_id': 11141}
# {u'Preguntas': 1, u'_id': 11127}
# {u'Preguntas': 1, u'_id': 11123}
# {u'Preguntas': 1, u'_id': 11121}
# {u'Preguntas': 1, u'_id': 11120}
# {u'Preguntas': 1, u'_id': 3054}
# {u'Preguntas': 1, u'_id': 11017}
# {u'Preguntas': 1, u'_id': 11093}
# {u'Preguntas': 1, u'_id': 11088}
# {u'Preguntas': 1, u'_id': 9947}
# {u'Preguntas': 1, u'_id': 11019}
# {u'Preguntas': 1, u'_id': 11015}
# {u'Preguntas': 1, u'_id': 11006}
# {u'Preguntas': 1, u'_id': 11002}
# {u'Preguntas': 1, u'_id': 1641}
# {u'Preguntas': 1, u'_id': 10986}
# {u'Preguntas': 1, u'_id': 10957}
# {u'Preguntas': 1, u'_id': 10945}
# {u'Preguntas': 1, u'_id': 10932}
# {u'Preguntas': 1, u'_id': 10765}
# {u'Preguntas': 1, u'_id': 10876}
# {u'Preguntas': 1, u'_id': 4564}
# {u'Preguntas': 1, u'_id': 10521}
# {u'Preguntas': 1, u'_id': 10890}
# {u'Preguntas': 1, u'_id': 10886}
# {u'Preguntas': 1, u'_id': 10878}
# {u'Preguntas': 1, u'_id': 10875}
# {u'Preguntas': 1, u'_id': 10872}
# {u'Preguntas': 1, u'_id': 10857}
# {u'Preguntas': 1, u'_id': 10826}
# {u'Preguntas': 1, u'_id': 10163}
# {u'Preguntas': 1, u'_id': 10641}
# {u'Preguntas': 1, u'_id': 10811}
# {u'Preguntas': 1, u'_id': 10782}
# {u'Preguntas': 1, u'_id': 10774}
# {u'Preguntas': 1, u'_id': 10147}
# {u'Preguntas': 1, u'_id': 10748}
# {u'Preguntas': 1, u'_id': 10725}
# {u'Preguntas': 1, u'_id': 10713}
# {u'Preguntas': 1, u'_id': 10708}
# {u'Preguntas': 1, u'_id': 9814}
# {u'Preguntas': 1, u'_id': 10689}
# {u'Preguntas': 1, u'_id': 10676}
# {u'Preguntas': 1, u'_id': 10671}
# {u'Preguntas': 1, u'_id': 10486}
# {u'Preguntas': 1, u'_id': 10663}
# {u'Preguntas': 1, u'_id': 10662}
# {u'Preguntas': 1, u'_id': 6644}
# {u'Preguntas': 1, u'_id': 10640}
# {u'Preguntas': 1, u'_id': 10638}
# {u'Preguntas': 1, u'_id': 10305}
# {u'Preguntas': 1, u'_id': 10610}
# {u'Preguntas': 1, u'_id': 10603}
# {u'Preguntas': 1, u'_id': 10600}
# {u'Preguntas': 1, u'_id': 7498}
# {u'Preguntas': 1, u'_id': 10579}
# {u'Preguntas': 1, u'_id': 10560}
# {u'Preguntas': 1, u'_id': 10550}
# {u'Preguntas': 1, u'_id': 10545}
# {u'Preguntas': 1, u'_id': 10536}
# {u'Preguntas': 1, u'_id': 10531}
# {u'Preguntas': 1, u'_id': 10511}
# {u'Preguntas': 1, u'_id': 10509}
# {u'Preguntas': 1, u'_id': 4678}
# {u'Preguntas': 1, u'_id': 10495}
# {u'Preguntas': 1, u'_id': 10018}
# {u'Preguntas': 1, u'_id': 10481}
# {u'Preguntas': 1, u'_id': 10476}
# {u'Preguntas': 1, u'_id': 10471}
# {u'Preguntas': 1, u'_id': 10464}
# {u'Preguntas': 1, u'_id': 10465}
# {u'Preguntas': 1, u'_id': 10455}
# {u'Preguntas': 1, u'_id': 5958}
# {u'Preguntas': 1, u'_id': 10401}
# {u'Preguntas': 1, u'_id': 10427}
# {u'Preguntas': 1, u'_id': 12913}
# {u'Preguntas': 1, u'_id': 10405}
# {u'Preguntas': 1, u'_id': 3512}
# {u'Preguntas': 1, u'_id': 10396}
# {u'Preguntas': 1, u'_id': 10394}
# {u'Preguntas': 1, u'_id': 10358}
# {u'Preguntas': 1, u'_id': 10357}
# {u'Preguntas': 1, u'_id': 10334}
# {u'Preguntas': 1, u'_id': 10304}
# {u'Preguntas': 1, u'_id': 10291}
# {u'Preguntas': 1, u'_id': 10292}
# {u'Preguntas': 1, u'_id': 10290}
# {u'Preguntas': 1, u'_id': 10288}
# {u'Preguntas': 1, u'_id': 10284}
# {u'Preguntas': 1, u'_id': 10273}
# {u'Preguntas': 1, u'_id': 9691}
# {u'Preguntas': 1, u'_id': 10258}
# {u'Preguntas': 1, u'_id': 10255}
# {u'Preguntas': 1, u'_id': 10249}
# {u'Preguntas': 1, u'_id': 10235}
# {u'Preguntas': 1, u'_id': 9761}
# {u'Preguntas': 1, u'_id': 4934}
# {u'Preguntas': 1, u'_id': 9983}
# {u'Preguntas': 1, u'_id': 9803}
# {u'Preguntas': 1, u'_id': 10197}
# {u'Preguntas': 1, u'_id': 10109}
# {u'Preguntas': 1, u'_id': 10185}
# {u'Preguntas': 1, u'_id': 10187}
# {u'Preguntas': 1, u'_id': 10186}
# {u'Preguntas': 1, u'_id': 10174}
# {u'Preguntas': 1, u'_id': 5297}
# {u'Preguntas': 1, u'_id': 10136}
# {u'Preguntas': 1, u'_id': 10134}
# {u'Preguntas': 1, u'_id': 10126}
# {u'Preguntas': 1, u'_id': 10115}
# {u'Preguntas': 1, u'_id': 10108}
# {u'Preguntas': 1, u'_id': 3902}
# {u'Preguntas': 1, u'_id': 10099}
# {u'Preguntas': 1, u'_id': 10094}
# {u'Preguntas': 1, u'_id': 10091}
# {u'Preguntas': 1, u'_id': 10086}
# {u'Preguntas': 1, u'_id': 2225}
# {u'Preguntas': 1, u'_id': 7424}
# {u'Preguntas': 1, u'_id': 9487}
# {u'Preguntas': 1, u'_id': 13798}
# {u'Preguntas': 1, u'_id': 10059}
# {u'Preguntas': 1, u'_id': 13797}
# {u'Preguntas': 1, u'_id': 10058}
# {u'Preguntas': 1, u'_id': 13788}
# {u'Preguntas': 1, u'_id': 7251}
# {u'Preguntas': 1, u'_id': 10052}
# {u'Preguntas': 1, u'_id': 10047}
# {u'Preguntas': 1, u'_id': 7478}
# {u'Preguntas': 1, u'_id': 10036}
# {u'Preguntas': 1, u'_id': 13773}
# {u'Preguntas': 1, u'_id': 10034}
# {u'Preguntas': 1, u'_id': 10030}
# {u'Preguntas': 1, u'_id': 10024}
# {u'Preguntas': 1, u'_id': 9999}
# {u'Preguntas': 1, u'_id': 13731}
# {u'Preguntas': 1, u'_id': 9992}
# {u'Preguntas': 1, u'_id': 13730}
# {u'Preguntas': 1, u'_id': 13711}
# {u'Preguntas': 1, u'_id': 9972}
# {u'Preguntas': 1, u'_id': 9955}
# {u'Preguntas': 1, u'_id': 9952}
# {u'Preguntas': 1, u'_id': 9944}
# {u'Preguntas': 1, u'_id': 1012}
# {u'Preguntas': 1, u'_id': 9930}
# {u'Preguntas': 1, u'_id': 13658}
# {u'Preguntas': 1, u'_id': 9919}
# {u'Preguntas': 1, u'_id': 13651}
# {u'Preguntas': 1, u'_id': 9907}
# {u'Preguntas': 1, u'_id': 9902}
# {u'Preguntas': 1, u'_id': 1368}
# {u'Preguntas': 1, u'_id': 9855}
# {u'Preguntas': 1, u'_id': 883}
# {u'Preguntas': 1, u'_id': 13577}
# {u'Preguntas': 1, u'_id': 9838}
# {u'Preguntas': 1, u'_id': 9822}
# {u'Preguntas': 1, u'_id': 9776}
# {u'Preguntas': 1, u'_id': 9808}
# {u'Preguntas': 1, u'_id': 9806}
# {u'Preguntas': 1, u'_id': 9798}
# {u'Preguntas': 1, u'_id': 9789}
# {u'Preguntas': 1, u'_id': 9786}
# {u'Preguntas': 1, u'_id': 9773}
# {u'Preguntas': 1, u'_id': 9756}
# {u'Preguntas': 1, u'_id': 9757}
# {u'Preguntas': 1, u'_id': 9692}
# {u'Preguntas': 1, u'_id': 9700}
# {u'Preguntas': 1, u'_id': 9745}
# {u'Preguntas': 1, u'_id': 9738}
# {u'Preguntas': 1, u'_id': 3615}
# {u'Preguntas': 1, u'_id': 13440}
# {u'Preguntas': 1, u'_id': 9701}
# {u'Preguntas': 1, u'_id': 13429}
# {u'Preguntas': 1, u'_id': 9690}
# {u'Preguntas': 1, u'_id': 9660}
# {u'Preguntas': 1, u'_id': 9658}
# {u'Preguntas': 1, u'_id': 9642}
# {u'Preguntas': 1, u'_id': 13165}
# {u'Preguntas': 1, u'_id': 9426}
# {u'Preguntas': 1, u'_id': 9632}
# {u'Preguntas': 1, u'_id': 9627}
# {u'Preguntas': 1, u'_id': 13362}
# {u'Preguntas': 1, u'_id': 9623}
# {u'Preguntas': 1, u'_id': 9616}
# {u'Preguntas': 1, u'_id': 9612}
# {u'Preguntas': 1, u'_id': 12822}
# {u'Preguntas': 1, u'_id': 6768}
# {u'Preguntas': 1, u'_id': 9592}
# {u'Preguntas': 1, u'_id': 9588}
# {u'Preguntas': 1, u'_id': 13303}
# {u'Preguntas': 1, u'_id': 9564}
# {u'Preguntas': 1, u'_id': 9547}
# {u'Preguntas': 1, u'_id': 9544}
# {u'Preguntas': 1, u'_id': 13282}
# {u'Preguntas': 1, u'_id': 9543}
# {u'Preguntas': 1, u'_id': 9542}
# {u'Preguntas': 1, u'_id': 13278}
# {u'Preguntas': 1, u'_id': 9530}
# {u'Preguntas': 1, u'_id': 9526}
# {u'Preguntas': 1, u'_id': 9523}
# {u'Preguntas': 1, u'_id': 9516}
# {u'Preguntas': 1, u'_id': 9514}
# {u'Preguntas': 1, u'_id': 9510}
# {u'Preguntas': 1, u'_id': 2744}
# {u'Preguntas': 1, u'_id': 4813}
# {u'Preguntas': 1, u'_id': 6554}
# {u'Preguntas': 1, u'_id': 4688}
# {u'Preguntas': 1, u'_id': 4799}
# {u'Preguntas': 1, u'_id': 3577}
# {u'Preguntas': 1, u'_id': 4788}
# {u'Preguntas': 1, u'_id': 12565}
# {u'Preguntas': 1, u'_id': 4756}
# {u'Preguntas': 1, u'_id': 9312}
# {u'Preguntas': 1, u'_id': 2685}
# {u'Preguntas': 1, u'_id': 4757}
# {u'Preguntas': 1, u'_id': 4520}
# {u'Preguntas': 1, u'_id': 77}
# {u'Preguntas': 1, u'_id': 12441}
# {u'Preguntas': 1, u'_id': 1349}
# {u'Preguntas': 1, u'_id': 11104}
# {u'Preguntas': 1, u'_id': 5909}
# {u'Preguntas': 1, u'_id': 9706}
# {u'Preguntas': 1, u'_id': 1481}
# {u'Preguntas': 1, u'_id': 6417}
# {u'Preguntas': 1, u'_id': 4663}
# {u'Preguntas': 1, u'_id': 7701}
# {u'Preguntas': 1, u'_id': 4656}
# {u'Preguntas': 1, u'_id': 4637}
# {u'Preguntas': 1, u'_id': 4208}
# {u'Preguntas': 1, u'_id': 659}
# {u'Preguntas': 1, u'_id': 6339}
# {u'Preguntas': 1, u'_id': 3945}
# {u'Preguntas': 1, u'_id': 10821}
# {u'Preguntas': 1, u'_id': 7637}
# {u'Preguntas': 1, u'_id': 4840}
# {u'Preguntas': 1, u'_id': 8966}
# {u'Preguntas': 1, u'_id': 4571}
# {u'Preguntas': 1, u'_id': 4563}
# {u'Preguntas': 1, u'_id': 3459}
# {u'Preguntas': 1, u'_id': 4544}
# {u'Preguntas': 1, u'_id': 6278}
# {u'Preguntas': 1, u'_id': 4516}
# {u'Preguntas': 1, u'_id': 4582}
# {u'Preguntas': 1, u'_id': 1136}
# {u'Preguntas': 1, u'_id': 4432}
# {u'Preguntas': 1, u'_id': 1415}
# {u'Preguntas': 1, u'_id': 6197}
# {u'Preguntas': 1, u'_id': 4474}
# {u'Preguntas': 1, u'_id': 13200}
# {u'Preguntas': 1, u'_id': 9461}
# {u'Preguntas': 1, u'_id': 3340}
# {u'Preguntas': 1, u'_id': 6188}
# {u'Preguntas': 1, u'_id': 4440}
# {u'Preguntas': 1, u'_id': 4439}
# {u'Preguntas': 1, u'_id': 6180}
# {u'Preguntas': 1, u'_id': 4423}
# {u'Preguntas': 1, u'_id': 4421}
# {u'Preguntas': 1, u'_id': 4414}
# {u'Preguntas': 1, u'_id': 6155}
# {u'Preguntas': 1, u'_id': 4384}
# {u'Preguntas': 1, u'_id': 13016}
# {u'Preguntas': 1, u'_id': 4370}
# {u'Preguntas': 1, u'_id': 4360}
# {u'Preguntas': 1, u'_id': 4362}
# {u'Preguntas': 1, u'_id': 2488}
# {u'Preguntas': 1, u'_id': 6103}
# {u'Preguntas': 1, u'_id': 4348}
# {u'Preguntas': 1, u'_id': 3221}
# {u'Preguntas': 1, u'_id': 7593}
# {u'Preguntas': 1, u'_id': 10485}
# {u'Preguntas': 1, u'_id': 11337}
# {u'Preguntas': 1, u'_id': 5897}
# {u'Preguntas': 1, u'_id': 7638}
# {u'Preguntas': 1, u'_id': 4271}
# {u'Preguntas': 1, u'_id': 4264}
# {u'Preguntas': 1, u'_id': 2430}
# {u'Preguntas': 1, u'_id': 7728}
# {u'Preguntas': 1, u'_id': 9005}
# {u'Preguntas': 1, u'_id': 4215}
# {u'Preguntas': 1, u'_id': 8943}
# {u'Preguntas': 1, u'_id': 376}
# {u'Preguntas': 1, u'_id': 2087}
# {u'Preguntas': 1, u'_id': 5301}
# {u'Preguntas': 1, u'_id': 2158}
# {u'Preguntas': 1, u'_id': 7184}
# {u'Preguntas': 1, u'_id': 4198}
# {u'Preguntas': 1, u'_id': 11309}
# {u'Preguntas': 1, u'_id': 749}
# {u'Preguntas': 1, u'_id': 11259}
# {u'Preguntas': 1, u'_id': 4105}
# {u'Preguntas': 1, u'_id': 7587}
# {u'Preguntas': 1, u'_id': 5811}
# {u'Preguntas': 1, u'_id': 4061}
# {u'Preguntas': 1, u'_id': 11045}
# {u'Preguntas': 1, u'_id': 4053}
# {u'Preguntas': 1, u'_id': 9189}
# {u'Preguntas': 1, u'_id': 3589}
# {u'Preguntas': 1, u'_id': 4787}
# {u'Preguntas': 1, u'_id': 5705}
# {u'Preguntas': 1, u'_id': 1719}
# {u'Preguntas': 1, u'_id': 4020}
# {u'Preguntas': 1, u'_id': 4008}
# {u'Preguntas': 1, u'_id': 11238}
# {u'Preguntas': 1, u'_id': 3987}
# {u'Preguntas': 1, u'_id': 7318}
# {u'Preguntas': 1, u'_id': 2478}
# {u'Preguntas': 1, u'_id': 3946}
# {u'Preguntas': 1, u'_id': 7278}
# {u'Preguntas': 1, u'_id': 3935}
# {u'Preguntas': 1, u'_id': 10561}
# {u'Preguntas': 1, u'_id': 3932}
# {u'Preguntas': 1, u'_id': 10553}
# {u'Preguntas': 1, u'_id': 3930}
# {u'Preguntas': 1, u'_id': 13778}
# {u'Preguntas': 1, u'_id': 7246}
# {u'Preguntas': 1, u'_id': 3927}
# {u'Preguntas': 1, u'_id': 2186}
# {u'Preguntas': 1, u'_id': 4577}
# {u'Preguntas': 1, u'_id': 10533}
# {u'Preguntas': 1, u'_id': 3925}
# {u'Preguntas': 1, u'_id': 7236}
# {u'Preguntas': 1, u'_id': 3906}
# {u'Preguntas': 1, u'_id': 3901}
# {u'Preguntas': 1, u'_id': 10341}
# {u'Preguntas': 1, u'_id': 3877}
# {u'Preguntas': 1, u'_id': 10859}
# {u'Preguntas': 1, u'_id': 2137}
# {u'Preguntas': 1, u'_id': 4465}
# {u'Preguntas': 1, u'_id': 10309}
# {u'Preguntas': 1, u'_id': 3874}
# {u'Preguntas': 1, u'_id': 9482}
# {u'Preguntas': 1, u'_id': 9470}
# {u'Preguntas': 1, u'_id': 10169}
# {u'Preguntas': 1, u'_id': 10149}
# {u'Preguntas': 1, u'_id': 3829}
# {u'Preguntas': 1, u'_id': 4383}
# {u'Preguntas': 1, u'_id': 3811}
# {u'Preguntas': 1, u'_id': 5267}
# {u'Preguntas': 1, u'_id': 3786}
# {u'Preguntas': 1, u'_id': 9720}
# {u'Preguntas': 1, u'_id': 786}
# {u'Preguntas': 1, u'_id': 5217}
# {u'Preguntas': 1, u'_id': 12869}
# {u'Preguntas': 1, u'_id': 13106}
# {u'Preguntas': 1, u'_id': 13592}
# ...
# {u'Preguntas': 1, u'_id': 13235}
# {u'Preguntas': 1, u'_id': 2731}
# {u'Preguntas': 1, u'_id': 5105}
# {u'Preguntas': 1, u'_id': 6846}
# {u'Preguntas': 1, u'_id': 5109}
# {u'Preguntas': 1, u'_id': 12729}
# {u'Preguntas': 1, u'_id': 13277}
# {u'Preguntas': 1, u'_id': 5126}
# {u'Preguntas': 1, u'_id': 8793}
# {u'Preguntas': 1, u'_id': 3490}
# {u'Preguntas': 1, u'_id': 6366}
# {u'Preguntas': 1, u'_id': 9540}
# {u'Preguntas': 1, u'_id': 5127}
# {u'Preguntas': 1, u'_id': 4316}
# {u'Preguntas': 1, u'_id': 9145}
# {u'Preguntas': 1, u'_id': 13347}
# {u'Preguntas': 1, u'_id': 5161}
# {u'Preguntas': 1, u'_id': 6902}
# {u'Preguntas': 1, u'_id': 13377}
# {u'Preguntas': 1, u'_id': 5176}
# {u'Preguntas': 1, u'_id': 7650}
# {u'Preguntas': 1, u'_id': 12958}
# {u'Preguntas': 1, u'_id': 8962}
# {u'Preguntas': 1, u'_id': 5218}
# {u'Preguntas': 1, u'_id': 5215}
# {u'Preguntas': 1, u'_id': 9758}
# {u'Preguntas': 1, u'_id': 5236}
# {u'Preguntas': 1, u'_id': 5240}
# {u'Preguntas': 1, u'_id': 4983}
# {u'Preguntas': 1, u'_id': 9252}
# {u'Preguntas': 1, u'_id': 5243}
# {u'Preguntas': 1, u'_id': 5262}
# {u'Preguntas': 1, u'_id': 13316}
# {u'Preguntas': 1, u'_id': 7015}
# {u'Preguntas': 1, u'_id': 4959}
# {u'Preguntas': 1, u'_id': 5295}
# {u'Preguntas': 1, u'_id': 13647}
# {u'Preguntas': 1, u'_id': 5311}
# {u'Preguntas': 1, u'_id': 4447}
# {u'Preguntas': 1, u'_id': 5076}
# {u'Preguntas': 1, u'_id': 2842}
# {u'Preguntas': 1, u'_id': 7068}
# {u'Preguntas': 1, u'_id': 9770}
# {u'Preguntas': 1, u'_id': 6983}
# {u'Preguntas': 1, u'_id': 12995}
# {u'Preguntas': 1, u'_id': 4985}
# {u'Preguntas': 1, u'_id': 9256}
# {u'Preguntas': 1, u'_id': 5130}
# {u'Preguntas': 1, u'_id': 9450}
# {u'Preguntas': 1, u'_id': 13709}
# {u'Preguntas': 1, u'_id': 9970}
# {u'Preguntas': 1, u'_id': 5342}
# {u'Preguntas': 1, u'_id': 9974}
# {u'Preguntas': 1, u'_id': 5344}
# {u'Preguntas': 1, u'_id': 13725}
# {u'Preguntas': 1, u'_id': 13569}
# {u'Preguntas': 1, u'_id': 9573}
# {u'Preguntas': 1, u'_id': 3685}
# {u'Preguntas': 1, u'_id': 5358}
# {u'Preguntas': 1, u'_id': 9804}
# {u'Preguntas': 1, u'_id': 2808}
# {u'Preguntas': 1, u'_id': 5244}
# {u'Preguntas': 1, u'_id': 1007}
# {u'Preguntas': 1, u'_id': 6985}
# {u'Preguntas': 1, u'_id': 9074}
# {u'Preguntas': 1, u'_id': 3496}
# {u'Preguntas': 1, u'_id': 5376}
# {u'Preguntas': 1, u'_id': 7130}
# {u'Preguntas': 1, u'_id': 12805}
# {u'Preguntas': 1, u'_id': 9265}
# {u'Preguntas': 1, u'_id': 2871}
# {u'Preguntas': 1, u'_id': 807}
# {u'Preguntas': 1, u'_id': 5385}
# {u'Preguntas': 1, u'_id': 10100}
# {u'Preguntas': 1, u'_id': 5407}
# {u'Preguntas': 1, u'_id': 7148}
# {u'Preguntas': 1, u'_id': 10104}
# {u'Preguntas': 1, u'_id': 5409}
# {u'Preguntas': 1, u'_id': 9847}
# {u'Preguntas': 1, u'_id': 7150}
# {u'Preguntas': 1, u'_id': 5427}
# {u'Preguntas': 1, u'_id': 5449}
# {u'Preguntas': 1, u'_id': 5456}
# {u'Preguntas': 1, u'_id': 7202}
# {u'Preguntas': 1, u'_id': 5467}
# {u'Preguntas': 1, u'_id': 5469}
# {u'Preguntas': 1, u'_id': 10995}
# {u'Preguntas': 1, u'_id': 5480}
# {u'Preguntas': 1, u'_id': 1548}
# {u'Preguntas': 1, u'_id': 5481}
# {u'Preguntas': 1, u'_id': 5483}
# {u'Preguntas': 1, u'_id': 7224}
# {u'Preguntas': 1, u'_id': 10202}
# {u'Preguntas': 1, u'_id': 1543}
# {u'Preguntas': 1, u'_id': 10298}
# {u'Preguntas': 1, u'_id': 1555}
# {u'Preguntas': 1, u'_id': 5506}
# {u'Preguntas': 1, u'_id': 5517}
# {u'Preguntas': 1, u'_id': 5521}
# {u'Preguntas': 1, u'_id': 5523}
# {u'Preguntas': 1, u'_id': 10336}
# {u'Preguntas': 1, u'_id': 5525}
# {u'Preguntas': 1, u'_id': 13818}
# {u'Preguntas': 1, u'_id': 10354}
# {u'Preguntas': 1, u'_id': 5534}
# {u'Preguntas': 1, u'_id': 5538}
# {u'Preguntas': 1, u'_id': 13491}
# {u'Preguntas': 1, u'_id': 2795}
# {u'Preguntas': 1, u'_id': 5233}
# {u'Preguntas': 1, u'_id': 13234}
# {u'Preguntas': 1, u'_id': 7061}
# {u'Preguntas': 1, u'_id': 3709}
# {u'Preguntas': 1, u'_id': 5351}
# {u'Preguntas': 1, u'_id': 5094}
# {u'Preguntas': 1, u'_id': 10448}
# {u'Preguntas': 1, u'_id': 2969}
# {u'Preguntas': 1, u'_id': 5581}
# {u'Preguntas': 1, u'_id': 5598}
# {u'Preguntas': 1, u'_id': 5620}
# {u'Preguntas': 1, u'_id': 5408}
# {u'Preguntas': 1, u'_id': 5630}
# {u'Preguntas': 1, u'_id': 7371}
# {u'Preguntas': 1, u'_id': 5638}
# {u'Preguntas': 1, u'_id': 10586}
# {u'Preguntas': 1, u'_id': 5650}
# {u'Preguntas': 1, u'_id': 7395}
# {u'Preguntas': 1, u'_id': 5665}
# {u'Preguntas': 1, u'_id': 10359}
# {u'Preguntas': 1, u'_id': 7406}
# {u'Preguntas': 1, u'_id': 3014}
# {u'Preguntas': 1, u'_id': 5671}
# {u'Preguntas': 1, u'_id': 7412}
# {u'Preguntas': 1, u'_id': 5668}
# {u'Preguntas': 1, u'_id': 10365}
# {u'Preguntas': 1, u'_id': 7409}
# {u'Preguntas': 1, u'_id': 5689}
# {u'Preguntas': 1, u'_id': 7430}
# {u'Preguntas': 1, u'_id': 10686}
# {u'Preguntas': 1, u'_id': 3899}
# {u'Preguntas': 1, u'_id': 3334}
# {u'Preguntas': 1, u'_id': 5706}
# {u'Preguntas': 1, u'_id': 5715}
# {u'Preguntas': 1, u'_id': 7456}
# {u'Preguntas': 1, u'_id': 1609}
# {u'Preguntas': 1, u'_id': 5722}
# {u'Preguntas': 1, u'_id': 5732}
# {u'Preguntas': 1, u'_id': 3053}
# {u'Preguntas': 1, u'_id': 5749}
# {u'Preguntas': 1, u'_id': 5582}
# {u'Preguntas': 1, u'_id': 7323}
# {u'Preguntas': 1, u'_id': 5758}
# {u'Preguntas': 1, u'_id': 5760}
# {u'Preguntas': 1, u'_id': 1119}
# {u'Preguntas': 1, u'_id': 5761}
# {u'Preguntas': 1, u'_id': 5768}
# {u'Preguntas': 1, u'_id': 4453}
# {u'Preguntas': 1, u'_id': 6194}
# {u'Preguntas': 1, u'_id': 5789}
# {u'Preguntas': 1, u'_id': 2074}
# {u'Preguntas': 1, u'_id': 7530}
# {u'Preguntas': 1, u'_id': 10900}
# {u'Preguntas': 1, u'_id': 5807}
# {u'Preguntas': 1, u'_id': 7548}
# {u'Preguntas': 1, u'_id': 5806}
# {u'Preguntas': 1, u'_id': 5816}
# {u'Preguntas': 1, u'_id': 5824}
# {u'Preguntas': 1, u'_id': 3961}
# {u'Preguntas': 1, u'_id': 7565}
# {u'Preguntas': 1, u'_id': 5838}
# {u'Preguntas': 1, u'_id': 7579}
# {u'Preguntas': 1, u'_id': 5840}
# {u'Preguntas': 1, u'_id': 5837}
# {u'Preguntas': 1, u'_id': 7578}
# {u'Preguntas': 1, u'_id': 11026}
# {u'Preguntas': 1, u'_id': 8819}
# {u'Preguntas': 1, u'_id': 13591}
# {u'Preguntas': 1, u'_id': 2820}
# {u'Preguntas': 1, u'_id': 3128}
# {u'Preguntas': 1, u'_id': 5899}
# {u'Preguntas': 1, u'_id': 7662}
# {u'Preguntas': 1, u'_id': 5919}
# {u'Preguntas': 1, u'_id': 5930}
# {u'Preguntas': 1, u'_id': 4191}
# {u'Preguntas': 1, u'_id': 12634}
# {u'Preguntas': 1, u'_id': 8895}
# {u'Preguntas': 1, u'_id': 3159}
# {u'Preguntas': 1, u'_id': 5961}
# {u'Preguntas': 1, u'_id': 8953}
# {u'Preguntas': 1, u'_id': 11266}
# {u'Preguntas': 1, u'_id': 11009}
# {u'Preguntas': 1, u'_id': 7731}
# {u'Preguntas': 1, u'_id': 12750}
# {u'Preguntas': 1, u'_id': 5980}
# {u'Preguntas': 1, u'_id': 5999}
# {u'Preguntas': 1, u'_id': 6000}
# {u'Preguntas': 1, u'_id': 6021}
# {u'Preguntas': 1, u'_id': 6037}
# {u'Preguntas': 1, u'_id': 6041}
# {u'Preguntas': 1, u'_id': 4062}
# {u'Preguntas': 1, u'_id': 9143}
# {u'Preguntas': 1, u'_id': 6076}
# {u'Preguntas': 1, u'_id': 6087}
# {u'Preguntas': 1, u'_id': 6091}
# {u'Preguntas': 1, u'_id': 272}
# {u'Preguntas': 1, u'_id': 6097}
# {u'Preguntas': 1, u'_id': 9225}
# {u'Preguntas': 1, u'_id': 6115}
# {u'Preguntas': 1, u'_id': 3607}
# {u'Preguntas': 1, u'_id': 3247}
# {u'Preguntas': 1, u'_id': 3618}
# {u'Preguntas': 1, u'_id': 5982}
# {u'Preguntas': 1, u'_id': 8995}
# {u'Preguntas': 1, u'_id': 3262}
# {u'Preguntas': 1, u'_id': 6167}
# {u'Preguntas': 1, u'_id': 6178}
# {u'Preguntas': 1, u'_id': 1733}
# {u'Preguntas': 1, u'_id': 6218}
# {u'Preguntas': 1, u'_id': 6217}
# {u'Preguntas': 1, u'_id': 9465}
# {u'Preguntas': 1, u'_id': 6042}
# {u'Preguntas': 1, u'_id': 6224}
# {u'Preguntas': 1, u'_id': 6230}
# {u'Preguntas': 1, u'_id': 6231}
# {u'Preguntas': 1, u'_id': 6239}
# {u'Preguntas': 1, u'_id': 6264}
# {u'Preguntas': 1, u'_id': 3311}
# {u'Preguntas': 1, u'_id': 6283}
# {u'Preguntas': 1, u'_id': 3330}
# {u'Preguntas': 1, u'_id': 6303}
# {u'Preguntas': 1, u'_id': 3331}
# {u'Preguntas': 1, u'_id': 6314}
# {u'Preguntas': 1, u'_id': 3336}
# {u'Preguntas': 1, u'_id': 6315}
# {u'Preguntas': 1, u'_id': 4574}
# {u'Preguntas': 1, u'_id': 6340}
# {u'Preguntas': 1, u'_id': 6147}
# {u'Preguntas': 1, u'_id': 6352}
# {u'Preguntas': 1, u'_id': 6356}
# {u'Preguntas': 1, u'_id': 6384}
# {u'Preguntas': 1, u'_id': 3167}
# {u'Preguntas': 1, u'_id': 6394}
# {u'Preguntas': 1, u'_id': 6432}
# {u'Preguntas': 1, u'_id': 3424}
# {u'Preguntas': 1, u'_id': 9499}
# {u'Preguntas': 1, u'_id': 6442}
# {u'Preguntas': 1, u'_id': 6453}
# {u'Preguntas': 1, u'_id': 6462}
# {u'Preguntas': 1, u'_id': 6471}
# {u'Preguntas': 1, u'_id': 1798}
# {u'Preguntas': 1, u'_id': 6478}
# {u'Preguntas': 1, u'_id': 6291}
# {u'Preguntas': 1, u'_id': 6496}
# {u'Preguntas': 1, u'_id': 6501}
# {u'Preguntas': 1, u'_id': 6503}
# {u'Preguntas': 1, u'_id': 6515}
# {u'Preguntas': 1, u'_id': 1812}
# {u'Preguntas': 1, u'_id': 3452}
# {u'Preguntas': 1, u'_id': 6547}
# {u'Preguntas': 1, u'_id': 6581}
# {u'Preguntas': 1, u'_id': 6584}
# {u'Preguntas': 1, u'_id': 6591}
# {u'Preguntas': 1, u'_id': 6519}
# {u'Preguntas': 1, u'_id': 6617}
# {u'Preguntas': 1, u'_id': 6618}
# {u'Preguntas': 1, u'_id': 2848}
# {u'Preguntas': 1, u'_id': 6625}
# {u'Preguntas': 1, u'_id': 8855}
# {u'Preguntas': 1, u'_id': 6666}
# {u'Preguntas': 1, u'_id': 6681}
# {u'Preguntas': 1, u'_id': 6687}
# {u'Preguntas': 1, u'_id': 12640}
# {u'Preguntas': 1, u'_id': 8901}
# {u'Preguntas': 1, u'_id': 9029}
# {u'Preguntas': 1, u'_id': 6747}
# {u'Preguntas': 1, u'_id': 2960}
# {u'Preguntas': 1, u'_id': 5563}
# {u'Preguntas': 1, u'_id': 6754}
# {u'Preguntas': 1, u'_id': 6778}
# {u'Preguntas': 1, u'_id': 4791}
# {u'Preguntas': 1, u'_id': 8868}
# {u'Preguntas': 1, u'_id': 6781}
# {u'Preguntas': 1, u'_id': 12902}
# {u'Preguntas': 1, u'_id': 6808}
# {u'Preguntas': 1, u'_id': 12645}
# {u'Preguntas': 1, u'_id': 6794}
# {u'Preguntas': 1, u'_id': 4822}
# {u'Preguntas': 1, u'_id': 6201}
# {u'Preguntas': 1, u'_id': 12936}
# {u'Preguntas': 1, u'_id': 9197}
# {u'Preguntas': 1, u'_id': 6825}
# {u'Preguntas': 1, u'_id': 6826}
# {u'Preguntas': 1, u'_id': 8942}
# {u'Preguntas': 1, u'_id': 6550}
# {u'Preguntas': 1, u'_id': 12952}
# {u'Preguntas': 1, u'_id': 6837}
# {u'Preguntas': 1, u'_id': 6870}
# {u'Preguntas': 1, u'_id': 4192}
# {u'Preguntas': 1, u'_id': 6884}
# {u'Preguntas': 1, u'_id': 6901}
# {u'Preguntas': 1, u'_id': 9391}
# {u'Preguntas': 1, u'_id': 6922}
# {u'Preguntas': 1, u'_id': 6948}
# {u'Preguntas': 1, u'_id': 9186}
# {u'Preguntas': 1, u'_id': 3656}
# {u'Preguntas': 1, u'_id': 6971}
# {u'Preguntas': 1, u'_id': 6849}
# {u'Preguntas': 1, u'_id': 7014}
# {u'Preguntas': 1, u'_id': 9599}
# {u'Preguntas': 1, u'_id': 7026}
# {u'Preguntas': 1, u'_id': 3545}
# {u'Preguntas': 1, u'_id': 7035}
# {u'Preguntas': 1, u'_id': 13410}
# {u'Preguntas': 1, u'_id': 7062}
# {u'Preguntas': 1, u'_id': 9414}
# {u'Preguntas': 1, u'_id': 6914}
# {u'Preguntas': 1, u'_id': 4916}
# {u'Preguntas': 1, u'_id': 9118}
# {u'Preguntas': 1, u'_id': 7071}
# {u'Preguntas': 1, u'_id': 9724}
# {u'Preguntas': 1, u'_id': 7063}
# {u'Preguntas': 1, u'_id': 13454}
# {u'Preguntas': 1, u'_id': 9749}
# {u'Preguntas': 1, u'_id': 9492}
# {u'Preguntas': 1, u'_id': 12876}
# {u'Preguntas': 1, u'_id': 6795}
# {u'Preguntas': 1, u'_id': 8880}
# {u'Preguntas': 1, u'_id': 7122}
# {u'Preguntas': 1, u'_id': 13552}
# {u'Preguntas': 1, u'_id': 7133}
# {u'Preguntas': 1, u'_id': 13560}
# {u'Preguntas': 1, u'_id': 4580}
# {u'Preguntas': 1, u'_id': 7167}
# {u'Preguntas': 1, u'_id': 13652}
# {u'Preguntas': 1, u'_id': 3770}
# {u'Preguntas': 1, u'_id': 7183}
# {u'Preguntas': 1, u'_id': 9861}
# {u'Preguntas': 1, u'_id': 3757}
# {u'Preguntas': 1, u'_id': 7157}
# {u'Preguntas': 1, u'_id': 7586}
# {u'Preguntas': 1, u'_id': 13670}
# {u'Preguntas': 1, u'_id': 3773}
# {u'Preguntas': 1, u'_id': 7189}
# {u'Preguntas': 1, u'_id': 7195}
# {u'Preguntas': 1, u'_id': 7201}
# {u'Preguntas': 1, u'_id': 9979}
# {u'Preguntas': 1, u'_id': 7227}
# {u'Preguntas': 1, u'_id': 7252}
# {u'Preguntas': 1, u'_id': 1308}
# {u'Preguntas': 1, u'_id': 5550}
# {u'Preguntas': 1, u'_id': 7296}
# {u'Preguntas': 1, u'_id': 6934}
# {u'Preguntas': 1, u'_id': 7332}
# {u'Preguntas': 1, u'_id': 3855}
# {u'Preguntas': 1, u'_id': 7353}
# {u'Preguntas': 1, u'_id': 13550}
# {u'Preguntas': 1, u'_id': 9811}
# {u'Preguntas': 1, u'_id': 10381}
# {u'Preguntas': 1, u'_id': 7417}
# {u'Preguntas': 1, u'_id': 3890}
# {u'Preguntas': 1, u'_id': 7423}
# {u'Preguntas': 1, u'_id': 10421}
# {u'Preguntas': 1, u'_id': 7437}
# {u'Preguntas': 1, u'_id': 10315}
# {u'Preguntas': 1, u'_id': 10467}
# {u'Preguntas': 1, u'_id': 7460}
# {u'Preguntas': 1, u'_id': 7249}
# {u'Preguntas': 1, u'_id': 4541}
# {u'Preguntas': 1, u'_id': 7485}
# {u'Preguntas': 1, u'_id': 6658}
# {u'Preguntas': 1, u'_id': 7494}
# {u'Preguntas': 1, u'_id': 10333}
# {u'Preguntas': 1, u'_id': 1721}
# {u'Preguntas': 1, u'_id': 7524}
# {u'Preguntas': 1, u'_id': 7536}
# {u'Preguntas': 1, u'_id': 3949}
# {u'Preguntas': 1, u'_id': 7545}
# {u'Preguntas': 1, u'_id': 3958}
# {u'Preguntas': 1, u'_id': 7559}
# {u'Preguntas': 1, u'_id': 7564}
# {u'Preguntas': 1, u'_id': 7573}
# {u'Preguntas': 1, u'_id': 7576}
# {u'Preguntas': 1, u'_id': 7584}
# {u'Preguntas': 1, u'_id': 3974}
# {u'Preguntas': 1, u'_id': 7605}
# {u'Preguntas': 1, u'_id': 2114}
# {u'Preguntas': 1, u'_id': 7610}
# {u'Preguntas': 1, u'_id': 7633}
# {u'Preguntas': 1, u'_id': 10902}
# {u'Preguntas': 1, u'_id': 10123}
# {u'Preguntas': 1, u'_id': 7686}
# {u'Preguntas': 1, u'_id': 9800}
# {u'Preguntas': 1, u'_id': 13539}
# {u'Preguntas': 1, u'_id': 9286}
# {u'Preguntas': 1, u'_id': 12554}
# {u'Preguntas': 1, u'_id': 10953}
# {u'Preguntas': 1, u'_id': 7719}
# {u'Preguntas': 1, u'_id': 2794}
# {u'Preguntas': 1, u'_id': 724}
# {u'Preguntas': 1, u'_id': 8730}
# {u'Preguntas': 1, u'_id': 7449}
# {u'Preguntas': 1, u'_id': 8755}
# {u'Preguntas': 1, u'_id': 7176}
# {u'Preguntas': 1, u'_id': 2549}
# {u'Preguntas': 1, u'_id': 8768}
# {u'Preguntas': 1, u'_id': 8788}
# {u'Preguntas': 1, u'_id': 8805}
# {u'Preguntas': 1, u'_id': 8842}
# {u'Preguntas': 1, u'_id': 5687}
# {u'Preguntas': 1, u'_id': 8876}
# {u'Preguntas': 1, u'_id': 6298}
# {u'Preguntas': 1, u'_id': 6942}
# {u'Preguntas': 1, u'_id': 8902}
# {u'Preguntas': 1, u'_id': 5866}
# {u'Preguntas': 1, u'_id': 6692}
# {u'Preguntas': 1, u'_id': 6723}
# {u'Preguntas': 1, u'_id': 8993}
# {u'Preguntas': 1, u'_id': 8996}
# {u'Preguntas': 1, u'_id': 9003}
# {u'Preguntas': 1, u'_id': 12761}
# {u'Preguntas': 1, u'_id': 9022}
# {u'Preguntas': 1, u'_id': 12766}
# {u'Preguntas': 1, u'_id': 9027}
# {u'Preguntas': 1, u'_id': 12772}
# {u'Preguntas': 1, u'_id': 6743}
# {u'Preguntas': 1, u'_id': 9033}
# {u'Preguntas': 1, u'_id': 12781}
# {u'Preguntas': 1, u'_id': 9042}
# {u'Preguntas': 1, u'_id': 9044}
# {u'Preguntas': 1, u'_id': 4881}
# {u'Preguntas': 1, u'_id': 9048}
# {u'Preguntas': 1, u'_id': 2631}
# {u'Preguntas': 1, u'_id': 9096}
# {u'Preguntas': 1, u'_id': 9100}
# {u'Preguntas': 1, u'_id': 7420}
# {u'Preguntas': 1, u'_id': 12855}
# {u'Preguntas': 1, u'_id': 9116}
# {u'Preguntas': 1, u'_id': 9117}
# {u'Preguntas': 1, u'_id': 9133}
# {u'Preguntas': 1, u'_id': 6802}
# {u'Preguntas': 1, u'_id': 9151}
# {u'Preguntas': 1, u'_id': 9152}
# {u'Preguntas': 1, u'_id': 4939}
# {u'Preguntas': 1, u'_id': 9181}
# {u'Preguntas': 1, u'_id': 6820}
# {u'Preguntas': 1, u'_id': 9187}
# {u'Preguntas': 1, u'_id': 9017}
# {u'Preguntas': 1, u'_id': 12932}
# {u'Preguntas': 1, u'_id': 3590}
# {u'Preguntas': 1, u'_id': 9193}
# {u'Preguntas': 1, u'_id': 12933}
# {u'Preguntas': 1, u'_id': 2649}
# {u'Preguntas': 1, u'_id': 9203}
# {u'Preguntas': 1, u'_id': 9226}
# {u'Preguntas': 1, u'_id': 9228}
# {u'Preguntas': 1, u'_id': 9241}
# {u'Preguntas': 1, u'_id': 9240}
# {u'Preguntas': 1, u'_id': 4984}
# {u'Preguntas': 1, u'_id': 9254}
# {u'Preguntas': 1, u'_id': 6388}
# {u'Preguntas': 1, u'_id': 12975}
# {u'Preguntas': 1, u'_id': 9236}
# {u'Preguntas': 1, u'_id': 9257}
# {u'Preguntas': 1, u'_id': 13003}
# {u'Preguntas': 1, u'_id': 2673}
# {u'Preguntas': 1, u'_id': 9264}
# {u'Preguntas': 1, u'_id': 9271}
# {u'Preguntas': 1, u'_id': 6578}
# {u'Preguntas': 1, u'_id': 7692}
# {u'Preguntas': 1, u'_id': 13043}
# {u'Preguntas': 1, u'_id': 9304}
# {u'Preguntas': 1, u'_id': 8821}
# {u'Preguntas': 1, u'_id': 9331}
# {u'Preguntas': 1, u'_id': 13076}
# {u'Preguntas': 1, u'_id': 9337}
# {u'Preguntas': 1, u'_id': 9345}
# {u'Preguntas': 1, u'_id': 6094}
# {u'Preguntas': 1, u'_id': 5036}
# {u'Preguntas': 1, u'_id': 9358}
# {u'Preguntas': 1, u'_id': 9368}
# {u'Preguntas': 1, u'_id': 9380}
# {u'Preguntas': 1, u'_id': 9379}
# {u'Preguntas': 1, u'_id': 5200}
# {u'Preguntas': 1, u'_id': 9408}
# {u'Preguntas': 1, u'_id': 9411}
# {u'Preguntas': 1, u'_id': 9347}
# {u'Preguntas': 1, u'_id': 13173}
# {u'Preguntas': 1, u'_id': 9435}
# {u'Preguntas': 1, u'_id': 9436}
# {u'Preguntas': 1, u'_id': 9437}
# {u'Preguntas': 1, u'_id': 9446}
# {u'Preguntas': 1, u'_id': 7527}
# {u'Preguntas': 1, u'_id': 407}
# {u'Preguntas': 1, u'_id': 5095}
# {u'Preguntas': 1, u'_id': 9476}
# {u'Preguntas': 1, u'_id': 10033}
# {u'Preguntas': 1, u'_id': 7243}
# {u'Preguntas': 1, u'_id': 9490}

# %%
db.post_preguntas.delete_many({})
posts_map = Code("""
function () {
  if(this.PostTypeId == 1)
      emit(this.OwnerUserId, 1);
}
""")

posts_reduce = Code("""
function (key, values) {
  return Array.sum(values);
}
""")

db.posts.map_reduce(posts_map, posts_reduce, out={'reduce' : 'post_preguntas'})
post_preguntas = list(db.post_preguntas.find().sort("value",pymongo.DESCENDING))
post_preguntas
# Out:
# [{u'_id': 2230.0, u'value': 116.0},
#  {u'_id': 4048.0, u'value': 68.0},
#  {u'_id': 9099.0, u'value': 52.0},
#  {u'_id': 342.0, u'value': 46.0},
#  {u'_id': 3115.0, u'value': 45.0},
#  {u'_id': 3415.0, u'value': 43.0},
#  {u'_id': 5370.0, u'value': 43.0},
#  {u'_id': 2896.0, u'value': 37.0},
#  {u'_id': 4361.0, u'value': 35.0},
#  {u'_id': 1368.0, u'value': 1.0},
#  {u'_id': 1390.0, u'value': 1.0},
#  {u'_id': 1407.0, u'value': 1.0},
#  {u'_id': 1415.0, u'value': 1.0},
#  {u'_id': 1427.0, u'value': 1.0},
#  {u'_id': 1481.0, u'value': 1.0},
#  {u'_id': 1482.0, u'value': 1.0},
#  {u'_id': 1507.0, u'value': 1.0},
#  {u'_id': 1543.0, u'value': 1.0},
#  {u'_id': 1545.0, u'value': 1.0},
#  {u'_id': 1547.0, u'value': 1.0},
#  {u'_id': 1548.0, u'value': 1.0},
#  {u'_id': 1555.0, u'value': 1.0},
#  {u'_id': 1577.0, u'value': 1.0},
#  {u'_id': 1583.0, u'value': 1.0},
#  {u'_id': 1596.0, u'value': 1.0},
#  {u'_id': 1609.0, u'value': 1.0},
#  {u'_id': 1612.0, u'value': 1.0},
#  {u'_id': 1623.0, u'value': 1.0},
#  {u'_id': 1641.0, u'value': 1.0},
#  {u'_id': 1666.0, u'value': 1.0},
#  {u'_id': 1687.0, u'value': 1.0},
#  {u'_id': 1719.0, u'value': 1.0},
#  {u'_id': 1721.0, u'value': 1.0},
#  {u'_id': 1725.0, u'value': 1.0},
#  {u'_id': 1733.0, u'value': 1.0},
#  ...]

# %% [markdown]
# En SQL RQ2 era
# %%sql
# SELECT OwnerUserId AS Autor, count(*) AS Preguntas FROM Posts WHERE PostTypeId = 2 AND OwnerUserId IS NOT NULL GROUP BY OwnerUserId ORDER BY Preguntas DESC;

# %%
RQ2 = posts.aggregate( [
        {'$match': { 'PostTypeId' : {'$eq': 2}}},
        {
            '$project' : {'OwnerUserId': True}
        },
        {
            "$group":{"_id":"$OwnerUserId", "Respuestas":{"$sum":1}}    
        },
        { 
            "$sort": {"Respuestas": -1} 
        }
    ])
print_respuestas(RQ2)
# Out:
# {u'Respuestas': 774, u'_id': 95}
# {u'Respuestas': 538, u'_id': 2600}
# {u'Respuestas': 336, u'_id': 250}
# {u'Respuestas': 227, u'_id': 227}
# {u'Respuestas': 221, u'_id': 25}
# {u'Respuestas': 178, u'_id': 73}
# {u'Respuestas': 174, u'_id': 100}
# {u'Respuestas': 145, u'_id': 2224}
# {u'Respuestas': 138, u'_id': 2230}
# {u'Respuestas': 106, u'_id': 7242}
# {u'Respuestas': 104, u'_id': 24}
# {u'Respuestas': 101, u'_id': 20}
# {u'Respuestas': 101, u'_id': 6088}
# {u'Respuestas': 94, u'_id': 2429}
# {u'Respuestas': 91, u'_id': 822}
# {u'Respuestas': 89, u'_id': 1882}
# {u'Respuestas': 76, u'_id': 463}
# {u'Respuestas': 70, u'_id': 602}
# {u'Respuestas': 68, u'_id': 6634}
# {u'Respuestas': 66, u'_id': 2937}
# {u'Respuestas': 65, u'_id': 2027}
# {u'Respuestas': 62, u'_id': 630}
# {u'Respuestas': 59, u'_id': 28}
# {u'Respuestas': 59, u'_id': 562}
# {u'Respuestas': 53, u'_id': 2742}
# {u'Respuestas': 50, u'_id': 2163}
# {u'Respuestas': 48, u'_id': 2008}
# {u'Respuestas': 47, u'_id': 517}
# {u'Respuestas': 47, u'_id': 4566}
# {u'Respuestas': 46, u'_id': 127}
# {u'Respuestas': 46, u'_id': 4804}
# {u'Respuestas': 43, u'_id': 398}
# {u'Respuestas': 43, u'_id': 2816}
# {u'Respuestas': 42, u'_id': 6635}
# {u'Respuestas': 42, u'_id': 7029}
# {u'Respuestas': 42, u'_id': 638}
# {u'Respuestas': 41, u'_id': 9316}
# {u'Respuestas': 41, u'_id': 634}
# {u'Respuestas': 41, u'_id': 4499}
# {u'Respuestas': 40, u'_id': 1462}
# {u'Respuestas': 39, u'_id': 342}
# {u'Respuestas': 39, u'_id': 2004}
# {u'Respuestas': 39, u'_id': 301}
# {u'Respuestas': 38, u'_id': 184}
# {u'Respuestas': 37, u'_id': 9099}
# {u'Respuestas': 37, u'_id': 191}
# {u'Respuestas': 33, u'_id': 729}
# {u'Respuestas': 32, u'_id': 166}
# {u'Respuestas': 32, u'_id': 225}
# {u'Respuestas': 31, u'_id': 1466}
# {u'Respuestas': 30, u'_id': 8924}
# {u'Respuestas': 30, u'_id': 21}
# {u'Respuestas': 30, u'_id': 2676}
# {u'Respuestas': 30, u'_id': 3834}
# {u'Respuestas': 28, u'_id': 10180}
# {u'Respuestas': 28, u'_id': 154}
# {u'Respuestas': 28, u'_id': 353}
# {u'Respuestas': 27, u'_id': 1596}
# {u'Respuestas': 27, u'_id': 3440}
# {u'Respuestas': 26, u'_id': 7661}
# {u'Respuestas': 26, u'_id': 6095}
# {u'Respuestas': 24, u'_id': 12625}
# {u'Respuestas': 24, u'_id': 3533}
# {u'Respuestas': 23, u'_id': 270}
# {u'Respuestas': 22, u'_id': 65}
# {u'Respuestas': 22, u'_id': 4684}
# {u'Respuestas': 21, u'_id': 10586}
# {u'Respuestas': 21, u'_id': 246}
# {u'Respuestas': 21, u'_id': 271}
# {u'Respuestas': 20, u'_id': 7071}
# {u'Respuestas': 20, u'_id': 5984}
# {u'Respuestas': 20, u'_id': 34}
# {u'Respuestas': 20, u'_id': 23}
# {u'Respuestas': 20, u'_id': 801}
# {u'Respuestas': 20, u'_id': 2848}
# {u'Respuestas': 19, u'_id': 12845}
# {u'Respuestas': 19, u'_id': 11132}
# {u'Respuestas': 19, u'_id': 7034}
# {u'Respuestas': 19, u'_id': 399}
# {u'Respuestas': 19, u'_id': 6491}
# {u'Respuestas': 19, u'_id': 6173}
# {u'Respuestas': 18, u'_id': 7358}
# {u'Respuestas': 18, u'_id': 2475}
# {u'Respuestas': 18, u'_id': 2186}
# {u'Respuestas': 18, u'_id': 74}
# {u'Respuestas': 18, u'_id': 5813}
# {u'Respuestas': 17, u'_id': 9568}
# {u'Respuestas': 17, u'_id': 26}
# {u'Respuestas': 17, u'_id': 2472}
# {u'Respuestas': 17, u'_id': 2659}
# {u'Respuestas': 17, u'_id': 1943}
# {u'Respuestas': 17, u'_id': 83}
# {u'Respuestas': 17, u'_id': 1399}
# {u'Respuestas': 17, u'_id': 2803}
# {u'Respuestas': 16, u'_id': 7176}
# {u'Respuestas': 16, u'_id': 2191}
# {u'Respuestas': 6, u'_id': 149}
# {u'Respuestas': 6, u'_id': 1980}
# {u'Respuestas': 6, u'_id': 8818}
# {u'Respuestas': 6, u'_id': 1918}
# {u'Respuestas': 6, u'_id': 5946}
# {u'Respuestas': 6, u'_id': 8934}
# {u'Respuestas': 6, u'_id': 172}
# {u'Respuestas': 6, u'_id': 3563}
# {u'Respuestas': 6, u'_id': 2099}
# {u'Respuestas': 6, u'_id': 629}
# {u'Respuestas': 6, u'_id': 5655}
# {u'Respuestas': 6, u'_id': 6606}
# {u'Respuestas': 6, u'_id': 3610}
# {u'Respuestas': 6, u'_id': 3170}
# {u'Respuestas': 6, u'_id': 3734}
# {u'Respuestas': 6, u'_id': 3848}
# {u'Respuestas': 6, u'_id': 3952}
# {u'Respuestas': 6, u'_id': 4617}
# {u'Respuestas': 6, u'_id': 2203}
# {u'Respuestas': 6, u'_id': 9113}
# {u'Respuestas': 6, u'_id': 7036}
# {u'Respuestas': 6, u'_id': 1744}
# {u'Respuestas': 6, u'_id': 6220}
# {u'Respuestas': 6, u'_id': 594}
# {u'Respuestas': 6, u'_id': 360}
# {u'Respuestas': 5, u'_id': 12826}
# {u'Respuestas': 5, u'_id': 11261}
# {u'Respuestas': 5, u'_id': 12972}
# {u'Respuestas': 5, u'_id': 9928}
# {u'Respuestas': 5, u'_id': 11038}
# {u'Respuestas': 5, u'_id': 2566}
# {u'Respuestas': 5, u'_id': 10915}
# {u'Respuestas': 5, u'_id': 9905}
# {u'Respuestas': 5, u'_id': 11071}
# {u'Respuestas': 5, u'_id': 7703}
# {u'Respuestas': 5, u'_id': 8878}
# {u'Respuestas': 5, u'_id': 3234}
# {u'Respuestas': 5, u'_id': 7280}
# {u'Respuestas': 5, u'_id': 9826}
# {u'Respuestas': 5, u'_id': 7268}
# {u'Respuestas': 5, u'_id': 4361}
# {u'Respuestas': 5, u'_id': 6831}
# {u'Respuestas': 5, u'_id': 5723}
# {u'Respuestas': 5, u'_id': 2184}
# {u'Respuestas': 5, u'_id': 9947}
# {u'Respuestas': 5, u'_id': 12708}
# {u'Respuestas': 5, u'_id': 2580}
# {u'Respuestas': 5, u'_id': 376}
# {u'Respuestas': 5, u'_id': 4883}
# {u'Respuestas': 5, u'_id': 2759}
# {u'Respuestas': 5, u'_id': 206}
# {u'Respuestas': 5, u'_id': 1527}
# {u'Respuestas': 5, u'_id': 294}
# {u'Respuestas': 5, u'_id': 178}
# {u'Respuestas': 5, u'_id': 103}
# {u'Respuestas': 5, u'_id': 3060}
# {u'Respuestas': 5, u'_id': 6238}
# {u'Respuestas': 5, u'_id': 3580}
# {u'Respuestas': 5, u'_id': 2884}
# {u'Respuestas': 5, u'_id': 2158}
# {u'Respuestas': 5, u'_id': 628}
# {u'Respuestas': 5, u'_id': 8738}
# {u'Respuestas': 5, u'_id': 13237}
# {u'Respuestas': 5, u'_id': 4934}
# {u'Respuestas': 5, u'_id': 4325}
# {u'Respuestas': 5, u'_id': 3514}
# {u'Respuestas': 5, u'_id': 302}
# {u'Respuestas': 4, u'_id': 5772}
# {u'Respuestas': 4, u'_id': 10726}
# {u'Respuestas': 4, u'_id': 6377}
# {u'Respuestas': 4, u'_id': 6643}
# {u'Respuestas': 4, u'_id': 2837}
# {u'Respuestas': 4, u'_id': 9305}
# {u'Respuestas': 3, u'_id': 13637}
# {u'Respuestas': 3, u'_id': 10388}
# {u'Respuestas': 3, u'_id': 12724}
# {u'Respuestas': 3, u'_id': 13177}
# {u'Respuestas': 3, u'_id': 7597}
# {u'Respuestas': 3, u'_id': 12591}
# {u'Respuestas': 3, u'_id': 10647}
# {u'Respuestas': 3, u'_id': 12511}
# {u'Respuestas': 3, u'_id': 12497}
# {u'Respuestas': 3, u'_id': 10848}
# {u'Respuestas': 3, u'_id': 12964}
# {u'Respuestas': 3, u'_id': 11053}
# {u'Respuestas': 3, u'_id': 10744}
# {u'Respuestas': 3, u'_id': 10674}
# {u'Respuestas': 3, u'_id': 10535}
# {u'Respuestas': 3, u'_id': 10450}
# {u'Respuestas': 3, u'_id': 10403}
# {u'Respuestas': 3, u'_id': 10377}
# {u'Respuestas': 3, u'_id': 4026}
# {u'Respuestas': 3, u'_id': 4775}
# {u'Respuestas': 3, u'_id': 9982}
# {u'Respuestas': 3, u'_id': 12431}
# {u'Respuestas': 3, u'_id': 10209}
# {u'Respuestas': 3, u'_id': 362}
# {u'Respuestas': 3, u'_id': 9071}
# {u'Respuestas': 3, u'_id': 8976}
# {u'Respuestas': 3, u'_id': 5836}
# {u'Respuestas': 3, u'_id': 8764}
# {u'Respuestas': 3, u'_id': 7591}
# {u'Respuestas': 3, u'_id': 7313}
# {u'Respuestas': 3, u'_id': 13389}
# {u'Respuestas': 3, u'_id': 11131}
# {u'Respuestas': 3, u'_id': 6955}
# {u'Respuestas': 3, u'_id': 2134}
# {u'Respuestas': 3, u'_id': 6407}
# {u'Respuestas': 3, u'_id': 13646}
# {u'Respuestas': 3, u'_id': 2282}
# {u'Respuestas': 3, u'_id': 11145}
# {u'Respuestas': 3, u'_id': 2605}
# {u'Respuestas': 3, u'_id': 1974}
# {u'Respuestas': 3, u'_id': 7085}
# {u'Respuestas': 3, u'_id': 2688}
# {u'Respuestas': 3, u'_id': 2838}
# {u'Respuestas': 3, u'_id': 10796}
# {u'Respuestas': 3, u'_id': 3216}
# {u'Respuestas': 3, u'_id': 6560}
# {u'Respuestas': 3, u'_id': 2767}
# {u'Respuestas': 3, u'_id': 2133}
# {u'Respuestas': 3, u'_id': 2448}
# {u'Respuestas': 3, u'_id': 834}
# {u'Respuestas': 3, u'_id': 3343}
# {u'Respuestas': 3, u'_id': 2013}
# {u'Respuestas': 3, u'_id': 305}
# {u'Respuestas': 3, u'_id': 5329}
# {u'Respuestas': 3, u'_id': 1144}
# {u'Respuestas': 3, u'_id': 1583}
# {u'Respuestas': 3, u'_id': 2692}
# {u'Respuestas': 3, u'_id': 5403}
# {u'Respuestas': 3, u'_id': 2802}
# {u'Respuestas': 3, u'_id': 299}
# {u'Respuestas': 3, u'_id': 2832}
# {u'Respuestas': 1, u'_id': 13325}
# {u'Respuestas': 1, u'_id': 13275}
# {u'Respuestas': 1, u'_id': 13199}
# {u'Respuestas': 1, u'_id': 12623}
# {u'Respuestas': 1, u'_id': 13226}
# {u'Respuestas': 1, u'_id': 13225}
# {u'Respuestas': 1, u'_id': 13227}
# {u'Respuestas': 1, u'_id': 13213}
# {u'Respuestas': 1, u'_id': 241}
# {u'Respuestas': 1, u'_id': 2103}
# {u'Respuestas': 1, u'_id': 13158}
# {u'Respuestas': 1, u'_id': 2335}
# {u'Respuestas': 1, u'_id': 13148}
# {u'Respuestas': 1, u'_id': 13077}
# {u'Respuestas': 1, u'_id': 12991}
# {u'Respuestas': 1, u'_id': 12604}
# {u'Respuestas': 1, u'_id': 12994}
# {u'Respuestas': 1, u'_id': 2304}
# {u'Respuestas': 1, u'_id': 12967}
# {u'Respuestas': 1, u'_id': 12913}
# {u'Respuestas': 1, u'_id': 4562}
# {u'Respuestas': 1, u'_id': 12908}
# {u'Respuestas': 1, u'_id': 10424}
# {u'Respuestas': 1, u'_id': 6209}
# {u'Respuestas': 1, u'_id': 8906}
# {u'Respuestas': 1, u'_id': 12753}
# {u'Respuestas': 1, u'_id': 10355}
# {u'Respuestas': 1, u'_id': 12644}
# {u'Respuestas': 1, u'_id': 12641}
# {u'Respuestas': 1, u'_id': 12632}
# {u'Respuestas': 1, u'_id': 12600}
# {u'Respuestas': 1, u'_id': 11001}
# {u'Respuestas': 1, u'_id': 12540}
# {u'Respuestas': 1, u'_id': 11254}
# {u'Respuestas': 1, u'_id': 12455}
# {u'Respuestas': 1, u'_id': 5694}
# {u'Respuestas': 1, u'_id': 10930}
# {u'Respuestas': 1, u'_id': 3249}
# {u'Respuestas': 1, u'_id': 5763}
# {u'Respuestas': 1, u'_id': 11367}
# {u'Respuestas': 1, u'_id': 13677}
# {u'Respuestas': 1, u'_id': 10195}
# {u'Respuestas': 1, u'_id': 11287}
# {u'Respuestas': 1, u'_id': 11249}
# {u'Respuestas': 1, u'_id': 11231}
# {u'Respuestas': 1, u'_id': 11223}
# {u'Respuestas': 1, u'_id': 11156}
# {u'Respuestas': 1, u'_id': 12873}
# {u'Respuestas': 1, u'_id': 10757}
# {u'Respuestas': 1, u'_id': 11025}
# {u'Respuestas': 1, u'_id': 11052}
# {u'Respuestas': 1, u'_id': 9580}
# {u'Respuestas': 1, u'_id': 3209}
# {u'Respuestas': 1, u'_id': 11000}
# {u'Respuestas': 1, u'_id': 10977}
# {u'Respuestas': 1, u'_id': 5756}
# {u'Respuestas': 1, u'_id': 9871}
# {u'Respuestas': 1, u'_id': 10935}
# {u'Respuestas': 1, u'_id': 10901}
# {u'Respuestas': 1, u'_id': 10452}
# {u'Respuestas': 1, u'_id': 12619}
# {u'Respuestas': 1, u'_id': 10878}
# {u'Respuestas': 1, u'_id': 9986}
# {u'Respuestas': 1, u'_id': 10844}
# {u'Respuestas': 1, u'_id': 10819}
# {u'Respuestas': 1, u'_id': 10807}
# {u'Respuestas': 1, u'_id': 12494}
# {u'Respuestas': 1, u'_id': 10753}
# {u'Respuestas': 1, u'_id': 10582}
# {u'Respuestas': 1, u'_id': 10736}
# {u'Respuestas': 1, u'_id': 10723}
# {u'Respuestas': 1, u'_id': 10510}
# {u'Respuestas': 1, u'_id': 10630}
# {u'Respuestas': 1, u'_id': 10569}
# {u'Respuestas': 1, u'_id': 10600}
# {u'Respuestas': 1, u'_id': 10592}
# {u'Respuestas': 1, u'_id': 10326}
# {u'Respuestas': 1, u'_id': 10352}
# {u'Respuestas': 1, u'_id': 6578}
# {u'Respuestas': 1, u'_id': 12889}
# {u'Respuestas': 1, u'_id': 6188}
# {u'Respuestas': 1, u'_id': 5958}
# {u'Respuestas': 1, u'_id': 262}
# {u'Respuestas': 1, u'_id': 9174}
# {u'Respuestas': 1, u'_id': 10420}
# {u'Respuestas': 1, u'_id': 10404}
# {u'Respuestas': 1, u'_id': 6834}
# {u'Respuestas': 1, u'_id': 10382}
# {u'Respuestas': 1, u'_id': 534}
# {u'Respuestas': 1, u'_id': 4087}
# {u'Respuestas': 1, u'_id': 13790}
# {u'Respuestas': 1, u'_id': 10308}
# {u'Respuestas': 1, u'_id': 4455}
# {u'Respuestas': 1, u'_id': 10311}
# {u'Respuestas': 1, u'_id': 13726}
# {u'Respuestas': 1, u'_id': 10244}
# {u'Respuestas': 1, u'_id': 10049}
# {u'Respuestas': 1, u'_id': 6944}
# {u'Respuestas': 1, u'_id': 10134}
# {u'Respuestas': 1, u'_id': 8839}
# {u'Respuestas': 1, u'_id': 10096}
# {u'Respuestas': 1, u'_id': 10068}
# {u'Respuestas': 1, u'_id': 10063}
# {u'Respuestas': 1, u'_id': 10042}
# {u'Respuestas': 1, u'_id': 9799}
# {u'Respuestas': 1, u'_id': 9902}
# {u'Respuestas': 1, u'_id': 7064}
# {u'Respuestas': 1, u'_id': 2797}
# {u'Respuestas': 1, u'_id': 8949}
# {u'Respuestas': 1, u'_id': 9883}
# {u'Respuestas': 1, u'_id': 13691}
# {u'Respuestas': 1, u'_id': 2731}
# {u'Respuestas': 1, u'_id': 5828}
# {u'Respuestas': 1, u'_id': 12613}
# {u'Respuestas': 1, u'_id': 9808}
# {u'Respuestas': 1, u'_id': 9692}
# {u'Respuestas': 1, u'_id': 9539}
# {u'Respuestas': 1, u'_id': 9732}
# {u'Respuestas': 1, u'_id': 6962}
# {u'Respuestas': 1, u'_id': 9629}
# {u'Respuestas': 1, u'_id': 9538}
# {u'Respuestas': 1, u'_id': 9179}
# {u'Respuestas': 1, u'_id': 9483}
# {u'Respuestas': 1, u'_id': 9286}
# {u'Respuestas': 1, u'_id': 7534}
# {u'Respuestas': 1, u'_id': 9347}
# {u'Respuestas': 1, u'_id': 9202}
# {u'Respuestas': 1, u'_id': 8867}
# {u'Respuestas': 1, u'_id': 9392}
# {u'Respuestas': 1, u'_id': 13455}
# {u'Respuestas': 1, u'_id': 4730}
# {u'Respuestas': 1, u'_id': 2074}
# {u'Respuestas': 1, u'_id': 9322}
# {u'Respuestas': 1, u'_id': 9288}
# {u'Respuestas': 1, u'_id': 9291}
# {u'Respuestas': 1, u'_id': 9280}
# {u'Respuestas': 1, u'_id': 9228}
# {u'Respuestas': 1, u'_id': 9225}
# {u'Respuestas': 1, u'_id': 9188}
# {u'Respuestas': 1, u'_id': 12616}
# {u'Respuestas': 1, u'_id': 9134}
# {u'Respuestas': 1, u'_id': 11361}
# {u'Respuestas': 1, u'_id': 7165}
# {u'Respuestas': 1, u'_id': 1076}
# {u'Respuestas': 1, u'_id': 3933}
# {u'Respuestas': 1, u'_id': 9081}
# {u'Respuestas': 1, u'_id': 8886}
# {u'Respuestas': 1, u'_id': 9020}
# {u'Respuestas': 1, u'_id': 10755}
# {u'Respuestas': 1, u'_id': 6807}
# {u'Respuestas': 1, u'_id': 12458}
# {u'Respuestas': 1, u'_id': 8967}
# {u'Respuestas': 1, u'_id': 8964}
# {u'Respuestas': 1, u'_id': 8963}
# {u'Respuestas': 1, u'_id': 8853}
# {u'Respuestas': 1, u'_id': 5248}
# {u'Respuestas': 1, u'_id': 3817}
# {u'Respuestas': 1, u'_id': 6738}
# {u'Respuestas': 1, u'_id': 8766}
# {u'Respuestas': 1, u'_id': 6605}
# {u'Respuestas': 1, u'_id': 8955}
# {u'Respuestas': 1, u'_id': 8852}
# {u'Respuestas': 1, u'_id': 8809}
# {u'Respuestas': 1, u'_id': 8813}
# {u'Respuestas': 1, u'_id': 8784}
# {u'Respuestas': 1, u'_id': 8739}
# {u'Respuestas': 1, u'_id': 2633}
# {u'Respuestas': 1, u'_id': 13124}
# {u'Respuestas': 1, u'_id': 9642}
# {u'Respuestas': 1, u'_id': 7627}
# {u'Respuestas': 1, u'_id': 2469}
# {u'Respuestas': 1, u'_id': 7529}
# {u'Respuestas': 1, u'_id': 10374}
# {u'Respuestas': 1, u'_id': 7532}
# {u'Respuestas': 1, u'_id': 13580}
# {u'Respuestas': 1, u'_id': 5663}
# {u'Respuestas': 1, u'_id': 9786}
# {u'Respuestas': 1, u'_id': 7248}
# {u'Respuestas': 1, u'_id': 7249}
# {u'Respuestas': 1, u'_id': 7427}
# {u'Respuestas': 1, u'_id': 7441}
# {u'Respuestas': 1, u'_id': 5989}
# {u'Respuestas': 1, u'_id': 291}
# {u'Respuestas': 1, u'_id': 7423}
# {u'Respuestas': 1, u'_id': 10506}
# {u'Respuestas': 1, u'_id': 8765}
# {u'Respuestas': 1, u'_id': 2370}
# {u'Respuestas': 1, u'_id': 6101}
# {u'Respuestas': 1, u'_id': 7414}
# {u'Respuestas': 1, u'_id': 13554}
# {u'Respuestas': 1, u'_id': 7391}
# {u'Respuestas': 1, u'_id': 113}
# {u'Respuestas': 1, u'_id': 6338}
# {u'Respuestas': 1, u'_id': 6890}
# {u'Respuestas': 1, u'_id': 7330}
# {u'Respuestas': 1, u'_id': 274}
# {u'Respuestas': 1, u'_id': 7311}
# {u'Respuestas': 1, u'_id': 7286}
# {u'Respuestas': 1, u'_id': 6438}
# {u'Respuestas': 1, u'_id': 7245}
# {u'Respuestas': 1, u'_id': 7239}
# {u'Respuestas': 1, u'_id': 4676}
# {u'Respuestas': 1, u'_id': 7223}
# {u'Respuestas': 1, u'_id': 7185}
# {u'Respuestas': 1, u'_id': 13180}
# {u'Respuestas': 1, u'_id': 7204}
# {u'Respuestas': 1, u'_id': 7181}
# {u'Respuestas': 1, u'_id': 7101}
# {u'Respuestas': 1, u'_id': 10579}
# {u'Respuestas': 1, u'_id': 8838}
# {u'Respuestas': 1, u'_id': 6774}
# {u'Respuestas': 1, u'_id': 6534}
# {u'Respuestas': 1, u'_id': 3698}
# {u'Respuestas': 1, u'_id': 1949}
# {u'Respuestas': 1, u'_id': 10972}
# {u'Respuestas': 1, u'_id': 3357}
# {u'Respuestas': 1, u'_id': 6187}
# {u'Respuestas': 1, u'_id': 9186}
# {u'Respuestas': 1, u'_id': 6948}
# {u'Respuestas': 1, u'_id': 12980}
# {u'Respuestas': 1, u'_id': 7102}
# {u'Respuestas': 1, u'_id': 1109}
# {u'Respuestas': 1, u'_id': 7050}
# {u'Respuestas': 1, u'_id': 7032}
# {u'Respuestas': 1, u'_id': 7024}
# {u'Respuestas': 1, u'_id': 6469}
# {u'Respuestas': 1, u'_id': 6982}
# {u'Respuestas': 1, u'_id': 12720}
# {u'Respuestas': 1, u'_id': 10299}
# {u'Respuestas': 1, u'_id': 6923}
# {u'Respuestas': 1, u'_id': 6937}
# {u'Respuestas': 1, u'_id': 6842}
# {u'Respuestas': 1, u'_id': 6901}
# {u'Respuestas': 1, u'_id': 6899}
# {u'Respuestas': 1, u'_id': 6875}
# {u'Respuestas': 1, u'_id': 6871}
# {u'Respuestas': 1, u'_id': 1274}
# {u'Respuestas': 1, u'_id': 9031}
# {u'Respuestas': 1, u'_id': 1840}
# {u'Respuestas': 1, u'_id': 306}
# {u'Respuestas': 1, u'_id': 3268}
# {u'Respuestas': 1, u'_id': 9741}
# {u'Respuestas': 1, u'_id': 807}
# {u'Respuestas': 1, u'_id': 3222}
# {u'Respuestas': 1, u'_id': 1627}
# {u'Respuestas': 1, u'_id': 12854}
# {u'Respuestas': 1, u'_id': 2957}
# {u'Respuestas': 1, u'_id': 5465}
# {u'Respuestas': 1, u'_id': 2169}
# {u'Respuestas': 1, u'_id': 9779}
# {u'Respuestas': 1, u'_id': 4633}
# {u'Respuestas': 1, u'_id': 13474}
# {u'Respuestas': 1, u'_id': 3112}
# {u'Respuestas': 1, u'_id': 702}
# {u'Respuestas': 1, u'_id': 7256}
# {u'Respuestas': 1, u'_id': 3935}
# {u'Respuestas': 1, u'_id': 9643}
# {u'Respuestas': 1, u'_id': 7265}
# {u'Respuestas': 1, u'_id': 3069}
# {u'Respuestas': 1, u'_id': 12486}
# {u'Respuestas': 1, u'_id': 2865}
# {u'Respuestas': 1, u'_id': 6572}
# {u'Respuestas': 1, u'_id': 2958}
# {u'Respuestas': 1, u'_id': 12886}
# {u'Respuestas': 1, u'_id': 2965}
# {u'Respuestas': 1, u'_id': 415}
# {u'Respuestas': 1, u'_id': 12758}
# {u'Respuestas': 1, u'_id': 9276}
# {u'Respuestas': 1, u'_id': 2933}
# {u'Respuestas': 1, u'_id': 2110}
# {u'Respuestas': 1, u'_id': 2673}
# {u'Respuestas': 1, u'_id': 3106}
# {u'Respuestas': 1, u'_id': 12459}
# {u'Respuestas': 1, u'_id': 4675}
# {u'Respuestas': 1, u'_id': 13440}
# {u'Respuestas': 1, u'_id': 3974}
# {u'Respuestas': 1, u'_id': 4330}
# {u'Respuestas': 1, u'_id': 12655}
# {u'Respuestas': 1, u'_id': 9173}
# {u'Respuestas': 1, u'_id': 819}
# {u'Respuestas': 1, u'_id': 3618}
# {u'Respuestas': 1, u'_id': 776}
# {u'Respuestas': 1, u'_id': 1965}
# {u'Respuestas': 1, u'_id': 11397}
# {u'Respuestas': 1, u'_id': 1612}
# {u'Respuestas': 1, u'_id': 2755}
# {u'Respuestas': 1, u'_id': 6352}
# {u'Respuestas': 1, u'_id': 9921}
# {u'Respuestas': 1, u'_id': 660}
# {u'Respuestas': 1, u'_id': 2723}
# {u'Respuestas': 1, u'_id': 12492}
# {u'Respuestas': 1, u'_id': 6480}
# {u'Respuestas': 1, u'_id': 6612}
# {u'Respuestas': 1, u'_id': 1960}
# {u'Respuestas': 1, u'_id': 13357}
# {u'Respuestas': 1, u'_id': 3518}
# {u'Respuestas': 1, u'_id': 5409}
# {u'Respuestas': 1, u'_id': 12942}
# {u'Respuestas': 1, u'_id': 2711}
# {u'Respuestas': 1, u'_id': 2034}
# {u'Respuestas': 1, u'_id': 13420}
# {u'Respuestas': 1, u'_id': 2228}
# {u'Respuestas': 1, u'_id': 758}
# {u'Respuestas': 1, u'_id': 4879}
# {u'Respuestas': 1, u'_id': 1962}
# {u'Respuestas': 1, u'_id': 704}
# {u'Respuestas': 1, u'_id': 3658}
# {u'Respuestas': 1, u'_id': 5689}
# {u'Respuestas': 1, u'_id': 3484}
# {u'Respuestas': 1, u'_id': 1736}
# {u'Respuestas': 1, u'_id': 9445}
# {u'Respuestas': 1, u'_id': 10188}
# {u'Respuestas': 1, u'_id': 5708}
# {u'Respuestas': 1, u'_id': 6033}
# {u'Respuestas': 1, u'_id': 2593}
# {u'Respuestas': 1, u'_id': 13160}
# {u'Respuestas': 1, u'_id': 2572}
# {u'Respuestas': 1, u'_id': 1487}
# {u'Respuestas': 1, u'_id': 2500}
# {u'Respuestas': 1, u'_id': 11014}
# {u'Respuestas': 1, u'_id': 2497}
# {u'Respuestas': 1, u'_id': 3320}
# {u'Respuestas': 1, u'_id': 2495}
# {u'Respuestas': 1, u'_id': 1037}
# {u'Respuestas': 1, u'_id': 5832}
# {u'Respuestas': 1, u'_id': 1579}
# {u'Respuestas': 1, u'_id': 2851}
# {u'Respuestas': 1, u'_id': 1021}
# {u'Respuestas': 1, u'_id': 13675}
# {u'Respuestas': 1, u'_id': 13544}
# {u'Respuestas': 1, u'_id': 1283}
# {u'Respuestas': 1, u'_id': 2397}
# {u'Respuestas': 1, u'_id': 144}
# {u'Respuestas': 1, u'_id': 2007}
# {u'Respuestas': 1, u'_id': 4819}
# {u'Respuestas': 1, u'_id': 3587}
# {u'Respuestas': 1, u'_id': 2345}
# {u'Respuestas': 1, u'_id': 10422}
# {u'Respuestas': 1, u'_id': 4090}
# {u'Respuestas': 1, u'_id': 2349}
# {u'Respuestas': 1, u'_id': 2358}
# {u'Respuestas': 1, u'_id': 925}
# {u'Respuestas': 1, u'_id': 5558}
# {u'Respuestas': 1, u'_id': 2980}
# {u'Respuestas': 1, u'_id': 10957}
# {u'Respuestas': 1, u'_id': 883}
# {u'Respuestas': 1, u'_id': 13489}
# {u'Respuestas': 1, u'_id': 3551}
# {u'Respuestas': 1, u'_id': 2708}
# {u'Respuestas': 1, u'_id': 6353}
# {u'Respuestas': 1, u'_id': 3531}
# {u'Respuestas': 1, u'_id': 3149}
# {u'Respuestas': 1, u'_id': 10061}
# {u'Respuestas': 1, u'_id': 2049}
# {u'Respuestas': 1, u'_id': 1074}
# {u'Respuestas': 1, u'_id': 5157}
# {u'Respuestas': 1, u'_id': 6968}
# {u'Respuestas': 1, u'_id': 3791}
# {u'Respuestas': 1, u'_id': 3874}
# {u'Respuestas': 1, u'_id': 7328}
# {u'Respuestas': 1, u'_id': 2705}
# {u'Respuestas': 1, u'_id': 11259}
# {u'Respuestas': 1, u'_id': 2123}
# {u'Respuestas': 1, u'_id': 188}
# {u'Respuestas': 1, u'_id': 3521}
# {u'Respuestas': 1, u'_id': 2198}
# {u'Respuestas': 1, u'_id': 9806}
# {u'Respuestas': 1, u'_id': 2195}
# {u'Respuestas': 1, u'_id': 2595}
# {u'Respuestas': 1, u'_id': 9770}
# {u'Respuestas': 1, u'_id': 700}
# {u'Respuestas': 1, u'_id': 11382}
# {u'Respuestas': 1, u'_id': 1291}
# {u'Respuestas': 1, u'_id': 238}
# {u'Respuestas': 1, u'_id': 813}
# {u'Respuestas': 1, u'_id': 2973}
# {u'Respuestas': 1, u'_id': 5975}
# {u'Respuestas': 1, u'_id': 2824}
# {u'Respuestas': 1, u'_id': 13655}
# {u'Respuestas': 1, u'_id': 2722}
# {u'Respuestas': 1, u'_id': 260}
# {u'Respuestas': 1, u'_id': 1913}
# {u'Respuestas': 1, u'_id': 1675}
# {u'Respuestas': 1, u'_id': 3828}
# {u'Respuestas': 1, u'_id': 6832}
# {u'Respuestas': 1, u'_id': 649}
# {u'Respuestas': 1, u'_id': 1641}
# {u'Respuestas': 1, u'_id': 2955}
# {u'Respuestas': 1, u'_id': 3394}
# {u'Respuestas': 1, u'_id': 152}
# {u'Respuestas': 1, u'_id': 7014}
# {u'Respuestas': 1, u'_id': 3814}
# {u'Respuestas': 1, u'_id': 4355}
# {u'Respuestas': 1, u'_id': 58}
# {u'Respuestas': 1, u'_id': 148}
# {u'Respuestas': 1, u'_id': 3229}
# {u'Respuestas': 1, u'_id': 762}
# {u'Respuestas': 1, u'_id': 1521}
# {u'Respuestas': 1, u'_id': 4476}
# {u'Respuestas': 1, u'_id': 3668}
# {u'Respuestas': 1, u'_id': 1117}
# {u'Respuestas': 1, u'_id': 1940}
# {u'Respuestas': 1, u'_id': 3103}
# {u'Respuestas': 1, u'_id': 771}
# {u'Respuestas': 1, u'_id': 9773}
# {u'Respuestas': 1, u'_id': 809}
# {u'Respuestas': 1, u'_id': 718}
# {u'Respuestas': 1, u'_id': 2859}
# {u'Respuestas': 1, u'_id': 9401}
# {u'Respuestas': 1, u'_id': 6596}
# {u'Respuestas': 1, u'_id': 9063}
# {u'Respuestas': 1, u'_id': 239}
# {u'Respuestas': 1, u'_id': 6496}
# {u'Respuestas': 1, u'_id': 9072}
# {u'Respuestas': 1, u'_id': 874}
# {u'Respuestas': 1, u'_id': 9578}
# {u'Respuestas': 1, u'_id': 358}
# {u'Respuestas': 1, u'_id': 2380}
# {u'Respuestas': 1, u'_id': 4046}
# {u'Respuestas': 1, u'_id': 13116}
# {u'Respuestas': 1, u'_id': 2484}
# {u'Respuestas': 1, u'_id': 4021}
# {u'Respuestas': 1, u'_id': 8847}
# {u'Respuestas': 1, u'_id': 2383}
# {u'Respuestas': 1, u'_id': 7349}
# {u'Respuestas': 1, u'_id': 504}
# {u'Respuestas': 1, u'_id': 5608}
# {u'Respuestas': 1, u'_id': 6431}
# {u'Respuestas': 1, u'_id': 3245}
# {u'Respuestas': 1, u'_id': 3075}
# {u'Respuestas': 1, u'_id': 1948}
# {u'Respuestas': 1, u'_id': 4538}
# {u'Respuestas': 1, u'_id': 2478}
# {u'Respuestas': 1, u'_id': 917}
# {u'Respuestas': 1, u'_id': 6570}
# {u'Respuestas': 1, u'_id': 10846}
# {u'Respuestas': 1, u'_id': 248}
# {u'Respuestas': 1, u'_id': 5993}
# {u'Respuestas': 1, u'_id': 1370}
# {u'Respuestas': 1, u'_id': 124}
# {u'Respuestas': 1, u'_id': 9171}
# {u'Respuestas': 1, u'_id': 98}
# {u'Respuestas': 1, u'_id': 11265}
# {u'Respuestas': 1, u'_id': 1651}
# {u'Respuestas': 1, u'_id': 6387}
# {u'Respuestas': 1, u'_id': 1803}
# {u'Respuestas': 1, u'_id': 7410}
# {u'Respuestas': 1, u'_id': 234}
# {u'Respuestas': 1, u'_id': 10551}
# {u'Respuestas': 1, u'_id': 5019}
# {u'Respuestas': 1, u'_id': 5633}
# {u'Respuestas': 1, u'_id': 1986}
# {u'Respuestas': 1, u'_id': 11130}
# {u'Respuestas': 1, u'_id': 2336}
# {u'Respuestas': 1, u'_id': 1571}
# {u'Respuestas': 1, u'_id': 2862}
# {u'Respuestas': 1, u'_id': 3008}
# {u'Respuestas': 1, u'_id': 326}
# {u'Respuestas': 1, u'_id': 10091}
# {u'Respuestas': 1, u'_id': 864}
# {u'Respuestas': 1, u'_id': 3550}
# {u'Respuestas': 1, u'_id': 7356}
# {u'Respuestas': 1, u'_id': 6214}
# {u'Respuestas': 1, u'_id': 5180}
# {u'Respuestas': 1, u'_id': 2897}
# {u'Respuestas': 1, u'_id': 10398}
# {u'Respuestas': 1, u'_id': 6636}
# {u'Respuestas': 1, u'_id': 13498}
# {u'Respuestas': 1, u'_id': 7363}
# {u'Respuestas': 1, u'_id': 261}
# {u'Respuestas': 1, u'_id': 2732}
# {u'Respuestas': 1, u'_id': 1981}
# {u'Respuestas': 1, u'_id': 9060}
# {u'Respuestas': 1, u'_id': 6885}
# {u'Respuestas': 1, u'_id': 2960}
# {u'Respuestas': 1, u'_id': 950}
# {u'Respuestas': 1, u'_id': 12725}
# {u'Respuestas': 1, u'_id': 4365}
# {u'Respuestas': 1, u'_id': 10548}
# {u'Respuestas': 1, u'_id': 309}
# {u'Respuestas': 1, u'_id': 129}
# {u'Respuestas': 1, u'_id': 6692}
# {u'Respuestas': 1, u'_id': 11395}
# {u'Respuestas': 1, u'_id': 5441}
# {u'Respuestas': 1, u'_id': 1232}
# {u'Respuestas': 1, u'_id': 5731}
# {u'Respuestas': 1, u'_id': 3758}
# {u'Respuestas': 1, u'_id': 1827}
# {u'Respuestas': 1, u'_id': 7406}
# {u'Respuestas': 1, u'_id': 1288}
# {u'Respuestas': 1, u'_id': 2669}
# {u'Respuestas': 1, u'_id': 334}
# {u'Respuestas': 1, u'_id': 3492}
# {u'Respuestas': 1, u'_id': 10559}
# {u'Respuestas': 1, u'_id': 5023}
# {u'Respuestas': 1, u'_id': 478}
# {u'Respuestas': 1, u'_id': 1500}
# {u'Respuestas': 1, u'_id': 2467}
# {u'Respuestas': 1, u'_id': 7517}
# {u'Respuestas': 1, u'_id': 731}
# {u'Respuestas': 1, u'_id': 2159}
# {u'Respuestas': 1, u'_id': 11237}
# {u'Respuestas': 1, u'_id': 13522}
# {u'Respuestas': 1, u'_id': 1100}
# {u'Respuestas': 1, u'_id': 4062}
# {u'Respuestas': 1, u'_id': 5674}
# {u'Respuestas': 1, u'_id': 515}
# {u'Respuestas': 1, u'_id': 5744}
# {u'Respuestas': 1, u'_id': 1752}
# {u'Respuestas': 1, u'_id': 3224}
# {u'Respuestas': 1, u'_id': 3040}
# {u'Respuestas': 1, u'_id': 13064}
# {u'Respuestas': 1, u'_id': 2733}
# {u'Respuestas': 1, u'_id': 8791}
# {u'Respuestas': 1, u'_id': 1777}
# {u'Respuestas': 1, u'_id': 1368}
# {u'Respuestas': 1, u'_id': 2518}
# {u'Respuestas': 1, u'_id': 1884}
# {u'Respuestas': 1, u'_id': 2932}
# {u'Respuestas': 1, u'_id': 3345}
# {u'Respuestas': 1, u'_id': 9204}
# {u'Respuestas': 1, u'_id': 2915}
# {u'Respuestas': 1, u'_id': 5081}
# {u'Respuestas': 1, u'_id': 13211}
# {u'Respuestas': 1, u'_id': 1459}
# {u'Respuestas': 1, u'_id': 6216}
# {u'Respuestas': 1, u'_id': 4780}
# {u'Respuestas': 1, u'_id': 1502}
# {u'Respuestas': 1, u'_id': 1900}
# {u'Respuestas': 1, u'_id': 2610}
# {u'Respuestas': 1, u'_id': 5239}
# {u'Respuestas': 1, u'_id': 1511}
# {u'Respuestas': 1, u'_id': 670}
# {u'Respuestas': 1, u'_id': 5259}
# {u'Respuestas': 1, u'_id': 2780}
# {u'Respuestas': 1, u'_id': 10514}
# {u'Respuestas': 1, u'_id': 2001}
# {u'Respuestas': 1, u'_id': 6881}
# {u'Respuestas': 1, u'_id': 3283}
# {u'Respuestas': 1, u'_id': 2420}
# {u'Respuestas': 1, u'_id': 13576}
# {u'Respuestas': 1, u'_id': 10094}
# {u'Respuestas': 1, u'_id': 37}
# {u'Respuestas': 1, u'_id': 2267}
# {u'Respuestas': 1, u'_id': 6199}
# {u'Respuestas': 1, u'_id': 12917}
# {u'Respuestas': 1, u'_id': 6202}
# {u'Respuestas': 1, u'_id': 1935}
# {u'Respuestas': 1, u'_id': 3468}
# {u'Respuestas': 1, u'_id': 936}
# {u'Respuestas': 1, u'_id': 10855}
# {u'Respuestas': 1, u'_id': 659}
# {u'Respuestas': 1, u'_id': 1930}
# {u'Respuestas': 1, u'_id': 6492}
# {u'Respuestas': 1, u'_id': 4751}
# {u'Respuestas': 1, u'_id': 10700}
# {u'Respuestas': 1, u'_id': 8959}
# {u'Respuestas': 1, u'_id': 10498}
# {u'Respuestas': 1, u'_id': 5863}
# {u'Respuestas': 1, u'_id': 13009}
# {u'Respuestas': 1, u'_id': 3426}
# {u'Respuestas': 1, u'_id': 12609}
# {u'Respuestas': 1, u'_id': 6048}
# {u'Respuestas': 1, u'_id': 481}
# {u'Respuestas': 1, u'_id': 9283}
# {u'Respuestas': 1, u'_id': 6666}
# {u'Respuestas': 1, u'_id': 1975}
# {u'Respuestas': 1, u'_id': 341}
# {u'Respuestas': 1, u'_id': 3548}
# {u'Respuestas': 1, u'_id': 9873}
# {u'Respuestas': 1, u'_id': 4680}
# {u'Respuestas': 1, u'_id': 4700}
# {u'Respuestas': 1, u'_id': 4805}
# {u'Respuestas': 1, u'_id': 345}
# {u'Respuestas': 1, u'_id': 823}
# {u'Respuestas': 1, u'_id': 6641}
# {u'Respuestas': 1, u'_id': 3304}
# {u'Respuestas': 1, u'_id': 29}
# {u'Respuestas': 1, u'_id': 13383}
# {u'Respuestas': 1, u'_id': 2654}
# {u'Respuestas': 1, u'_id': 1610}
# {u'Respuestas': 1, u'_id': 3374}
# {u'Respuestas': 1, u'_id': 6771}
# {u'Respuestas': 1, u'_id': 3387}
# {u'Respuestas': 1, u'_id': 10132}
# {u'Respuestas': 1, u'_id': 5680}
# {u'Respuestas': 1, u'_id': 3439}
# {u'Respuestas': 1, u'_id': 11288}
# {u'Respuestas': 1, u'_id': 3436}
# {u'Respuestas': 1, u'_id': 10430}
# {u'Respuestas': 1, u'_id': 409}
# {u'Respuestas': 1, u'_id': 2351}
# {u'Respuestas': 1, u'_id': 10359}
# {u'Respuestas': 1, u'_id': 12894}
# {u'Respuestas': 1, u'_id': 486}
# {u'Respuestas': 1, u'_id': 2967}
# {u'Respuestas': 1, u'_id': 4328}
# {u'Respuestas': 1, u'_id': 3537}
# {u'Respuestas': 1, u'_id': 2985}
# {u'Respuestas': 1, u'_id': 6812}
# {u'Respuestas': 1, u'_id': 4897}
# {u'Respuestas': 1, u'_id': 696}
# {u'Respuestas': 1, u'_id': 3664}
# {u'Respuestas': 1, u'_id': 1305}
# {u'Respuestas': 1, u'_id': 4878}
# {u'Respuestas': 1, u'_id': 6524}
# {u'Respuestas': 1, u'_id': 10479}
# {u'Respuestas': 1, u'_id': 6724}
# {u'Respuestas': 1, u'_id': 2354}
# {u'Respuestas': 1, u'_id': 3701}
# {u'Respuestas': 1, u'_id': 2878}
# {u'Respuestas': 1, u'_id': 3257}
# {u'Respuestas': 1, u'_id': 9974}
# {u'Respuestas': 1, u'_id': 5601}
# {u'Respuestas': 1, u'_id': 4778}
# {u'Respuestas': 1, u'_id': 3629}
# {u'Respuestas': 1, u'_id': 1168}
# {u'Respuestas': 1, u'_id': 3770}
# {u'Respuestas': 1, u'_id': 337}
# {u'Respuestas': 1, u'_id': 6291}
# {u'Respuestas': 1, u'_id': 11385}
# {u'Respuestas': 1, u'_id': 778}
# {u'Respuestas': 1, u'_id': 3812}
# {u'Respuestas': 1, u'_id': 9690}
# {u'Respuestas': 1, u'_id': 2166}
# {u'Respuestas': 1, u'_id': 3488}
# {u'Respuestas': 1, u'_id': 3228}
# {u'Respuestas': 1, u'_id': 6277}
# {u'Respuestas': 1, u'_id': 3729}
# {u'Respuestas': 1, u'_id': 4001}
# {u'Respuestas': 1, u'_id': 5619}
# {u'Respuestas': 1, u'_id': 3987}
# {u'Respuestas': 1, u'_id': 7142}
# {u'Respuestas': 1, u'_id': 3480}
# {u'Respuestas': 1, u'_id': 881}
# {u'Respuestas': 1, u'_id': 4093}
# {u'Respuestas': 1, u'_id': 2653}
# {u'Respuestas': 1, u'_id': 6433}
# {u'Respuestas': 1, u'_id': 7624}
# {u'Respuestas': 1, u'_id': 4316}
# {u'Respuestas': 1, u'_id': 514}
# {u'Respuestas': 1, u'_id': 8785}
# {u'Respuestas': 1, u'_id': 5877}
# {u'Respuestas': 1, u'_id': 13342}
# {u'Respuestas': 1, u'_id': 1693}
# {u'Respuestas': 1, u'_id': 5164}
# {u'Respuestas': 1, u'_id': 7482}
# {u'Respuestas': 1, u'_id': 4370}
# {u'Respuestas': 1, u'_id': 1792}
# {u'Respuestas': 1, u'_id': 4482}
# {u'Respuestas': 1, u'_id': 4096}
# {u'Respuestas': 1, u'_id': 13011}
# {u'Respuestas': 1, u'_id': 9529}
# {u'Respuestas': 1, u'_id': 9553}
# {u'Respuestas': 1, u'_id': 182}
# {u'Respuestas': 1, u'_id': 11380}
# {u'Respuestas': 1, u'_id': 4563}
# {u'Respuestas': 1, u'_id': 1039}
# {u'Respuestas': 1, u'_id': 4288}
# {u'Respuestas': 1, u'_id': 5111}
# {u'Respuestas': 1, u'_id': 4641}
# {u'Respuestas': 1, u'_id': 3419}
# {u'Respuestas': 1, u'_id': 573}
# {u'Respuestas': 1, u'_id': 3217}
# {u'Respuestas': 1, u'_id': 4634}
# {u'Respuestas': 1, u'_id': 4738}
# {u'Respuestas': 1, u'_id': 2698}
# {u'Respuestas': 1, u'_id': 10026}
# {u'Respuestas': 1, u'_id': 6450}
# {u'Respuestas': 1, u'_id': 2713}
# {u'Respuestas': 1, u'_id': 4815}
# {u'Respuestas': 1, u'_id': 4777}
# {u'Respuestas': 1, u'_id': 315}
# {u'Respuestas': 1, u'_id': 2736}
# {u'Respuestas': 1, u'_id': 6505}
# {u'Respuestas': 1, u'_id': 4910}
# {u'Respuestas': 1, u'_id': 3507}
# {u'Respuestas': 1, u'_id': 4930}
# {u'Respuestas': 1, u'_id': 5429}
# {u'Respuestas': 1, u'_id': 2151}
# {u'Respuestas': 1, u'_id': 1544}
# {u'Respuestas': 1, u'_id': 4948}
# {u'Respuestas': 1, u'_id': 5897}
# {u'Respuestas': 1, u'_id': 5802}
# {u'Respuestas': 1, u'_id': 36}
# {u'Respuestas': 1, u'_id': 4673}
# {u'Respuestas': 1, u'_id': 866}
# {u'Respuestas': 1, u'_id': 5339}
# {u'Respuestas': 1, u'_id': 575}
# {u'Respuestas': 1, u'_id': 6278}
# {u'Respuestas': 1, u'_id': 4537}
# {u'Respuestas': 1, u'_id': 8932}
# {u'Respuestas': 1, u'_id': 1577}
# {u'Respuestas': 1, u'_id': 5080}
# {u'Respuestas': 1, u'_id': 4845}
# {u'Respuestas': 1, u'_id': 13495}
# {u'Respuestas': 1, u'_id': 6872}
# {u'Respuestas': 1, u'_id': 2025}
# {u'Respuestas': 1, u'_id': 4300}
# {u'Respuestas': 1, u'_id': 5098}
# {u'Respuestas': 1, u'_id': 4198}
# {u'Respuestas': 1, u'_id': 5247}
# {u'Respuestas': 1, u'_id': 1119}
# {u'Respuestas': 1, u'_id': 4989}
# {u'Respuestas': 1, u'_id': 12790}
# {u'Respuestas': 1, u'_id': 2941}
# {u'Respuestas': 1, u'_id': 5268}
# {u'Respuestas': 1, u'_id': 1188}
# {u'Respuestas': 1, u'_id': 5265}
# {u'Respuestas': 1, u'_id': 2180}
# {u'Respuestas': 1, u'_id': 9207}
# {u'Respuestas': 1, u'_id': 4347}
# {u'Respuestas': 1, u'_id': 11135}
# {u'Respuestas': 1, u'_id': 2092}
# {u'Respuestas': 1, u'_id': 5311}
# {u'Respuestas': 1, u'_id': 5328}
# {u'Respuestas': 1, u'_id': 5236}
# {u'Respuestas': 1, u'_id': 5378}
# {u'Respuestas': 1, u'_id': 5381}
# {u'Respuestas': 1, u'_id': 5396}
# {u'Respuestas': 1, u'_id': 5295}
# {u'Respuestas': 1, u'_id': 3316}
# {u'Respuestas': 1, u'_id': 1246}
# {u'Respuestas': 1, u'_id': 5497}
# {u'Respuestas': 1, u'_id': 3562}
# {u'Respuestas': 1, u'_id': 5505}
# {u'Respuestas': 1, u'_id': 7140}
# {u'Respuestas': 1, u'_id': 3877}
# {u'Respuestas': 1, u'_id': 5399}
# {u'Respuestas': 1, u'_id': 5530}
# {u'Respuestas': 1, u'_id': 4598}
# {u'Respuestas': 1, u'_id': 6244}
# {u'Respuestas': 1, u'_id': 9854}
# {u'Respuestas': 1, u'_id': 5541}
# {u'Respuestas': 1, u'_id': 469}
# {u'Respuestas': 1, u'_id': 1569}
# {u'Respuestas': 1, u'_id': 5087}
# {u'Respuestas': 1, u'_id': 12999}
# {u'Respuestas': 1, u'_id': 9517}
# {u'Respuestas': 1, u'_id': 2558}
# {u'Respuestas': 1, u'_id': 5725}
# {u'Respuestas': 1, u'_id': 2288}
# {u'Respuestas': 1, u'_id': 5703}
# {u'Respuestas': 1, u'_id': 282}
# {u'Respuestas': 1, u'_id': 5538}
# {u'Respuestas': 1, u'_id': 5765}
# {u'Respuestas': 1, u'_id': 5597}
# {u'Respuestas': 1, u'_id': 3287}
# {u'Respuestas': 1, u'_id': 5960}
# {u'Respuestas': 1, u'_id': 8969}
# {u'Respuestas': 1, u'_id': 5969}
# {u'Respuestas': 1, u'_id': 170}
# {u'Respuestas': 1, u'_id': 5977}
# {u'Respuestas': 1, u'_id': 6008}
# {u'Respuestas': 1, u'_id': 10465}
# {u'Respuestas': 1, u'_id': 9121}
# {u'Respuestas': 1, u'_id': 6045}
# {u'Respuestas': 1, u'_id': 3013}
# {u'Respuestas': 1, u'_id': 6049}
# {u'Respuestas': 1, u'_id': 12615}
# {u'Respuestas': 1, u'_id': 6051}
# {u'Respuestas': 1, u'_id': 6073}
# {u'Respuestas': 1, u'_id': 6085}
# {u'Respuestas': 1, u'_id': 11154}
# {u'Respuestas': 1, u'_id': 6191}
# {u'Respuestas': 1, u'_id': 9417}
# {u'Respuestas': 1, u'_id': 6193}
# {u'Respuestas': 1, u'_id': 6031}
# {u'Respuestas': 1, u'_id': 4479}
# {u'Respuestas': 1, u'_id': 11320}
# {u'Respuestas': 1, u'_id': 13061}
# {u'Respuestas': 1, u'_id': 6274}
# {u'Respuestas': 1, u'_id': 9583}
# {u'Respuestas': 1, u'_id': 6276}
# {u'Respuestas': 1, u'_id': 4528}
# {u'Respuestas': 1, u'_id': 6269}
# {u'Respuestas': 1, u'_id': 6315}
# {u'Respuestas': 1, u'_id': 6466}
# {u'Respuestas': 1, u'_id': 4729}
# {u'Respuestas': 1, u'_id': 6484}
# {u'Respuestas': 1, u'_id': 1455}
# {u'Respuestas': 1, u'_id': 5271}
# {u'Respuestas': 1, u'_id': 10035}
# {u'Respuestas': 1, u'_id': 6502}
# {u'Respuestas': 1, u'_id': 3635}
# {u'Respuestas': 1, u'_id': 643}
# {u'Respuestas': 1, u'_id': 2003}
# {u'Respuestas': 1, u'_id': 6784}
# {u'Respuestas': 1, u'_id': 6786}
# {u'Respuestas': 1, u'_id': 6801}
# {u'Respuestas': 1, u'_id': 2807}
# {u'Respuestas': 1, u'_id': 6741}
# {u'Respuestas': 1, u'_id': 6765}
# {u'Respuestas': 1, u'_id': 4872}
# {u'Respuestas': 1, u'_id': 6613}
# {u'Respuestas': 1, u'_id': 4396}
# {u'Respuestas': 1, u'_id': 6137}

# %%
db.post_respuestas.delete_many({})
posts_map = Code("""
function () {
  if(this.PostTypeId == 2)
      emit(this.OwnerUserId, 1);
}
""")

posts_reduce = Code("""
function (key, values) {
  return Array.sum(values);
}
""")

db.posts.map_reduce(posts_map, posts_reduce, out={'reduce' : 'post_respuestas'})
post_respuestas = list(db.post_respuestas.find().sort("value",pymongo.DESCENDING))
post_respuestas
# Out:
#  {u'_id': 7311.0, u'value': 1.0},
#  {u'_id': 7328.0, u'value': 1.0},
#  {u'_id': 7330.0, u'value': 1.0},
#  {u'_id': 7349.0, u'value': 1.0},
#  {u'_id': 7356.0, u'value': 1.0},
#  {u'_id': 7363.0, u'value': 1.0},
#  {u'_id': 7391.0, u'value': 1.0},
#  {u'_id': 7406.0, u'value': 1.0},
#  {u'_id': 7410.0, u'value': 1.0},
#  {u'_id': 7414.0, u'value': 1.0},
#  {u'_id': 7423.0, u'value': 1.0},
#  {u'_id': 7427.0, u'value': 1.0},
#  {u'_id': 7441.0, u'value': 1.0},
#  {u'_id': 7482.0, u'value': 1.0},
#  {u'_id': 7517.0, u'value': 1.0},
#  {u'_id': 7529.0, u'value': 1.0},
#  {u'_id': 7532.0, u'value': 1.0},
#  {u'_id': 7534.0, u'value': 1.0},
#  {u'_id': 7624.0, u'value': 1.0},
#  {u'_id': 7627.0, u'value': 1.0},
#  {u'_id': 8739.0, u'value': 1.0},
#  {u'_id': 8765.0, u'value': 1.0},
#  {u'_id': 8766.0, u'value': 1.0},
#  {u'_id': 8784.0, u'value': 1.0},
#  {u'_id': 8785.0, u'value': 1.0},
#  {u'_id': 8791.0, u'value': 1.0},
#  {u'_id': 8809.0, u'value': 1.0},
#  {u'_id': 8813.0, u'value': 1.0},
#  {u'_id': 8838.0, u'value': 1.0},
#  {u'_id': 8839.0, u'value': 1.0},
#  {u'_id': 8847.0, u'value': 1.0},
#  {u'_id': 8852.0, u'value': 1.0},
#  {u'_id': 8853.0, u'value': 1.0},
#  ...]

# %% [markdown]
# ## EJERCICIO (opcional): Con Map-Reduce y con el Framework de Agregación, mostrar la consulta RQ3

# %% [markdown]
# En SQL el RQ3 era
# %%sql
# SELECT count(*) AS UsuariosQuePreguntanYResponden FROM (SELECT DISTINCT p1.OwnerUserId FROM Posts p1
# INNER JOIN Posts p2 ON p2.OwnerUserId = p1.OwnerUserId AND p1.PostTypeId = 1 AND p2.PostTypeId = 2) datos;

# %%
RQ3 = posts.aggregate( [
        {'$match': { 'PostTypeId' : 1}},
        {'$lookup': {
            'from': "posts", 
            'localField': "OwnerUserId",
            'foreignField': "OwnerUserId",
            'as': "respuesta"}
        },
        {
            '$project' : {'OwnerUserId': True,
                          'QId' : '$OwnerUserId',
                          'AId' : '$respuesta.OwnerUserId',
                          'respuesta.PostTypeId': 2}
        },
        {
            '$group' : {'_id' : "$OwnerUserId", 'count':{'$sum':1}, 'considered_pairs' : { '$push' : {'QId' : '$QId', 'AId' : '$AId'}}
                        }
        },
        {
            '$project': {
                'answers' : True,
                'considered_pairs' : True
            }
        }
    ])
print(len(list(RQ3)))
print_respuestas(RQ3)
# Out:
# 2602

# %% [markdown]
# ### Ejemplo de realización de la consulta RQ4

# %% [markdown]
# Como ejemplo de consulta compleja con el Framework de Agregación, adjunto una posible solución a la consulta RQ4:

# %%
RQ4 = posts.aggregate( [
        {'$match': { 'AcceptedAnswerId' : {'$ne': ''}}},
        {'$lookup': {
            'from': "posts", 
            'localField': "AcceptedAnswerId",
            'foreignField': "Id",
            'as': "answer"}
        },
        {
            '$project' : {'OwnerUserId': True, 
                           'answerer' : {'$arrayElemAt' :[ '$answer.OwnerUserId' , 0 ]}}
        },
        {
            '$group' : {'_id' : {'min' : { '$min' : ['$OwnerUserId' , '
],
#  u'nanswers': 2}
# {u'_id': {u'max': 2171, u'min': 398},
#  u'answers': [{u'0q': 2171, u'1a': 398}, {u'0q': 398, u'1a': 2171}],
#  u'nanswers': 2}

# %% [markdown]
# La explicación es como sigue:
#
# 1. Se eligen sólo las preguntas que tienen respuesta (campo `AcceptedAnswerId` no es vacío)
# 2. Se accede a la tabla `posts` para recuperar los datos de la respuesta
# 3. A continuación se proyectan sólo el usuario que pregunta y el que hace la respuesta
# 4. El paso más imaginativo es el de agrupación. Lo que se intenta es que ambos pares de usuarios que están relacionados como preguntante -> respondiente y viceversa, caigan en la misma clave. Por ello, se coge el máximo y el mínimo de ambos identificadores de usuarios y se construye una clave con ambos números en las mismas posiciones. Así, ambas combinaciones de usuario que pregunta y que responde caerán en la misma clave. También se usa un conjunto (en `answers`), y sólo se añadirá una vez las posibles combinaciones iguales de preguntador/respondiente.
# 5. Sólo nos interesan aquellas tuplas cuyo tamaño del conjunto de pares de pregunta/respuesta sea igual a dos (en un elemento uno de los dos usuarios habrá preguntado y el otro habrá respondido y en el otro viceversa).
#
# La implementación en Map-Reduce se puede realizar con la misma idea.

# %% [markdown]
# En el caso de que queramos tener como referencia las preguntas y respuestas a las que se refiere la conversación, se puede añadir un campo más que guarde todas las preguntas junto con sus respuestas consideradas

# %%
RQ4 = posts.aggregate( [
        {'$match': { 'AcceptedAnswerId' : {'$ne': ''}}},
        {'$lookup': {
            'from': "posts", 
            'localField': "AcceptedAnswerId",
            'foreignField': "Id",
            'as': "answer"}
        },
        {
            '$project' : {'OwnerUserId': True,
                          'QId' : '$Id',
                          'AId' : '$answer.Id',
                          'answerer' : {'$arrayElemAt' :[ '$answer.OwnerUserId' , 0 ]}}
        },
        {
            '$group' : {'_id' : {'min' : { '$min' : ['$OwnerUserId' , '$answerer'] },
                                 'max' : { '$max' : ['$OwnerUserId' , '$answerer'] }},
                        'answers' : {'$addToSet' : { '0q':'$OwnerUserId', '1a': '$answerer'}},
                        'considered_pairs' : { '$push' : {'QId' : '$QId', 'AId' : '$AId'}}
                        }
        },
        {
            '$project': {
                'answers' : True,
                'nanswers' : { '$size' : '$answers'},
                'considered_pairs' : True
            }
        },
        {
            '$match' : { 'nanswers' : { '$eq' : 2}}
        }
    ])
print_respuestas(RQ4)
# Out:
# {u'_id': {u'max': 9897, u'min': 250},
#  u'answers': [{u'0q': 250, u'1a': 9897}, {u'0q': 9897, u'1a': 250}],
#  u'considered_pairs': [{u'AId': [17603], u'QId': 17595},
#                        {u'AId': [18558], u'QId': 18547},
#                        {u'AId': [19956], u'QId': 19955},
#                        {u'AId': [20093], u'QId': 20089},
#                        {u'AId': [20923], u'QId': 20917},
#                        {u'AId': [21137], u'QId': 21106}],
#  u'nanswers': 2}
# {u'_id': {u'max': 100, u'min': 83},
#  u'answers': [{u'0q': 100, u'1a': 83}, {u'0q': 83, u'1a': 100}],
#  u'considered_pairs': [{u'AId': [223], u'QId': 222},
#                        {u'AId': [243], u'QId': 238}],
#  u'nanswers': 2}
# {u'_id': {u'max': 250, u'min': 34},
#  u'answers': [{u'0q': 34, u'1a': 250}, {u'0q': 250, u'1a': 34}],
#  u'considered_pairs': [{u'AId': [5061], u'QId': 5017},
#                        {u'AId': [5115], u'QId': 5106}],
#  u'nanswers': 2}
# {u'_id': {u'max': 2429, u'min': 250},
#  u'answers': [{u'0q': 250, u'1a':
],
#  u'nanswers': 2}
# {u'_id': {u'max': 2722, u'min': 2509},
#  u'answers': [{u'0q': 2509, u'1a': 2722}, {u'0q': 2722, u'1a': 2509}],
#  u'considered_pairs': [{u'AId': [2432], u'QId': 2431},
#                        {u'AId': [2444], u'QId': 2441},
#                        {u'AId': [2788], u'QId': 2700}],
#  u'nanswers': 2}
# {u'_id': {u'max': 9905, u'min': 3275},
#  u'answers': [{u'0q': 9905, u'1a': 3275}, {u'0q': 3275, u'1a': 9905}],
#  u'considered_pairs': [{u'AId': [15607], u'QId': 15491},
#                        {u'AId': [15606], u'QId': 15580},
#                        {u'AId': [15758], u'QId': 15757},
#                        {u'AId': [16224], u'QId': 16221},
#                        {u'AId': [16399], u'QId': 16231},
#                        {u'AId': [22289], u'QId': 22284},
#                        {u'AId': [22291], u'QId': 22285}],
#  u'nanswers': 2}
# {u'_id': {u'max': 12625, u'min': 250},
#  u'answers': [{u'0q': 250, u'1a': 12625}, {u'0q': 12625, u'1a': 250}],
#  u'considered_pairs': [{u'AId': [20451], u'QId': 20438},
#                        {u'AId': [21224], u'QId': 21090}],
#  u'nanswers': 2}
# {u'_id': {u'max': 2171, u'min': 398},
#  u'answers': [{u'0q': 2171, u'1a': 398}, {u'0q': 398, u'1a': 2171}],
#  u'considered_pairs': [{u'AId': [2730], u'QId': 2726},
#                        {u'AId': [10468], u'QId': 10436}],
#  u'nanswers': 2}

# %%
(posts.find_one({'Id': 238}), posts.find_one({'Id': 243}),
posts.find_one({'Id': 222}), posts.find_one({'Id': 223}))
# Out:
# ({u'AcceptedAnswerId': 243,
#   u'AnswerCount': 1,
#   u'Body': u"<p>Estoy observando un mensaje de alerta (no es un error) <code>InsecurePlatformWarning</code> al ejecutar el comando <code>pip</code> en Linux:</p><br/><br/><pre><code>$ pip search reportlab<br/>/usr/local/lib/python2.7/dist-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:90:<br/>         InsecurePlatformWarning: A true SSLContext object is not available.<br/>         This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail.<br/>         For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.<br/>  InsecurePlatformWarning<br/>reportlab           - The ReportLab Toolkit<br/></code></pre><br/><br/><p>Tengo instalada la \xfaltima versi\xf3n de <code>pip</code>:</p><br/><br/><pre><code>$ pip show pip<br/>---<br/>Metadata-Version: 2.0<br/>Name: pip<br/>Version: 7.1.2<br/>Summary: The PyPA recommended tool for installing Python packages.<br/>Home-page: https://pip.pypa.io/<br/>Author: The pip developers<br/>Author-email: python-virtualenv@groups.google.com<br/>License: MIT<br/>Location: /usr/local/lib/python2.7/dist-packages<br/>Requires: <br/></code></pre><br/><br/><p>Estoy usando Python 2.7.6.</p><br/><br/><p>En versiones anteriores no me mostraba este mensaje. Entiendo que me est\xe1 indicando que mi plataforma es insegura, \xbfc\xf3mo o qu\xe9 tengo que instalar para evitar recibir esta alerta?</p><br/><br/><p><strong>Actualizaci\xf3n:</strong></p><br/><br/><p>Ya tengo instalada la \xfaltima versi\xf3n de PyOpenSSL:</p><br/><br/><pre><code>$ pip show pyOpenSSL<br/>---<br/>Metadata-Version: 1.0<br/>Name: pyOpenSSL<br/>Version: 0.13<br/>Summary: Python wrapper module around the OpenSSL library<br/>Home-page: http://pyopenssl.sourceforge.net/<br/>Author: Jean-Paul Calderone<br/>Author-email: exarkun@twistedmatrix.com<br/>License: APL2<br/>Location: /usr/lib/python2.7/dist-packages<br/>Requires: <br/></code></pre><br/><br/><p>Si intento instalar <code>request[security]</code> me da el siguiente mensaje:</p><br/><br/><pre><code>$ pip install 'request[security]'<br/>requests 2.2.1 does not provide the extra 'security'<br/></code></pre><br/>",
#   u'ClosedDate': u'',
#   u'CommentCount': 7,
#   u'CommunityOwnedDate': u'',
#   u'CreationDate': u'2015-12-02T14:39:34.293',
#   u'FavoriteCount': 1,
#   u'Id': 238,
#   u'LastActivityDate': u'2015-12-02T15:22:56.327',
#   u'LastEditDate': u'2015-12-02T15:22:56.327',
#   u'LastEditorDisplayName': u'',
#   u'LastEditorUserId': 83,
#   u'OwnerDisplayName': u'',
#   u'OwnerUserId': 100,
#   u'ParentId': u'',
#   u'PostTypeId': 1,
#   u'Score': 4,
#   u'Tags': u'<python><linux><pip><ubuntu><python-2.7>',
#   u'Title': u'InsecurePlatformWarning al usar pip en Ubuntu',
#   u'ViewCount': 101,
#   u'_id': ObjectId('584ac9ae0b09c35439b1750a')},
#  {u'AcceptedAnswerId': u'',
#   u'AnswerCount': u'',
#   u'Body': u'<p><sub>Respondo tras consultar la <a href="http://stackoverflow.com/a/29202163/1983854">respuesta equivalente en ingl\xe9s</a> y "debugar" en los comentarios</sub></p><br/><br/><p>Simplemente debes instalar los paquetes de seguridad:</p><br/><br/><pre><code>pip install requests[security]<br/></code></pre><br/><br/><p>o instalarlos directamente:</p><br/><br/><pre><code>pip install pyopenssl ndg-httpsclient pyasn1<br/></code></pre><br/><br/><p>Si en Ubuntu tienes problemas instalando <code>pyopenssl</code>, deber\xe1s instalar tambi\xe9n las siguientes dependencias:</p><br/><br/><pre><code>apt-get install libffi-dev libssl-dev<br/></code></pre><br/>',
#   u'ClosedDate': u'',
#   u'CommentCount': 1,
#   u'CommunityOwnedDate': u'',
#   u'CreationDate': u'2015-12-02T15:00:04.050',
#   u'FavoriteCount': u'',
#   u'Id': 243,
#   u'LastActivityDate': u'2015-12-02T15:07:13.380',
#   u'LastEditDate': u'2015-12-02T15:07:13.380',
#   u'LastEditorDisplayName': u'',
#   u'LastEditorUserId': 83,
#   u'OwnerDisplayName': u'',
#   u'OwnerUserId': 83,
#   u'ParentId': 238,
#   u'PostTypeId': 2,
#   u'Score': 3,
#   u'Tags': u'',
#   u'Title': u'',
#   u'ViewCount': u'',
#   u'_id': ObjectId('584ac9ae0b09c35439b1750e')},
#  {u'AcceptedAnswerId': 223,
#   u'AnswerCount': 1,
#   u'Body': u'<p>Hasta hace poco utilizaba Bash. All\xed, puedes eliminar todo el contenido de la l\xednea desde donde est\xe1 el cursor hasta el principo de la l\xednea apretando <kbd>Ctrl</kbd> + <kbd>U</kbd>.</p><br/><br/><pre><code>$ hola que tal estas<br/>          ^<br/>$ tal estas            # Ctrl+U<br/>  ^<br/></code></pre><br/><br/><p>Y as\xed lo indica el manual de Bash en <a href="https://www.gnu.org/software/bash/manual/html_node/Commands-For-Killing.html" rel="nofollow">8.4.4 Killing And Yanking</a>:</p><br/><br/><blockquote><br/>  <p><strong>unix-line-discard (C-u)</strong></p><br/>  <br/>  <p>Kill backward from the cursor to the beginning of the current line.</p><br/></blockquote><br/><br/><p>Sin embargo, ahora uso <code>zsh</code> (<a href="http://ohmyz.sh/" rel="nofollow">Oh My Zsh</a> en concreto) y esta funcionalidad ha desaparecido. Ahora cuando pulso <kbd>Ctrl</kbd> + <kbd>U</kbd> se elimina la l\xednea entera. Si hago <kbd>Ctrl</kbd> + <kbd>W</kbd> se eliminan palabras de la siguiente forma:</p><br/><br/><pre><code> $ hola que_tal estas<br/>               ^<br/> $ hola que_ estas        # Ctrl+U<br/>            ^<br/> $ hola  estas            # Ctrl+U<br/>        ^<br/></code></pre><br/><br/><p>\xbfAlguien sabe qu\xe9 debo configurar para que Ctrl+U vuelva a eliminar todo desde el cursor hasta el principo de la l\xednea?</p><br/>',
#   u'ClosedDate': u'',
#   u'CommentCount': 5,
#   u'CommunityOwnedDate': u'',
#   u'CreationDate': u'2015-12-02T12:05:19.570',
#   u'FavoriteCount': u'',
#   u'Id': 222,
#   u'LastActivityDate': u'2015-12-07T12:53:32.643',
#   u'LastEditDate': u'',
#   u'LastEditorDisplayName': u'',
#   u'LastEditorUserId': u'',
#   u'OwnerDisplayName': u'',
#   u'OwnerUserId': 83,
#   u'ParentId': u'',
#   u'PostTypeId': 1,
#   u'Score': 3,
#   u'Tags': u'<bash><zsh>',
#   u'Title': u'\xbfC\xf3mo eliminar el contenido de la consola desde el cursor hasta el principio?',
#   u'ViewCount': 95,
#   u'_id': ObjectId('584ac9ae0b09c35439b174fb')},
#  {u'AcceptedAnswerId': u'',
#   u'AnswerCount': u'',
#   u'Body': u'<p>Al parecer <kbd>Ctrl</kbd>+<kbd>U</kbd> en zsh cumpla la funci\xf3n <code>kill-whole-line</code> por defecto, lo que necesitas es que haga un <code>backward-kill-line</code>, intenta agregando esto a tu <code>.zshrc</code>:</p><br/><br/><pre><code>bindkey \\^U backward-kill-line<br/></code></pre><br/><br/><p>Cabe mencionar que la lista de comandos (o widgets) la puedes encontrar en el manpage de <code>zshzle</code> en la secci\xf3n <em>STANDARD WIDGETS</em></p><br/><br/><p>Para mayor referencia:</p><br/><br/><ul><br/><li><a href="http://zsh.sourceforge.net/Guide/zshguide04.html">The Z-Shell Line Editor</a></li><br/></ul><br/>',
#   u'ClosedDate': u'',
#   u'CommentCount': 1,
#   u'CommunityOwnedDate': u'',
#   u'CreationDate': u'2015-12-02T12:10:43.770',
#   u'FavoriteCount': u'',
#   u'Id': 223,
#   u'LastActivityDate': u'2015-12-02T12:17:23.367',
#   u'LastEditDate': u'2015-12-02T12:17:23.367',
#   u'LastEditorDisplayName': u'',
#   u'LastEditorUserId': 100,
#   u'OwnerDisplayName': u'',
#   u'OwnerUserId': 100,
#   u'ParentId': 222,
#   u'PostTypeId': 2,
#   u'Score': 10,
#   u'Tags': u'',
#   u'Title': u'',
#   u'ViewCount': u'',
#   u'_id': ObjectId('584ac9ae0b09c35439b174fd')})
