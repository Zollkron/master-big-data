# %% [markdown]
# # NoSQL (Neo4j) (sesión 7)

# %% [markdown]
# ![Image of HBase](https://neo4j.com/wp-content/themes/neo4jweb/assets/images/neo4j-logo-2015.png)
#
# Esta hoja muestra cómo acceder a bases de datos Neo4j y también a conectar la salida con Jupyter.
#
# Se puede utilizar el propio interfaz de Neo4j también en la dirección http://127.0.0.1:7474.

# %% [markdown]
# Iniciamos Neo4j:

# %%
# %%bash
# ~/start-neo4j.sh
# Out:
# Neo4j not running
# Starting Neo4j.
# Started neo4j (pid 1794). By default, it is available at http://localhost:7474/
# There may be a short delay until the server is ready.
# See /home/vagrant/neo4j-community-3.0.3/logs/neo4j.log for current status.

# %%
from pprint import pprint as pp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# Vamos a cargar la extensión `ipython-cypher` para poder lanzar consultas Cypher directamente a través de la hoja. En mi ordenador he configurado "`root`" como el _password_.
#
# Para iniciar Neo4j hay que ir primero a la página de su browser y hacer login con el usuario y clave iniciales:
#
# http://127.0.0.1:7474
#
# Usuario: neo4j
# Password: neo4j
#
# Después pide la nueva clave. Yo he puesto "`root`" en esta hoja.
#
# Utilizaremos una extensión de Jupyter Notebook que se llama `ipython-cypher`. Está instalada en la máquina virtual. Si no, se podría instalar con:
#
#     sudo pip2 install ipython-cypher
#
# Después, todas las celdas que comiencen por `%%cypher` y todas las instrucciones Python que comiencen por `%cypher` se enviarán a Neo4j para su interpretación

# %%
# %load_ext cypher
# %config CypherMagic.uri='http://neo4j:moises1980@127.0.0.1:7474/db/data'
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /usr/local/lib/python2.7/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# %config CypherMagic.auto_html=False

# %% [markdown]
# La carga de datos CSV no se puede realizar directamente desde la hoja, porque la extensión `ipython-cypher` falla por alguna cuestión de codificación UTF-8. Además, el CSV que acepta Neo4j no es estándar y he enviado un fallo para que lo arreglen (no parece que estén muy por la labor):
#
# https://github.com/neo4j/neo4j/issues/8472
#
# Mientras tanto, se pueden importar los Posts de Stackoverflow español simplemente añadiendo una barra inversa a cada barra inversa que aparece en el fichero:
#
#     sed -ie 's/\\/\\\\/g' Posts.csv
#
# Ya lo he preparado en el fichero que aparece abajo. Sin embargo, no se puede ejecutar aquí, hay que ir al browser: http://127.0.0.1:7474.
#
# El siguiente código carga el CSV modificado. Hay varias guías que ayudan a saber

# %%
# %%cypher
# USING PERIODIC COMMIT 10000
# LOAD CSV WITH HEADERS FROM "http://neuromancer.inf.um.es:8080/es.stackoverflow/Posts-for-neo4j.csv" AS row
# CREATE (n)
# SET n = row
# FOREACH(ignoreMe IN CASE WHEN trim(row.PostTypeId) = "1" THEN [1] ELSE [] END |
#   SET n :Question)
# FOREACH(ignoreMe IN CASE WHEN trim(row.PostTypeId) = "2" THEN [1] ELSE [] END |
#   SET n :Answer)
# FOREACH(ignoreMe IN CASE WHEN trim(row.OwnerUserId) <> "" THEN [1] ELSE [] END |
#   MERGE (u:User {Id: n.OwnerUserId})
#   MERGE (u)-[:WROTE]->(n)
# )
# SET n :Post
# ;
# Out:
# 37981 labels added.
# 21428 nodes created.
# 380348 properties set.
# 17934 relationships created.
# []

# %% [markdown]
# ### El lenguaje Cypher
#
# El lenguaje Cypher tiene una sintaxis de _Query By Example_. Acepta funciones y permite creación y búsqueda de nodos y relaciones. Tiene algunas peculiaridades que veremos a continuación. Por lo pronto, se puede ver un resumen de características en la [Cypher Reference Card](https://neo4j.com/docs/cypher-refcard/current/).
#
# La anterior consulta utiliza la construcción `LOAD CSV` para leer datos CSV dentro de nodos. La cláusula `CREATE` crea nuevos nodos. La `SET` permite poner valores a las propiedades de los nodos.
#
# Para hacer asignaciones condicionales, el lenguaje no ofrece una construcción adecuada. Por lo tanto, hay que utilizar una construcción `FOREACH` donde se utiliza otra construcción `CASE WHEN` con una condición. Si se cumple, se devuelve una lista con un elemento. Si no, una lista vacía. En el caso de la lista con un elemento (cuando se cumple la condición) se ejecuta la parte final del `FOREACH` tan sólo una vez.
#
# En el caso de la consulta de arriba, a todos los datos leídos se les copia los datos de la línea (primer `SET`). Después, dependiendo del valor de `PostTypeId`, se les etiqueta como `:Question` o como `:Answer`. Si tienen un usuario asignado a través de `OwnerUserId`, se añade un usuario si no existe y se crea la relación `:WROTE`.
#
# Finalmente se le asigna también el tag `:Post` a cada pregunta o respuesta. Esto añade más de una etiqueta a algunos nodos, y permite buscarlos por diferentes criterios.
#
# También hay otros posts especiales que no eran preguntas ni respuestas. A estos no se les asigna una segunda etiqueta:

# %%
# %%cypher
# match (n:Post) WHERE size(labels(n)) = 1 RETURN n;
# Out:
# 1393 rows affected.
# [[{u'Body': u'<p><strong>\xbfQu\xe9 es C ++?</strong></p><br/><br/><p>C ++ es de tipado est\xe1tico (statically typed), (por lo general) compilado, multi-paradigma, que no debe confundirse con C o C ++ / CLI. Se desarroll\xf3 en la d\xe9cada de 1980 por Bjarne Stroustrup, inicialmente como un conjunto de extensiones para el lenguaje de programaci\xf3n C. Bas\xe1ndose en C, C ++ ha mejorado la seguridad de tipos y ha a\xf1adido soporte para la gesti\xf3n autom\xe1tica de recursos, la orientaci\xf3n a objetos, programaci\xf3n gen\xe9rica, y el manejo de excepciones, entre otras caracter\xedsticas.</p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-30T16:53:47.187',
#    u'Id': u'14',
#    u'LastActivityDate': u'2016-03-31T20:32:49.003',
#    u'LastEditDate': u'2016-03-31T20:32:49.003',
#    u'LastEditorUserId': u'4595',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'C ++ es un lenguaje de programaci\xf3n de prop\xf3sito general de nivel intermedio basado en C. Use esta etiqueta para preguntas acerca de c\xf3digo para ser compilado con el compilador de C ++.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-30T16:53:47.187',
#    u'Id': u'15',
#    u'LastActivityDate': u'2015-12-05T20:51:37.347',
#    u'LastEditDate': u'2015-12-05T20:51:37.347',
#    u'LastEditorUserId': u'24',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Delphi es un lenguaje de prop\xf3sito general para el desarrollo r\xe1pido de nativo de Windows, OS X, iOS y aplicaciones Android.</p><br/><br/><p>El nombre utilizado para referirse a la lengua es Delphi, pero los desarrolladores decidier\xf3n regresar el nombre original al lenguaje, Object Pascal, restringiendo el nombre al IDE, que se utiliza para ayudar a editar y depurar proyectos de Delphi de manera m\xe1s eficiente. Es desarrollado por Embarcadero Technologies, y se vende, ya sea como un producto independiente o como parte de RAD Studio, que incluye otros idiomas tambi\xe9n.</p><br/><br/><p>Delphi es una mejora del lenguaje de Niklaus Wirth Pascal (y Object Pascal).</p><br/><br/><p>Delphi se origin\xf3 en 1995 en Borland, evolucionando desde Turbo Pascal, y es la segunda mayor plataforma de desarrollo de Windows despu\xe9s de .NET de Microsoft.</p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-31T01:47:38.807',
#    u'Id': u'19',
#    u'LastActivityDate': u'2015-12-06T18:28:40.030',
#    u'LastEditDate': u'2015-12-06T18:28:40.030',
#    u'LastEditorUserId': u'24',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Delphi es un lenguaje para el desarrollo r\xe1pido de nativo en Windows, OS X, iOS, y aplicaciones de Android a trav\xe9s del uso de Object Pascal. El nombre hace referencia al lenguaje Delphi, as\xed como su IDE, que se utiliza para ayudar a editar y depurar proyectos de Delphi.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-31T01:47:38.807',
#    u'Id': u'20',
#    u'LastActivityDate': u'2015-12-06T04:14:11.190',
#    u'LastEditDate': u'2015-12-06T04:14:11.190',
#    u'LastEditorUserId': u'24',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><strong><em><a href="https://angularjs.org/" rel="nofollow">AngularJS</a></em></strong> es un framework de JavaScript de c\xf3digo abierto.</p><br/><br/><p>Este framework adapta y ampl\xeda el HTML tradicional para servir mejor contenido din\xe1mico a trav\xe9s de un data-binding bidireccional que permite la sincronizaci\xf3n autom\xe1tica de modelos y vistas.</p><br/><br/><p>AngularJS fue desarrollado y es mantenido por Google, y se utiliza <a href="https://docs.google.com/presentation/d/1-M5U0B6JI2JKU2ibVmU-xKkR7a88Uz1ZN0pc2lEuGzE/edit?pli=1#slide=id.g48b143717_069" rel="nofollow">internamente por 1600+ aplicaciones</a>. La versi\xf3n inicial se llev\xf3 a cabo en 2009.</p><br/><br/><h2>Filosof\xeda</h2><br/><br/><ul><br/><li>La filosof\xeda angularjs anima a los desarrolladores a crear sus propias directivas, convirtiendo el HTML en un <a href="https://es.wikipedia.org/wiki/Lenguaje_espec%C3%ADfico_del_dominio" rel="nofollow">DSL</a> adecuado para la construcci\xf3n de su tipo de aplicaci\xf3n. El resultado reduce significativamente la cantidad y complejidad de JavaScript necesario para construir aplicaciones web.</li><br/><li>La filosof\xeda angularjs es que la interfaz de usuario se describe mejor en forma declarativa (HTML), y que el comportamiento se describe mejor en forma imperativa (JavaScript) y que los dos nunca se re\xfanan.</li><br/></ul><br/><br/><h2>Versiones</h2><br/><br/><p><strong>AngularJS notables versiones, nombres en clave y las fechas de lanzamiento son:</strong></p><br/><br/><pre class="lang-none prettyprint-override"><code>AngularJS 1.0.0 [temporal-domination]      (6 de junio de 2012)<br/>AngularJS 1.1.0 [increase-gravatas]        (31 de agosto de 2012)<br/>AngularJS 1.2.0 [timely-delivery]          (8 de noviembre de 2013)<br/>AngularJS 1.3.0 [superluminal-nudge]       (13 de octubre de 2014)<br/>AngularJS 1.4.0 [jaracimrman-existence]    (26 de mayo de 2015)<br/>AngularJS 1.5.0 [ennoblement-facilitation] (05 de Febrero de 2016)<br/></code></pre><br/><br/><p><strong>La \xfaltima versi\xf3n estable:</strong></p><br/><br/><pre class="lang-none prettyprint-override"><code>AngularJS 1.5.8 [arbitrary-fallbacks]      (22 de Julio de 2016)<br/></code></pre><br/><br/><p><strong>Actualmente en desarrollo</strong></p><br/><br/><pre class="lang-none prettyprint-override"><code>AngularJS 2.0.0<br/></code></pre><br/><br/><p><sup>*<a href="https://github.com/angular/angular" rel="nofollow">Candidata a lanzamiento en GitHub</a></sup></p><br/><br/><h2>Referencias</h2><br/><br/><ol><br/><li><a href="https://angularjs.org/" rel="nofollow">Sitio oficial</a></li><br/><li><a href="http://tombatossals.github.io/angularjs-tutorial/#/" rel="nofollow">Tutorial sencillo de AngularJS (tombatossals.github.io)</a></li><br/><li><a href="http://www.desarrolloweb.com/manuales/manual-angularjs.html" rel="nofollow">Manual de AngularJS (desarrolloweb.com)</a></li><br/><li><a href="https://docs.angularjs.org/tutorial" rel="nofollow">Tutorial oficial (<em>ingl\xe9s</em>)</a></li><br/><li><a href="https://docs.angularjs.org/api" rel="nofollow">Documentaci\xf3n de APIs (<em>ingl\xe9s</em>)</a></li><br/><li><a href="https://docs.angularjs.org/guide" rel="nofollow">Manual para el desarrollador (<em>ingl\xe9s</em>)</a></li><br/><li><a href="https://dashboard.angularjs.org/" rel="nofollow">Dashboard (<em>ingl\xe9s</em>)</a></li><br/></ol><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-31T02:13:17.220',
#    u'Id': u'21',
#    u'LastActivityDate': u'2016-09-02T11:21:00.667',
#    u'LastEditDate': u'2016-09-02T11:21:00.667',
#    u'LastEditorUserId': u'127',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'AngularJS es un framework de JavaScript de c\xf3digo abierto. Su objetivo es aumentar las aplicaciones basadas en navegador con Modelo-Vista-Lo (MV *) "Model\u2013View\u2013Whatever" y reducir la cantidad de c\xf3digo JavaScript necesario para hacer aplicaciones web funcionales. Este tipo de aplicaciones tambi\xe9n se conocen con frecuencia como aplicaciones de una sola p\xe1gina (Single-Page-Application).',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-10-31T02:13:17.220',
#    u'Id': u'22',
#    u'LastActivityDate': u'2016-04-06T12:43:25.967',
#    u'LastEditDate': u'2016-04-06T12:43:25.967',
#    u'LastEditorUserId': u'100',
#    u'OwnerUserId': u'24',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Se utiliza principalmente en su forma del lado del cliente (client-side), implementado como parte de un navegador Web permitiendo mejoras en la interfaz de usuario y p\xe1ginas Web din\xe1micas aunque existe una forma de JavaScript del lado del servidor (Server-side JavaScript o SSJS). Su uso en aplicaciones externas a la Web, por ejemplo en documentos PDF, aplicaciones de escritorio (mayoritariamente widgets) es tambi\xe9n significativo.</p><br/><br/><p>JavaScript se dise\xf1\xf3 con una sintaxis similar al C, aunque adopta nombres y convenciones del lenguaje de programaci\xf3n Java. Sin embargo Java y JavaScript no est\xe1n relacionados y tienen sem\xe1nticas y prop\xf3sitos diferentes.</p><br/><br/><p>Todos los navegadores modernos interpretan el c\xf3digo JavaScript integrado en las p\xe1ginas Web. Para interactuar con una p\xe1gina Web se provee al lenguaje JavaScript de una implementaci\xf3n del Document Object Model (DOM).</p><br/><br/><p>Tradicionalmente se ven\xeda utilizando en p\xe1ginas web HTML para realizar operaciones y \xfanicamente en el marco de la aplicaci\xf3n cliente, sin acceso a funciones del servidor. Actualmente es ampliamente utilizado para enviar y recibir informaci\xf3n del servidor junto con ayuda de otras tecnolog\xedas como AJAX. JavaScript se interpreta en el agente de usuario al mismo tiempo que las sentencias van descarg\xe1ndose junto con el c\xf3digo HTML.<br/>Desde el lanzamiento en junio de 1997 del est\xe1ndar ECMAScript 1, han existido las versiones 2, 3 y 5, que es la m\xe1s usada actualmente (la 4 se abandon\xf3 ). En junio de 2015 se cerr\xf3 y public\xf3 la versi\xf3n ECMAScript 6.</p><br/><br/><h2>Referencias:</h2><br/><br/><ul><br/><li><a href="https://es.wikipedia.org/wiki/JavaScript#Caracter.C3.ADsticas" rel="nofollow">JavaScript</a> (Wikipedia)</li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T18:03:01.290',
#    u'Id': u'85',
#    u'LastActivityDate': u'2016-02-09T20:54:53.620',
#    u'LastEditDate': u'2016-02-09T20:54:53.620',
#    u'LastEditorUserId': u'100',
#    u'OwnerUserId': u'100',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'JavaScript (no confundir con Java) es un lenguaje usado tanto del lado del cliente como del servidor. Utiliza esta etiqueta para referirte a ECMAScript y sus distintas implementaciones (excluyendo ActionScript y Google-Apps-Script). A menos que tambi\xe9n se incluya una etiqueta de un framework / librer\xeda, se espera una respuesta de JavaScript puro.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T18:03:01.290',
#    u'Id': u'86',
#    u'LastActivityDate': u'2016-02-12T09:40:31.423',
#    u'LastEditDate': u'2016-02-12T09:40:31.423',
#    u'LastEditorUserId': u'519',
#    u'OwnerUserId': u'178',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><a href="http://mysql.com" rel="nofollow">MySQL</a> es un Sistema de Administraci\xf3n de Bases de Datos Relacionales (<em>RDBMS</em>). Es software libre, y su c\xf3digo fuente est\xe1 disponible bajo la licencia GNU GPL. Est\xe1 disponible para las plataformas Windows, OS X, Linux, Solaris y FreeBSD. Actualmente, MySQL es uno de los RDBMS m\xe1s utilizados en el desarrollo de aplicaciones Web.</p><br/><br/><p>MySQL ofrece, entre otras, las siguientes prestaciones:</p><br/><br/><ul><br/><li>Un amplio subconjunto del estandar ANSI SQL99, as\xed como extensiones.</li><br/><li>Sentencias <code>SELECT</code> anidadas ("sub-SELECT")</li><br/><li>Procedimientos almacenados (<em>stored procedures</em>)</li><br/><li>Disparadores (<em>triggers</em>)</li><br/><li>Soporte UNICODE</li><br/><li>Maquinarias de almacenamiento nativas: InnoDB, MyISAM, MEMORY, ARCHIVE, entre otras</li><br/><li>Transacciones <em>ACID</em> (utilizando InnoDB)</li><br/><li>Soporte para conexiones SSL</li><br/><li>Soporte integrado para replicaci\xf3n</li><br/><li>Partici\xf3n de tablas</li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T18:48:16.407',
#    u'Id': u'98',
#    u'LastActivityDate': u'2015-12-06T18:27:39.787',
#    u'LastEditDate': u'2015-12-06T18:27:39.787',
#    u'LastEditorUserId': u'271',
#    u'OwnerUserId': u'271',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'MySQL es un Sistema de Administraci\xf3n de Bases de Datos Relacionales (RDBMS por sus siglas en ingl\xe9s) que utiliza el lenguaje SQL. ',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T18:48:16.407',
#    u'Id': u'99',
#    u'LastActivityDate': u'2015-12-07T01:09:33.487',
#    u'LastEditDate': u'2015-12-07T01:09:33.487',
#    u'LastEditorUserId': u'271',
#    u'OwnerUserId': u'271',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Hoja de estilo en cascada o CSS (siglas en ingl\xe9s de <em>cascading style sheets</em>) es un lenguaje usado para definir y crear la presentaci\xf3n de un documento estructurado escrito en HTML o XML2 (y por extensi\xf3n en XHTML).</p><br/><br/><p>La presentaci\xf3n visual del HTML estaba originalmente definida en los atributos HTML pero HTML4 dejo estos atributos obsoletos y CSS fue introducido para separar el control de la presentaci\xf3n visual del contenido.</p><br/><br/><p>Un documento CSS b\xe1sico esta hecho de conjuntos de reglas. Cada conjunto de reglas empieza con un <a href="http://www.w3.org/TR/css3-selectors/" rel="nofollow"><strong>selector</strong></a>, que hace de nexo de uni\xf3n entre el documento <strong>HTML</strong> o<strong>XML</strong> y el CSS , seguido por un bloque de cero o mas propiedades que definen la presentaci\xf3n . Ejemplo :</p><br/><br/><pre class="lang-css prettyprint-override"><code>/* Esto es un comentario*/ <br/><br/>a {                             /* Selecciona todos los elementos <a> (HTML links), */<br/>    color: orange;              /* cambia su color a naranja, */<br/>    background-color: pink;     /* cambia el color de fondo a rosa, */<br/>    text-decoration: none;      /* y remueve el subrayado. */<br/>}<br/><br/>a:hover {                       /* Selecciona todos los elementos <a> que tienen el puntero encima*/<br/>    color: red;                 /* cambia su color a rojo */<br/>    text-decoration: underline; /* y los subraya de nuevo */<br/>}<br/></code></pre><br/><br/><p>El simple ejemplo de arriba tambi\xe9n ilustra el estilo cascada de los elementos CSS. Cuando colocas el puntero sobre un link (ej., un elemento <code><a></code>) en <a href="http://www.htmldog.com/guides/cssbeginner/applyingcss/" rel="nofollow">una p\xe1gina HTML con esta hoja de estilos aplicada</a> las 2 reglas se aplican ; por la primera regla el color del fondo se vuelve rosa pero como el selector <code>a:hover</code> es mas especifico sus propiedades  <code>color</code> y <code>text-decoration</code> anulan las de el conjunto de reglas de <code><a></code>.</p><br/><br/><p>El <a href="http://www.w3.org/TR/CSS2/cascade.html#cascade" rel="nofollow">orden de la cascada</a> define como la <a href="http://www.stuffandnonsense.co.uk/archives/css_specificity_wars.html" rel="nofollow">especificidad </a> y otros factores determinan que valor de una propiedades se aplica a un elemento.</p><br/><br/><p>Algo m\xe1s de CSS , continuando desde el ejemplo anterior :</p><br/><br/><pre class="lang-css prettyprint-override"><code>/* Selectores con mayor especificidad anulan a otros con menos */<br/>#article a.tag {<br/>    color: #F00;<br/>}<br/><br/>/* Selectores complejos pueden ser creados uniendo varios simples */<br/>#sidebar > h3 + p a:first-child {<br/>    border-bottom: 1px solid #333;<br/>    font-style: italic;<br/>}<br/><br/>/* Tambi\xe9n es posible dar estilo a elementos dependiendo de un atributo  */<br/>div[id] a[target="_blank"] {<br/>    color: white;<br/>}<br/><br/>/* tambi\xe9n pueden anular estilos heredadas usando la palabra clave important */<br/>div.nested {<br/>    color: orange !important;<br/>}<br/></code></pre><br/><br/><h2>Precedencia de los selectores</h2><br/><br/><p>Cada componente de un un selector CSS puede estar basado en uno de tres posibles atributos de un elemento HTML</p><br/><br/><ol><br/><li>El elemento ID (del atributo <code>id</code>)</li><br/><li>El nombre de una clase del elemento (en el atributo <code>class</code>)</li><br/><li>La etiqueta del elemento</li><br/></ol><br/><br/><p>Selectores que usan ID tienen mayor prioridad que los que usan nombres de clase y los selectores que usan nombres de clases tienen a su vez mayor prioridad que los que usan etiquetas. <code>!important</code> puede ser usar para anular la precedencia de los selectores , sin embargo siempre que sea posible se debe usar mayor especificidad en vez de <code>!important</code> para prevenir a ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T19:23:39.370',
#    u'Id': u'113',
#    u'LastActivityDate': u'2015-12-24T07:36:42.353',
#    u'LastEditDate': u'2015-12-24T07:36:42.353',
#    u'LastEditorUserId': u'1594',
#    u'OwnerUserId': u'1594',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Hoja de estilo en cascada o CSS (siglas en ingl\xe9s de *cascading style sheets*) es un lenguaje usado para definir y crear la presentaci\xf3n de un documento estructurado escrito en HTML o XML2 (y por extensi\xf3n en XHTML).',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T19:23:39.370',
#    u'Id': u'114',
#    u'LastActivityDate': u'2015-12-06T04:15:31.850',
#    u'LastEditDate': u'2015-12-06T04:15:31.850',
#    u'LastEditorUserId': u'280',
#    u'OwnerUserId': u'280',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><a href="http://www.android.com" rel="nofollow">Android</a> es un sistema operativo open-source basado en el <a href="https://es.wikipedia.org/wiki/N%C3%BAcleo_Linux" rel="nofollow">kernel de Linux</a> desarrollado y mantenido por Google. Fue dise\xf1ado principalmente para dispositivos de pantalla t\xe1ctil como smartphones y tabletas, pero actualmente su uso se ha expandido a <a href="https://es.wikipedia.org/wiki/Wearable" rel="nofollow">dispositivos wearable</a> tal como <a href="/questions/tagged/google-glass" class="post-tag" title="mostrar preguntas con la etiqueta "google-glass"" rel="tag">google-glass</a>, <a href="/questions/tagged/android-wear" class="post-tag" title="mostrar preguntas con la etiqueta "android-wear"" rel="tag">android-wear</a>, <a href="/questions/tagged/android-auto" class="post-tag" title="mostrar preguntas con la etiqueta "android-auto"" rel="tag">android-auto</a> and <a href="/questions/tagged/android-tv" class="post-tag" title="mostrar preguntas con la etiqueta "android-tv"" rel="tag">android-tv</a>. Originalmente fue desarrollado por Android Inc siendo adquirido por Google en el 2005. Android fue dado a conocer en el 2007 junto con el establecimiento de <a href="http://www.openhandsetalliance.com" rel="nofollow">Open Handset Alliance</a>.</p><br/><br/><p>La IDE oficial es <a href="http://developer.android.com/sdk/installing/studio.html" rel="nofollow">Android Studio</a>, junto con el complemento ADT (Android Development Tools plugin).</p><br/><br/><hr><br/><br/><h3>Uso de la etiqueta</h3><br/><br/><p>Para preguntas relacionadas exclusivamente con el desarrollo para Android.</p><br/><br/><p>Adem\xe1s, intenta usar etiquetar espec\xedficas, por ejemplo <a href="/questions/tagged/android-activity" class="post-tag" title="mostrar preguntas con la etiqueta "android-activity"" rel="tag">android-activity</a> en lugar de <a href="/questions/tagged/activity" class="post-tag" title="mostrar preguntas con la etiqueta "activity"" rel="tag">activity</a>.</p><br/><br/><p>Siempre se deber\xe1 incluir todo el c\xf3digo relacionado a la pregunta y, si hubiese alg\xfan error, se deber\xe1 incluir la descripci\xf3n completa del error con su respectivo volcado de pila (<em>stack trace</em>).</p><br/><br/><hr><br/><br/><h3>Versiones de Android</h3><br/><br/><p><img src="http://i.stack.imgur.com/cR0n1.jpg" alt="Versiones de Android"></p><br/><br/><h3>Documentaci\xf3n de las APIs</h3><br/><br/><ul><br/><li><a href="http://developer.android.com/about/versions/android-2.0.html" rel="nofollow">Android 2.0 Eclair (Nivel de API 5)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.0.1.html" rel="nofollow">Android 2.0.1 Eclair (Nivel de API 6)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.1.html" rel="nofollow">Android 2.1 Eclair (Nivel de API 7)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.2.html" rel="nofollow">Android 2.2 Froyo (Nivel de API 8)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.3.html" rel="nofollow">Android 2.3 Gingerbread (Nivel de API 9)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.3.3.html" rel="nofollow">Android 2.3.3 Gingerbread (Nivel de API 10)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-2.3.4.html" rel="nofollow">Android 2.3.4 Gingerbread (Nivel de API 10)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-3.0.html" rel="nofollow">Android 3.0 Honeycomb (Nivel de API 11)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-3.1.html" rel="nofollow">Android 3.1 Honeycomb (Nivel de API 12)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-3.2.html" rel="nofollow">Android 3.2 Honeycomb (Nivel de API 13)</a></li><br/><li><a href="http://developer.android.com/about/versions/android-4.0.html" rel="nofollow">Androi ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T19:29:30.283',
#    u'Id': u'115',
#    u'LastActivityDate': u'2016-08-16T12:21:15.153',
#    u'LastEditDate': u'2016-08-16T12:21:15.153',
#    u'LastEditorUserId': u'127',
#    u'OwnerUserId': u'305',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Android es un sistema operativo de Google para dispositivos digitales tales como tel\xe9fonos inteligentes, tablets, autom\xf3viles, TV, Wear y Google Glass. Para preguntas relacionadas con desarrollo para Android intenta usar etiquetar espec\xedficas, por ejemplo android-activity en lugar de activity.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T19:29:30.283',
#    u'Id': u'116',
#    u'LastActivityDate': u'2015-12-22T19:00:09.853',
#    u'LastEditDate': u'2015-12-22T19:00:09.853',
#    u'LastEditorUserId': u'1943',
#    u'OwnerUserId': u'305',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>C# es un Lenguaje de programaci\xf3n multi-paradigma. Las preguntas deber\xedan incluir ejemplos de c\xf3digo y la suficiente informaci\xf3n para reproducir el problema. Hacer uso de otras etiquetas relacionadas con el runtime de la plataforma es recomendado ya que algunas caracter\xedsticas del lenguaje solo funcionan en determinados escenarios. Ejemplo de etiquetas: mono, xamarin, winrt, .net, .net-4.0</p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T20:02:49.717',
#    u'Id': u'124',
#    u'LastActivityDate': u'2016-06-16T14:29:50.983',
#    u'LastEditDate': u'2016-06-16T14:29:50.983',
#    u'LastEditorUserId': u'7242',
#    u'OwnerUserId': u'7242',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'C# es un Lenguaje de programaci\xf3n multi-paradigma. Las preguntas deber\xedan incluir ejemplos de c\xf3digo y la suficiente informaci\xf3n para reproducir el problema.<br/>Hacer uso de otras etiquetas relacionadas con el runtime de la plataforma es recomendado ya que algunas caracter\xedsticas del lenguaje solo funcionan en determinados escenarios. Ejemplo de etiquetas: mono, xamarin, winrt, .net, .net-4.0',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T20:02:49.717',
#    u'Id': u'125',
#    u'LastActivityDate': u'2016-06-16T16:11:22.073',
#    u'LastEditDate': u'2016-06-16T16:11:22.073',
#    u'LastEditorUserId': u'7242',
#    u'OwnerUserId': u'225',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>SQL significa <em>Structured Query Language</em> o lenguaje de consulta estructurado.</p><br/><br/><p>Un subconjunto del est\xe1ndar SQL es <strong>DDL</strong> (Data Definition Language) o lenguaje de definici\xf3n de datos, que se utiliza para crear tablas y restricciones. \xc9stas incluyen:</p><br/><br/><ul><br/><li><code>CREATE</code></li><br/><li><code>DROP</code></li><br/><li><code>ALTER</code></li><br/></ul><br/><br/><p>Otro subconjunto es <strong>DML</strong> (Data Manipulation Language) o lenguaje de manipulaci\xf3n de datos, que se utiliza para modificar y ver los datos dentro de la base de datos:</p><br/><br/><ul><br/><li><code>SELECT</code></li><br/><li><code>INSERT</code></li><br/><li><code>UPDATE</code></li><br/><li><code>DELETE</code></li><br/></ul><br/><br/><p>La final subconjunto "est\xe1ndar" de los comandos es <strong>DCL</strong> (Data Control Language) o lenguaje de control de datos:</p><br/><br/><ul><br/><li><code>GRANT</code></li><br/><li><code>REVOKE</code><br/>\xa0\xa0<br/>Muchas implementaciones de bases de datos requieren el uso de SQL, y con los a\xf1os, los vendedores han implementado dialectos de SQL para proporcionar m\xe1s funcionalidad, as\xed como simplificarlo. Debido a estas desviaciones de la norma, SQL se fractura - sintaxis que trabaja en uno implementaciones no necesariamente funciona en otro.</li><br/></ul><br/><br/><p><strong>ISO/IEC</strong> (antes ANSI) Las normas han sido beneficiosos para resolver este tipo de situaciones, pero la adopci\xf3n es selectiva. Las consultas que se ajusten a estas normas deben ser portable a otras bases de datos, aunque el rendimiento puede variar.</p><br/><br/><p>La mayor\xeda de los DBMS (sistemas de gesti\xf3n de base de datos) tienen idiomas adicionales para la escritura de procedimientos almacenados. En Oracle se trata de PL/SQL (lenguaje de procedimiento/lenguaje de consulta estructurado), en PostgreSQL es PL/pgSQL (lenguaje de procedimiento/PostgreSQL). Fuera de procedimientos o funciones almacenadas, Oracle y PostgreSQL utilizan SQL. Microsoft SQL Server utiliza el t\xe9rmino T-SQL (Transact-SQL) para SQL "llanura" (consultas, DML, ..) y el lenguaje utilizado para procedimientos almacenados.</p><br/><br/><h3>Recomendaci\xf3n Etiquetado</h3><br/><br/><p>Esta etiqueta se debe utilizar para SQL generales preguntas de lenguaje de programaci\xf3n, adem\xe1s de etiquetas para productos espec\xedficos. Por ejemplo, las preguntas sobre Microsoft SQL Server deben utilizar su propio etiqueta, mientras que preguntas acerca de MySQL deben utilizar el etiqueta de MySQL. SQL es el paraguas bajo el cual existen estos productos; etiquet\xe1ndolos por producto (incluyendo la versi\xf3n, por ejemplo, Oracle11g, Sql Server 2008 es la forma m\xe1s f\xe1cil de saber qu\xe9 funcionalidad est\xe1 disponible para la tarea en cuesti\xf3n. Es muy com\xfan que los MySQL preguntas que omiten esta etiqueta porque las discusiones de consulta en MySQL son m\xe1s a menudo expresan como MySQL en lugar de SQL en general.</p><br/><br/><p>Por favor, lea este <a href="http://en.wikipedia.org/wiki/SQL-92" rel="nofollow">Resumen</a> (en Ingl\xe9s) sobre el est\xe1ndar SQL (el 1992 uno en este caso, implementado en t\xe9rminos generales) y si se puede, consulte el <a href="http://www.contrib.andrew.cmu.edu/~shadow/sql/sql1992.txt" rel="nofollow">libro en s\xed</a> (tambi\xe9n en Ingl\xe9s).</p><br/><br/><h3>Libros de programaci\xf3n SQL gratuito</h3><br/><br/><ul><br/><li><a href="http://www.cs.arizona.edu/people/rts/publications.html" rel="nofollow">Developing Time-Oriented Database Applications in SQL</a></li><br/><li><a href="http://use-the-index-luke.com" rel="nofollow">Use the Index, Luke!: A Guide To SQL Database Performance</a></li><br/><li><a href="http://sql.learncodethehardway.org" rel="nofollow">Learn SQL The Hard Way</a></li><br/><li><a href="http://www.w3schools.com/sql/default.asp" rel="nofollow">SQL Tutorial For Starters</a></li><br/><li><a href="http:/ ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T20:58:14.733',
#    u'Id': u'143',
#    u'LastActivityDate': u'2015-12-05T21:04:03.123',
#    u'LastEditDate': u'2015-12-05T21:04:03.123',
#    u'LastEditorUserId': u'345',
#    u'OwnerUserId': u'345',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Structured Query Language (SQL) es un lenguaje para realizar consultas a bases de datos. Las preguntas deben incluir c\xf3digo de ejemplo, estructura de la tabla, muestra de datos, [SQL Fiddle](http://sqlfiddle.com) y una etiqueta para la aplicaci\xf3n DBMS (por ejemplo, MySQL, PostgreSQL, Oracle, MS SQL Server, IBM DB2) que se utiliza. Si su pregunta se refiere a un DBMS espec\xedfico (usa extensiones/caracter\xedsticas), utilice esa etiqueta de DBMS en su lugar.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T20:58:14.733',
#    u'Id': u'144',
#    u'LastActivityDate': u'2015-12-07T16:21:53.777',
#    u'LastEditDate': u'2015-12-07T16:21:53.777',
#    u'LastEditorUserId': u'26',
#    u'OwnerUserId': u'345',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>HTML (HyperText Markup Language) es el lenguaje de marcado est\xe1ndar usado para la estructuraci\xf3n de p\xe1ginas web y formato de contenido. HTML describe sem\xe1nticamente la estructura de un sitio web a trav\xe9s de elementos de presentaci\xf3n convirti\xe9ndolo en un lenguaje de interpretaci\xf3n en vez de un lenguaje de programaci\xf3n. Las especificaciones m\xe1s recientes de HTML  se encuentran en la revisi\xf3n de HTML5.</p><br/><br/><p>Los elementos HTML forman los elementos esenciales de todas las p\xe1ginas web. HTML permite que  im\xe1genes y objetos sean incrustados y puedan ser usados para crear formularios interactivos. Proporciona un m\xe9todo para crear documentos estructurados mediante una sem\xe1ntica estructural para el texto como cabeceras, p\xe1rrafos, listas, enlaces, citas y otros art\xedculos. Puede tener incrustados scripts escritos en otros lenguajes como JavaScript que afectan al comportamiento de las p\xe1ginas web HTML.  Todas las p\xe1ginas web escritas en otros lenguajes (PHP, JSP, VF etc.) se representan como HTML en el navegador.</p><br/><br/><hr><br/><br/><h3>Sintaxis</h3><br/><br/><p>HTML se escribe de la siguiente forma, los elementos HTML consisten en etiquetas (y sus atributos) rodeados por corchetes angulares (como <code><html></code>), dentro del contenido de la pagina web. </p><br/><br/><p>Las etiquetas en HTML vienen com\xfanmente en pareja, de la forma <code><h1></code> y <code></h1></code>, aunque algunas etiquetas, conocidos como elementos vacios, esta desemparejadas, como por ejemplo <code><img></code>,  estos elementos son cerrados por lo general colocando <code>/</code> al final (ej. <code><img src=\'image.jpg\'/></code>). <br/>La primera etiqueta en una pareja es la etiqueta de inicio y la segunda es la etiqueta de cierre. Entre estas etiquetas los autores pueden a\xf1adir, texto, etiquetas, comentarios y otros tipos de contenido basado en texto.</p><br/><br/><p>El prop\xf3sito de un navegador web es leer los documentos HTML e interpretarlos en web visible o audible. El navegador no muestra las etiquetas html, pero las usa para interpretar el contenido de la pagina.</p><br/><br/><hr><br/><br/><h3>Estandares</h3><br/><br/><p>HTML est\xe1ndar as\xed como otras muchas tecnolog\xedas web son mantenidas por el <a href="http://www.w3.org/" rel="nofollow">World Wide Web Consortium</a> (<a href="/questions/tagged/w3c" class="post-tag" title="mostrar preguntas con la etiqueta "w3c"" rel="tag">w3c</a>). </p><br/><br/><p>HTML4 fue introducido en 1997 y su sucesor, <a href="/questions/tagged/html5" class="post-tag" title="mostrar preguntas con la etiqueta "html5"" rel="tag">html5</a> fue recientemente desarrollado por W3C. Lo que  W3C llama <em>HTML5</em> es un subconjunto de  HTML-Living-Standard que son especificados por el  <a href="https://whatwg.org/" rel="nofollow">Web Hypertext Application Technology Working Group</a> (WHATWG).</p><br/><br/><p>HTML4 was introduced in 1997, and the latest iteration, <a href="/questions/tagged/html5" class="post-tag" title="mostrar preguntas con la etiqueta "html5"" rel="tag">html5</a> was recently developed by the W3C. What W3C calls <em>HTML5</em> is a subset of the HTML-Living-Standard which is specified by the <a href="https://whatwg.org/" rel="nofollow">Web Hypertext Application Technology Working Group</a> (WHATWG).<br/>Las especificaciones de lenguaje y los documentos del est\xe1ndar HTML5 est\xe1n disponibles online <a href="http://www.w3.org/TR/html5/" rel="nofollow">aqu\xed</a>.</p><br/><br/><hr><br/><br/><h3>FAQ</h3><br/><br/><ul><br/><li><a href="https://developer.mozilla.org/en-US/docs/Web/Guide/HTML/HTML5/HTML5_element_list" rel="nofollow">HTML5 Elements List</a></li><br/></ul><br/><br/><h2>Refer\xe9ncias</h2><br/><br/><ul><br/><li><a href="https://www.w3.org/wiki/HTML/Specifications" rel="nofollow">W3C HTML/Specifications</a></li><br/><li><a href="https://validator.w3.org/" rel="nofollow">W3C HTML Validator</a></li>< ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:12:00.550',
#    u'Id': u'163',
#    u'LastActivityDate': u'2015-12-24T07:29:53.163',
#    u'LastEditDate': u'2015-12-24T07:29:53.163',
#    u'LastEditorUserId': u'1594',
#    u'OwnerUserId': u'342',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'HTML (HyperText Markup Language) es el lenguaje de marcado est\xe1ndar usado para la estructuraci\xf3n de p\xe1ginas web y formato de contenido. HTML describe sem\xe1nticamente la estructura de un sitio web a trav\xe9s de elementos de presentaci\xf3n convirti\xe9ndolo en un lenguaje de interpretaci\xf3n en vez de un lenguaje de programaci\xf3n. Las especificaciones m\xe1s recientes de HTML  se encuentra en la revisi\xf3n de HTML5. ',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:12:00.550',
#    u'Id': u'164',
#    u'LastActivityDate': u'2015-12-06T04:15:55.850',
#    u'LastEditDate': u'2015-12-06T04:15:55.850',
#    u'LastEditorUserId': u'360',
#    u'OwnerUserId': u'360',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<h2>Documentaci\xf3n</h2><br/><br/><ul><br/><li><a href="http://laravel.com/docs/master" rel="nofollow">Documentaci\xf3n m\xe1s reciente</a></li><br/><li><a href="http://laravel.com/docs/5.1" rel="nofollow">Documentaci\xf3n de Laravel 5.1</a></li><br/><li><a href="http://laravel.com/docs/5.0" rel="nofollow">Documentaci\xf3n de Laravel 5</a></li><br/><li><a href="http://laravel.com/docs/4.2" rel="nofollow">Documentaci\xf3n de Laravel 4.2</a></li><br/><li><a href="http://laravel.com/api/5.1/" rel="nofollow">Laravel 5.1 API</a></li><br/><li><a href="http://laravel.com/api/5.0/" rel="nofollow">Laravel 5 API</a></li><br/><li><a href="http://laravel.com/api/4.2/" rel="nofollow">Laravel 4.2 API</a></li><br/><li><a href="http://laravel.com/api/4.1/" rel="nofollow">Laravel 4.1 API</a></li><br/><li><a href="http://laravel.com/api/4.0/" rel="nofollow">Laravel 4 API</a></li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:24:52.357',
#    u'Id': u'165',
#    u'LastActivityDate': u'2016-04-05T20:20:49.980',
#    u'LastEditDate': u'2016-04-05T20:20:49.980',
#    u'LastEditorUserId': u'73',
#    u'OwnerUserId': u'360',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Laravel es framework basado en el patr\xf3n MVC que tiene como finalidad el desarrollo de aplicaciones web. Es de c\xf3digo abierto y escrito en PHP creado por Taylor Otwell. Laravel ayuda a crear aplicaciones usando simplicidad y sintaxis expresivo.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:24:52.357',
#    u'Id': u'166',
#    u'LastActivityDate': u'2015-12-06T04:14:14.923',
#    u'LastEditDate': u'2015-12-06T04:14:14.923',
#    u'LastEditorUserId': u'360',
#    u'OwnerUserId': u'360',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><a href="https://www.java.com/es/" rel="nofollow">Java</a> es un lenguaje de alto nivel que forma parte del paradigma de la <a href="https://es.wikipedia.org/wiki/Programaci%C3%B3n_orientada_a_objetos" rel="nofollow">Programaci\xf3n Orientada a Objetos</a>. Su sintaxis es similar a los lenguajes <a href="/questions/tagged/c" class="post-tag" title="mostrar preguntas con la etiqueta "c"" rel="tag">c</a> y <a href="/questions/tagged/c%2b%2b" class="post-tag" title="mostrar preguntas con la etiqueta "c++"" rel="tag">c++</a>, pero su modelo de objetos es m\xe1s simple que el de <a href="/questions/tagged/c%2b%2b" class="post-tag" title="mostrar preguntas con la etiqueta "c++"" rel="tag">c++</a> y tiene menos facilidades para trabajar a bajo nivel. Las aplicaciones Java se compilan com\xfanmente a <strong>bytecode</strong> (denominados archivos <strong>class</strong>) que pueden ser ejecutados por una <a href="/questions/tagged/jvm" class="post-tag" title="mostrar preguntas con la etiqueta "jvm"" rel="tag">jvm</a> (siglas: Java Virtual Machine, o M\xe1quina Virtual Java en espa\xf1ol), independientemente de la arquitectura del computador. La JVM muy a menudo compila este c\xf3digo a c\xf3digo nativo de m\xe1quina para optimizar el rendimiento.</p><br/><br/><p>La JVM administra la memoria con la ayuda de un <strong>recolector de basura</strong>, m\xe1s conocido por su nombre en ingl\xe9s <strong>garbage collector</strong> (ver <a href="https://es.wikipedia.org/wiki/Recolector_de_basura" rel="nofollow">recolector de basura</a>) para manejar la liberaci\xf3n de objetos de la memoria cuando ya no se utilizan. La <a href="https://es.wikipedia.org/wiki/Sistema_de_tipos" rel="nofollow">disciplina de tipos</a> de Java es est\xe1tica, fuerte, segura, nominativa, y manifiesta. Java soporta caracter\xedsticas como reflexi\xf3n y comunicaci\xf3n con <a href="/questions/tagged/c" class="post-tag" title="mostrar preguntas con la etiqueta "c"" rel="tag">c</a> y <a href="/questions/tagged/c%2b%2b" class="post-tag" title="mostrar preguntas con la etiqueta "c++"" rel="tag">c++</a> v\xeda <a href="/questions/tagged/jni" class="post-tag" title="mostrar preguntas con la etiqueta "jni"" rel="tag">jni</a>.</p><br/><br/><p>Java est\xe1 dise\xf1ado a tener pocas dependencias de implementaci\xf3n en lo posible, de manera que permite a los desarrolladores de aplicaciones a <strong>escribir una vez, ejecutar donde sea</strong>: el c\xf3digo que se ejecuta en una plataforma no necesita ser recompilado para ejecutarse en otra m\xe1quina. Java fue desarrollado originalmente por <a href="https://es.wikipedia.org/wiki/James_Gosling" rel="nofollow">James Gosling</a> en Sun Microsystems (que se uni\xf3 a la Corporaci\xf3n Oracle en abril de 2009) y fue liberado en 1995 como un componente fundamental de la plataforma Java de Sun Microsystem.</p><br/><br/><p>La plataforma Java es el nombre brindado por Sun (ahora Oracle) a los sistemas computacionales que tienen instalados herramientas para desarrollar y ejecutar programas de Java. La plataforma posee una variedad de herramientas que permiten a los desarrolladores trabajar eficientemente con el lenguaje de programaci\xf3n Java.</p><br/><br/><p>La plataforma consiste de dos paquetes de software esenciales:</p><br/><br/><ul><br/><li>El <strong>Entorno de Ejecuci\xf3n Java</strong>, conocido en ingl\xe9s como <strong>Java Runtime Environment (JRE)</strong>, que es necesario para <em>ejecutar</em> las aplicaciones Java y los applets, y</li><br/><li>El <strong>Equipo de Desarrollo Java</strong>, conocido en ingl\xe9s como <strong>Java Development Kit (JDK)</strong>, que es necesario para <em>desarrollar</em> aplicaciones Java y applets. El JDK viene con un JRE.</li><br/></ul><br/><br/><p>En esta secci\xf3n, se explorar\xe1n en detalle qu\xe9 es lo que cada uno de estos componentes hacen en la plataforma Java.</p><br/><br/><h2>Conocimientos Previos</h2><br/><br/><p>La principal implementaci\xf3n de referenc ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:46:31.803',
#    u'Id': u'172',
#    u'LastActivityDate': u'2015-12-29T09:50:57.400',
#    u'LastEditDate': u'2015-12-29T09:50:57.400',
#    u'LastEditorUserId': u'2027',
#    u'OwnerUserId': u'342',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Java (no se debe confundir con JavaScript)  es un lenguaje de programaci\xf3n de prop\xf3sito general que soporta la programaci\xf3n orientada a objetos. Para correr depende de una M\xe1quina Virtual de Java (JVM). Plataforma de Java es el nombre para un sistema que tiene instaladas las herramientas para desarrollar y ejecutar programas de Java. Use esta etiqueta para preguntas referentes al languaje de programaci\xf3n Java o las herramientas de la plataforma de Java. ',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T22:46:31.803',
#    u'Id': u'173',
#    u'LastActivityDate': u'2015-12-06T18:27:09.433',
#    u'LastEditDate': u'2015-12-06T18:27:09.433',
#    u'LastEditorUserId': u'342',
#    u'OwnerUserId': u'342',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Git es un <a href="https://es.wikipedia.org/wiki/Control_de_versiones_distribuido" rel="nofollow">sistema de control de versiones distribuido</a> inicialmente dise\xf1ado y desarrollado por <a href="https://es.wikipedia.org/wiki/Linus_Torvalds" rel="nofollow">Linus Torvalds</a> para el desarrollo del kernel de <a href="https://es.wikipedia.org/wiki/N%C3%BAcleo_Linux" rel="nofollow">Linux</a>. Cada directorio de trabajo de Git contiene un repositorio con la historia completa del desarrollo y capacidades completas de revisi\xf3n y seguimiento que no dependen de acceso a la red o a un servidor central.</p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T23:42:54.503',
#    u'Id': u'182',
#    u'LastActivityDate': u'2015-12-08T00:41:10.537',
#    u'LastEditDate': u'2015-12-08T00:41:10.537',
#    u'LastEditorUserId': u'417',
#    u'OwnerUserId': u'417',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Git es un sistema de control de versiones distribuido, gratuito y de c\xf3digo abierto.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-01T23:42:54.503',
#    u'Id': u'183',
#    u'LastActivityDate': u'2015-12-18T14:29:24.953',
#    u'LastEditDate': u'2015-12-18T14:29:24.953',
#    u'LastEditorUserId': u'291',
#    u'OwnerUserId': u'342',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><a href="http://i.stack.imgur.com/wil8l.png" rel="nofollow"><img src="http://i.stack.imgur.com/wil8l.png" alt="Bower"></a></p><br/><br/><p>Con <a href="http://bower.io" rel="nofollow">Bower</a> puedes instalar paquetes para tu aplicaci\xf3n web f\xe1cilmente. Es tan sencillo como indicar el <a href="http://bower.io/search/" rel="nofollow">nombre del paquete</a> que deseas instalar: <code>bower install NOMBRE_DEL_PAQUETE</code>.</p><br/><br/><ul><br/><li><a href="http://bower.io" rel="nofollow">Sitio oficial</a></li><br/><li><a href="http://bower.io/search/" rel="nofollow">B\xfasqueda de paquetes</a></li><br/><li><a href="https://github.com/bower/bower" rel="nofollow">Repositorio en GitHiub</a></li><br/></ul><br/><br/><p>Instalaci\xf3n usando <a href="https://www.npmjs.com/" rel="nofollow">npm</a> <code>npm install -g bower</code></p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T00:01:45.093',
#    u'Id': u'185',
#    u'LastActivityDate': u'2015-12-05T21:10:07.920',
#    u'LastEditDate': u'2015-12-05T21:10:07.920',
#    u'LastEditorUserId': u'404',
#    u'OwnerUserId': u'404',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Bower es un administrador de paquetes para desarollo web moderno. Bower te permite instalar paquetes o librer\xedas y sus dependencias de forma r\xe1pida y sencilla.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T00:01:45.093',
#    u'Id': u'186',
#    u'LastActivityDate': u'2015-12-07T01:11:43.893',
#    u'LastEditDate': u'2015-12-07T01:11:43.893',
#    u'LastEditorUserId': u'404',
#    u'OwnerUserId': u'404',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><strong>Recursos</strong></p><br/><br/><ul><br/><li><a href="http://fideloper.com/best-way-to-install-laravel4" rel="nofollow">Configuraci\xf3n Laravel 4</a></li><br/><li><a href="http://laravel.com/docs/4.2" rel="nofollow">Documentaci\xf3n Oficial</a></li><br/></ul><br/><br/><p><strong>Social Media</strong></p><br/><br/><ul><br/><li><a href="http://twitter.com/laravelphp" rel="nofollow" title="Laravel on Twitter">Twitter</a></li><br/><li><a href="https://github.com/laravel/laravel" rel="nofollow" title="Laravel on Github">Github</a></li><br/><li><a href="https://plus.google.com/communities/106838454910116161868" rel="nofollow" title="Laravel on Google+">Google+</a></li><br/><li><a href="http://laravel.io/chat" rel="nofollow" title="Laravel IRC">Laravel IRC</a></li><br/><li><a href="https://github.com/laravel/framework/issues" rel="nofollow">Issue tracker</a></li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T09:41:14.427',
#    u'Id': u'213',
#    u'LastActivityDate': u'2015-12-06T18:27:16.520',
#    u'LastEditDate': u'2015-12-06T18:27:16.520',
#    u'LastEditorUserId': u'234',
#    u'OwnerUserId': u'234',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Laravel 4  es la versi\xf3n anterior del framework MVC de c\xf3digo abierto para desarrollo web en PHP creado por Taylor Otwell. Laravel le ayuda a crear aplicaciones utilizando una sintaxis simple y expresiva.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T09:41:14.427',
#    u'Id': u'214',
#    u'LastActivityDate': u'2015-12-06T04:15:18.503',
#    u'LastEditDate': u'2015-12-06T04:15:18.503',
#    u'LastEditorUserId': u'234',
#    u'OwnerUserId': u'234',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Laravel 5 es la versi\xf3n actual del framework  PHP de desarrollo web creado por Taylor Otwell. Laravel le ayuda a crear aplicaciones utilizando una sintaxis simple y expresiva.</p><br/><br/><p>Laravel 5 fue lanzado el 04 de febrero de 2015. Se requiere PHP 5.4 o superior para funcionar.</p><br/><br/><p>Larvel 5 utiliza los \xfaltimos componentes y t\xe9cnicas de patr\xf3nes de dise\xf1o y componentes de PHP5. Laravel utiliza Composer para la gesti\xf3n de las dependencias. Laravel tiene su propio motor de plantillas opcional llamado Blade.</p><br/><br/><p>Para Laravel 5,1 aseg\xfarate de que tienes PHP 5.5.9.</p><br/><br/><h3>Documentaci\xf3n</h3><br/><br/><ul><br/><li><a href="http://laravel.com/docs/5.0" rel="nofollow">Laravel 5 Documentaci\xf3n</a></li><br/><li><a href="https://laracasts.com/series/laravel-5-fundamentals" rel="nofollow">Laravel 5 Fundamentals</a></li><br/><li><a href="http://laravel.com/api/5.0/" rel="nofollow">Laravel 5 API</a></li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T09:46:15.667',
#    u'Id': u'215',
#    u'LastActivityDate': u'2015-12-07T11:55:36.603',
#    u'LastEditDate': u'2015-12-07T11:55:36.603',
#    u'LastEditorUserId': u'234',
#    u'OwnerUserId': u'234',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Laravel 5 es la versi\xf3n actual del framework  PHP de desarrollo web creado por Taylor Otwell. Laravel le ayuda a crear aplicaciones utilizando una sintaxis simple y expresiva.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T09:46:15.667',
#    u'Id': u'216',
#    u'LastActivityDate': u'2015-12-06T04:15:22.333',
#    u'LastEditDate': u'2015-12-06T04:15:22.333',
#    u'LastEditorUserId': u'234',
#    u'OwnerUserId': u'234',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T10:31:43.837',
#    u'Id': u'218',
#    u'LastActivityDate': u'2015-12-02T10:31:43.837',
#    u'LastEditDate': u'2015-12-02T10:31:43.837',
#    u'LastEditorUserId': u'-1',
#    u'OwnerUserId': u'-1',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'CommentCount': u'0',
#    u'CreationDate': u'2015-12-02T10:31:43.837',
#    u'Id': u'219',
#    u'LastActivityDate': u'2015-12-02T10:31:43.837',
#    u'LastEditDate': u'2015-12-02T10:31:43.837',
#    u'LastEditorUserId': u'-1',
#    u'OwnerUserId': u'-1',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
# ...
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-08T05:15:29.537',
#    u'Id': u'7292',
#    u'LastActivityDate': u'2016-04-08T12:12:39.660',
#    u'LastEditDate': u'2016-04-08T12:12:39.660',
#    u'LastEditorUserId': u'250',
#    u'OwnerUserId': u'250',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'CodeIgniter 3.x es la \xfaltima versi\xf3n principal (3.0.0 se lanzo en Abril de 2015) del popular framework de c\xf3digo abierto para el desarrollo de aplicaciones web en PHP CodeIgniter. Visitar la  etiqueta [tag:codeigniter] para obtener m\xe1s informaci\xf3n',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-08T05:15:29.537',
#    u'Id': u'7293',
#    u'LastActivityDate': u'2016-04-08T12:12:35.647',
#    u'LastEditDate': u'2016-04-08T12:12:35.647',
#    u'LastEditorUserId': u'250',
#    u'OwnerUserId': u'250',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-09T17:10:00.270',
#    u'Id': u'7393',
#    u'LastActivityDate': u'2016-04-09T17:10:00.270',
#    u'LastEditDate': u'2016-04-09T17:10:00.270',
#    u'LastEditorUserId': u'-1',
#    u'OwnerUserId': u'-1',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'CoffeeScript es un lenguaje que compila en JavaScript. Tras bambalinas de aquellas molestas llaves y punto y comas, JavaScript siempre ha tenido un glorioso modelo de objetos en su n\xfacleo. CoffeeScript es un intento de exponer las partes buenas de JavaScript de una manera simple.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-09T17:10:00.270',
#    u'Id': u'7394',
#    u'LastActivityDate': u'2016-04-10T10:36:46.217',
#    u'LastEditDate': u'2016-04-10T10:36:46.217',
#    u'LastEditorUserId': u'25',
#    u'OwnerUserId': u'342',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-17T16:09:52.353',
#    u'Id': u'7925',
#    u'LastActivityDate': u'2016-04-17T16:09:52.353',
#    u'LastEditDate': u'2016-04-17T16:09:52.353',
#    u'LastEditorUserId': u'-1',
#    u'OwnerUserId': u'-1',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'SharePoint Online proporciona en la nube las caracter\xedsticas eficaces de SharePoint sin la sobrecarga asociada que supone administrar la infraestructura por s\xed mismo.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-17T16:09:52.353',
#    u'Id': u'7926',
#    u'LastActivityDate': u'2016-04-17T21:40:36.467',
#    u'LastEditDate': u'2016-04-17T21:40:36.467',
#    u'LastEditorUserId': u'3313',
#    u'OwnerUserId': u'3313',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-17T16:10:49.467',
#    u'Id': u'7927',
#    u'LastActivityDate': u'2016-04-17T16:10:49.467',
#    u'LastEditDate': u'2016-04-17T16:10:49.467',
#    u'LastEditorUserId': u'-1',
#    u'OwnerUserId': u'-1',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Entorno de pruebas que permite probar r\xe1pidamente c\xf3digo HTML, CSS y Javascript. Es una herramienta 100% web, se utiliza desde el navegador web sin instalar nada, s\xf3lo visitando la p\xe1gina oficial de la herramienta.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-17T16:10:49.467',
#    u'Id': u'7928',
#    u'LastActivityDate': u'2016-04-17T21:40:32.747',
#    u'LastEditDate': u'2016-04-17T21:40:32.747',
#    u'LastEditorUserId': u'3313',
#    u'OwnerUserId': u'3313',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>WildFly est\xe1 escrito en Java y es multi plataforma: se puede utilizar en cualquier sistema operativo que soporte Java.</p><br/><br/><p>WildFly fue desarrollado por JBoss, ahora una divisi\xf3n de Red Hat. Est\xe1 licenciado bajo los t\xe9rminos de GNU Lesser General Public License, WildFly es gratuito y software de c\xf3digo abierto.</p><br/><br/><p>El renombre a WildFly fue hecho para reducir confusi\xf3n. Este solo afecta al proyecto JBoss Application Server. La Comunidad Jboss o la l\xednea de productos JBoss de Red Hat (donde est\xe1 JBoss Enterprise Application Platform) mantendr\xe1n sus nombres.</p><br/><br/><p>Para mayor informaci\xf3n, visita el <a href="http://www.wildfly.org" rel="nofollow" title="WildFly website">sitio web de WildFly</a> (en ingl\xe9s).</p><br/><br/><h2>Informaci\xf3n de versiones</h2><br/><br/><ul><br/><li>Versi\xf3n de \xfaltimo <em>lanzamiento</em>: <strong>10.0.0.Final</strong></li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T16:52:08.417',
#    u'Id': u'8136',
#    u'LastActivityDate': u'2016-04-20T16:52:08.417',
#    u'LastEditDate': u'2016-04-20T16:52:08.417',
#    u'LastEditorUserId': u'227',
#    u'OwnerUserId': u'227',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'WildFly, conocido com\xfanmente como JBoss Application Server, es un servidor de aplicaciones que implementa la Edici\xf3n Empresarial de la Plataforma Java, en ingl\xe9s: Java Platform, Enterprise Edition (Java EE).',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T16:52:08.417',
#    u'Id': u'8137',
#    u'LastActivityDate': u'2016-04-20T16:52:08.417',
#    u'LastEditDate': u'2016-04-20T16:52:08.417',
#    u'LastEditorUserId': u'227',
#    u'OwnerUserId': u'227',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Java Flight Recorder es un marco de trabajo para evaluaci\xf3n y eventos construido para Oracle JDK (no confundir con HotSpot). Permite a los administradores y desarrolladores Java obtener informaci\xf3n detallada de bajo nivel sobre c\xf3mo se comporta la m\xe1quina virtual Java (JVM) y la aplicaci\xf3n Java. Java Mission Control es un conjunto avanzado de herramientas que habilitan el an\xe1lisis eficiente y detallado de los datos recolectados por Java Flight Recorder. La cadena de herramientas permite a los desarrolladores y administradores recolectar y analizar datos de las aplicaciones Java que se ejecutan de manera local o en ambientes de producci\xf3n. Desde la versi\xf3n Java SE 7 actualizaci\xf3n 40 de HotSpot, estas herramientas vienen incluidas de manera gratuita para el an\xe1lisis de las aplicaciones Java en ambientes que utilicen HotSpot como m\xe1quina virtual Java.</p><br/><br/><p>Sitio oficial del producto: <a href="http://www.oracle.com/technetwork/java/javaseproducts/mission-control/index.html" rel="nofollow">http://www.oracle.com/technetwork/java/javaseproducts/mission-control/index.html</a></p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T16:58:48.857',
#    u'Id': u'8138',
#    u'LastActivityDate': u'2016-04-20T16:58:48.857',
#    u'LastEditDate': u'2016-04-20T16:58:48.857',
#    u'LastEditorUserId': u'227',
#    u'OwnerUserId': u'227',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Java Flight Recorder y Java Mission Control juntos crean una cadena de herramientas para recolectar informaci\xf3n de bajo nivel y de ejecuci\xf3n detallada habilitando an\xe1lisis de incidentes luego del hecho.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T16:58:48.857',
#    u'Id': u'8139',
#    u'LastActivityDate': u'2016-04-20T16:58:48.857',
#    u'LastEditDate': u'2016-04-20T16:58:48.857',
#    u'LastEditorUserId': u'227',
#    u'OwnerUserId': u'227',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<h2><a href="https://www.visualstudio.com/es-es/products/visual-studio-team-services-vs.aspx" rel="nofollow">Visual Studio Team Services</a></h2><br/><br/><p><strong>Herramientas de colaboraci\xf3n en la nube para equipos</strong></p><br/><br/><p>No es un IDE, es todo lo dem\xe1s. Visual Studio Team Services ofrece un conjunto de herramientas de colaboraci\xf3n con tecnolog\xeda de la nube que funcionan con su editor o IDE existentes, para que su equipo pueda trabajar de manera eficiente en proyectos de software de cualquier \xedndole y envergadura.</p><br/><br/><p><a href="http://i.stack.imgur.com/6eiiL.png" rel="nofollow"><img src="http://i.stack.imgur.com/6eiiL.png" alt="introducir la descripci\xf3n de la imagen aqu\xed"></a></p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T20:48:50.473',
#    u'Id': u'8168',
#    u'LastActivityDate': u'2016-04-20T23:37:32.103',
#    u'LastEditDate': u'2016-04-20T23:37:32.103',
#    u'LastEditorUserId': u'602',
#    u'OwnerUserId': u'602',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Servicio de Microsoft que ofrece un conjunto de herramientas de colaboraci\xf3n con tecnolog\xeda de la nube que funcionan con su editor o IDE existentes, para que su equipo pueda trabajar de manera eficiente en proyectos de software de cualquier \xedndole y envergadura.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-20T20:48:50.473',
#    u'Id': u'8169',
#    u'LastActivityDate': u'2016-04-20T23:37:36.137',
#    u'LastEditDate': u'2016-04-20T23:37:36.137',
#    u'LastEditorUserId': u'602',
#    u'OwnerUserId': u'602',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p><a href="https://es.wikipedia.org/wiki/Prolog" rel="nofollow">Prolog</a>, proveniente del franc\xe9s <strong>PRO</strong>grammation en <strong>LOG</strong>ique, es el lenguaje de programaci\xf3n l\xf3gica m\xe1s antiguo y popular. Su ejecuci\xf3n se basa en dos conceptos: la <a href="https://en.wikipedia.org/wiki/Unification_%28computer_science%29" rel="nofollow">unificaci\xf3n</a> y la <a href="https://es.wikipedia.org/wiki/Vuelta_atr%C3%A1s" rel="nofollow">vuelta atr\xe1s</a>.</p><br/><br/><h1>Programaci\xf3n en PROLOG</h1><br/><br/><p>Los programas en Prolog se componen de <a href="https://es.wikipedia.org/wiki/Cl%C3%A1usula_de_Horn" rel="nofollow">cl\xe1usulas de Horn</a> que constituyen reglas del tipo <a href="https://es.wikipedia.org/wiki/Modus_ponendo_ponens" rel="nofollow">modus ponendo ponens</a>. Existen dos tipos de cl\xe1usulas: <strong>hechos</strong> y <strong>reglas</strong>.</p><br/><br/><p>Una <strong>regla</strong> es del tipo <code>Cabeza :- Cuerpo.</code>, y se lee como <em>"la cabeza es verdad si el cuerpo es verdad"</em>. Por ejemplo, la concatenaci\xf3n de una lista <code>[H|T]</code> con una lista <code>X</code> es otra lista <code>[H|S]</code> si la concatenaci\xf3n de la lista <code>T</code> con la lista <code>X</code> es la lista <code>S</code>:</p><br/><br/><pre><code>append([H|T], X, [H|S]) :- append(T, X, S).<br/></code></pre><br/><br/><p>Un <strong>hecho</strong> es una regla que no tiene cuerpo, es decir, es una regla que siempre es verdad. Por ejemplo, la concatenaci\xf3n de una lista vac\xeda <code>[]</code> con una lista <code>X</code> cualquiera es la propia lista <code>X</code>:</p><br/><br/><pre><code>append([], X, X).<br/></code></pre><br/><br/><h1>Implementaciones</h1><br/><br/><ul><br/><li><a href="http://www.swi-prolog.org/" rel="nofollow">SWI-Prolog</a> (gratis) <a href="/questions/tagged/swi-prolog" class="post-tag" title="mostrar preguntas con la etiqueta "swi-prolog"" rel="tag">swi-prolog</a></li><br/><li><a href="https://sicstus.sics.se/" rel="nofollow">SICStus Prolog</a> (comercial) <a href="/questions/tagged/sicstus-prolog" class="post-tag" title="mostrar preguntas con la etiqueta "sicstus-prolog"" rel="tag">sicstus-prolog</a></li><br/><li><a href="http://www.gprolog.org/" rel="nofollow">GNU Prolog</a> (gratis) <a href="/questions/tagged/gnu-prolog" class="post-tag" title="mostrar preguntas con la etiqueta "gnu-prolog"" rel="tag">gnu-prolog</a></li><br/></ul><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-27T07:28:19.007',
#    u'Id': u'8576',
#    u'LastActivityDate': u'2016-08-27T10:23:21.853',
#    u'LastEditDate': u'2016-08-27T10:23:21.853',
#    u'LastEditorUserId': u'12808',
#    u'OwnerUserId': u'2633',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'Prolog es el lenguaje de programaci\xf3n l\xf3gica m\xe1s com\xfanmente utilizado. Soporta la programaci\xf3n no determinista a trav\xe9s de la vuelta atr\xe1s cronol\xf3gica, y el ajuste de patrones a trav\xe9s de la unificaci\xf3n.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-27T07:28:19.007',
#    u'Id': u'8577',
#    u'LastActivityDate': u'2016-08-27T10:20:32.617',
#    u'LastEditDate': u'2016-08-27T10:20:32.617',
#    u'LastEditorUserId': u'12808',
#    u'OwnerUserId': u'2633',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>ngCordova crea una simple capa de abstracci\xf3n por encima de los cerca de 70+ plugins m\xe1s populares de Cordova y PhoneGap para poder tirar fotos, subir ficheros, obtener la localizaci\xf3n actual con s\xf3lo unas pocas l\xedneas de c\xf3digo.</p><br/><br/><p>Fue creado para ayudar a construir aplicaciones r\xe1pida y eficientemente. Esta capa de abstracci\xf3n usa AngularJS y por lo general es compatible con el sistema de <a href="https://docs.angularjs.org/api/ng/service/$q" rel="nofollow">promesas</a> por lo que el c\xf3digo se integra a la perfecci\xf3n con el resto del c\xf3digo escrito con el mismo framework.</p><br/><br/><p><strong>Sitio oficial:</strong></p><br/><br/><p><a href="http://ngcordova.com/" rel="nofollow">http://ngcordova.com/</a></p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-28T13:53:39.987',
#    u'Id': u'8670',
#    u'LastActivityDate': u'2016-04-28T15:40:32.023',
#    u'LastEditDate': u'2016-04-28T15:40:32.023',
#    u'LastEditorUserId': u'2224',
#    u'OwnerUserId': u'2224',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  [{u'Body': u'ngCordova es una colecci\xf3n de extensiones a los plugins de Cordova con AngularJS para hacer el c\xf3digo m\xe1s eficiente y compatible con la filosof\xeda de las promesas de AngularJS.',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-04-28T13:53:39.987',
#    u'Id': u'8671',
#    u'LastActivityDate': u'2016-04-28T15:40:34.680',
#    u'LastEditDate': u'2016-04-28T15:40:34.680',
#    u'LastEditorUserId': u'2224',
#    u'OwnerUserId': u'2224',
#    u'PostTypeId': u'4',
#    u'Score': u'0'}],
#  [{u'Body': u'<p>Kivy es una biblioteca de <a href="/questions/tagged/python" class="post-tag" title="mostrar preguntas con la etiqueta "python"" rel="tag">python</a> para el desarrollo de aplicaciones ricas con los medios de comunicaci\xf3n multi-touch habilitado. </p><br/><br/><p>El objetivo es permitir el dise\xf1o de interacci\xf3n f\xe1cil y r\xe1pido y prototipado r\xe1pido, al tiempo que su c\xf3digo sea reutilizable y desplegable.</p><br/><br/><p>Kivy est\xe1 escrito en <a href="/questions/tagged/python" class="post-tag" title="mostrar preguntas con la etiqueta "python"" rel="tag">python</a>, basado en <a href="/questions/tagged/opengl" class="post-tag" title="mostrar preguntas con la etiqueta "opengl"" rel="tag">opengl</a> y es compatible con diferentes dispositivos de entrada como: Rat\xf3n, rat\xf3n dual, TUIO, WiiMote, WM_TOUCH, HIDtouch, los productos de Apple y as\xed sucesivamente.</p><br/><br/><p>Kivy activa est\xe1 siendo desarrollado por la comunidad y es de uso gratuito. Funciona en todas las plataformas (Linux, OSX, de Windows, Android, iOS).</p><br/><br/><p>El principal recurso de informaci\xf3n es la p\xe1gina web: <a href="http://kivy.org" rel="nofollow">http://kivy.org</a>.</p><br/>',
#    u'CommentCount': u'0',
#    u'CreationDate': u'2016-05-01T22:00:24.513',
#    u'Id': u'8891',
#    u'LastActivityDate': u'2016-05-01T22:17:12.187',
#    u'LastEditDate': u'2016-05-01T22:17:12.187',
#    u'LastEditorUserId': u'1596',
#    u'OwnerUserId': u'1596',
#    u'PostTypeId': u'5',
#    u'Score': u'0'}],
#  ...]

# %% [markdown]
# Creamos un índice sobre el `Id` para acelerar las siguientes búsquedas:

# %%
# %%cypher
# CREATE INDEX ON :Post(Id);
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Añadimos una relación entre las preguntas y las respuestas:

# %%
# %%cypher
# MATCH (a:Answer), (q:Question {Id: a.ParentId})
# MERGE (a)-[:ANSWERS]->(q)
# ;
# Out:
# 9526 relationships created.
# []

# %% [markdown]
# Las construcciones `%cypher` retornan resultados de los que se puede obtener un `dataframe` de `pandas`:

# %%
#%%cypher
res = %cypher MATCH q=(r)-[:ANSWERS]->(p) RETURN p.Id,r.Id;
df = res.get_dataframe()
df['r.Id'] = pd.to_numeric(df['r.Id'],downcast='unsigned')
df['p.Id'] = pd.to_numeric(df['p.Id'],downcast='unsigned')

df.plot(kind='scatter',x='p.Id',y='r.Id',figsize=(15,15))
# Out:
# 9526 rows affected.

# %% [markdown]
# La consulta RQ4 se puede resolver de manera muy fácil. En esta primera consulta se devuelve los nodos:

# %%
# %%cypher
# // RQ4
# MATCH
# (u)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u2),
# (u2)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u)
# WHERE u2 <> u AND u.Id < u2.Id
# RETURN DISTINCT u,u2
# ;
# Out:
# 51 rows affected.
# [[{u'Id': u'24'}, {u'Id': u'25'}],
#  [{u'Id': u'23'}, {u'Id': u'25'}],
#  [{u'Id': u'24'}, {u'Id': u'95'}],
#  [{u'Id': u'100'}, {u'Id': u'83'}],
#  [{u'Id': u'100'}, {u'Id': u'529'}],
#  [{u'Id': u'100'}, {u'Id': u'638'}],
#  [{u'Id': u'100'}, {u'Id': u'187'}],
#  [{u'Id': u'227'}, {u'Id': u'342'}],
#  [{u'Id': u'250'}, {u'Id': u'731'}],
#  [{u'Id': u'22'}, {u'Id': u'288'}],
#  [{u'Id': u'25'}, {u'Id': u'288'}],
#  [{u'Id': u'22'}, {u'Id': u'342'}],
#  [{u'Id': u'120'}, {u'Id': u'531'}],
#  [{u'Id': u'100'}, {u'Id': u'729'}],
#  [{u'Id': u'1798'}, {u'Id': u'729'}],
#  [{u'Id': u'100'}, {u'Id': u'399'}],
#  [{u'Id': u'100'}, {u'Id': u'2004'}],
#  [{u'Id': u'1839'}, {u'Id': u'729'}],
#  [{u'Id': u'399'}, {u'Id': u'555'}],
#  [{u'Id': u'227'}, {u'Id': u'400'}],
#  [{u'Id': u'2224'}, {u'Id': u'729'}],
#  [{u'Id': u'398'}, {u'Id': u'547'}],
#  [{u'Id': u'100'}, {u'Id': u'353'}],
#  [{u'Id': u'2230'}, {u'Id': u'24'}],
#  [{u'Id': u'225'}, {u'Id': u'25'}],
#  [{u'Id': u'2367'}, {u'Id': u'342'}],
#  [{u'Id': u'22'}, {u'Id': u'729'}],
#  [{u'Id': u'100'}, {u'Id': u'2838'}],
#  [{u'Id': u'2509'}, {u'Id': u'2722'}],
#  [{u'Id': u'342'}, {u'Id': u'517'}],
#  [{u'Id': u'2676'}, {u'Id': u'517'}],
#  [{u'Id': u'2004'}, {u'Id': u'227'}],
#  [{u'Id': u'2230'}, {u'Id': u'250'}],
#  [{u'Id': u'2004'}, {u'Id': u'2747'}],
#  [{u'Id': u'2163'}, {u'Id': u'2230'}],
#  [{u'Id': u'2429'}, {u'Id': u'250'}],
#  [{u'Id': u'250'}, {u'Id': u'34'}],
#  [{u'Id': u'191'}, {u'Id': u'2230'}],
#  [{u'Id': u'250'}, {u'Id': u'73'}],
#  [{u'Id': u'2171'}, {u'Id': u'398'}],
#  [{u'Id': u'2832'}, {u'Id': u'6497'}],
#  [{u'Id': u'2163'}, {u'Id': u'250'}],
#  [{u'Id': u'65'}, {u'Id': u'7661'}],
#  [{u'Id': u'9099'}, {u'Id': u'9754'}],
#  [{u'Id': u'6173'}, {u'Id': u'9099'}],
#  [{u'Id': u'3234'}, {u'Id': u'9099'}],
#  [{u'Id': u'3275'}, {u'Id': u'9905'}],
#  [{u'Id': u'12625'}, {u'Id': u'250'}],
#  [{u'Id': u'250'}, {u'Id': u'9897'}],
#  [{u'Id': u'2224'}, {u'Id': u'73'}],
#  [{u'Id': u'250'}, {u'Id': u'729'}]]

# %% [markdown]
# O bien retornar los `Id` de cada usuario:

# %%
# %%cypher
# MATCH
# (u)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u2),
# (u2)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u)
# WHERE u2 <> u AND toInt(u.Id) < toInt(u2.Id)
# RETURN DISTINCT u.Id,u2.Id
# ORDER BY toInt(u.Id)
# ;
# Out:
# 51 rows affected.
# [[u'22', u'288'],
#  [u'22', u'342'],
#  [u'22', u'729'],
#  [u'23', u'25'],
#  [u'24', u'25'],
#  [u'24', u'95'],
#  [u'24', u'2230'],
#  [u'25', u'288'],
#  [u'25', u'225'],
#  [u'34', u'250'],
#  [u'65', u'7661'],
#  [u'73', u'250'],
#  [u'73', u'2224'],
#  [u'83', u'100'],
#  [u'100', u'529'],
#  [u'100', u'638'],
#  [u'100', u'187'],
#  [u'100', u'729'],
#  [u'100', u'399'],
#  [u'100', u'2004'],
#  [u'100', u'353'],
#  [u'100', u'2838'],
#  [u'120', u'531'],
#  [u'191', u'2230'],
#  [u'227', u'342'],
#  [u'227', u'2004'],
#  [u'227', u'400'],
#  [u'250', u'731'],
#  [u'250', u'2429'],
#  [u'250', u'12625'],
#  [u'250', u'9897'],
#  [u'250', u'2230'],
#  [u'250', u'2163'],
#  [u'250', u'729'],
#  [u'342', u'517'],
#  [u'342', u'2367'],
#  [u'398', u'547'],
#  [u'398', u'2171'],
#  [u'399', u'555'],
#  [u'517', u'2676'],
#  [u'729', u'1798'],
#  [u'729', u'1839'],
#  [u'729', u'2224'],
#  [u'2004', u'2747'],
#  [u'2163', u'2230'],
#  [u'2509', u'2722'],
#  [u'2832', u'6497'],
#  [u'3234', u'9099'],
#  [u'3275', u'9905'],
#  [u'6173', u'9099'],
#  [u'9099', u'9754']]

# %% [markdown]
# Y finalmente, la creación de relaciones `:RECIPROCATE` entre los usuarios. Se introduce también la construcción `WITH`.
#
# `WITH` sirve para introducir "espacios de nombres". Permite importar nombres de filas anteriores, hacer alias con `AS` e introducir nuevos valores con funciones de Cypher. La siguiente consulta es la misma de arriba, RQ4, pero creando relaciones `:RECIPROCATE` entre cada dos usuarios que se ayudan recíprocamente.

# %%
# %%cypher
# // RQ4 creando relaciones de reciprocidad
# MATCH
# (u:User)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u2:User),
# (u2)-[:WROTE]->()-[:ANSWERS]->()<-[:WROTE]-(u)
# WHERE u2 <> u AND u.Id < u2.Id
# WITH u AS user1,u2 AS user2
# MERGE (user1)-[:RECIPROCATE]->(user2)
# MERGE (user2)-[:RECIPROCATE]->(user1)
# ;
# Out:
# 102 relationships created.
# []

# %% [markdown]
# ## EJERCICIO: Construir los nodos `:Tag` para cada uno de los tags que aparecen en las preguntas. Construir las relaciones `post-[:TAGGED]->tag` para cada tag y también `tag-[:TAGS]->post`
#
# Para ello, buscar en la ayuda las construcciones `WITH` y `UNWIND` y las funciones `replace()` y `split()` de Cypher. La siguiente consulta debe retornar 1192 resultados:

# %%
# %%cypher
# MATCH (q:Question)
# WITH (split(trim(replace(replace(replace(q.Tags, '><', ','), '<', ''), '>', '')), ',')) as tags,  q as post
# UNWIND tags as tag
# MERGE (t:Tag {name: tag})
# MERGE (Posts)-[:TAGGED]->(t)
# MERGE (t)-[:TAGS]->(post);
# Out:
# 0 rows affected.
# []

# %%
# %%cypher
# MATCH p=(t:Tag)-[:TAGS]->(:Question) WHERE t.name =~ "^java$|^c\\+\\+$" RETURN count(p);
# Out:
# 1 rows affected.
# [[1192]]

# %% [markdown]
# La siguiente consulta muestra los usuarios que preguntan por cada Tag:

# %%
# %%cypher
# MATCH (t:Tag)-->(:Question)<--(u:User) RETURN t.name,collect(distinct u.Id) ORDER BY t.name;
# Out:
# 873 rows affected.
# [[u'.htaccess',
#   [u'3248',
#    u'10399',
#    u'11342',
#    u'2770',
#    u'166',
#    u'4530',
#    u'4571',
#    u'1746',
#    u'517',
#    u'3947',
#    u'5248',
#    u'5716',
#    u'8752',
#    u'6187',
#    u'9529',
#    u'7358',
#    u'9470',
#    u'5438',
#    u'9754',
#    u'6044',
#    u'10486',
#    u'10293',
#    u'5583',
#    u'4328',
#    u'12545']],
#  [u'.htpasswd', [u'5716']],
#  [u'.net',
#   [u'5602',
#    u'10428',
#    u'8873',
#    u'13209',
#    u'13432',
#    u'13577',
#    u'5729',
#    u'3249',
#    u'12640',
#    u'2224',
#    u'12891',
#    u'7254',
#    u'4361',
#    u'3008',
#    u'7216',
#    u'4499',
#    u'4779',
#    u'10686',
#    u'7242',
#    u'10952',
#    u'8990',
#    u'7692',
#    u'2633',
#    u'5866',
#    u'6298',
#    u'7132',
#    u'9883',
#    u'9476',
#    u'4612',
#    u'4048',
#    u'6764',
#    u'5271',
#    u'6808',
#    u'1962',
#    u'7273',
#    u'7491',
#    u'7545',
#    u'5715',
#    u'5671',
#    u'5668',
#    u'2247',
#    u'3727',
#    u'5723',
#    u'547',
#    u'921',
#    u'745',
#    u'298',
#    u'23',
#    u'2393',
#    u'2488',
#    u'463',
#    u'2004',
#    u'1482',
#    u'3088',
#    u'2947',
#    u'3142',
#    u'2946',
#    u'531',
#    u'2945',
#    u'1168',
#    u'4787',
#    u'3544',
#    u'3541']],
#  [u'2d', [u'13724', u'2257']],
#  [u'3d', [u'2998', u'342']],
#  [u'abap', [u'12530', u'1098']],
#  [u'accordion', [u'4021']],
#  [u'adfs', [u'717']],
#  [u'admob', [u'2985', u'2837', u'2163', u'1943', u'342']],
#  [u'adobe-muse', [u'10187']],
#  [u'adword', [u'10388', u'4688']],
#  [u'aem', [u'250']],
#  [u'agarrar-y-soltar', [u'531', u'3879']],
#  [u'agregaci\xf3n', [u'1575']],
#  [u'aix', [u'12476']],
#  [u'ajax',
#   [u'5997',
#    u'10903',
#    u'13547',
#    u'4775',
#    u'13731',
#    u'13637',
#    u'7064',
#    u'11342',
#    u'11376',
#    u'4726',
#    u'10930',
#    u'5566',
#    u'12621',
#    u'8994',
#    u'12586',
#    u'9130',
#    u'6635',
#    u'12906',
#    u'2838',
#    u'241',
#    u'13112',
#    u'13131',
#    u'12625',
#    u'11053',
#    u'10108',
#    u'10126',
#    u'5583',
#    u'3115',
#    u'6992',
#    u'9675',
#    u'6399',
#    u'5283',
#    u'10348',
#    u'1805',
#    u'10147',
#    u'3060',
#    u'9885',
#    u'9897',
#    u'10848',
#    u'10872',
#    u'6829',
#    u'7142',
#    u'4381',
#    u'7165',
#    u'7349',
#    u'8876',
#    u'9102',
#    u'5558',
#    u'7358',
#    u'3966',
#    u'9700',
#    u'4811',
#    u'9910',
#    u'9907',
#    u'6751',
#    u'9197',
#    u'3008',
#    u'2208',
#    u'7068',
#    u'4661',
#    u'7014',
#    u'7013',
#    u'6506',
#    u'6692',
#    u'2429',
#    u'5654',
#    u'7288',
#    u'7591',
#    u'5720',
#    u'4633',
#    u'4612',
#    u'7255',
#    u'4710',
#    u'2163',
#    u'5408',
#    u'4548',
#    u'5601',
#    u'4782',
#    u'5368',
#    u'2352',
#    u'5236',
#    u'3976',
#    u'4225',
#    u'6270',
#    u'6394',
#    u'6252',
#    u'3539',
#    u'6283',
#    u'4725',
#    u'2247',
#    u'5710',
#    u'4654',
#    u'5897',
#    u'3727',
#    u'4085',
#    u'371',
#    u'3877',
#    u'3013',
#    u'3712',
#    u'2675',
#    u'4736',
#    u'4881',
#    u'73',
#    u'23',
#    u'225',
#    u'2784',
#    u'1466',
#    u'1841',
#    u'2394',
#    u'2041',
#    u'629',
#    u'807',
#    u'250',
#    u'1168',
#    u'353',
#    u'3550',
#    u'4507']],
#  [u'alamofire', [u'9099']],
#  [u'alamofireimage', [u'9099']],
#  [u'alertdialog', [u'13670', u'10059', u'7541', u'5370', u'7242']],
#  [u'alfresco', [u'400']],
#  [u'algoritmos',
#   [u'10835',
#    u'4610',
#    u'2980',
#    u'2241',
#    u'9645',
#    u'6989',
#    u'7645',
#    u'8740',
#    u'5469',
#    u'5806',
#    u'3773',
#    u'166',
#    u'4440',
#    u'517']],
#  [u'almacenamiento', [u'250']],
#  [u'amcharts', [u'2955']],
#  [u'anaconda', [u'4723']],
#  [u'android',
#   [u'12708',
#    u'13222',
#    u'2230',
#    u'12994',
#    u'4528',
#    u'6955',
#    u'5339',
#    u'13047',
#    u'9484',
#    u'12774',
#    u'13278',
#    u'9610',
#    u'12912',
#    u'13339',
#    u'10019',
#    u'9174',
#    u'12446',
#    u'9939',
#    u'1958',
#    u'12681',
#    u'13440',
#    u'12531',
#    u'9785',
#    u'13466',
#    u'6363',
#    u'13506',
#    u'12510',
#    u'13552',
#    u'11110',
#    u'13574',
#    u'13569',
#    u'13571',
#    u'7490',
#    u'13547',
#    u'12817',
#    u'13648',
#    u'13670',
#    u'9099',
#    u'9277',
#    u'13709',
#    u'13425',
#    u'13798',
#    u'1914',
#    u'9800',
#    u'13750',
#    u'9840',
#    u'7541',
#    u'4878',
#    u'4815',
#    u'9179',
#    u'9348',
#    u'12458',
#    u'12441',
#    u'4418',
#    u'11203',
#    u'3460',
#    u'9991',
#    u'10422',
#    u'11292',
#    u'11295',
#    u'9539',
#    u'250',
#    u'11309',
#    u'6646',
#    u'11184',
#    u'7280',
#    u'2676',
#    u'6296',
#    u'9958',
#    u'12657',
#    u'10451',
#    u'12554',
#    u'4874',
#    u'12478',
#    u'2539',
#    u'2670',
#    u'12914',
#    u'2681',
#    u'12843',
#    u'11103',
#    u'6838',
#    u'12745',
#    u'10062',
#    u'5902',
#    u'12790',
#    u'13104',
#    u'9282',
#    u'13076',
#    u'13064',
#    u'10807',
#    u'12991',
#    u'13003',
#    u'13001',
#    u'12975',
#    u'12930',
#    u'10083',
#    u'535',
#    u'10119',
#    u'9737',
#    u'10100',
#    u'10136',
#    u'10148',
#    u'5297',
#    u'9972',
#    u'9762',
#    u'4227',
#    u'9396',
#    u'6774',
#    u'7116',
#    u'6044',
#    u'10405',
#    u'10402',
#    u'10399',
#    u'3415',
#    u'10186',
#    u'10225',
#    u'6564',
#    u'10292',
#    u'10290',
#    u'9130',
#    u'5370',
#    u'10724',
#    u'10636',
#    u'10811',
#    u'10782',
#    u'8907',
#    u'10545',
#    u'10685',
#    u'6644',
#    u'10600',
#    u'4836',
#    u'11013',
#    u'2074',
#    u'3878',
#    u'5851',
#    u'2896',
#    u'10932',
#    u'9257',
#    u'6613',
#    u'9238',
#    u'9240',
#    u'4680',
#    u'4708',
#    u'4568',
#    u'9194',
#    u'9184',
#    u'9152',
#    u'9143',
#    u'4532',
#    u'5219',
#    u'8821',
#    u'9304',
#    u'8899',
#    u'4142',
#    u'4684',
#    u'8915',
#    u'7520',
#    u'7621',
#    u'8895',
#    u'5710',
#    u'9003',
#    u'8962',
#    u'9770',
#    u'9749',
#    u'9789',
#    u'9773',
#    u'9780',
#    u'9695',
#    u'4866',
#    u'6360',
#    u'9384',
#    u'883',
#    u'7243',
#    u'9492',
#    u'9505',
#    u'7358',
#    u'7293',
#    u'9429',
#    u'6560',
#    u'9436',
#    u'9543',
#    u'9540',
#    u'9588',
#    u'6677',
#    u'6948',
#    u'6535',
#    u'6502',
#    u'6831',
#    u'3726',
#    u'7026',
#    u'6946',
#    u'7177',
#    u'7141',
#    u'7021',
#    u'6278',
#    u'5516',
#    u'5259',
#    u'3004',
#    u'6399',
#    u'2551',
#    u'6386',
#    u'5703',
#    u'7584',
#    u'206',
#    u'3533',
#    u'2163',
#    u'7643',
#    u'7682',
#    u'7686',
#    u'7731',
#    u'8755',
#    u'2803',
#    u'8793',
#    u'6438',
#    u'5327',
#    u'7303',
#    u'7340',
#    u'2645',
#    u'5272',
#    u'7559',
#    u'5653',
#    u'5616',
#    u'5351',
#    u'5244',
#    u'5344',
#    u'5311',
#    u'191',
#    u'5087',
#    u'5094',
#    u'4729',
#    u'4943',
#    u'4916',
#    u'4924',
#    u'3170',
#    u'6468',
#    u'6366',
#    u'6042',
#    u'5493',
#    u'6315',
#    u'6194',
#    u'731',
#    u'6073',
#    u'6071',
#    u'5909',
#    u'3563',
#    u'5837',
#    u'5356',
#    u'4453',
#    u'4020',
#    u'4116',
#    u'4164',
#    u'2718',
#    u'3440',
#    u'3665',
#    u'3802',
#    u'3871',
#    u'3653',
#    u'3771',
#    u'3751',
#    u'3202',
#    u'3557',
#    u'4766',
#    u'4715',
#    u'4805',
#    u'4810',
#    u'4814',
#    u'4823',
#    u'4859',
#    u'2957',
#    u'4656',
#    u'4671',
#    u'2862',
#    u'4757',
#    u'4392',
#    u'4439',
#    u'2653',
#    u'4537',
#    u'4563',
#    u'4244',
#    u'3656',
#    u'1940',
#    u'4382',
#    u'4365',
#    u'4362',
#    u'4357',
#    u'2953',
#    u'2981',
#    u'2955',
#    u'2975',
#    u'2998',
#    u'95',
#    u'3325',
#    u'3290',
#    u'1943',
#    u'1592',
#    u'2034',
#    u'2041',
#    u'1415',
#    u'27',
#    u'1870',
#    u'608',
#    u'846',
#    u'2379',
#    u'100',
#    u'2430',
#    u'305',
#    u'546',
#    u'21',
#    u'24',
#    u'2685']],
#  [u'android-asynctask',
#   [u'7541',
#    u'9991',
#    u'206',
#    u'5370',
#    u'8847',
#    u'4528',
#    u'2676',
#    u'9304',
#    u'7280']],
#  [u'android-auto', [u'546']],
#  [u'android-drawerlayout', [u'535', u'5370', u'206']],
#  [u'android-fragment', [u'9238']],
#  [u'android-glide', [u'5297', u'6315', u'95']],
#  [u'android-intent',
#   [u'6363',
#    u'12446',
#    u'4418',
#    u'4684',
#    u'9588',
#    u'6502',
#    u'6386',
#    u'7731',
#    u'4805',
#    u'206']],
#  [u'android-jellybean', [u'2230']],
#  [u'android-layout',
#   [u'2230',
#    u'12446',
#    u'9099',
#    u'12554',
#    u'9484',
#    u'4874',
#    u'9958',
#    u'10186',
#    u'9539',
#    u'8821',
#    u'7541',
#    u'9764',
#    u'9505',
#    u'5370',
#    u'6386',
#    u'4684',
#    u'305',
#    u'1870',
#    u'2953',
#    u'4757',
#    u'5703',
#    u'3004',
#    u'2957',
#    u'4418',
#    u'3533',
#    u'7490',
#    u'535',
#    u'4142']],
#  [u'android-sdk',
#   [u'12994', u'12681', u'10062', u'12975', u'9130', u'7490', u'8853']],
#  [u'android-softkeyboard', [u'6044', u'5370', u'305']],
#  [u'android-sqlite',
#   [u'9174',
#    u'9179',
#    u'11232',
#    u'5370',
#    u'4568',
#    u'5710',
#    u'4684',
#    u'9764',
#    u'4874',
#    u'5344',
#    u'5921',
#    u'3871',
#    u'2718',
#    u'3656',
#    u'206']],
#  [u'android-studio',
#   [u'5602',
#    u'13222',
#    u'13047',
#    u'12774',
#    u'9174',
#    u'12681',
#    u'12531',
#    u'12510',
#    u'13574',
#    u'13425',
#    u'7541',
#    u'4878',
#    u'9348',
#    u'12458',
#    u'4418',
#    u'6646',
#    u'12554',
#    u'12517',
#    u'4487',
#    u'11223',
#    u'11110',
#    u'11103',
#    u'8899',
#    u'13194',
#    u'5370',
#    u'10100',
#    u'5297',
#    u'5493',
#    u'9484',
#    u'6946',
#    u'9958',
#    u'9539',
#    u'6564',
#    u'9130',
#    u'2230',
#    u'4528',
#    u'10731',
#    u'10399',
#    u'10760',
#    u'10605',
#    u'4836',
#    u'2074',
#    u'5851',
#    u'8853',
#    u'5710',
#    u'2681',
#    u'9695',
#    u'7280',
#    u'6360',
#    u'8847',
#    u'9384',
#    u'535',
#    u'7021',
#    u'4568',
#    u'6677',
#    u'4680',
#    u'2803',
#    u'191',
#    u'4874',
#    u'5087',
#    u'24',
#    u'2172',
#    u'3325',
#    u'3004',
#    u'1940',
#    u'4577',
#    u'3665',
#    u'3871',
#    u'3935',
#    u'2896',
#    u'4729']],
#  [u'android-viewpager', [u'5837', u'4532']],
#  [u'android-widget', [u'4708', u'4528']],
#  [u'angular-directivas',
#   [u'12654',
#    u'9010',
#    u'11278',
#    u'10284',
#    u'9308',
#    u'3628',
#    u'3013',
#    u'4718',
#    u'154']],
#  [u'angular-translate', [u'2747']],
#  [u'angular2-template', [u'13085', u'10109', u'24']],
#  [u'angularjs',
#   [u'10452',
#    u'13245',
#    u'13203',
#    u'13042',
#    u'638',
#    u'12654',
#    u'13039',
#    u'1204',
#    u'10950',
#    u'9720',
#    u'10329',
#    u'9883',
#    u'13587',
#    u'10832',
#    u'13658',
#    u'13722',
#    u'5005',
#    u'4718',
#    u'13744',
#    u'9010',
#    u'3628',
#    u'7615',
#    u'11278',
#    u'11214',
#    u'10080',
#    u'8930',
#    u'3291',
#    u'12474',
#    u'12496',
#    u'12498',
#    u'5365',
#    u'3203',
#    u'12876',
#    u'1505',
#    u'13184',
#    u'4325',
#    u'11313',
#    u'9594',
#    u'294',
#    u'2896',
#    u'10059',
#    u'10381',
#    u'10468',
#    u'10284',
#    u'3073',
#    u'8756',
#    u'9517',
#    u'10628',
#    u'10374',
#    u'10850',
#    u'10857',
#    u'9191',
#    u'9379',
#    u'9308',
#    u'8943',
#    u'4610',
#    u'8868',
#    u'9052',
#    u'8859',
#    u'8966',
#    u'9390',
#    u'9919',
#    u'9808',
#    u'9849',
#    u'9286',
#    u'9465',
#    u'9523',
#    u'9521',
#    u'7166',
#    u'5147',
#    u'6547',
#    u'3013',
#    u'7709',
#    u'7538',
#    u'8834',
#    u'5461',
#    u'5441',
#    u'5056',
#    u'6461',
#    u'6147',
#    u'6172',
#    u'6021',
#    u'5732',
#    u'2659',
#    u'191',
#    u'154',
#    u'1039',
#    u'3906',
#    u'3907',
#    u'1330',
#    u'3648',
#    u'2747',
#    u'4688',
#    u'2549',
#    u'4677',
#    u'4420',
#    u'636',
#    u'4479',
#    u'430',
#    u'3014',
#    u'23',
#    u'2652',
#    u'2722',
#    u'2566',
#    u'1839',
#    u'2509',
#    u'2256',
#    u'1964',
#    u'2136',
#    u'1407',
#    u'1996',
#    u'1610',
#    u'3327',
#    u'2424',
#    u'1654',
#    u'3158']],
#  [u'angularjs-2.0',
#   [u'6095',
#    u'13184',
#    u'13085',
#    u'4678',
#    u'10109',
#    u'10921',
#    u'4610',
#    u'6942',
#    u'353',
#    u'8768',
#    u'154',
#    u'24']],
#  [u'angularjs-injector', [u'4610', u'3013', u'154']],
#  [u'animaci\xf3n', [u'9897', u'10187', u'7662', u'6173', u'3901', u'2224']],
#  [u'anotaciones', [u'517']],
#  [u'ant', [u'6794']],
#  [u'apache',
#   [u'9179',
#    u'9885',
#    u'5997',
#    u'2429',
#    u'13005',
#    u'5005',
#    u'6764',
#    u'360',
#    u'9130',
#    u'10354',
#    u'10365',
#    u'10863',
#    u'9236',
#    u'9235',
#    u'7615',
#    u'8898',
#    u'9012',
#    u'9470',
#    u'3933',
#    u'7576',
#    u'5248',
#    u'8752',
#    u'7530',
#    u'4541',
#    u'7404',
#    u'2770',
#    u'2649',
#    u'3423',
#    u'166',
#    u'3004',
#    u'371',
#    u'822',
#    u'4530',
#    u'4274',
#    u'4654',
#    u'4634',
#    u'3249',
#    u'3715',
#    u'1666',
#    u'3811',
#    u'5743',
#    u'5957',
#    u'5972',
#    u'6178',
#    u'517',
#    u'5716']],
#  [u'apache-commons-validator', [u'2769']],
#  [u'apache-poi', [u'5126', u'4105', u'227', u'1809']],
#  [u'apache-shiro', [u'4008']],
#  [u'apache-spark', [u'9345']],
#  [u'api',
#   [u'13425',
#    u'11289',
#    u'5465',
#    u'872',
#    u'12657',
#    u'13077',
#    u'13104',
#    u'10169',
#    u'10004',
#    u'10402',
#    u'10464',
#    u'10550',
#    u'9539',
#    u'10832',
#    u'5921',
#    u'8855',
#    u'901',
#    u'29',
#    u'2808',
#    u'2186',
#    u'1947',
#    u'2802',
#    u'1092',
#    u'4878',
#    u'4874',
#    u'2896',
#    u'3459',
#    u'870',
#    u'3094',
#    u'4150',
#    u'2981',
#    u'5824',
#    u'6461',
#    u'5311',
#    u'8831',
#    u'7183',
#    u'9855',
#    u'9675',
#    u'9786']],
#  [u'aplicacion-web', [u'12708', u'13575', u'6044']],
#  [u'aplicaci\xf3n-web',
#   [u'6646',
#    u'13203',
#    u'5199',
#    u'10930',
#    u'10921',
#    u'13557',
#    u'7541',
#    u'5272',
#    u'6353',
#    u'7529',
#    u'7490',
#    u'12914',
#    u'4610',
#    u'6044',
#    u'4328',
#    u'3073',
#    u'1092',
#    u'4357',
#    u'1349',
#    u'4612',
#    u'2420',
#    u'6352',
#    u'6173',
#    u'4545',
#    u'5616',
#    u'1721',
#    u'6497',
#    u'5274',
#    u'9529',
#    u'7210',
#    u'9724',
#    u'9164',
#    u'9236',
#    u'4361',
#    u'10513',
#    u'1166']],
#  [u'app',
#   [u'10950',
#    u'13547',
#    u'13648',
#    u'12708',
#    u'9840',
#    u'11346',
#    u'12745',
#    u'5339',
#    u'9099']],
#  [u'appcelerator', [u'13648']],
#  [u'appdelegate', [u'9099']],
#  [u'appinventor', [u'13547', u'11223']],
#  [u'arcgis', [u'7296']],
#  [u'archivo',
#   [u'13450',
#    u'4229',
#    u'6568',
#    u'7378',
#    u'1092',
#    u'4790',
#    u'3343',
#    u'1184',
#    u'2152',
#    u'83',
#    u'632',
#    u'100']],
#  [u'arduino',
#   [u'5272',
#    u'10485',
#    u'10671',
#    u'7621',
#    u'7554',
#    u'4528',
#    u'5094',
#    u'3259',
#    u'3325',
#    u'2673']],
#  [u'arm', [u'250', u'12845']],
#  [u'arquitectura', [u'1805', u'4048']],
#  [u'array',
#   [u'13326',
#    u'13450',
#    u'9168',
#    u'21',
#    u'6170',
#    u'2429',
#    u'9897',
#    u'11309',
#    u'9134',
#    u'12700',
#    u'5972',
#    u'7621',
#    u'10577',
#    u'6534',
#    u'5988',
#    u'13146',
#    u'11004',
#    u'5179',
#    u'12870',
#    u'6137',
#    u'5370',
#    u'9396',
#    u'10725',
#    u'9834',
#    u'10586',
#    u'2980',
#    u'4610',
#    u'2676',
#    u'9145',
#    u'9333',
#    u'6962',
#    u'8958',
#    u'9690',
#    u'6897',
#    u'8847',
#    u'8899',
#    u'9205',
#    u'9099',
#    u'9449',
#    u'9452',
#    u'4991',
#    u'9547',
#    u'2352',
#    u'3869',
#    u'6833',
#    u'8740',
#    u'4633',
#    u'7338',
#    u'7399',
#    u'7393',
#    u'7564',
#    u'5272',
#    u'4632',
#    u'5478',
#    u'149',
#    u'4023',
#    u'6172',
#    u'6044',
#    u'1958',
#    u'6212',
#    u'3621',
#    u'1505',
#    u'132',
#    u'127',
#    u'25',
#    u'100',
#    u'74',
#    u'729',
#    u'22',
#    u'301',
#    u'517',
#    u'3347',
#    u'2762',
#    u'2670',
#    u'2950',
#    u'4673',
#    u'4663',
#    u'4629',
#    u'1092',
#    u'3343',
#    u'3645',
#    u'65',
#    u'3890',
#    u'2399']],
#  [u'arrayadapter', [u'5370']],
#  [u'as400', [u'2744', u'120']],
#  [u'ascii', [u'2633', u'83']],
#  [u'asincronismo', [u'6625', u'3727', u'100']],
#  [u'asincr\xf3nico', [u'9099', u'2472', u'400']],
#  [u'asm-pic', [u'9005', u'9634']],
#  [u'asp',
#   [u'11309',
#    u'2854',
#    u'6646',
#    u'3727',
#    u'8980',
#    u'9724',
#    u'4548',
#    u'7242',
#    u'6524',
#    u'4381',
#    u'6471',
#    u'3038',
#    u'3688',
#    u'2675',
#    u'4048',
#    u'2904',
#    u'2917']],
#  [u'asp.net',
#   [u'6730',
#    u'13335',
#    u'13350',
#    u'10605',
#    u'4695',
#    u'13108',
#    u'13601',
#    u'13577',
#    u'2854',
#    u'13701',
#    u'13767',
#    u'6646',
#    u'11394',
#    u'10688',
#    u'11323',
#    u'11259',
#    u'10952',
#    u'4361',
#    u'12604',
#    u'12865',
#    u'3008',
#    u'12891',
#    u'13131',
#    u'2366',
#    u'12781',
#    u'3115',
#    u'9471',
#    u'5723',
#    u'10350',
#    u'3060',
#    u'2826',
#    u'10360',
#    u'10475',
#    u'9788',
#    u'10769',
#    u'10301',
#    u'4098',
#    u'10686',
#    u'10640',
#    u'11168',
#    u'10945',
#    u'9928',
#    u'4487',
#    u'8980',
#    u'5852',
#    u'3834',
#    u'9434',
#    u'6983',
#    u'6088',
#    u'6845',
#    u'4584',
#    u'7650',
#    u'7719',
#    u'4381',
#    u'6765',
#    u'7332',
#    u'5389',
#    u'7132',
#    u'5845',
#    u'2766',
#    u'2247',
#    u'4786',
#    u'5180',
#    u'4538',
#    u'3726',
#    u'4811',
#    u'1092',
#    u'6269',
#    u'3617',
#    u'5908',
#    u'2747',
#    u'4030',
#    u'4048',
#    u'2478',
#    u'3727',
#    u'78',
#    u'3927',
#    u'2675',
#    u'3585',
#    u'4494',
#    u'3746',
#    u'4348',
#    u'1338',
#    u'2917',
#    u'533',
#    u'2969',
#    u'35',
#    u'23',
#    u'2533',
#    u'1399',
#    u'1482',
#    u'2429',
#    u'3452',
#    u'1175',
#    u'1839']],
#  [u'asp.net-core', [u'6635', u'1171', u'2744', u'822', u'298', u'211']],
#  [u'asp.net-mvc',
#   [u'10903',
#    u'2366',
#    u'13454',
#    u'10605',
#    u'10688',
#    u'13042',
#    u'13603',
#    u'2472',
#    u'10952',
#    u'12431',
#    u'12472',
#    u'10626',
#    u'5324',
#    u'10880',
#    u'9788',
#    u'3008',
#    u'3746',
#    u'3060',
#    u'9910',
#    u'2826',
#    u'10301',
#    u'1805',
#    u'10686',
#    u'6644',
#    u'9331',
#    u'6881',
#    u'4811',
#    u'8980',
#    u'9521',
#    u'9907',
#    u'6635',
#    u'8983',
#    u'2429',
#    u'7195',
#    u'7202',
#    u'6088',
#    u'6501',
#    u'5563',
#    u'7536',
#    u'3038',
#    u'5180',
#    u'225',
#    u'5118',
#    u'2247',
#    u'2659',
#    u'3294',
#    u'4048',
#    u'4042',
#    u'2478',
#    u'1795',
#    u'3700',
#    u'534',
#    u'1494',
#    u'629',
#    u'1466',
#    u'2990',
#    u'2969',
#    u'376']],
#  [u'asp.net-mvc-5',
#   [u'10903',
#    u'7165',
#    u'2366',
#    u'6635',
#    u'1012',
#    u'3746',
#    u'10359',
#    u'7251',
#    u'2826',
#    u'10621',
#    u'11015',
#    u'6881',
#    u'7615',
#    u'9902',
#    u'3480',
#    u'6902',
#    u'6088',
#    u'7449',
#    u'4811',
#    u'5408',
#    u'225',
#    u'5118',
#    u'2247',
#    u'3726',
#    u'3294',
#    u'3617',
#    u'4048',
#    u'3700',
#    u'1494',
#    u'1168',
#    u'1203',
#    u'629',
#    u'2036',
#    u'3250',
#    u'2990',
#    u'2960']],
#  [u'asp.net-web-api',
#   [u'11308',
#    u'10626',
#    u'1188',
#    u'23',
#    u'225',
#    u'2659',
#    u'2256',
#    u'1175',
#    u'2610',
#    u'2990',
#    u'3480',
#    u'1092',
#    u'547',
#    u'5908',
#    u'5668',
#    u'9883',
#    u'9788']],
#  [u'aspnet', [u'11187', u'10348']],
#  [u'asterisk', [u'3284']],
#  [u'atmel', [u'4528']],
#  [u'atmosphere', [u'608']],
#  [u'atom-editor', [u'4430']],
#  [u'aurelia.io', [u'629']],
#  [u'autenticaci\xf3n', [u'11095', u'3480', u'5984', u'2659', u'4423']],
#  [u'autocompletar', [u'9029', u'9806', u'3583']],
#  [u'autofac', [u'6088']],
#  [u'automapper', [u'4048', u'1188']],
#  [u'avd', [u'250', u'9436', u'1592']],
#  [u'awk', [u'83']],
#  [u'aws', [u'12483', u'12772', u'4989']],
#  [u'aws-s3', [u'4989']],
#  [u'azul-zulu', [u'342']],
#  [u'azure',
#   [u'1609',
#    u'11308',
#    u'11203',
#    u'9656',
#    u'10058',
#    u'6644',
#    u'9182',
#    u'7122',
#    u'7602',
#    u'5668',
#    u'4181',
#    u'3821',
#    u'2960',
#    u'1338',
#    u'1482',
#    u'398',
#    u'1494',
#    u'348']],
#  [u'azure-redis', [u'4181', u'1494']],
#  [u'azure-sql', [u'1609']],
#  [u'azure-storage', [u'9182', u'1482']],
#  [u'babeljs', [u'2509', u'3829', u'353']],
#  [u'back-button', [u'6044']],
#  [u'backbone', [u'9313', u'1204', u'1037']],
#  [u'base-de-datos',
#   [u'13234',
#    u'6363',
#    u'13266',
#    u'13304',
#    u'9174',
#    u'5004',
#    u'10930',
#    u'12575',
#    u'11261',
#    u'250',
#    u'11110',
#    u'12805',
#    u'11124',
#    u'7621',
#    u'10577',
#    u'12995',
#    u'12933',
#    u'12781',
#    u'7520',
#    u'9261',
#    u'517',
#    u'9524',
#    u'10288',
#    u'8728',
#    u'10163',
#    u'10561',
#    u'10531',
#    u'10491',
#    u'10952',
#    u'4610',
#    u'1631',
#    u'9249',
#    u'4361',
#    u'9048',
#    u'6360',
#    u'9724',
#    u'8923',
#    u'6768',
#    u'9604',
#    u'9660',
#    u'6849',
#    u'5438',
#    u'535',
#    u'6137',
#    u'4661',
#    u'4684',
#    u'7461',
#    u'100',
#    u'417',
#    u'2990',
#    u'1005',
#    u'3065',
#    u'3281',
#    u'4603',
#    u'1399',
#    u'4813',
#    u'4781',
#    u'5881',
#    u'4984',
#    u'5024',
#    u'5090',
#    u'2163',
#    u'2134',
#    u'5194',
#    u'5487',
#    u'2230',
#    u'1776']],
#  [u'base64', [u'13039', u'5438', u'1555']],
#  [u'bash',
#   [u'9023',
#    u'6564',
#    u'13080',
#    u'9958',
#    u'1204',
#    u'4610',
#    u'9391',
#    u'9612',
#    u'7043',
#    u'83',
#    u'100',
#    u'729',
#    u'2222',
#    u'1965',
#    u'2512',
#    u'1575',
#    u'2152',
#    u'399',
#    u'1481',
#    u'4298',
#    u'187',
#    u'5977',
#    u'6467',
#    u'4989',
#    u'6612',
#    u'6778',
#    u'6723']],
#  [u'bigdecimal', [u'3488', u'517']],
#  [u'binding', [u'9461', u'6088', u'6501', u'1401', u'4598', u'3014', u'2596']],
#  [u'bitbucket', [u'11381', u'4874']],
#  [u'bitmap', [u'12657', u'12975', u'2879', u'846']],
#  [u'blob', [u'6534', u'10587']],
#  [u'bluetooth', [u'12618', u'7638', u'3771', u'4674']],
#  [u'bookmarklet', [u'65']],
#  [u'booleano', [u'10136', u'22', u'288']],
#  [u'bootstrap',
#   [u'6730',
#    u'9885',
#    u'3115',
#    u'2854',
#    u'13108',
#    u'13610',
#    u'1575',
#    u'2338',
#    u'10930',
#    u'11406',
#    u'6897',
#    u'11340',
#    u'6943',
#    u'12625',
#    u'12616',
#    u'7384',
#    u'12870',
#    u'12795',
#    u'10880',
#    u'6974',
#    u'11342',
#    u'9205',
#    u'3234',
#    u'9159',
#    u'3512',
#    u'342',
#    u'3767',
#    u'10253',
#    u'10832',
#    u'10648',
#    u'10765',
#    u'3727',
#    u'9379',
#    u'8906',
#    u'7591',
#    u'8930',
#    u'4811',
#    u'9022',
#    u'9760',
#    u'9517',
#    u'9776',
#    u'7192',
#    u'3004',
#    u'1360',
#    u'250',
#    u'4156',
#    u'6399',
#    u'154',
#    u'4770',
#    u'6635',
#    u'6497',
#    u'4612',
#    u'3763',
#    u'2366',
#    u'4786',
#    u'5262',
#    u'4939',
#    u'4948',
#    u'4381',
#    u'6252',
#    u'6037',
#    u'2675',
#    u'3746',
#    u'3583',
#    u'4071',
#    u'3089',
#    u'822',
#    u'3451',
#    u'2601',
#    u'1389',
#    u'225',
#    u'1827',
#    u'1274',
#    u'3228',
#    u'3248',
#    u'3257',
#    u'3278',
#    u'3190',
#    u'2917',
#    u'371',
#    u'4215',
#    u'4507',
#    u'4661']],
#  [u'bootstrap-carousel',
#   [u'10832', u'3234', u'10468', u'9022', u'6497', u'4770', u'3278']],
#  [u'bottle', [u'292']],
#  [u'boundary', [u'9099']],
#  [u'bower', [u'6172', u'35']],
#  [u'boxing', [u'417']],
#  [u'brew', [u'870']],
#  [u'bundler', [u'75']],
#  [u'buscador', [u'7424']],
#  [u'c',
#   [u'13165',
#    u'13326',
#    u'4456',
#    u'13347',
#    u'13450',
#    u'13485',
#    u'13756',
#    u'11213',
#    u'2171',
#    u'13083',
#    u'4961',
#    u'12932',
#    u'9669',
#    u'3199',
#    u'3234',
#    u'4528',
#    u'11045',
#    u'11123',
#    u'10806',
#    u'10963',
#    u'7554',
#    u'2909',
#    u'5772',
#    u'9645',
#    u'9397',
#    u'3665',
#    u'5977',
#    u'4595',
#    u'6278',
#    u'6589',
#    u'6754',
#    u'2633',
#    u'7605',
#    u'7278',
#    u'7353',
#    u'7378',
#    u'7399',
#    u'6568',
#    u'5641',
#    u'5350',
#    u'5532',
#    u'5233',
#    u'5358',
#    u'5242',
#    u'5296',
#    u'5218',
#    u'5215',
#    u'5095',
#    u'149',
#    u'4899',
#    u'6265',
#    u'6314',
#    u'6303',
#    u'5989',
#    u'3909',
#    u'187',
#    u'24',
#    u'2673',
#    u'2013',
#    u'3443',
#    u'301',
#    u'2941',
#    u'4544',
#    u'4432',
#    u'2236',
#    u'4708',
#    u'4673',
#    u'4629',
#    u'3765']],
#  [u'c#',
#   [u'4048',
#    u'5602',
#    u'5847',
#    u'10428',
#    u'4923',
#    u'13282',
#    u'13042',
#    u'13304',
#    u'3759',
#    u'4677',
#    u'5938',
#    u'1805',
#    u'13410',
#    u'2366',
#    u'13432',
#    u'13454',
#    u'5729',
#    u'12431',
#    u'13483',
#    u'10605',
#    u'4695',
#    u'2854',
#    u'10744',
#    u'13560',
#    u'2800',
#    u'13577',
#    u'10835',
#    u'13571',
#    u'13652',
#    u'13693',
#    u'13767',
#    u'7165',
#    u'13490',
#    u'6646',
#    u'13811',
#    u'11353',
#    u'12415',
#    u'6560',
#    u'12467',
#    u'11203',
#    u'3316',
#    u'4361',
#    u'11394',
#    u'11389',
#    u'2472',
#    u'10775',
#    u'11187',
#    u'11259',
#    u'12709',
#    u'12710',
#    u'12578',
#    u'2224',
#    u'9788',
#    u'10903',
#    u'12899',
#    u'12901',
#    u'12891',
#    u'12865',
#    u'10626',
#    u'7541',
#    u'12825',
#    u'12750',
#    u'10880',
#    u'12737',
#    u'6534',
#    u'10076',
#    u'78',
#    u'12958',
#    u'1092',
#    u'12781',
#    u'4499',
#    u'10099',
#    u'6046',
#    u'10174',
#    u'10180',
#    u'9992',
#    u'4584',
#    u'10036',
#    u'3060',
#    u'2826',
#    u'7542',
#    u'4456',
#    u'10451',
#    u'10360',
#    u'10475',
#    u'9910',
#    u'10491',
#    u'10495',
#    u'7251',
#    u'10206',
#    u'8983',
#    u'4811',
#    u'10301',
#    u'7242',
#    u'6495',
#    u'4779',
#    u'10689',
#    u'10533',
#    u'9947',
#    u'10763',
#    u'11140',
#    u'10945',
#    u'10952',
#    u'10173',
#    u'3727',
#    u'2019',
#    u'10621',
#    u'9427',
#    u'8990',
#    u'8999',
#    u'9331',
#    u'5421',
#    u'7692',
#    u'6881',
#    u'5866',
#    u'8842',
#    u'8907',
#    u'3834',
#    u'7615',
#    u'3682',
#    u'2123',
#    u'3615',
#    u'9883',
#    u'9878',
#    u'9928',
#    u'5487',
#    u'9521',
#    u'1171',
#    u'9476',
#    u'4612',
#    u'9434',
#    u'2862',
#    u'9452',
#    u'9592',
#    u'9542',
#    u'1005',
#    u'6927',
#    u'6922',
#    u'6914',
#    u'3545',
#    u'7035',
#    u'7019',
#    u'7133',
#    u'3621',
#    u'7202',
#    u'6989',
#    u'5845',
#    u'6501',
#    u'6589',
#    u'5259',
#    u'6505',
#    u'6519',
#    u'6617',
#    u'5563',
#    u'4191',
#    u'6765',
#    u'2706',
#    u'6845',
#    u'6808',
#    u'7593',
#    u'7587',
#    u'7548',
#    u'4083',
#    u'2596',
#    u'7714',
#    u'7449',
#    u'8788',
#    u'4381',
#    u'6269',
#    u'7273',
#    u'7332',
#    u'5389',
#    u'7406',
#    u'6305',
#    u'7430',
#    u'7457',
#    u'7491',
#    u'7393',
#    u'7545',
#    u'7565',
#    u'5715',
#    u'1839',
#    u'5671',
#    u'2247',
#    u'5523',
#    u'5562',
#    u'5301',
#    u'5174',
#    u'5034',
#    u'225',
#    u'5105',
#    u'5118',
#    u'4951',
#    u'5027',
#    u'4985',
#    u'2659',
#    u'4914',
#    u'2636',
#    u'4598',
#    u'6471',
#    u'6324',
#    u'3294',
#    u'6266',
#    u'120',
#    u'3088',
#    u'6122',
#    u'6155',
#    u'3617',
#    u'6167',
#    u'547',
#    u'6047',
#    u'5908',
#    u'5881',
#    u'5899',
#    u'5655',
#    u'5180',
#    u'5789',
#    u'4042',
#    u'3480',
#    u'3967',
#    u'2478',
#    u'4098',
#    u'1795',
#    u'531',
#    u'3927',
#    u'3688',
#    u'534',
#    u'1039',
#    u'3343',
#    u'3724',
#    u'3541',
#    u'2974',
#    u'2879',
#    u'3486',
#    u'1494',
#    u'3585',
#    u'1466',
#    u'1962',
#    u'3562',
#    u'3544',
#    u'4810',
#    u'3945',
#    u'4208',
#    u'4447',
#    u'4494',
#    u'195',
#    u'376',
#    u'4348',
#    u'4369',
#    u'1168',
#    u'2408',
#    u'2883',
#    u'2935',
#    u'822',
#    u'1338',
#    u'533',
#    u'2945',
#    u'2767',
#    u'2969',
#    u'2946',
#    u'2990',
#    u'3142',
#    u'1175',
#    u'2184',
#    u'3229',
#    u'3342',
#    u'3344',
#    u'2230',
#    u'25',
#    u'1840',
#    u'1941',
#    u'1482',
#    u'629',
#    u'2036',
#    u'1577',
#    u'2004',
#    u'2238',
#    u'2027',
#    u'2257',
#    u'342',
#    u'2325',
#    u'463',
#    u'2488',
#    u'23',
#    u'92',
#    u'1188',
#    u'149',
#    u'298',
#    u'2797',
#    u'676',
#    u'2766']],
#  [u'c++',
#   [u'13063',
#    u'4456',
#    u'13490',
#    u'13485',
#    u'13566',
#    u'6489',
#    u'13724',
#    u'13792',
#    u'407',
#    u'3621',
#    u'11300',
#    u'7389',
#    u'11101',
#    u'5911',
#    u'12809',
#    u'2742',
#    u'4229',
#    u'12932',
#    u'9454',
#    u'10033',
#    u'10396',
#    u'6323',
#    u'10333',
#    u'10774',
#    u'9713',
#    u'10725',
#    u'9814',
#    u'10806',
#    u'5272',
#    u'4610',
#    u'6984',
#    u'5772',
#    u'8979',
#    u'9770',
#    u'9745',
#    u'3665',
#    u'9804',
#    u'7654',
#    u'9482',
#    u'5200',
#    u'9426',
#    u'6887',
#    u'4676',
#    u'7061',
#    u'7037',
#    u'5928',
#    u'6278',
#    u'6836',
#    u'7610',
#    u'2236',
#    u'4499',
#    u'7564',
#    u'2133',
#    u'5472',
#    u'5480',
#    u'3834',
#    u'5431',
#    u'5449',
#    u'5242',
#    u'5295',
#    u'5274',
#    u'149',
#    u'5907',
#    u'5582',
#    u'5758',
#    u'5760',
#    u'3718',
#    u'3697',
#    u'3642',
#    u'3773',
#    u'3782',
#    u'3759',
#    u'3592',
#    u'4791',
#    u'4673',
#    u'4870',
#    u'4613',
#    u'4663',
#    u'4669',
#    u'4697',
#    u'4544',
#    u'3974',
#    u'4187',
#    u'4198',
#    u'4383',
#    u'301',
#    u'3081',
#    u'1997',
#    u'24',
#    u'463',
#    u'25']],
#  [u'c++-faq', [u'2742']],
#  [u'c++11',
#   [u'13485',
#    u'12809',
#    u'2742',
#    u'5431',
#    u'5272',
#    u'2236',
#    u'24',
#    u'463',
#    u'25']],
#  [u'c++1z', [u'2742']],
#  [u'c++98', [u'5218', u'301']],
#  [u'c3.js', [u'11274', u'9999']],
#  [u'cabeceras-http', [u'9099', u'227']],
#  [u'cache', [u'11395', u'10293', u'10886', u'3933', u'6497', u'1076']],
#  [u'cakephp', [u'12591']],
#  [u'calculo-relacional', [u'2633']],
#  [u'callback', [u'12924', u'2676']],
#  [u'canvas', [u'12657', u'8821']],
#  [u'cast', [u'10422']],
#  [u'casting', [u'21', u'9099', u'10491', u'1092', u'24']],
#  [u'ccs', [u'4528', u'11026', u'11123']],
#  [u'celery', [u'2402', u'100']],
#  [u'centos', [u'11117', u'7404']],
#  [u'chartkick', [u'3287']],
#  [u'ciencia-de-la-computaci\xf3n', [u'11261']],
#  [u'cil', [u'3249']],
#  [u'clase',
#   [u'10688',
#    u'7389',
#    u'12991',
#    u'4328',
#    u'7061',
#    u'5272',
#    u'3642',
#    u'301',
#    u'100']],
#  [u'clase-abstracta', [u'5431', u'187']],
#  [u'clickonce', [u'6020', u'2393']],
#  [u'clojure', [u'252']],
#  [u'cloud9', [u'12424']],
#  [u'cmd', [u'6564', u'9039', u'10708', u'5763', u'5654']],
#  [u'cms', [u'12680', u'1914']],
#  [u'cocoapods', [u'9099']],
#  [u'codeigniter',
#   [u'11263',
#    u'3248',
#    u'11153',
#    u'13725',
#    u'11294',
#    u'12655',
#    u'12608',
#    u'12567',
#    u'7621',
#    u'12811',
#    u'6974',
#    u'11261',
#    u'11093',
#    u'5569',
#    u'6461',
#    u'5921',
#    u'2304',
#    u'3181',
#    u'3583',
#    u'2429',
#    u'1389',
#    u'3577',
#    u'3852',
#    u'5768',
#    u'4451',
#    u'6103',
#    u'6097',
#    u'2163',
#    u'5024',
#    u'7261',
#    u'7227',
#    u'2208',
#    u'4325',
#    u'9168']],
#  [u'codeigniter-3',
#   [u'7615',
#    u'2429',
#    u'2304',
#    u'11261',
#    u'10486',
#    u'6316',
#    u'5921',
#    u'9919',
#    u'7227',
#    u'4451',
#    u'2163',
#    u'4548',
#    u'5024',
#    u'3577']],
#  [u'codificaci\xf3n', [u'8977', u'6550', u'2909', u'5478', u'127']],
#  [u'coffeescript', [u'342']],
#  [u'com-object', [u'7242']],
#  [u'coma-flotante', [u'3488', u'416']],
#  [u'combobox', [u'6031', u'517', u'9883', u'3343']],
#  [u'commit', [u'6832', u'260']],
#  [u'comparaciones', [u'4787', u'4736', u'517']],
#  [u'conda', [u'4723', u'630', u'353']],
#  [u'condiciones', [u'73', u'11025', u'9514', u'517', u'1092', u'4360']],
#  [u'configuraci\xf3n', [u'3231', u'4661', u'1092', u'2659', u'100']],
#  [u'conflictos', [u'1505', u'75']],
#  [u'consola',
#   [u'2980', u'11242', u'1654', u'6564', u'9039', u'9182', u'78', u'1184']],
#  [u'constantes', [u'517', u'430']],
#  [u'constraints', [u'9099']],
#  [u'constructor', [u'6095', u'4632', u'301', u'187']],
#  [u'control-de-versiones', [u'13464', u'2004', u'75', u'100']],
#  [u'conversi\xf3n-de-tipos',
#   [u'2633', u'7242', u'10491', u'5370', u'3705', u'2027', u'22']],
#  [u'cordova',
#   [u'250',
#    u'2652',
#    u'6353',
#    u'10062',
#    u'3628',
#    u'10685',
#    u'7638',
#    u'2896',
#    u'5921',
#    u'5920',
#    u'4021',
#    u'1666',
#    u'4357',
#    u'2981',
#    u'2041',
#    u'100',
#    u'239']],
#  [u'corona', [u'9435', u'1415']],
#  [u'coroutine', [u'187']],
#  [u'couchdb', [u'2186']],
#  [u'cq5', [u'250']],
#  [u'criptograf\xeda', [u'3203']],
#  [u'crontab', [u'8930', u'7043', u'6612']],
#  [u'crystal-reports',
#   [u'2854', u'8873', u'9788', u'6534', u'3762', u'3675', u'3470']],
#  [u'css',
#   [u'13240',
#    u'9897',
#    u'11313',
#    u'9253',
#    u'1188',
#    u'3115',
#    u'2224',
#    u'10329',
#    u'1575',
#    u'13580',
#    u'9885',
#    u'10574',
#    u'73',
#    u'5674',
#    u'12878',
#    u'11406',
#    u'11342',
#    u'517',
#    u'10636',
#    u'250',
#    u'11238',
#    u'10379',
#    u'12611',
#    u'12625',
#    u'4231',
#    u'11261',
#    u'5005',
#    u'12902',
#    u'5997',
#    u'10787',
#    u'6646',
#    u'13200',
#    u'6353',
#    u'13049',
#    u'6943',
#    u'10092',
#    u'4610',
#    u'9955',
#    u'2241',
#    u'6270',
#    u'342',
#    u'10471',
#    u'3094',
#    u'10253',
#    u'4748',
#    u'10676',
#    u'9099',
#    u'4718',
#    u'9159',
#    u'10765',
#    u'10986',
#    u'3628',
#    u'9254',
#    u'7347',
#    u'9129',
#    u'9313',
#    u'7591',
#    u'6534',
#    u'8895',
#    u'8855',
#    u'8868',
#    u'9760',
#    u'6173',
#    u'6881',
#    u'9390',
#    u'9517',
#    u'5566',
#    u'4021',
#    u'4770',
#    u'5403',
#    u'4487',
#    u'4696',
#    u'6399',
#    u'5487',
#    u'4156',
#    u'5888',
#    u'7601',
#    u'7176',
#    u'7383',
#    u'4708',
#    u'6497',
#    u'1168',
#    u'7536',
#    u'93',
#    u'5320',
#    u'5253',
#    u'2659',
#    u'5262',
#    u'1599',
#    u'2854',
#    u'4939',
#    u'4811',
#    u'6091',
#    u'5921',
#    u'2366',
#    u'34',
#    u'3746',
#    u'3901',
#    u'3879',
#    u'3884',
#    u'3753',
#    u'4756',
#    u'3275',
#    u'4661',
#    u'4420',
#    u'4402',
#    u'353',
#    u'1360',
#    u'801',
#    u'3221',
#    u'4229',
#    u'2509',
#    u'2920',
#    u'260',
#    u'2824',
#    u'2295',
#    u'65',
#    u'729',
#    u'225',
#    u'660',
#    u'3257',
#    u'3234',
#    u'3228',
#    u'3243',
#    u'2894',
#    u'2958']],
#  [u'css-transform', [u'250']],
#  [u'css3',
#   [u'9897',
#    u'12844',
#    u'1188',
#    u'12878',
#    u'2224',
#    u'250',
#    u'12625',
#    u'9130',
#    u'12708',
#    u'5005',
#    u'12795',
#    u'10777',
#    u'6173',
#    u'6270',
#    u'9277',
#    u'3094',
#    u'6646',
#    u'9159',
#    u'4718',
#    u'6974',
#    u'7662',
#    u'9099',
#    u'4487',
#    u'5257',
#    u'3763',
#    u'4770',
#    u'5481',
#    u'5320',
#    u'342',
#    u'294',
#    u'2295',
#    u'1389',
#    u'225',
#    u'3440',
#    u'1274',
#    u'2509',
#    u'3676',
#    u'822',
#    u'3746',
#    u'3901',
#    u'2366',
#    u'5921',
#    u'4479',
#    u'5674',
#    u'4111',
#    u'5710',
#    u'2896']],
#  [u'csv',
#   [u'5199',
#    u'12995',
#    u'1092',
#    u'4937',
#    u'11154',
#    u'3004',
#    u'7231',
#    u'6549',
#    u'801']],
#  [u'cucumber', [u'608']],
#  [u'cuenta-usuario', [u'11061', u'801', u'3480', u'7254', u'4985', u'292']],
#  [u'curl',
#   [u'13178',
#    u'9282',
#    u'10334',
#    u'10986',
#    u'9116',
#    u'7518',
#    u'4989',
#    u'6384',
#    u'2670']],
#  [u'cython', [u'6656']],
#  [u'c\xf3digo-abierto', [u'25']],
#  [u'd3.js', [u'250', u'11181', u'13156', u'9999', u'6436']],
#  [u'dapper', [u'1805']],
#  [u'data-atributos', [u'250']],
#  [u'datatables',
#   [u'13304',
#    u'2429',
#    u'12904',
#    u'4487',
#    u'12586',
#    u'6635',
#    u'1841',
#    u'547',
#    u'2137',
#    u'78',
#    u'4420',
#    u'1092',
#    u'5881',
#    u'6432',
#    u'3130',
#    u'7697',
#    u'9427',
#    u'9465',
#    u'7384',
#    u'9249',
#    u'2019',
#    u'10876',
#    u'10032',
#    u'10740',
#    u'2838']],
#  [u'date',
#   [u'11103',
#    u'13023',
#    u'3533',
#    u'6438',
#    u'4612',
#    u'7529',
#    u'908',
#    u'6478',
#    u'3248',
#    u'2659',
#    u'4771']],
#  [u'datepicker',
#   [u'10930',
#    u'8954',
#    u'9776',
#    u'7621',
#    u'7132',
#    u'5236',
#    u'4612',
#    u'3685',
#    u'3583',
#    u'4757']],
#  [u'datetime',
#   [u'10123',
#    u'4612',
#    u'7132',
#    u'3316',
#    u'4548',
#    u'5977',
#    u'517',
#    u'3645',
#    u'100',
#    u'636',
#    u'21']],
#  [u'db2', [u'517']],
#  [u'dbexpress', [u'1184']],
#  [u'dbml', [u'2795']],
#  [u'debian',
#   [u'12845',
#    u'2429',
#    u'5274',
#    u'6666',
#    u'5248',
#    u'7530',
#    u'6612',
#    u'4610',
#    u'5438',
#    u'371',
#    u'3488',
#    u'271']],
#  [u'delphi', [u'21', u'1184', u'10532', u'7169', u'7633', u'6217', u'3077']],
#  [u'delphi-2010', [u'1184']],
#  [u'deployment', [u'5681', u'4872', u'5972', u'4361', u'1005', u'2393']],
#  [u'depuraci\xf3n', [u'5737', u'342']],
#  [u'depurar', [u'187']],
#  [u'descarga', [u'6534']],
#  [u'desplegable', [u'6173']],
#  [u'dev-c++', [u'10033', u'5272', u'5233']],
#  [u'devexpress',
#   [u'7254', u'10740', u'9471', u'8999', u'4779', u'2766', u'2854']],
#  [u'devices', [u'722']],
#  [u'diagrama-de-flujo', [u'2241']],
#  [u'dialogo', [u'12708', u'7541', u'6831', u'5370', u'95']],
#  [u'digitalocean', [u'10787']],
#  [u'directorioactivo', [u'6618', u'1092', u'398', u'717']],
#  [u'dise\xf1o',
#   [u'13546', u'12625', u'9484', u'10225', u'4048', u'3415', u'5930', u'4603']],
#  [u'dispatch-async', [u'9099']],
#  [u'div', [u'12611', u'9885', u'4021']],
#  [u'django',
#   [u'11395',
#    u'13480',
#    u'2402',
#    u'13115',
#    u'10253',
#    u'2838',
#    u'12459',
#    u'801',
#    u'5763',
#    u'11279',
#    u'638',
#    u'12740',
#    u'9912',
#    u'3976',
#    u'6215',
#    u'6992',
#    u'371',
#    u'10197',
#    u'10240',
#    u'10341',
#    u'10748',
#    u'10701',
#    u'10163',
#    u'10787',
#    u'10531',
#    u'4654',
#    u'4819',
#    u'10933',
#    u'7519',
#    u'6094',
#    u'1005',
#    u'6751',
#    u'5972',
#    u'6919',
#    u'561',
#    u'6901',
#    u'5826',
#    u'6549',
#    u'6985',
#    u'901',
#    u'6172',
#    u'7201',
#    u'1792',
#    u'6007',
#    u'7530',
#    u'2718',
#    u'4710',
#    u'7357',
#    u'6921',
#    u'5248',
#    u'6658',
#    u'2512',
#    u'4894',
#    u'5292',
#    u'3287',
#    u'4381',
#    u'4892',
#    u'5932',
#    u'5461',
#    u'3946',
#    u'4087',
#    u'816',
#    u'1575',
#    u'353',
#    u'3877',
#    u'3138',
#    u'3570',
#    u'1274',
#    u'2394',
#    u'4748',
#    u'2802',
#    u'3243',
#    u'1270',
#    u'100',
#    u'535',
#    u'2759',
#    u'2690',
#    u'1596',
#    u'2636']],
#  [u'django-admin', [u'13115', u'2838', u'801', u'3976', u'1005', u'1274']],
#  [u'django-forms',
#   [u'2838', u'10253', u'1005', u'10933', u'6007', u'6751', u'371', u'4087']],
#  [u'django-migrations', [u'2402']],
#  [u'django-models',
#   [u'13480',
#    u'13115',
#    u'2838',
#    u'5763',
#    u'11395',
#    u'6215',
#    u'10197',
#    u'10531',
#    u'1005',
#    u'7519',
#    u'6094',
#    u'5972',
#    u'6751',
#    u'2636',
#    u'2394',
#    u'1270',
#    u'2512',
#    u'1274',
#    u'816',
#    u'5461',
#    u'6007',
#    u'371']],
#  [u'django-smart-selects', [u'1005']],
#  [u'djangorestframework',
#   [u'638', u'1005', u'5972', u'901', u'1792', u'2802', u'2718']],
#  [u'dns',
#   [u'4584', u'10399', u'12629', u'9953', u'9312', u'5368', u'7137', u'307']],
#  [u'docker', [u'2770', u'4388', u'399']],
#  [u'doctrine', [u'5005', u'8916', u'9847', u'5957', u'3165', u'1960', u'360']],
#  [u'doctrine2', [u'5005', u'9741', u'3644', u'1960', u'360']],
#  [u'docx', [u'7242']],
#  [u'dom', [u'10374', u'7137', u'2848', u'2854', u'5732', u'3234', u'132']],
#  [u'domain-driven-design', [u'5562']],
#  [u'double', [u'517', u'4697']],
#  [u'drag-and-drop', [u'5700', u'531', u'3879']],
#  [u'drools', [u'458']],
#  [u'dukescript', [u'342']],
#  [u'dup', [u'2633']],
#  [u'ec2', [u'12772', u'5438', u'1005', u'631']],
#  [u'eclipse',
#   [u'13316',
#    u'3878',
#    u'3249',
#    u'12807',
#    u'12790',
#    u'7004',
#    u'10019',
#    u'10603',
#    u'11124',
#    u'8898',
#    u'342',
#    u'93',
#    u'2387',
#    u'2908',
#    u'4164',
#    u'400',
#    u'3550',
#    u'3702',
#    u'5403',
#    u'7441',
#    u'2670',
#    u'3231',
#    u'517',
#    u'4595',
#    u'4321',
#    u'9920',
#    u'9695',
#    u'5902',
#    u'9027',
#    u'4879']],
#  [u'ecmascript-2015', [u'2894', u'399', u'729']],
#  [u'edittext', [u'7254', u'5370']],
#  [u'eficiencia', [u'517']],
#  [u'ejb',
#   [u'9327',
#    u'7191',
#    u'9803',
#    u'9164',
#    u'6578',
#    u'7494',
#    u'1204',
#    u'3249',
#    u'4612']],
#  [u'electron', [u'7266', u'353']],
#  [u'elixir', [u'37']],
#  [u'email',
#   [u'11117',
#    u'9099',
#    u'12424',
#    u'11394',
#    u'10476',
#    u'9001',
#    u'9741',
#    u'9529',
#    u'7449',
#    u'4316',
#    u'3094',
#    u'5558',
#    u'4451',
#    u'3925',
#    u'4468',
#    u'238',
#    u'2826',
#    u'127']],
#  [u'embebido', [u'10428', u'12550', u'2676', u'801']],
#  [u'ember.js', [u'430']],
#  [u'emmet', [u'9029', u'7395']],
#  [u'encriptacion',
#   [u'4677',
#    u'12988',
#    u'6046',
#    u'9098',
#    u'9099',
#    u'7238',
#    u'4225',
#    u'4932',
#    u'3869',
#    u'2747',
#    u'3765',
#    u'1792']],
#  [u'end-of-line', [u'2379']],
#  [u'ensamblador',
#   [u'9023',
#    u'4404',
#    u'4610',
#    u'9005',
#    u'9634',
#    u'9560',
#    u'6550',
#    u'4321',
#    u'5133',
#    u'1575']],
#  [u'entity-framework',
#   [u'7165',
#    u'4361',
#    u'12431',
#    u'2366',
#    u'13042',
#    u'10047',
#    u'10301',
#    u'4923',
#    u'9521',
#    u'3060',
#    u'6501',
#    u'4048',
#    u'5552',
#    u'5562',
#    u'3617',
#    u'3480',
#    u'3865',
#    u'921',
#    u'298',
#    u'2795',
#    u'2472',
#    u'2767',
#    u'2659',
#    u'1795',
#    u'2184',
#    u'531',
#    u'1168',
#    u'4348',
#    u'2744',
#    u'1494']],
#  [u'entity-framework-6',
#   [u'4048',
#    u'4923',
#    u'13042',
#    u'12781',
#    u'4811',
#    u'10301',
#    u'7195',
#    u'4584',
#    u'5523',
#    u'2472']],
#  [u'entrada', [u'13063']],
#  [u'enum', [u'1505', u'2742']],
#  [u'errores',
#   [u'2429',
#    u'12431',
#    u'13480',
#    u'11213',
#    u'7529',
#    u'5566',
#    u'10577',
#    u'12723',
#    u'10774',
#    u'10491',
#    u'9282',
#    u'7601',
#    u'9616',
#    u'22']],
#  [u'estructuras-de-datos',
#   [u'13347',
#    u'4048',
#    u'12524',
#    u'3199',
#    u'10725',
#    u'3665',
#    u'6187',
#    u'5076',
#    u'4899',
#    u'6248',
#    u'4708',
#    u'302']],
#  [u'est\xe1ndares', [u'2742']],
#  [u'eventos',
#   [u'250',
#    u'13277',
#    u'11013',
#    u'11095',
#    u'6774',
#    u'4548',
#    u'2676',
#    u'7293',
#    u'4362',
#    u'3275',
#    u'22']],
#  [u'excel',
#   [u'9281',
#    u'13380',
#    u'13714',
#    u'13711',
#    u'11370',
#    u'7231',
#    u'11320',
#    u'5972',
#    u'10421',
#    u'12869',
#    u'10117',
#    u'9471',
#    u'6771',
#    u'10550',
#    u'749',
#    u'2724',
#    u'1809',
#    u'78',
#    u'2184',
#    u'4279',
#    u'4781',
#    u'3855',
#    u'4105',
#    u'5980',
#    u'6356',
#    u'4983',
#    u'5287',
#    u'6505',
#    u'6902',
#    u'4361',
#    u'4026',
#    u'9151',
#    u'9181',
#    u'9928',
#    u'10763',
#    u'7242',
#    u'10583',
#    u'10511']],
#  [u'excepciones',
#   [u'2429',
#    u'12431',
#    u'2980',
#    u'13077',
#    u'10577',
#    u'9427',
#    u'2659',
#    u'1958',
#    u'1839',
#    u'1505',
#    u'100']],
#  [u'express',
#   [u'3287',
#    u'9885',
#    u'3902',
#    u'9912',
#    u'6829',
#    u'3618',
#    u'6449',
#    u'3812',
#    u'2133',
#    u'3743',
#    u'3281']],
#  [u'extension-method', [u'5566', u'2659']],
#  [u'extjs', [u'11017', u'4914', u'4111', u'5874', u'3750', u'4317']],
#  [u'facebook',
#   [u'9484',
#    u'13612',
#    u'13104',
#    u'3234',
#    u'10004',
#    u'10052',
#    u'9414',
#    u'6044',
#    u'8752',
#    u'5919',
#    u'5761',
#    u'608',
#    u'3751',
#    u'2282',
#    u'4878',
#    u'4468',
#    u'3118',
#    u'2957',
#    u'2352',
#    u'1583']],
#  [u'facebook-api',
#   [u'13612', u'4874', u'10004', u'3234', u'7542', u'1839', u'9414']],
#  [u'factorial', [u'630']],
#  [u'fail2ban', [u'4266']],
#  [u'fecha', [u'9099', u'7177', u'6170', u'517']],
#  [u'filtros-css', [u'6270', u'2509']],
#  [u'firebase',
#   [u'12994',
#    u'11095',
#    u'10148',
#    u'4678',
#    u'9939',
#    u'4418',
#    u'8907',
#    u'9808',
#    u'883',
#    u'5219',
#    u'2282',
#    u'4466',
#    u'3170',
#    u'4766',
#    u'4798',
#    u'636']],
#  [u'firebird', [u'6878', u'9262', u'4325', u'6406', u'1687']],
#  [u'firefox',
#   [u'10930', u'12855', u'12844', u'9159', u'7266', u'6279', u'3038']],
#  [u'firma-digital', [u'13342', u'3203']],
#  [u'fish', [u'302']],
#  [u'flask', [u'5049']],
#  [u'formas', [u'7358']],
#  [u'formularios',
#   [u'10930',
#    u'13304',
#    u'11344',
#    u'8728',
#    u'160',
#    u'100',
#    u'801',
#    u'2224',
#    u'1390',
#    u'2910',
#    u'2838',
#    u'2676',
#    u'4822',
#    u'3341',
#    u'2958',
#    u'5024',
#    u'4612',
#    u'8795',
#    u'4451',
#    u'5720',
#    u'6497',
#    u'1360',
#    u'6547',
#    u'7227',
#    u'6316',
#    u'12935',
#    u'11053',
#    u'11395']],
#  [u'formulas', [u'65']],
#  [u'foundation', [u'1721']],
#  [u'framework7', [u'12708']],
#  [u'frecuencia', [u'4991', u'4458']],
#  [u'ftp',
#   [u'13637',
#    u'9484',
#    u'1812',
#    u'120',
#    u'7573',
#    u'2596',
#    u'3362',
#    u'3361',
#    u'2387']],
#  [u'fullcalendar', [u'9675', u'8834', u'3130']],
#  [u'funciones',
#   [u'13525',
#    u'6095',
#    u'3248',
#    u'12831',
#    u'217',
#    u'100',
#    u'1092',
#    u'4548',
#    u'4676',
#    u'1399',
#    u'3773',
#    u'3920',
#    u'4899',
#    u'1360',
#    u'5075',
#    u'2134',
#    u'5641',
#    u'6497',
#    u'6897',
#    u'7063',
#    u'8880',
#    u'9305',
#    u'10662',
#    u'10774',
#    u'9886',
#    u'9119']],
#  [u'gemfile', [u'75', u'3257']],
#  [u'generator', [u'187']],
#  [u'genexus',
#   [u'9610',
#    u'1201',
#    u'2335',
#    u'728',
#    u'722',
#    u'725',
#    u'676',
#    u'3290',
#    u'1155',
#    u'3203',
#    u'724',
#    u'514',
#    u'5816',
#    u'6478',
#    u'9408',
#    u'10521']],
#  [u'gentoo', [u'4610']],
#  [u'genymotion', [u'2896', u'3170']],
#  [u'gen\xe9ricos', [u'3415']],
#  [u'geo-localizacion',
#   [u'13016', u'10119', u'9539', u'4568', u'5370', u'3533', u'4583', u'2994']],
#  [u'ggplot2', [u'6910', u'8810', u'4355', u'271']],
#  [u'gif', [u'11025', u'6173']],
#  [u'git',
#   [u'13235',
#    u'3248',
#    u'13407',
#    u'5997',
#    u'11381',
#    u'2896',
#    u'5972',
#    u'8995',
#    u'2429',
#    u'638',
#    u'2509',
#    u'1281',
#    u'3231',
#    u'2766',
#    u'4874',
#    u'5566',
#    u'154',
#    u'4883',
#    u'22',
#    u'1005',
#    u'25',
#    u'1505',
#    u'23',
#    u'399',
#    u'2004',
#    u'299',
#    u'342',
#    u'417',
#    u'729',
#    u'260',
#    u'83',
#    u'555',
#    u'398',
#    u'75',
#    u'1171',
#    u'2013',
#    u'1914',
#    u'2027',
#    u'1943',
#    u'1798',
#    u'3234',
#    u'3151']],
#  [u'git-commit',
#   [u'3248', u'6826', u'5566', u'2004', u'1943', u'83', u'342', u'299']],
#  [u'git-fork', [u'2013', u'342']],
#  [u'git-push', [u'3248', u'5972', u'5566', u'2004', u'3151', u'2013', u'342']],
#  [u'github',
#   [u'3248',
#    u'13407',
#    u'5997',
#    u'13788',
#    u'2896',
#    u'5972',
#    u'2509',
#    u'6826',
#    u'3231',
#    u'1401',
#    u'2013',
#    u'1171',
#    u'342']],
#  [u'glassfish',
#   [u'9261',
#    u'9327',
#    u'7142',
#    u'6578',
#    u'9273',
#    u'4612',
#    u'8839',
#    u'1204',
#    u'2676']],
#  [u'gmail', [u'9039', u'7380', u'4316', u'5558', u'65']],
#  [u'go', [u'1641', u'9669', u'22', u'3834', u'399']],
#  [u'google+', [u'4874', u'2352']],
#  [u'google-app-engine', [u'3533', u'1368', u'866', u'870', u'2981', u'2004']],
#  [u'google-apps-script',
#   [u'10388',
#    u'11302',
#    u'11223',
#    u'9121',
#    u'7661',
#    u'9039',
#    u'7380',
#    u'9525',
#    u'65']],
#  [u'google-chrome',
#   [u'10930',
#    u'5997',
#    u'12855',
#    u'12844',
#    u'9159',
#    u'7266',
#    u'9420',
#    u'6469',
#    u'3763',
#    u'870',
#    u'4756',
#    u'2920',
#    u'238',
#    u'2004']],
#  [u'google-datastore', [u'3533', u'1368', u'2004']],
#  [u'google-drive', [u'13209', u'13767', u'9525', u'65', u'3459', u'1947']],
#  [u'google-forms', [u'65']],
#  [u'google-hoja-de-calculo',
#   [u'10388', u'65', u'6654', u'7661', u'7255', u'3144', u'1184']],
#  [u'google-maps',
#   [u'10921',
#    u'10832',
#    u'6646',
#    u'13797',
#    u'9840',
#    u'13746',
#    u'12418',
#    u'12441',
#    u'517',
#    u'10777',
#    u'6677',
#    u'2225',
#    u'4610',
#    u'9939',
#    u'9762',
#    u'10399',
#    u'10638',
#    u'10605',
#    u'3878',
#    u'7615',
#    u'7490',
#    u'4361',
#    u'5902',
#    u'9675',
#    u'9855',
#    u'4568',
#    u'3004',
#    u'2551',
#    u'729',
#    u'23',
#    u'2004',
#    u'2969',
#    u'2230',
#    u'2653',
#    u'4312',
#    u'3280',
#    u'4421',
#    u'4392',
#    u'4583',
#    u'4823',
#    u'3906',
#    u'5723',
#    u'5824',
#    u'3533',
#    u'6497',
#    u'7280',
#    u'8795',
#    u'7384']],
#  [u'google-newsstand-producer', [u'95']],
#  [u'google-places', [u'9855']],
#  [u'google-play',
#   [u'3828',
#    u'7541',
#    u'9184',
#    u'4528',
#    u'8907',
#    u'7021',
#    u'6677',
#    u'2230',
#    u'4418']],
#  [u'google-play-games', [u'10019', u'8907']],
#  [u'google-plus', [u'7661', u'2352']],
#  [u'google-visualization', [u'9305', u'2759']],
#  [u'goutte', [u'10297']],
#  [u'gpg', [u'729']],
#  [u'gpl', [u'13569', u'7216']],
#  [u'gps', [u'10561', u'9539', u'3004']],
#  [u'gradle',
#   [u'6353',
#    u'11322',
#    u'7541',
#    u'10807',
#    u'4836',
#    u'2074',
#    u'9282',
#    u'2681',
#    u'9780',
#    u'5403',
#    u'608',
#    u'4568',
#    u'6042',
#    u'4874',
#    u'24',
#    u'2230',
#    u'1914',
#    u'2430',
#    u'2685']],
#  [u'grails', [u'4246', u'5403', u'6407', u'4753', u'6591', u'4764']],
#  [u'grep', [u'2013', u'83']],
#  [u'grid', [u'10952', u'7254', u'3313', u'9471', u'6173']],
#  [u'gridview', [u'11187', u'12843', u'10640', u'10348', u'2163']],
#  [u'grobid', [u'4246']],
#  [u'groovy', [u'4246', u'8923', u'9510', u'6591', u'4753', u'4764', u'25']],
#  [u'gson', [u'13076', u'6386', u'143']],
#  [u'gstreamer', [u'6584', u'2364']],
#  [u'gtk', [u'9669']],
#  [u'gui', [u'13489', u'4328', u'9669']],
#  [u'gulp', [u'6585', u'9883', u'1204', u'7157', u'7601', u'638', u'294']],
#  [u'gulp-sass', [u'6585', u'294']],
#  [u'gvnix', [u'10094', u'11019', u'5855', u'5650', u'3182', u'3760', u'701']],
#  [u'gwt', [u'3878']],
#  [u'handlebars.js', [u'3013']],
#  [u'hapijs', [u'430']],
#  [u'hashmap', [u'12524', u'12525', u'3726', u'6248', u'1111']],
#  [u'haskell', [u'9348', u'4117', u'100', u'630', u'302']],
#  [u'herencia',
#   [u'6881', u'5422', u'5274', u'5930', u'4632', u'4676', u'4753']],
#  [u'heroku', [u'5005', u'9953', u'10718', u'1005', u'4748']],
#  [u'hibernate',
#   [u'13349',
#    u'12475',
#    u'3249',
#    u'12807',
#    u'9944',
#    u'10426',
#    u'3488',
#    u'9228',
#    u'8923',
#    u'7210',
#    u'4932',
#    u'608',
#    u'4830',
#    u'1972',
#    u'2004',
#    u'187']],
#  [u'hibernate-formula', [u'608']],
#  [u'highcharts',
#   [u'6399', u'9885', u'10610', u'3767', u'5601', u'908', u'166', u'100']],
#  [u'hilos',
#   [u'13349',
#    u'13432',
#    u'12458',
#    u'517',
#    u'10336',
#    u'3727',
#    u'7485',
#    u'6851',
#    u'5307',
#    u'3415',
#    u'3443',
#    u'187']],
#  [u'hls', [u'10454']],
#  [u'hql', [u'12575', u'4830', u'342']],
#  [u'html',
#   [u'5997',
#    u'4748',
#    u'9897',
#    u'10452',
#    u'2338',
#    u'12878',
#    u'9458',
#    u'1188',
#    u'13470',
#    u'12935',
#    u'1204',
#    u'13547',
#    u'250',
#    u'12613',
#    u'2224',
#    u'13557',
#    u'11313',
#    u'1575',
#    u'9883',
#    u'10832',
#    u'13580',
#    u'13637',
#    u'10848',
#    u'4840',
#    u'12708',
#    u'10574',
#    u'73',
#    u'5674',
#    u'5272',
#    u'5911',
#    u'13788',
#    u'4878',
#    u'13800',
#    u'10298',
# ...
#    u'5525',
#    u'5552',
#    u'5301',
#    u'5109',
#    u'6339',
#    u'6340',
#    u'6360',
#    u'6272',
#    u'120',
#    u'3316',
#    u'5913',
#    u'5881',
#    u'5852',
#    u'4654',
#    u'1719',
#    u'4030',
#    u'1795',
#    u'4059',
#    u'3932',
#    u'3786',
#    u'4786',
#    u'4799',
#    u'4650',
#    u'531',
#    u'77',
#    u'2600',
#    u'2724',
#    u'1365',
#    u'2256',
#    u'1203',
#    u'2675',
#    u'1092',
#    u'1466',
#    u'3040',
#    u'533',
#    u'2948',
#    u'2555',
#    u'4360',
#    u'3541',
#    u'4351',
#    u'4499']],
#  [u'sqldeveloper', [u'6849', u'1184', u'5175', u'342']],
#  [u'sqlfiddle', [u'1184', u'342']],
#  [u'sqlite',
#   [u'9174',
#    u'13222',
#    u'4815',
#    u'10744',
#    u'11232',
#    u'8873',
#    u'12930',
#    u'5370',
#    u'4568',
#    u'6020',
#    u'10724',
#    u'10782',
#    u'7238',
#    u'7254',
#    u'5710',
#    u'301',
#    u'1972',
#    u'2512',
#    u'3243',
#    u'2539',
#    u'4598',
#    u'2230',
#    u'4943',
#    u'2636',
#    u'8847',
#    u'4684',
#    u'7728',
#    u'2896',
#    u'6549',
#    u'3343',
#    u'9427',
#    u'9764']],
#  [u'sqlite3',
#   [u'10744',
#    u'4858',
#    u'8873',
#    u'7238',
#    u'4568',
#    u'9427',
#    u'4142',
#    u'2636',
#    u'3249',
#    u'1972',
#    u'301',
#    u'2596']],
#  [u'ssis', [u'13282', u'10069', u'120', u'2659', u'6802', u'1092']],
#  [u'ssms', [u'1905']],
#  [u'ssrs', [u'6534']],
#  [u'staticfiles', [u'638']],
#  [u'stored-procedure',
#   [u'12690',
#    u'9182',
#    u'7621',
#    u'12865',
#    u'7582',
#    u'1092',
#    u'12933',
#    u'9117',
#    u'8945',
#    u'9045',
#    u'9724',
#    u'5487',
#    u'9347',
#    u'2676',
#    u'4654',
#    u'2747',
#    u'1466',
#    u'2453']],
#  [u'str-replace', [u'11004', u'6206', u'217']],
#  [u'string',
#   [u'6170',
#    u'13237',
#    u'13781',
#    u'3621',
#    u'9099',
#    u'11101',
#    u'517',
#    u'6206',
#    u'8842',
#    u'5772',
#    u'9205',
#    u'2230',
#    u'6187',
#    u'6836',
#    u'2742',
#    u'2399',
#    u'5370',
#    u'6212',
#    u'4595',
#    u'5729',
#    u'2645',
#    u'2676',
#    u'3909',
#    u'3890',
#    u'3491',
#    u'149',
#    u'217',
#    u'24',
#    u'21',
#    u'2235',
#    u'2004',
#    u'3341',
#    u'3199',
#    u'301',
#    u'2878',
#    u'100',
#    u'4317',
#    u'2879',
#    u'4736',
#    u'1092',
#    u'4787',
#    u'3004']],
#  [u'struts', [u'10848', u'9225', u'4541', u'417']],
#  [u'stylus', [u'7176']],
#  [u'sublimetext', [u'7703', u'6354', u'4023', u'3202', u'3013', u'292']],
#  [u'sublimetext3',
#   [u'13235', u'7703', u'7601', u'9029', u'6354', u'5516', u'3013', u'292']],
#  [u'subrepositorios', [u'227']],
#  [u'subversion', [u'2004']],
#  [u'svg', [u'250', u'6897', u'6353', u'4610', u'7358', u'7662', u'4418']],
#  [u'svn', [u'2004']],
#  [u'swagger', [u'608']],
#  [u'swift',
#   [u'9099',
#    u'13341',
#    u'13730',
#    u'4265',
#    u'10870',
#    u'11001',
#    u'4866',
#    u'3415',
#    u'2282',
#    u'9487',
#    u'1281',
#    u'10049',
#    u'9194',
#    u'3022',
#    u'8880',
#    u'1147',
#    u'6560',
#    u'8847',
#    u'2878',
#    u'4858',
#    u'2985',
#    u'6041',
#    u'2472',
#    u'2837',
#    u'4798',
#    u'4880',
#    u'270',
#    u'1527',
#    u'1881',
#    u'1513',
#    u'3280',
#    u'95',
#    u'4264']],
#  [u'swift2',
#   [u'9099',
#    u'6560',
#    u'13518',
#    u'13626',
#    u'13730',
#    u'4265',
#    u'11001',
#    u'10870',
#    u'2282',
#    u'1281',
#    u'10115',
#    u'10104',
#    u'10049',
#    u'9194',
#    u'7615',
#    u'3415',
#    u'8880',
#    u'7254',
#    u'4924',
#    u'1147',
#    u'6837',
#    u'2472',
#    u'4858',
#    u'5577',
#    u'6041',
#    u'3590',
#    u'1499',
#    u'1527',
#    u'1784',
#    u'1513',
#    u'2137',
#    u'1913',
#    u'2837',
#    u'2878',
#    u'4264']],
#  [u'swing',
#   [u'13354',
#    u'3415',
#    u'6170',
#    u'7597',
#    u'517',
#    u'7004',
#    u'9261',
#    u'10536',
#    u'2980',
#    u'5703',
#    u'4321',
#    u'3244',
#    u'3021',
#    u'342',
#    u'4394',
#    u'3855',
#    u'4100',
#    u'2645',
#    u'3949',
#    u'4328',
#    u'271',
#    u'8728',
#    u'7586',
#    u'5894',
#    u'8958']],
#  [u'swt', [u'93']],
#  [u'symfony2',
#   [u'5005',
#    u'13462',
#    u'10674',
#    u'9130',
#    u'4872',
#    u'9741',
#    u'9675',
#    u'3283',
#    u'3165',
#    u'4306',
#    u'4389',
#    u'4680',
#    u'3644',
#    u'3950',
#    u'5841',
#    u'5859',
#    u'6000',
#    u'5265',
#    u'5665',
#    u'6506',
#    u'3933',
#    u'7148',
#    u'9530',
#    u'9847',
#    u'8916']],
#  [u'symfony3', [u'10674', u'9130']],
#  [u'sync-framework', [u'3682']],
#  [u'tad', [u'2909']],
#  [u'tcp', [u'10495', u'6461', u'5689', u'1943', u'21']],
#  [u'tcpip', [u'5932', u'1943', u'4271', u'21']],
#  [u'telnet', [u'12476']],
#  [u'template', [u'11395', u'2742']],
#  [u'teor\xeda', [u'11261']],
#  [u'test-ng', [u'1505']],
#  [u'thread',
#   [u'10350',
#    u'517',
#    u'10336',
#    u'7142',
#    u'2676',
#    u'3415',
#    u'3727',
#    u'7545',
#    u'2935',
#    u'1943',
#    u'870']],
#  [u'thymeleaf', [u'400']],
#  [u'timespan', [u'2659']],
#  [u'timestamp', [u'4612', u'2747', u'21', u'132']],
#  [u'tinymce', [u'4748', u'2957', u'2394', u'417', u'2832']],
#  [u'tipos', [u'2027', u'630', u'22', u'288']],
#  [u'tkinter',
#   [u'13489', u'10937', u'10997', u'1527', u'7701', u'1792', u'2122']],
#  [u'tomcat',
#   [u'13251',
#    u'10587',
#    u'9944',
#    u'10520',
#    u'10995',
#    u'9236',
#    u'8898',
#    u'9408',
#    u'608',
#    u'517',
#    u'7142',
#    u'4541']],
#  [u'transacciones', [u'2335', u'4779', u'8945', u'5487', u'2676', u'4654']],
#  [u'trigger',
#   [u'10552', u'7384', u'9271', u'2230', u'6849', u'4612', u'6503', u'4529']],
#  [u'try-catch', [u'10903', u'7242', u'261']],
#  [u'tsql', [u'12510', u'9098', u'6340', u'3316', u'4529', u'1859', u'2256']],
#  [u'tweepy', [u'529']],
#  [u'twig', [u'13462', u'9099', u'10674', u'9130', u'12775', u'7148', u'4306']],
#  [u'twitter', [u'13425', u'5465', u'6044', u'9232']],
#  [u'twitter-api',
#   [u'13425',
#    u'13612',
#    u'5465',
#    u'3767',
#    u'9232',
#    u'8752',
#    u'1965',
#    u'3496',
#    u'529',
#    u'2896']],
#  [u'typescript', [u'6095', u'4678', u'353', u'8768', u'154', u'629', u'20']],
#  [u'typings', [u'3743']],
#  [u'ubuntu',
#   [u'12727',
#    u'11183',
#    u'9023',
#    u'10731',
#    u'5005',
#    u'1592',
#    u'10796',
#    u'10807',
#    u'6578',
#    u'9012',
#    u'9029',
#    u'8970',
#    u'9798',
#    u'100',
#    u'631',
#    u'2172',
#    u'3138',
#    u'2004',
#    u'2236',
#    u'4871',
#    u'3869',
#    u'6279',
#    u'5175',
#    u'3976',
#    u'7137',
#    u'6741',
#    u'6612',
#    u'2770',
#    u'9524',
#    u'3966']],
#  [u'ui.router', [u'638']],
#  [u'uicollectionview', [u'9099']],
#  [u'uitableview', [u'9099', u'10049']],
#  [u'uitableviewcontroller', [u'10049', u'9757', u'9099']],
#  [u'uiview', [u'9099']],
#  [u'uiwebview', [u'575', u'95', u'965']],
#  [u'underscorejs', [u'1204', u'636']],
#  [u'unidades-de-medici\xf3n', [u'250', u'305']],
#  [u'union', [u'2676']],
#  [u'unity2d', [u'3759', u'6560', u'2257', u'9770']],
#  [u'unity3d',
#   [u'3759',
#    u'3828',
#    u'6560',
#    u'2797',
#    u'342',
#    u'2257',
#    u'2862',
#    u'5356',
#    u'5838',
#    u'7714',
#    u'1005',
#    u'8907',
#    u'9152',
#    u'7542',
#    u'10304',
#    u'9952',
#    u'10076']],
#  [u'unix',
#   [u'4676',
#    u'6723',
#    u'7530',
#    u'5274',
#    u'187',
#    u'4298',
#    u'2890',
#    u'870',
#    u'2633',
#    u'83']],
#  [u'unreal-engine', [u'4198']],
#  [u'url', [u'2429', u'12625']],
#  [u'users-roles', [u'9979', u'3618', u'1005']],
#  [u'utf-8', [u'9189', u'10485', u'9305', u'1596', u'127']],
#  [u'uwp', [u'2123', u'6914', u'2596', u'3562', u'3053', u'2230']],
#  [u'vagrant', [u'13612', u'5409', u'399']],
#  [u'validaci\xf3n',
#   [u'13433',
#    u'13277',
#    u'10930',
#    u'8930',
#    u'11266',
#    u'2162',
#    u'1505',
#    u'10097',
#    u'6316',
#    u'4451',
#    u'4612',
#    u'3950',
#    u'3341',
#    u'1839',
#    u'4822',
#    u'4298',
#    u'100',
#    u'127']],
#  [u'validate', [u'9099']],
#  [u'variables',
#   [u'10930',
#    u'10454',
#    u'8771',
#    u'10760',
#    u'9045',
#    u'9099',
#    u'6897',
#    u'3869',
#    u'4328',
#    u'7564',
#    u'4676',
#    u'4991',
#    u'2539',
#    u'218']],
#  [u'vb.net',
#   [u'8873',
#    u'13350',
#    u'11320',
#    u'13711',
#    u'13108',
#    u'2633',
#    u'6851',
#    u'12606',
#    u'10421',
#    u'10740',
#    u'4779',
#    u'9610',
#    u'3115',
#    u'4361',
#    u'9471',
#    u'10350',
#    u'6020',
#    u'4487',
#    u'3054',
#    u'10890',
#    u'6298',
#    u'5852',
#    u'4729',
#    u'7242',
#    u'6764',
#    u'5271',
#    u'7585',
#    u'5272',
#    u'7626',
#    u'5602',
#    u'5552',
#    u'1401',
#    u'5071',
#    u'5066',
#    u'4985',
#    u'5723',
#    u'2675',
#    u'4030',
#    u'2366',
#    u'4059',
#    u'3762',
#    u'3491',
#    u'3705',
#    u'745',
#    u'1168',
#    u'2533',
#    u'2531',
#    u'1399',
#    u'3052',
#    u'1839',
#    u'4633',
#    u'3551']],
#  [u'vba',
#   [u'13380',
#    u'11320',
#    u'7231',
#    u'9181',
#    u'9151',
#    u'9706',
#    u'9861',
#    u'9449',
#    u'4779',
#    u'4782',
#    u'4983',
#    u'4781',
#    u'749']],
#  [u'verilog', [u'4263', u'389']],
#  [u'vibracion', [u'6044']],
#  [u'video-adaptativo', [u'10454']],
#  [u'viewport', [u'5674', u'2659']],
#  [u'vim', [u'12845']],
#  [u'virtualbox', [u'8990', u'9193', u'8882']],
#  [u'vistas', [u'5997', u'1037', u'29']],
#  [u'visual-basic', [u'10117']],
#  [u'visual-basic-6',
#   [u'5847',
#    u'13282',
#    u'78',
#    u'8945',
#    u'6020',
#    u'9430',
#    u'7242',
#    u'8730',
#    u'5706',
#    u'4083',
#    u'3688']],
#  [u'visual-c++', [u'10902', u'2236', u'6323', u'5243', u'6264']],
#  [u'visual-studio',
#   [u'8873',
#    u'13429',
#    u'10744',
#    u'13693',
#    u'11353',
#    u'11325',
#    u'4048',
#    u'1092',
#    u'5938',
#    u'6046',
#    u'2472',
#    u'10428',
#    u'10401',
#    u'6020',
#    u'10689',
#    u'4361',
#    u'10348',
#    u'10878',
#    u'2747',
#    u'6534',
#    u'9505',
#    u'3316',
#    u'6469',
#    u'5271',
#    u'6589',
#    u'5421',
#    u'8788',
#    u'7371',
#    u'5723',
#    u'5552',
#    u'5071',
#    u'2636',
#    u'5272',
#    u'3617',
#    u'5908',
#    u'2826',
#    u'93',
#    u'211',
#    u'398',
#    u'2724',
#    u'1839',
#    u'3088',
#    u'2990',
#    u'2967',
#    u'2974',
#    u'3828']],
#  [u'visual-studio-2010',
#   [u'10258', u'8990', u'3675', u'4336', u'1399', u'2236']],
#  [u'visual-studio-2013',
#   [u'8873',
#    u'13209',
#    u'6704',
#    u'11325',
#    u'10033',
#    u'10878',
#    u'9212',
#    u'8999',
#    u'5908',
#    u'2842']],
#  [u'visual-studio-2015',
#   [u'13239',
#    u'5938',
#    u'13464',
#    u'11320',
#    u'4048',
#    u'6046',
#    u'10180',
#    u'5729',
#    u'2472',
#    u'6020',
#    u'8842',
#    u'2429',
#    u'6534',
#    u'6589',
#    u'5259',
#    u'6613',
#    u'2826',
#    u'398',
#    u'2967',
#    u'25',
#    u'4613',
#    u'3726',
#    u'3642',
#    u'4042',
#    u'5552',
#    u'5523',
#    u'2766']],
#  [u'visual-studio-ts', [u'2766']],
#  [u'volatile', [u'517']],
#  [u'vpn', [u'9241', u'9319', u'4456', u'1303', u'813']],
#  [u'vscode', [u'4048', u'10350', u'227', u'3743']],
#  [u'vue.js', [u'13405', u'8784', u'4991']],
#  [u'wagtail', [u'801']],
#  [u'wasync', [u'608']],
#  [u'wav', [u'7554']],
#  [u'wcf',
#   [u'10605',
#    u'13560',
#    u'13651',
#    u'13731',
#    u'10291',
#    u'4923',
#    u'2883',
#    u'2184',
#    u'2766',
#    u'325']],
#  [u'web2py', [u'908']],
#  [u'webbrowser', [u'10744', u'7132', u'5723']],
#  [u'webforms', [u'2366', u'2854', u'10945']],
#  [u'webgl', [u'342']],
#  [u'webpack', [u'801']],
#  [u'webservice',
#   [u'5602',
#    u'11117',
#    u'12912',
#    u'13178',
#    u'13651',
#    u'10428',
#    u'13658',
#    u'10744',
#    u'7541',
#    u'9539',
#    u'4361',
#    u'9698',
#    u'11309',
#    u'10399',
#    u'12530',
#    u'5370',
#    u'9610',
#    u'7318',
#    u'1092',
#    u'8831',
#    u'8776',
#    u'4923',
#    u'9516',
#    u'7280',
#    u'8847',
#    u'8944',
#    u'2241',
#    u'9304',
#    u'6646',
#    u'11002',
#    u'11095',
#    u'11168',
#    u'10724',
#    u'4227']],
#  [u'websocket', [u'7166', u'1943']],
#  [u'websphere', [u'4677', u'10848']],
#  [u'websphere-mq', [u'4677']],
#  [u'webview', [u'9099', u'12822', u'10062', u'6044', u'10636', u'10600']],
#  [u'webview-android', [u'6044']],
#  [u'whatsapp', [u'9939', u'12817', u'9099']],
#  [u'wikitude', [u'9972']],
#  [u'wildfly', [u'10426', u'9803', u'9164', u'227']],
#  [u'winapi', [u'13485', u'2171', u'6323']],
#  [u'windows',
#   [u'5847',
#    u'11061',
#    u'9179',
#    u'13485',
#    u'13538',
#    u'13591',
#    u'5972',
#    u'5674',
#    u'10399',
#    u'4048',
#    u'12640',
#    u'10428',
#    u'12517',
#    u'6564',
#    u'21',
#    u'13005',
#    u'360',
#    u'9039',
#    u'10134',
#    u'10708',
#    u'3231',
#    u'2896',
#    u'2241',
#    u'3933',
#    u'9738',
#    u'9437',
#    u'7192',
#    u'2171',
#    u'78',
#    u'5663',
#    u'5772',
#    u'8827',
#    u'154',
#    u'5145',
#    u'4325',
#    u'4958',
#    u'6173',
#    u'6471',
#    u'813',
#    u'2820',
#    u'2230',
#    u'398',
#    u'2379',
#    u'1119',
#    u'1184',
#    u'2825',
#    u'3423',
#    u'353',
#    u'3440',
#    u'2247',
#    u'1839',
#    u'2946',
#    u'3013',
#    u'342',
#    u'2596',
#    u'4520',
#    u'4610',
#    u'3486',
#    u'3757',
#    u'371',
#    u'630']],
#  [u'windows-forms',
#   [u'11353',
#    u'5729',
#    u'4048',
#    u'12710',
#    u'12467',
#    u'5938',
#    u'78',
#    u'10206',
#    u'10744',
#    u'6495',
#    u'4361',
#    u'4137',
#    u'9427',
#    u'4487',
#    u'9878',
#    u'6305',
#    u'7430',
#    u'5671',
#    u'4779',
#    u'1401',
#    u'5174',
#    u'1092',
#    u'5071',
#    u'531',
#    u'1168',
#    u'2238',
#    u'1577',
#    u'1840',
#    u'3043',
#    u'2879',
#    u'3617',
#    u'1795',
#    u'5723',
#    u'4951']],
#  [u'windows-installer', [u'4361', u'1011']],
#  [u'windows-mobile', [u'10428']],
#  [u'windows-phone', [u'12822', u'10428', u'5421', u'6495', u'2636']],
#  [u'windows10',
#   [u'5847',
#    u'13538',
#    u'12640',
#    u'638',
#    u'4723',
#    u'3562',
#    u'3170',
#    u'2247',
#    u'398']],
#  [u'wireshark', [u'4271']],
#  [u'wolfram-mathematica', [u'1623']],
#  [u'wollok', [u'3899']],
#  [u'woocommerce', [u'6974']],
#  [u'wordpress',
#   [u'12625',
#    u'13240',
#    u'10388',
#    u'2832',
#    u'2162',
#    u'4878',
#    u'13192',
#    u'10086',
#    u'7424',
#    u'9974',
#    u'7478',
#    u'10365',
#    u'9761',
#    u'9099',
#    u'10886',
#    u'9254',
#    u'9237',
#    u'5271',
#    u'9100',
#    u'6974',
#    u'9470',
#    u'4192',
#    u'5877',
#    u'6554',
#    u'6497',
#    u'7013',
#    u'8795',
#    u'2768',
#    u'1389',
#    u'533',
#    u'3331',
#    u'3162',
#    u'4421',
#    u'4388',
#    u'4754',
#    u'3527',
#    u'5876',
#    u'3248',
#    u'5248',
#    u'6394',
#    u'5438',
#    u'517',
#    u'5240',
#    u'5593']],
#  [u'wordpress-theme', [u'9099']],
#  [u'wp-query', [u'2162']],
#  [u'wpf',
#   [u'13432',
#    u'92',
#    u'2123',
#    u'2238',
#    u'2408',
#    u'4208',
#    u'3945',
#    u'3682',
#    u'1962',
#    u'5655',
#    u'5852',
#    u'6167',
#    u'5259',
#    u'4083',
#    u'6589',
#    u'9573',
#    u'9883',
#    u'10291',
#    u'5729',
#    u'12640']],
#  [u'wso2', [u'6845', u'4068']],
#  [u'x86', [u'6550']],
#  [u'xamarin',
#   [u'13571',
#    u'6613',
#    u'5259',
#    u'6266',
#    u'6155',
#    u'2766',
#    u'731',
#    u'5899',
#    u'3544',
#    u'4810']],
#  [u'xamarin.forms', [u'11203', u'6515', u'731']],
#  [u'xaml',
#   [u'12822',
#    u'5729',
#    u'2123',
#    u'9883',
#    u'92',
#    u'2596',
#    u'2230',
#    u'2238',
#    u'3053',
#    u'2408',
#    u'195',
#    u'4598',
#    u'3945',
#    u'1962',
#    u'6167',
#    u'6495']],
#  [u'xampp',
#   [u'13725',
#    u'9179',
#    u'1592',
#    u'7615',
#    u'7142',
#    u'5593',
#    u'5161',
#    u'4316',
#    u'6178',
#    u'4846']],
#  [u'xcode',
#   [u'6560',
#    u'13730',
#    u'4265',
#    u'10870',
#    u'9099',
#    u'9958',
#    u'9487',
#    u'1281',
#    u'7615',
#    u'3022',
#    u'7254',
#    u'2472',
#    u'233',
#    u'37',
#    u'1499',
#    u'1527',
#    u'2282',
#    u'2837',
#    u'4264',
#    u'3280',
#    u'4880',
#    u'4798',
#    u'575',
#    u'2909',
#    u'5838',
#    u'2878',
#    u'7542']],
#  [u'xhtml', [u'13696', u'10360', u'10452', u'120']],
#  [u'xlrd', [u'6388']],
#  [u'xml',
#   [u'13178',
#    u'12510',
#    u'13560',
#    u'250',
#    u'2676',
#    u'4878',
#    u'2670',
#    u'6353',
#    u'3203',
#    u'4584',
#    u'6044',
#    u'1812',
#    u'10600',
#    u'4456',
#    u'3533',
#    u'9331',
#    u'8855',
#    u'6467',
#    u'9054',
#    u'7132',
#    u'9476',
#    u'9516',
#    u'5219',
#    u'6983',
#    u'4874',
#    u'7621',
#    u'5997',
#    u'127',
#    u'2766',
#    u'1914',
#    u'1839',
#    u'2059',
#    u'1776',
#    u'2911',
#    u'1505',
#    u'1360',
#    u'25',
#    u'2019',
#    u'3834',
#    u'1092',
#    u'3170',
#    u'4654',
#    u'5703',
#    u'6291',
#    u'2539',
#    u'4142']],
#  [u'xpath', [u'7423', u'3834', u'729']],
#  [u'xstream', [u'3217']],
#  [u'yield', [u'187', u'74']],
#  [u'yii', [u'5049', u'1365', u'1076']],
#  [u'yii2', [u'13267', u'7437', u'4053', u'3205', u'2158', u'1055', u'729']],
#  [u'yiibooster', [u'1076']],
#  [u'youtube', [u'13425', u'11313', u'12550', u'6365', u'238']],
#  [u'zend', [u'1281', u'4775', u'9490', u'6594', u'4984']],
#  [u'zepto', [u'2367']],
#  [u'zip', [u'1092', u'4388', u'166']],
#  [u'zoom', [u'13726', u'2659']],
#  [u'zsh', [u'371', u'83']],
#  [u'\xe1lgebra-relacional', [u'2633']],
#  [u'\xe1rboles', [u'2974']],
#  [u'\xe1rboles-binarios', [u'2974']]]

# %% [markdown]
# El mismo `MATCH` se puede usar para encontrar qué conjunto de tags ha usado cada usuario cambiando lo que retornamos:

# %%
# %%cypher
# MATCH (t:Tag)-->(:Question)<--(u:User) RETURN u.Id,collect(distinct t.name) ORDER BY toInt(u.Id);
# Out:
# 2601 rows affected.
# [[u'20', [u'typescript']],
#  [u'21',
#   [u'delphi',
#    u'string',
#    u'casting',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'socket',
#    u'tcpip',
#    u'tcp',
#    u'mysql',
#    u'datetime',
#    u'timestamp',
#    u'sql',
#    u'inner-join',
#    u'join',
#    u'oracle',
#    u'oracle-10g',
#    u'poo',
#    u'windows',
#    u'split',
#    u'sobrecarga',
#    u'pascal',
#    u'impresi\xf3n',
#    u'lenguaje-compilado']],
#  [u'22',
#   [u'array',
#    u'perl',
#    u'javascript',
#    u'jquery',
#    u'git',
#    u'nodejs',
#    u'sandbox',
#    u'seguridad',
#    u'tipos',
#    u'booleano',
#    u'pouchdb',
#    u'go',
#    u'conversi\xf3n-de-tipos',
#    u'eventos',
#    u'errores']],
#  [u'23',
#   [u'.net',
#    u'asp.net-web-api',
#    u'asp.net',
#    u'google-maps',
#    u'angularjs',
#    u'jasmine',
#    u'karma-jasmine',
#    u'javascript',
#    u'momentjs',
#    u'git',
#    u'ajax',
#    u'c#',
#    u'mercurial']],
#  [u'24',
#   [u'c++',
#    u'string',
#    u'casting',
#    u'android',
#    u'c++11',
#    u'java',
#    u'c',
#    u'android-studio',
#    u'gradle',
#    u'angularjs-2.0',
#    u'angular2-template']],
#  [u'25',
#   [u'c++',
#    u'array',
#    u'javascript',
#    u'c++11',
#    u'java',
#    u'git',
#    u'c#',
#    u'nodejs',
#    u'xml',
#    u'licencias',
#    u'c\xf3digo-abierto',
#    u'visual-studio-2015',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'groovy']],
#  [u'27', [u'javascript', u'android', u'reactjs', u'react-native']],
#  [u'29', [u'rails', u'ruby', u'vistas', u'api', u'http', u'post']],
#  [u'34', [u'rails', u'html', u'css']],
#  [u'35', [u'asp.net', u'javascript', u'bower', u'kendoui', u'knockoutjs']],
#  [u'37', [u'ios', u'xcode', u'lista', u'elixir']],
#  [u'65',
#   [u'array',
#    u'javascript',
#    u'google-apps-script',
#    u'css',
#    u'regex',
#    u'optimizaci\xf3n',
#    u'google-hoja-de-calculo',
#    u'google-forms',
#    u'bookmarklet',
#    u'gmail',
#    u'google-drive',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'formulas']],
#  [u'73',
#   [u'javascript',
#    u'laravel',
#    u'php',
#    u'ajax',
#    u'html',
#    u'css',
#    u'html5',
#    u'condiciones',
#    u'revisi\xf3n-de-c\xf3digo']],
#  [u'74', [u'array', u'python', u'numpy', u'yield']],
#  [u'75',
#   [u'ruby',
#    u'git',
#    u'control-de-versiones',
#    u'reactjs',
#    u'conflictos',
#    u'bundler',
#    u'gemfile']],
#  [u'77', [u'sql', u'sql-server']],
#  [u'78',
#   [u'asp.net',
#    u'javascript',
#    u'sql',
#    u'html',
#    u'c#',
#    u'windows-forms',
#    u'sharepoint',
#    u'sharepoint-online',
#    u'excel',
#    u'windows',
#    u'ms-access-2010',
#    u'datatables',
#    u'consola',
#    u'jquery-datepicker',
#    u'visual-basic-6',
#    u'regsvr32']],
#  [u'83',
#   [u'bash',
#    u'archivo',
#    u'git',
#    u'linux',
#    u'shell',
#    u'sed',
#    u'awk',
#    u'git-commit',
#    u'zsh',
#    u'unix',
#    u'grep',
#    u'ascii']],
#  [u'90', [u'mysql', u'sql']],
#  [u'92', [u'c#', u'wpf', u'xaml', u'reflexi\xf3n']],
#  [u'93',
#   [u'javascript', u'java', u'css', u'eclipse', u'visual-studio', u'swt']],
#  [u'95',
#   [u'javascript',
#    u'android',
#    u'java',
#    u'google-newsstand-producer',
#    u'rss',
#    u'objective-c',
#    u'swift',
#    u'uiwebview',
#    u'dialogo',
#    u'android-glide']],
#  [u'100',
#   [u'string',
#    u'array',
#    u'lista',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'mysql',
#    u'datetime',
#    u'bash',
#    u'archivo',
#    u'python',
#    u'linux',
#    u'validaci\xf3n',
#    u'funciones',
#    u'django',
#    u'mercurial',
#    u'control-de-versiones',
#    u'pip',
#    u'ubuntu',
#    u'python-2.7',
#    u'formularios',
#    u'html5',
#    u'python-3.x',
#    u'cordova',
#    u'pdf',
#    u'reportlab',
#    u'excepciones',
#    u'base-de-datos',
#    u'clase',
#    u'm\xe9todo',
#    u'haskell',
#    u'asincronismo',
#    u'nginx',
#    u'logrotate',
#    u'configuraci\xf3n',
#    u'ionic',
#    u'celery',
#    u'parse.com',
#    u'highcharts',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'lua']],
#  [u'120',
#   [u'javascript',
#    u'sql',
#    u'html',
#    u'c#',
#    u'sql-server',
#    u'ssis',
#    u'ms-access-2010',
#    u'xhtml',
#    u'ftp',
#    u'as400']],
#  [u'127',
#   [u'array',
#    u'javascript',
#    u'php',
#    u'regex',
#    u'email',
#    u'validaci\xf3n',
#    u'xml',
#    u'codificaci\xf3n',
#    u'utf-8']],
#  [u'132',
#   [u'array',
#    u'javascript',
#    u'jquery',
#    u'timestamp',
#    u'php',
#    u'dom',
#    u'object']],
#  [u'143', [u'java', u'json', u'gson']],
#  [u'149',
#   [u'c++',
#    u'string',
#    u'array',
#    u'javascript',
#    u'c#',
#    u'rendimiento',
#    u'nodejs',
#    u'c']],
#  [u'154',
#   [u'angularjs',
#    u'typescript',
#    u'javascript',
#    u'jquery',
#    u'git',
#    u'laravel',
#    u'php',
#    u'windows',
#    u'bootstrap',
#    u'angular-directivas',
#    u'angularjs-2.0',
#    u'angularjs-injector',
#    u'laravel-4']],
#  [u'160', [u'ios', u'formularios', u'objective-c']],
#  [u'166',
#   [u'jquery',
#    u'python',
#    u'php',
#    u'html',
#    u'matem\xe1ticas',
#    u'python-2.7',
#    u'algoritmos',
#    u'json',
#    u'seguridad',
#    u'apache',
#    u'highcharts',
#    u'.htaccess',
#    u'zip']],
#  [u'167', [u'java', u'java-ee', u'ide']],
#  [u'184', [u'javascript', u'nodejs', u'npm']],
#  [u'187',
#   [u'javascript',
#    u'mysql',
#    u'bash',
#    u'java',
#    u'spring',
#    u'hibernate',
#    u'python',
#    u'linux',
#    u'constructor',
#    u'clase-abstracta',
#    u'orientaci\xf3n-a-objetos',
#    u'nodejs',
#    u'json',
#    u'c',
#    u'manejo-de-memoria',
#    u'mongodb',
#    u'hilos',
#    u'depurar',
#    u'unix',
#    u'nosql',
#    u'yield',
#    u'generator',
#    u'coroutine']],
#  [u'191',
#   [u'angularjs',
#    u'android',
#    u'mysql',
#    u'java',
#    u'spring',
#    u'json',
#    u'android-studio',
#    u'materialize',
#    u'reflection',
#    u'recyclerview']],
#  [u'195', [u'c#', u'xaml']],
#  [u'198', [u'python', u'pip']],
#  [u'206',
#   [u'android',
#    u'socket',
#    u'java',
#    u'android-intent',
#    u'android-asynctask',
#    u'optimizaci\xf3n',
#    u'android-sqlite',
#    u'android-drawerlayout']],
#  [u'211', [u'asp.net-core', u'json', u'visual-studio']],
#  [u'217', [u'string', u'php', u'str-replace', u'funciones']],
#  [u'218', [u'python', u'variables']],
#  [u'225',
#   [u'asp.net-web-api',
#    u'jquery',
#    u'ajax',
#    u'css',
#    u'c#',
#    u'html5',
#    u'css3',
#    u'asp.net-mvc-5',
#    u'razor',
#    u'bootstrap',
#    u'asp.net-mvc']],
#  [u'227',
#   [u'java',
#    u'spring',
#    u'lenguaje-agn\xf3stico',
#    u'mercurial',
#    u'maven',
#    u'java-ee',
#    u'servlets',
#    u'apache-poi',
#    u'paso-por-valor',
#    u'paso-por-referencia',
#    u'spring-mvc',
#    u'rest',
#    u'subrepositorios',
#    u'vscode',
#    u'cabeceras-http',
#    u'wildfly',
#    u'jmc']],
#  [u'233',
#   [u'ios',
#    u'xcode',
#    u'javascript',
#    u'html',
#    u'objective-c',
#    u'osx',
#    u'midi',
#    u'serializaci\xf3n',
#    u'polymer']],
#  [u'238', [u'jquery', u'html', u'email', u'youtube', u'google-chrome']],
#  [u'239', [u'ios', u'jquery', u'cordova']],
#  [u'241', [u'jquery', u'ajax']],
#  [u'250',
#   [u'ios',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'mysql',
#    u'sql',
#    u'php',
#    u'ajax',
#    u'html',
#    u'css',
#    u'unidades-de-medici\xf3n',
#    u'lenguaje-agn\xf3stico',
#    u'html5',
#    u'css3',
#    u'xml',
#    u'cordova',
#    u'seguridad',
#    u'base-de-datos',
#    u'bootstrap',
#    u'avd',
#    u'eventos',
#    u'd3.js',
#    u'jsp',
#    u'cq5',
#    u'aem',
#    u'promises',
#    u'internacionalizaci\xf3n',
#    u'local-storage',
#    u'svg',
#    u'phonegap',
#    u'inyecci\xf3n-sql',
#    u'css-transform',
#    u'arm',
#    u'intel-atom',
#    u'namespace',
#    u'almacenamiento',
#    u'data-atributos',
#    u'programaci\xf3n-m\xf3vil']],
#  [u'252', [u'clojure']],
#  [u'260', [u'java', u'git', u'commit', u'html', u'css']],
#  [u'261', [u'java', u'try-catch']],
#  [u'264', [u'sql', u'oracle', u'java', u'jvm', u'jdk']],
#  [u'270', [u'ios', u'objective-c', u'swift']],
#  [u'271',
#   [u'mysql',
#    u'java',
#    u'python',
#    u'html',
#    u'linux',
#    u'html5',
#    u'json',
#    u'pdf',
#    u'osx',
#    u'latex',
#    u'r',
#    u'ggplot2',
#    u'debian',
#    u'ntfs',
#    u'swing',
#    u'lyx']],
#  [u'272', [u'javascript', u'nodejs', u'socket.io']],
#  [u'288',
#   [u'perl', u'ordenamiento', u'tipos', u'booleano', u'matrices-asociativas']],
#  [u'292',
#   [u'javascript',
#    u'python',
#    u'nodejs',
#    u'python-3.x',
#    u'mongodb',
#    u'ide',
#    u'sublimetext',
#    u'sublimetext3',
#    u'meteor',
#    u'cuenta-usuario',
#    u'pycharm',
#    u'bottle',
#    u'iron-router',
#    u'indices']],
#  [u'294',
#   [u'angularjs',
#    u'javascript',
#    u'css3',
#    u'ionic',
#    u'sass',
#    u'gulp',
#    u'gulp-sass']],
#  [u'298',
#   [u'.net',
#    u'c#',
#    u'entity-framework',
#    u'asp.net-core',
#    u'model-view-controller']],
#  [u'299',
#   [u'java', u'spring', u'git', u'git-commit', u'inyeccion-de-dependencias']],
#  [u'301',
#   [u'c++',
#    u'string',
#    u'array',
#    u'sql',
#    u'java',
#    u'rendimiento',
#    u'optimizaci\xf3n',
#    u'constructor',
#    u'c',
#    u'punteros',
#    u'clase',
#    u'sqlite3',
#    u'sqlite',
#    u'paso-por-valor',
#    u'paso-por-referencia',
#    u'localizaci\xf3n',
#    u'makefile',
#    u'c++98']],
#  [u'302',
#   [u'python',
#    u'fish',
#    u'pharo',
#    u'smalltalk',
#    u'programaci\xf3n-funcional',
#    u'python-3.x',
#    u'haskell',
#    u'estructuras-de-datos']],
#  [u'305',
#   [u'android',
#    u'java',
#    u'android-layout',
#    u'unidades-de-medici\xf3n',
#    u'android-softkeyboard']],
#  [u'307', [u'dns', u'iana']],
#  [u'325', [u'soap', u'soapui', u'wcf', u'servicio']],
#  [u'342',
#   [u'ruby',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'oracle',
#    u'oracle-10g',
#    u'knockoutjs',
#    u'java',
#    u'git',
#    u'html',
#    u'css',
#    u'regex',
#    u'c#',
#    u'git-commit',
#    u'dukescript',
#    u'admob',
#    u'eclipse',
#    u'depuraci\xf3n',
#    u'jboss',
#    u'html5',
#    u'css3',
#    u'3d',
#    u'importaci\xf3n',
#    u'json',
#    u'netbeans',
#    u'plugin',
#    u'maven',
#    u'hql',
#    u'jpa',
#    u'seam',
#    u'github',
#    u'git-push',
#    u'git-fork',
#    u'i18n',
#    u'windows',
#    u'bootstrap',
#    u'jboss-eap',
#    u'jdbc',
#    u'primefaces',
#    u'sqlfiddle',
#    u'unity3d',
#    u'oracle-11g',
#    u'jsfiddle',
#    u'scss',
#    u'webgl',
#    u'swing',
#    u'plsql',
#    u'sqldeveloper',
#    u'java-9',
#    u'azul-zulu',
#    u'spring-tool-suite',
#    u'jboss-as',
#    u'jboss-cli',
#    u'jboss-as-7',
#    u'rubygems',
#    u'coffeescript',
#    u'primefaces-calendar']],
#  [u'345', [u'sequelize.js']],
#  [u'348', [u'azure']],
#  [u'353',
#   [u'typescript',
#    u'javascript',
#    u'jquery',
#    u'python',
#    u'ajax',
#    u'html',
#    u'css',
#    u'django',
#    u'nodejs',
#    u'python-3.x',
#    u'conda',
#    u'poo',
#    u'windows',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'angularjs-2.0',
#    u'babeljs',
#    u'material-design-lite',
#    u'pyqt',
#    u'electron']],
#  [u'360',
#   [u'laravel',
#    u'php',
#    u'linux',
#    u'doctrine',
#    u'doctrine2',
#    u'laravel-5',
#    u'windows',
#    u'apache']],
#  [u'366', [u'javascript']],
#  [u'371',
#   [u'sql',
#    u'java',
#    u'python',
#    u'ajax',
#    u'zsh',
#    u'django',
#    u'select2',
#    u'python-3.x',
#    u'reportlab',
#    u'windows',
#    u'django-models',
#    u'postgresql',
#    u'bootstrap',
#    u'debian',
#    u'apache',
#    u'django-forms']],
#  [u'376', [u'c#', u'asp.net-mvc']],
#  [u'389', [u'python', u'verilog', u'punteros', u'im\xe1genes']],
#  [u'398',
#   [u'git',
#    u'nodejs',
#    u'azure',
#    u'visual-studio',
#    u'directorioactivo',
#    u'windows',
#    u'visual-studio-2015',
#    u'windows10',
#    u'registro-windows']],
#  [u'399',
#   [u'javascript',
#    u'mysql',
#    u'http',
#    u'bash',
#    u'git',
#    u'regex',
#    u'vagrant',
#    u'puppet',
#    u'nodejs',
#    u'go',
#    u'makefile',
#    u'ecmascript-2015',
#    u'docker']],
#  [u'400',
#   [u'javascript',
#    u'jquery',
#    u'java',
#    u'spring',
#    u'eclipse',
#    u'thymeleaf',
#    u'json',
#    u'maven',
#    u'jpa',
#    u'asincr\xf3nico',
#    u'spring-mvc',
#    u'alfresco']],
#  [u'403', [u'ios', u'objective-c']],
#  [u'407', [u'c++', u'lista']],
#  [u'416',
#   [u'javascript',
#    u'matem\xe1ticas',
#    u'coma-flotante',
#    u'lenguaje-agn\xf3stico']],
#  [u'417',
#   [u'javascript',
#    u'jquery',
#    u'java',
#    u'git',
#    u'html',
#    u'linux',
#    u'regex',
#    u'soap',
#    u'html5',
#    u'struts',
#    u'base-de-datos',
#    u'm\xe9todo',
#    u'spring-webflow',
#    u'tinymce',
#    u'boxing',
#    u'sobrecarga']],
#  [u'430',
#   [u'angularjs',
#    u'javascript',
#    u'nodejs',
#    u'ember.js',
#    u'hapijs',
#    u'constantes',
#    u'pm2',
#    u'slack-api']],
#  [u'458', [u'java', u'drools', u'rabbit-mq']],
#  [u'463', [u'.net', u'c++', u'c++11', u'c#', u'qt']],
#  [u'514', [u'mysql', u'java', u'genexus']],
#  [u'517',
#   [u'string',
#    u'google-maps',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'datetime',
#    u'java',
#    u'html',
#    u'css',
#    u'regex',
#    u'eclipse',
#    u'lenguaje-agn\xf3stico',
#    u'comparaciones',
#    u'html5',
#    u'importaci\xf3n',
#    u'algoritmos',
#    u'loops',
#    u'condiciones',
#    u'pattern',
#    u'servlets',
#    u'base-de-datos',
#    u'hilos',
#    u'i18n',
#    u'wordpress',
#    u'java-8',
#    u'java-stream',
#    u'bigdecimal',
#    u'redondeo',
#    u'double',
#    u'thread',
#    u'localizaci\xf3n',
#    u'constantes',
#    u'apache',
#    u'.htaccess',
#    u'redirecci\xf3n',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'swing',
#    u'jsp',
#    u'internacionalizaci\xf3n',
#    u'fecha',
#    u'eficiencia',
#    u'anotaciones',
#    u'tomcat',
#    u'combobox',
#    u'db2',
#    u'oracle-sqldeveloper',
#    u'volatile',
#    u'infobox']],
#  [u'529',
#   [u'javascript', u'python', u'nodejs', u'json', u'tweepy', u'twitter-api']],
#  [u'531',
#   [u'.net',
#    u'c#',
#    u'entity-framework',
#    u'windows-forms',
#    u'sql-server',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'drag-and-drop',
#    u'agarrar-y-soltar',
#    u'irc']],
#  [u'533', [u'asp.net', u'c#', u'sql-server', u'plugin', u'wordpress']],
#  [u'534', [u'c#', u'asp.net-mvc']],
#  [u'535',
#   [u'android',
#    u'python',
#    u'android-layout',
#    u'django',
#    u'ordenamiento',
#    u'json',
#    u'base-de-datos',
#    u'android-studio',
#    u'android-drawerlayout']],
#  [u'546', [u'android', u'java', u'android-auto']],
#  [u'547',
#   [u'.net',
#    u'asp.net-web-api',
#    u'javascript',
#    u'c#',
#    u'nodejs',
#    u'npm',
#    u'sharepoint',
#    u'signalr',
#    u'real-time',
#    u'datatables',
#    u'powershell']],
#  [u'555', [u'git']],
#  [u'561', [u'python', u'django', u'postgresql']],
#  [u'575', [u'ios', u'xcode', u'uiwebview']],
#  [u'608',
#   [u'android',
#    u'java',
#    u'hibernate',
#    u'mongodb',
#    u'navigationview',
#    u'jersey',
#    u'atmosphere',
#    u'swagger',
#    u'facebook',
#    u'jsf',
#    u'primefaces',
#    u'gradle',
#    u'intellij',
#    u'javadoc',
#    u'wasync',
#    u'oauth2',
#    u'hibernate-formula',
#    u'tomcat',
#    u'cucumber',
#    u'jersey2']],
#  [u'629',
#   [u'typescript',
#    u'javascript',
#    u'jquery',
#    u'ajax',
#    u'c#',
#    u'aurelia.io',
#    u'select2',
#    u'asp.net-mvc-5',
#    u'asp.net-mvc']],
#  [u'630',
#   [u'programaci\xf3n-funcional',
#    u'python-3.x',
#    u'tipos',
#    u'conda',
#    u'haskell',
#    u'windows',
#    u'scala',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'rust',
#    u'factorial']],
#  [u'631', [u'rails', u'ubuntu', u'nodejs', u'ec2', u'npm', u'rspec']],
#  [u'632', [u'archivo', u'linux', u'rsync', u'perl6']],
#  [u'636',
#   [u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'datetime',
#    u'momentjs',
#    u'underscorejs',
#    u'firebase']],
#  [u'638',
#   [u'angularjs',
#    u'javascript',
#    u'python',
#    u'git',
#    u'django',
#    u'mongodb',
#    u'djangorestframework',
#    u'powershell',
#    u'gulp',
#    u'windows10',
#    u'rest',
#    u'staticfiles',
#    u'mongoose',
#    u'ngroute',
#    u'ngresource',
#    u'restful',
#    u'ui.router',
#    u'node']],
#  [u'659', [u'php', u'poo']],
#  [u'660', [u'javascript', u'jquery', u'mysql', u'sql', u'php', u'css']],
#  [u'676', [u'mysql', u'c#', u'genexus']],
#  [u'701', [u'spring', u'spring-roo', u'gvnix']],
#  [u'717', [u'directorioactivo', u'office365', u'smartcard', u'adfs']],
#  [u'722', [u'genexus', u'devices']],
#  [u'724', [u'genexus']],
#  [u'725', [u'genexus']],
#  [u'728', [u'genexus']],
#  [u'729',
#   [u'google-maps',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'bash',
#    u'git',
#    u'php',
#    u'html',
#    u'css',
#    u'linux',
#    u'regex',
#    u'orientaci\xf3n-a-objetos',
#    u'yii2',
#    u'xpath',
#    u'magento2',
#    u'joomla3',
#    u'ecmascript-2015',
#    u'gpg',
#    u'magento-1.9']],
#  [u'731',
#   [u'javascript',
#    u'jquery',
#    u'android',
#    u'json',
#    u'xamarin',
#    u'xamarin.forms']],
#  [u'745', [u'.net', u'regex', u'vb.net']],
#  [u'749', [u'excel', u'vba']],
#  [u'783', [u'python', u'pip', u'pillow']],
#  [u'786', [u'javascript', u'jquery']],
#  [u'801',
#   [u'javascript',
#    u'jquery',
#    u'python',
#    u'html',
#    u'css',
#    u'django',
#    u'formularios',
#    u'python-3.x',
#    u'mongodb',
#    u'matplotlib',
#    u'pyqt5',
#    u'embebido',
#    u'postgresql',
#    u'meteor',
#    u'cuenta-usuario',
#    u'scss',
#    u'sass',
#    u'webpack',
#    u'django-admin',
#    u'wagtail',
#    u'csv',
#    u'searchview']],
#  [u'807', [u'javascript', u'jquery', u'php', u'ajax']],
#  [u'813', [u'vpn', u'windows']],
#  [u'816', [u'java', u'python', u'django', u'django-models']],
#  [u'822',
#   [u'javascript',
#    u'linux',
#    u'c#',
#    u'asp.net-core',
#    u'html5',
#    u'css3',
#    u'reactjs',
#    u'bootstrap',
#    u'apache']],
#  [u'846', [u'android', u'java', u'bitmap']],
#  [u'866', [u'google-app-engine', u'oauth2']],
#  [u'870',
#   [u'api',
#    u'python',
#    u'linux',
#    u'python-2.7',
#    u'unix',
#    u'osx',
#    u'thread',
#    u'google-chrome',
#    u'google-app-engine',
#    u'python-2.x',
#    u'brew']],
#  [u'872', [u'javascript', u'api', u'map']],
#  [u'883', [u'android', u'firebase']],
#  [u'901', [u'api', u'python', u'django', u'djangorestframework', u'permisos']],
#  [u'908', [u'python', u'python-2.7', u'web2py', u'highcharts', u'date']],
#  [u'921', [u'.net', u'entity-framework']],
#  [u'965', [u'ios', u'javascript', u'objective-c', u'uiwebview', u'ios8']],
#  [u'1005',
#   [u'python',
#    u'git',
#    u'c#',
#    u'django',
#    u'ec2',
#    u'python-3.x',
#    u'json',
#    u'djangorestframework',
#    u'base-de-datos',
#    u'django-models',
#    u'users-roles',
#    u'unity3d',
#    u'deployment',
#    u'django-admin',
#    u'django-forms',
#    u'rest',
#    u'serializaci\xf3n',
#    u'django-smart-selects',
#    u'heroku']],
#  [u'1007', [u'mysql', u'phpmyadmin']],
#  [u'1011', [u'windows-installer']],
#  [u'1012', [u'asp.net-mvc-5']],
#  [u'1037', [u'vistas', u'javascript', u'html', u'backbone']],
#  [u'1039', [u'angularjs', u'c#', u'nodejs', u'pdf']],
#  [u'1055', [u'php', u'yii2', u'i18n']],
#  [u'1076', [u'select2', u'yii', u'yiibooster', u'cache']],
#  [u'1092',
#   [u'asp.net-web-api',
#    u'asp.net',
#    u'string',
#    u'casting',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'api',
#    u'archivo',
#    u'c#',
#    u'funciones',
#    u'windows-forms',
#    u'xml',
#    u'loops',
#    u'condiciones',
#    u'sql-server',
#    u'pdf',
#    u'visual-studio',
#    u'directorioactivo',
#    u'ssis',
#    u'm\xe9todo',
#    u'configuraci\xf3n',
#    u'datatables',
#    u'linq',
#    u'iis',
#    u'aplicaci\xf3n-web',
#    u'zip',
#    u'stored-procedure',
#    u'csv',
#    u'webservice']],
#  [u'1098', [u'jquery', u'mysql', u'php', u'abap']],
#  [u'1111', [u'java', u'python', u'hashmap']],
#  [u'1119', [u'windows']],
#  [u'1136', [u'java']],
#  [u'1145', [u'python', u'regex']],
#  [u'1147', [u'ios', u'swift', u'json', u'swift2']],
#  [u'1155', [u'genexus']],
#  [u'1166', [u'javascript', u'html', u'aplicaci\xf3n-web', u'pagejs', u'jade']],
#  [u'1168',
#   [u'.net',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'ajax',
#    u'html',
#    u'css',
#    u'c#',
#    u'entity-framework',
#    u'windows-forms',
#    u'vb.net',
#    u'asp.net-mvc-5',
#    u'razor',
#    u'linq']],
#  [u'1171', [u'git', u'c#', u'asp.net-core', u'github']],
#  [u'1173', [u'javascript', u'html5', u'indexeddb']],
#  [u'1175', [u'asp.net-web-api', u'asp.net', u'c#']],
#  [u'1184',
#   [u'delphi',
#    u'mysql',
#    u'sql',
#    u'oracle',
#    u'archivo',
#    u'regex',
#    u'sql-server',
#    u'google-hoja-de-calculo',
#    u'windows',
#    u'consola',
#    u'proceso',
#    u'sqlfiddle',
#    u'oracle-11g',
#    u'sqldeveloper',
#    u'delphi-2010',
#    u'dbexpress']],
#  [u'1188',
#   [u'asp.net-web-api',
#    u'html',
#    u'css',
#    u'c#',
#    u'html5',
#    u'css3',
#    u'automapper']],
#  [u'1201', [u'licencias', u'genexus']],
#  [u'1203', [u'sql-server', u'asp.net-mvc-5']],
#  [u'1204',
#   [u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'sql',
#    u'oracle',
#    u'bash',
#    u'java',
#    u'html',
#    u'json',
#    u'jpa',
#    u'jersey',
#    u'postgresql',
#    u'backbone',
#    u'underscorejs',
#    u'jsf',
#    u'gulp',
#    u'plsql',
#    u'jsp',
#    u'ejb',
#    u'glassfish']],
#  [u'1262', [u'python', u'soap']],
#  [u'1270', [u'django', u'python-3.x', u'django-models']],
#  [u'1274',
#   [u'python',
#    u'django',
#    u'python-2.7',
#    u'html5',
#    u'css3',
#    u'django-models',
#    u'bootstrap',
#    u'django-admin']],
#  [u'1281',
#   [u'ios', u'xcode', u'git', u'swift', u'swift2', u'spritekit', u'zend']],
#  [u'1303', [u'linux', u'vpn']],
#  [u'1308', [u'mysql', u'php', u'pdo']],
#  [u'1330', [u'angularjs', u'karma-jasmine', u'nodejs']],
#  [u'1338', [u'asp.net', u'c#', u'azure']],
#  [u'1349', [u'java', u'java-ee', u'aplicaci\xf3n-web']],
#  [u'1360',
#   [u'javascript',
#    u'css',
#    u'regex',
#    u'funciones',
#    u'formularios',
#    u'xml',
#    u'pdf',
#    u'bootstrap',
#    u'jspdf',
#    u'openlayers',
#    u'openlayers-3']],
#  [u'1365', [u'laravel', u'php', u'laravel-5', u'sql-server', u'yii', u'iis']],
#  [u'1368', [u'python', u'google-datastore', u'google-app-engine']],
#  [u'1389',
#   [u'javascript',
#    u'mysql',
#    u'php',
#    u'html5',
#    u'css3',
#    u'wordpress',
#    u'bootstrap',
#    u'codeigniter']],
#  [u'1390', [u'oracle', u'oracle-10g', u'formularios']],
#  [u'1399',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'funciones',
#    u'base-de-datos',
#    u'vb.net',
#    u'ms-access-2010',
#    u'visual-studio-2010',
#    u'jquery-tooltip']],
#  [u'1401',
#   [u'windows-forms',
#    u'netbeans',
#    u'github',
#    u'phpmyadmin',
#    u'vb.net',
#    u'binding']],
#  [u'1407', [u'angularjs', u'javascript']],
#  [u'1415', [u'android', u'corona']],
#  [u'1427', [u'laravel', u'php', u'laravel-5']],
#  [u'1466',
#   [u'javascript',
#    u'jquery',
#    u'sql',
#    u'ajax',
#    u'html',
#    u'c#',
#    u'sql-server',
#    u'postgresql',
#    u'asp.net-mvc',
#    u'stored-procedure']],
#  [u'1481', [u'bash', u'linux']],
#  [u'1482', [u'.net', u'asp.net', u'c#', u'azure', u'azure-storage']],
#  [u'1494',
#   [u'c#',
#    u'entity-framework',
#    u'azure',
#    u'asp.net-mvc-5',
#    u'asp.net-mvc',
#    u'linq',
#    u'azure-redis',
#    u'revisi\xf3n-de-c\xf3digo']],
#  [u'1499', [u'ios', u'xcode', u'objective-c', u'swift2']],
#  [u'1505',
#   [u'angularjs',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'java',
#    u'spring',
#    u'git',
#    u'validaci\xf3n',
#    u'optimizaci\xf3n',
#    u'xml',
#    u'json',
#    u'excepciones',
#    u'mongodb',
#    u'spring-mvc',
#    u'conflictos',
#    u'test-ng',
#    u'map',
#    u'promesas',
#    u'enum',
#    u'microservicios',
#    u'set',
#    u'response']],
#  [u'1507', [u'php', u'optimizaci\xf3n', u'poo']],
#  [u'1513', [u'ios', u'swift', u'swift2']],
#  [u'1527',
#   [u'ios',
#    u'xcode',
#    u'python',
#    u'python-2.7',
#    u'swift',
#    u'python-3.x',
#    u'ios8',
#    u'swift2',
#    u'tkinter',
#    u'pyinstaller',
#    u'python-2.x']],
#  [u'1543', [u'r', u'rodbc']],
#  [u'1545', [u'php', u'laravel-5']],
#  [u'1547', [u'javascript']],
#  [u'1548', [u'java']],
#  [u'1555', [u'oracle', u'java', u'base64']],
#  [u'1575',
#   [u'bash',
#    u'python',
#    u'html',
#    u'css',
#    u'linux',
#    u'django',
#    u'python-2.7',
#    u'mongodb',
#    u'bootstrap',
#    u'ensamblador',
#    u'masm',
#    u'agregaci\xf3n']],
#  [u'1577', [u'c#', u'windows-forms']],
#  [u'1583', [u'javascript', u'facebook', u'internet-explorer-11']],
#  [u'1592',
#   [u'android', u'mysql', u'java', u'laravel-5', u'ubuntu', u'avd', u'xampp']],
#  [u'1596', [u'django', u'python-2.7', u'utf-8']],
#  [u'1599', [u'mysql', u'php', u'css', u'servidores']],
#  [u'1609', [u'azure', u'azure-sql']],
#  [u'1610', [u'angularjs', u'rails', u'ruby']],
#  [u'1612', [u'laravel', u'php']],
#  [u'1623', [u'wolfram-mathematica']],
#  [u'1631', [u'jquery', u'mysql', u'php', u'base-de-datos', u'indices']],
#  [u'1641', [u'go']],
#  [u'1654', [u'angularjs', u'javascript', u'java', u'nodejs', u'consola']],
#  [u'1666', [u'cordova', u'apache']],
#  [u'1687', [u'java', u'firebird']],
#  [u'1719', [u'oracle', u'sql-server', u'plsql']],
#  [u'1721', [u'aplicaci\xf3n-web', u'foundation']],
#  [u'1725', [u'mongodb', u'nosql']],
#  [u'1733', [u'java', u'java-ee', u'jsf']],
#  [u'1746', [u'mysql', u'php', u'laravel-5', u'mysqli', u'.htaccess']],
#  [u'1776', [u'xml', u'base-de-datos']],
#  [u'1784', [u'ios', u'swift2']],
#  [u'1788', [u'javascript', u'html']],
#  [u'1792',
#   [u'python',
#    u'django',
#    u'python-3.x',
#    u'djangorestframework',
#    u'tkinter',
#    u'encriptacion']],
#  [u'1795',
#   [u'sql',
#    u'kendoui',
#    u'c#',
#    u'entity-framework',
#    u'windows-forms',
#    u'sql-server',
#    u'asp.net-mvc']],
#  [u'1798', [u'git']],
#  [u'1805',
#   [u'ajax',
#    u'c#',
#    u'asp.net-mvc',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'arquitectura',
#    u'orm',
#    u'dapper']],
#  [u'1809', [u'java', u'excel', u'apache-poi']],
#  [u'1812', [u'php', u'xml', u'ftp', u'parsear']],
#  [u'1827', [u'javascript', u'html5', u'bootstrap']],
#  [u'1839',
#   [u'asp.net',
#    u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'validaci\xf3n',
#    u'c#',
#    u'xml',
#    u'json',
#    u'visual-studio',
#    u'excepciones',
#    u'vb.net',
#    u'windows',
#    u'razor',
#    u'nuget',
#    u'iis',
#    u'sailsjs',
#    u'facebook-api']],
#  [u'1840', [u'c#', u'windows-forms']],
#  [u'1841', [u'javascript', u'jquery', u'ajax', u'datatables']],
#  [u'1859', [u'tsql']],
#  [u'1870', [u'android', u'java', u'android-layout']],
#  [u'1881', [u'swift']],
#  [u'1905', [u'ssms']],
#  [u'1913', [u'json', u'swift2']],
#  [u'1914',
#   [u'android',
#    u'sql',
#    u'java',
#    u'git',
#    u'php',
#    u'html',
#    u'xml',
#    u'sql-server',
#    u'gradle',
#    u'prestashop',
#    u'cms']],
#  [u'1940', [u'android', u'android-studio']],
#  [u'1941', [u'c#', u'ofuscacion']],
#  [u'1943',
#   [u'android',
#    u'socket',
#    u'tcpip',
#    u'tcp',
#    u'java',
#    u'git',
#    u'git-commit',
#    u'admob',
#    u'thread',
#    u'multitasking',
#    u'websocket']],
#  [u'1947', [u'javascript', u'jquery', u'api', u'google-drive']],
#  [u'1948', [u'jsf', u'primefaces']],
#  [u'1958', [u'array', u'android', u'java', u'json', u'excepciones']],
#  [u'1960', [u'doctrine', u'doctrine2']],
#  [u'1962', [u'.net', u'c#', u'wpf', u'xaml', u'mvvm']],
#  [u'1964', [u'angularjs', u'javascript', u'nodejs', u'mongodb']],
#  [u'1965',
#   [u'lista',
#    u'bash',
#    u'python',
#    u'shell',
#    u'python-2.7',
#    u'mongodb',
#    u'twitter-api']],
#  [u'1972', [u'java', u'hibernate', u'sqlite3', u'sqlite']],
#  [u'1996', [u'angularjs']],
#  [u'1997', [u'c++']],
#  [u'2000', [u'linux']],
#  [u'2004',
#   [u'.net',
#    u'string',
#    u'google-maps',
#    u'javascript',
#    u'java',
#    u'spring',
#    u'hibernate',
#    u'python',
#    u'git',
#    u'html',
#    u'c#',
#    u'git-commit',
#    u'matem\xe1ticas',
#    u'control-de-versiones',
#    u'ubuntu',
#    u'json',
#    u'maven',
#    u'jpa',
#    u'git-push',
#    u'google-chrome',
#    u'spring-mvc',
#    u'oauth',
#    u'google-datastore',
#    u'google-app-engine',
#    u'objectify',
#    u'subversion',
#    u'svn']],
#  [u'2013',
#   [u'git', u'linux', u'c', u'github', u'git-push', u'git-fork', u'grep']],
#  [u'2019',
#   [u'oracle',
#    u'java',
#    u'python',
#    u'linux',
#    u'c#',
#    u'xml',
#    u'netbeans',
#    u'postgresql',
#    u'datatables',
#    u'profiler']],
#  [u'2027',
#   [u'javascript',
#    u'jquery',
#    u'java',
#    u'git',
#    u'c#',
#    u'tipos',
#    u'conversi\xf3n-de-tipos',
#    u'jquery-datepicker']],
#  [u'2034', [u'android', u'java']],
#  [u'2036', [u'java', u'c#', u'asp.net-mvc-5']],
#  [u'2041', [u'javascript', u'android', u'ajax', u'cordova', u'jquery-mobile']],
#  [u'2059', [u'python', u'xml']],
#  [u'2074', [u'android', u'android-studio', u'gradle']],
#  [u'2087', [u'laravel']],
#  [u'2113', [u'javascript']],
#  [u'2114', [u'javascript', u'jquery', u'knockoutjs']],
#  [u'2122', [u'python', u'python-3.x', u'tkinter']],
#  [u'2123', [u'c#', u'wpf', u'xaml', u'uwp', u'mvvm']],
#  [u'2133',
#   [u'c++',
#    u'php',
#    u'linux',
#    u'nodejs',
#    u'mongodb',
#    u'nosql',
#    u'reactjs',
#    u'express']],
#  [u'2134',
#   [u'mysql', u'sql', u'java', u'funciones', u'base-de-datos', u'postgresql']],
#  [u'2136', [u'angularjs', u'http', u'post', u'json']],
#  [u'2137', [u'swift2', u'datatables']],
#  [u'2152', [u'bash', u'archivo', u'python', u'python-2.7']],
#  [u'2156', [u'javascript', u'jquery']],
#  [u'2158', [u'php', u'yii2', u'nginx']],
#  [u'2162',
#   [u'javascript',
#    u'php',
#    u'validaci\xf3n',
#    u'wordpress',
#    u'rest',
#    u'wp-query']],
#  [u'2163',
#   [u'android',
#    u'mysql',
#    u'post',
#    u'java',
#    u'php',
#    u'ajax',
#    u'html',
#    u'admob',
#    u'json',
#    u'base-de-datos',
#    u'codeigniter',
#    u'codeigniter-3',
#    u'gridview']],
#  [u'2171', [u'c', u'windows', u'winapi']],
#  [u'2172', [u'java', u'jdk', u'ubuntu', u'android-studio']],
#  [u'2184', [u'c#', u'wcf', u'entity-framework', u'excel', u'linq']],
#  [u'2186', [u'api', u'nosql', u'couchdb']],
#  [u'2208', [u'php', u'ajax', u'seo', u'codeigniter']],
#  [u'2222', [u'bash', u'shell']],
#  [u'2224',
#   [u'.net',
#    u'javascript',
#    u'jquery',
#    u'html',
#    u'css',
#    u'c#',
#    u'formularios',
#    u'css3',
#    u'operador',
#    u'animaci\xf3n',
#    u'reflection']],
#  [u'2225', [u'google-maps', u'javascript']],
#  [u'2230',
#   [u'string',
#    u'google-maps',
#    u'android',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'php',
#    u'android-layout',
#    u'c#',
#    u'json',
#    u'base-de-datos',
#    u'xaml',
#    u'windows',
#    u'sqlite',
#    u'uwp',
#    u'android-studio',
#    u'gradle',
#    u'trigger',
#    u'google-play',
#    u'material-design',
#    u'live-template',
#    u'realm',
#    u'android-jellybean']],
#  [u'2234', [u'python']],
#  [u'2235', [u'string', u'python', u'ordenamiento']],
#  [u'2236',
#   [u'c++',
#    u'c++11',
#    u'python',
#    u'linux',
#    u'ubuntu',
#    u'python-3.x',
#    u'c',
#    u'visual-studio-2010',
#    u'makefile',
#    u'visual-c++']],
#  [u'2238',
#   [u'javascript', u'jquery', u'c#', u'windows-forms', u'wpf', u'xaml']],
#  [u'2241',
#   [u'mysql',
#    u'sql',
#    u'python',
#    u'php',
#    u'html',
#    u'css',
#    u'linux',
#    u'matem\xe1ticas',
#    u'html5',
#    u'numpy',
#    u'python-3.x',
#    u'algoritmos',
#    u'matplotlib',
#    u'windows',
#    u'latex',
#    u'webservice',
#    u'diagrama-de-flujo',
#    u'jupyter',
#    u'ipython']],
#  [u'2247',
#   [u'.net',
#    u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'ajax',
#    u'regex',
#    u'c#',
#    u'html5',
#    u'json',
#    u'windows',
#    u'asp.net-mvc-5',
#    u'razor',
#    u'asp.net-mvc',
#    u'windows10']],
#  [u'2256',
#   [u'asp.net-web-api',
#    u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'json',
#    u'sql-server',
#    u'tsql']],
#  [u'2257', [u'c#', u'motor-de-juego', u'unity3d', u'2d', u'unity2d']],
#  [u'2262', [u'mysql', u'sql', u'php', u'phpmyadmin', u'mysqli']],
#  [u'2282',
#   [u'ios',
#    u'xcode',
#    u'swift',
#    u'swift2',
#    u'facebook',
#    u'firebase',
#    u'oauth',
#    u'parse.com']],
#  [u'2288', [u'java', u'spring', u'spring-mvc', u'spring-security']],
#  [u'2293', [u'java']],
#  [u'2295', [u'html', u'css', u'html5', u'css3']],
#  [u'2304',
#   [u'mysql',
#    u'python',
#    u'php',
#    u'matem\xe1ticas',
#    u'codeigniter',
#    u'codeigniter-3']],
#  [u'2325', [u'c#']],
#  [u'2327', [u'post', u'nodejs', u'permisos']],
#  [u'2335', [u'html', u'genexus', u'transacciones']],
#  [u'2338',
#   [u'javascript',
#    u'jquery',
#    u'mysql',
#    u'sql',
#    u'python',
#    u'php',
#    u'html',
#    u'python-2.7',
#    u'bootstrap']],
#  [u'2346', [u'javascript']],
#  [u'2349', [u'rails']],
#  [u'2352',
#   [u'array',
#    u'javascript',
#    u'php',
#    u'ajax',
#    u'html',
#    u'html5',
#    u'facebook',
#    u'paypal',
#    u'google-plus',
#    u'google+']],
#  [u'2357', [u'java', u'java-ee', u'jsf']],
#  [u'2361', [u'python']],
#  [u'2364', [u'python', u'gstreamer']],
#  [u'2366',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'html',
#    u'css',
#    u'c#',
#    u'entity-framework',
#    u'html5',
#    u'css3',
#    u'vb.net',
#    u'asp.net-mvc-5',
#    u'razor',
#    u'bootstrap',
#    u'asp.net-mvc',
#    u'linq',
#    u'linq-to-sql',
#    u'webforms']],
#  [u'2367', [u'javascript', u'jquery', u'html5', u'zepto']],
#  [u'2379', [u'android', u'java', u'linux', u'windows', u'end-of-line']],
#  [u'2387', [u'eclipse', u'ftp']],
#  [u'2392', [u'sql', u'php']],
#  [u'2393', [u'.net', u'clickonce', u'deployment']],
#  [u'2394',
#   [u'jquery', u'python', u'ajax', u'django', u'django-models', u'tinymce']],
#  [u'2399',
#   [u'string',
#    u'array',
#    u'java',
#    u'orientaci\xf3n-a-objetos',
#    u'io',
#    u'revisi\xf3n-de-c\xf3digo']],
#  [u'2402',
#   [u'python',
#    u'django',
#    u'python-2.7',
#    u'python-3.x',
#    u'celery',
#    u'django-migrations']],
#  [u'2408', [u'c#', u'wpf', u'xaml']],
#  [u'2420', [u'javascript', u'java', u'postgresql', u'aplicaci\xf3n-web']],
#  [u'2424', [u'angularjs', u'nginx']],
#  [u'2429',
#   [u'asp.net',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'java',
#    u'git',
#    u'php',
#    u'ajax',
#    u'html',
#    u'html5',
#    u'ordenamiento',
#    u'excepciones',
#    u'seguridad',
#    u'postgresql',
#    u'asp.net-mvc',
#    u'datatables',
#    u'debian',
#    u'codeigniter',
#    u'codeigniter-3',
#    u'visual-studio-2015',
#    u'apache',
#    u'mono',
#    u'materialize',
#    u'errores',
#    u'login',
#    u'url']],
#  [u'2430', [u'android', u'java', u'gradle']],
#  [u'2448', [u'sql']],
#  [u'2453',
#   [u'mysql',
#    u'java',
#    u'java-ee',
#    u'jdbc',
#    u'jsf',
#    u'primefaces',
#    u'stored-procedure']],
#  [u'2472',
#   [u'ios',
#    u'xcode',
#    u'c#',
#    u'entity-framework',
#    u'swift',
#    u'sharepoint',
#    u'visual-studio',
#    u'razor',
#    u'swift2',
#    u'asp.net-mvc',
#    u'asincr\xf3nico',
#    u'visual-studio-2015',
#    u'entity-framework-6',
#    u'mvc']],
#  [u'2478', [u'asp.net', u'c#', u'asp.net-mvc']],
#  [u'2488', [u'.net', u'c#']],
#  [u'2500', [u'java', u'seguridad', u'ingenier\xeda-inversa']],
#  [u'2509',
#   [u'angularjs',
#    u'javascript',
#    u'git',
#    u'html',
#    u'css',
#    u'html5',
#    u'css3',
#    u'github',
#    u'reactjs',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'filtros-css',
#    u'babeljs']],
#  [u'2512',
#   [u'mysql',
#    u'sql',
#    u'bash',
#    u'python',
#    u'django',
#    u'python-3.x',
#    u'django-models',
#    u'sqlite']],
#  [u'2531', [u'vb.net']],
#  [u'2533', [u'asp.net', u'javascript', u'jquery', u'vb.net']],
#  [u'2539',
#   [u'android',
#    u'mysql',
#    u'java',
#    u'variables',
#    u'php',
#    u'xml',
#    u'json',
#    u'sqlite']],
#  [u'2540', [u'python', u'python-2.7', u'python-3.x', u'ponyorm']],
#  [u'2549', [u'angularjs', u'json']],
#  [u'2551', [u'google-maps', u'android', u'java']],
#  [u'2555', [u'sql-server']],
#  [u'2566', [u'angularjs', u'php', u'laravel-5', u'mysqli', u'jwt']],
#  [u'2596',
#   [u'c#',
#    u'xaml',
#    u'windows',
#    u'sqlite3',
#    u'uwp',
#    u'ftp',
#    u'powershell',
#    u'binding',
#    u'mvvm']],
#  [u'2600', [u'sql-server']],
#  [u'2601', [u'mysql', u'php', u'bootstrap']],
#  [u'2610', [u'asp.net-web-api', u'nodejs']],
#  [u'2631', [u'lista', u'java', u'ordenamiento']],
#  [u'2633',
#   [u'.net',
#    u'sql',
#    u'java',
#    u'python',
#    u'shell',
#    u'lenguaje-agn\xf3stico',
#    u'c',
#    u'conversi\xf3n-de-tipos',
#    u'unix',
#    u'ascii',
#    u'vb.net',
#    u'postgresql',
#    u'dup',
#    u'calculo-relacional',
#    u'\xe1lgebra-relacional',
#    u'prolog']],
#  [u'2636',
#   [u'php',
#    u'c#',
#    u'django',
#    u'visual-studio',
#    u'django-models',
#    u'sqlite3',
#    u'sqlite',
#    u'windows-phone']],
#  [u'2645', [u'string', u'android', u'java', u'swing']],
#  [u'2649', [u'html5', u'apache']],
#  [u'2652',
#   [u'angularjs',
#    u'javascript',
#    u'http',
#    u'nodejs',
#    u'cordova',
#    u'json',
#    u'ionic']],
#  [u'2653',
#   [u'google-maps',
#    u'javascript',
#    u'android',
#    u'mysql',
#    u'php',
#    u'seguridad',
#    u'react-native',
#    u'mysqli']],
#  [u'2659',
#   [u'asp.net-web-api',
#    u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'http',
#    u'html',
#    u'css',
#    u'regex',
#    u'c#',
#    u'servicio',
#    u'entity-framework',
#    u'json',
#    u'sql-server',
#    u'excepciones',
#    u'signalr',
#    u'ssis',
#    u'm\xe9todo',
#    u'configuraci\xf3n',
#    u'asp.net-mvc',
#    u'jquery-ui',
#    u'timespan',
#    u'date',
#    u'odata',
#    u'autenticaci\xf3n',
#    u'extension-method',
#    u'intellisence',
#    u'zoom',
#    u'viewport',
#    u'scale',
#    u'ngview']],
#  [u'2670',
#   [u'array',
#    u'javascript',
#    u'android',
#    u'mysql',
#    u'java',
#    u'php',
#    u'eclipse',
#    u'xml',
#    u'curl']],
#  [u'2673', [u'c', u'arduino']],
#  [u'2675',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'sql',
#    u'ajax',
#    u'html',
#    u'html5',
#    u'json',
#    u'sql-server',
#    u'vb.net',
#    u'bootstrap',
#    u'asp']],
#  [u'2676',
#   [u'string',
#    u'array',
#    u'lista',
#    u'javascript',
#    u'android',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'android-asynctask',
#    u'php',
#    u'html',
#    u'optimizaci\xf3n',
#    u'formularios',
#    u'xml',
#    u'json',
#    u'pdf',
#    u'java-ee',
#    u'embebido',
#    u'reflexi\xf3n',
#    u'java-8',
#    u'thread',
#    u'eventos',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'map',
#    u'stored-procedure',
#    u'pdo',
#    u'transacciones',
#    u'glassfish',
#    u'lambda',
#    u'markdown',
#    u'union',
#    u'pdfmake',
#    u'callback']],
#  [u'2681', [u'android', u'android-studio', u'gradle', u'recyclerview']],
#  [u'2685', [u'android', u'http', u'json', u'gradle']],
#  [u'2690', [u'python', u'django']],
#  [u'2706', [u'c#']],
#  [u'2718',
#   [u'android',
#    u'java',
#    u'python',
#    u'django',
#    u'djangorestframework',
#    u'android-sqlite',
#    u'nginx']],
#  [u'2722', [u'angularjs', u'javascript']],
#  [u'2724', [u'sql', u'python', u'sql-server', u'visual-studio', u'excel']],
#  [u'2731', [u'php']],
#  [u'2742',
#   [u'c++',
#    u'string',
#    u'c++11',
#    u'serializaci\xf3n',
#    u'enum',
#    u'template',
#    u'c++1z',
#    u'c++-faq',
#    u'est\xe1ndares']],
#  [u'2744', [u'entity-framework', u'asp.net-core', u'as400']],
#  [u'2747',
#   [u'asp.net',
#    u'angularjs',
#    u'javascript',
#    u'timestamp',
#    u'oracle',
#    u'java',
#    u'html',
#    u'regex',
#    u'html5',
#    u'visual-studio',
#    u'spring-mvc',
#    u'spring-security',
#    u'oracle-11g',
#    u'iis',
#    u'angular-translate',
#    u'moodle',
#    u'md5',
#    u'encriptacion',
#    u'ngcookies',
#    u'stored-procedure']],
#  [u'2759', [u'javascript', u'python', u'django', u'google-visualization']],
#  [u'2762', [u'array', u'php']],
#  [u'2766',
#   [u'asp.net',
#    u'git',
#    u'c#',
#    u'soap',
#    u'wcf',
#    u'xml',
#    u'visual-studio-2015',
#    u'xamarin',
#    u'devexpress',
#    u'visual-studio-ts']],
#  [u'2767', [u'c#', u'entity-framework', u'linq']],
#  [u'2768', [u'wordpress']],
#  [u'2769',
#   [u'java',
#    u'netbeans',
#    u'jpa',
#    u'java-ee',
#    u'jsf',
#    u'apache-commons-validator']],
#  [u'2770',
#   [u'ubuntu',
#    u'apache',
#    u'.htaccess',
#    u'redirecci\xf3n',
#    u'reescritura-url',
#    u'mod-rewrite',
#    u'docker']],
#  [u'2771', [u'php']],
#  [u'2779', [u'javascript']],
#  [u'2784', [u'jquery', u'ajax', u'laravel-5']],
#  [u'2785',
#   [u'javascript', u'java', u'nodejs', u'spring-mvc', u'jsp', u'sailsjs']],
#  [u'2794', [u'laravel']],
#  [u'2795', [u'entity-framework', u'linq-to-sql', u'dbml']],
#  [u'2797', [u'c#', u'unity3d']],
#  [u'2800', [u'c#']],
#  [u'2802', [u'api', u'python', u'django', u'djangorestframework']],
#  [u'2803', [u'android', u'android-studio']],
#  [u'2808', [u'api', u'php', u'html']],
#  [u'2820', [u'linux', u'windows']],
#  [u'2822', [u'php', u'html']],
#  [u'2824', [u'css', u'internet-explorer', u'internet-explorer-9']],
#  [u'2825', [u'mysql', u'python', u'python-2.7', u'windows']],
#  [u'2826',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'knockoutjs',
#    u'email',
#    u'c#',
#    u'html5',
#    u'visual-studio',
#    u'asp.net-mvc-5',
#    u'asp.net-mvc',
#    u'visual-studio-2015']],
#  [u'2832', [u'post', u'wordpress', u'tinymce']],
#  [u'2837', [u'ios', u'xcode', u'admob', u'objective-c', u'swift', u'swift2']],
#  [u'2838',
#   [u'javascript',
#    u'python',
#    u'ajax',
#    u'django',
#    u'formularios',
#    u'html5',
#    u'python-3.x',
#    u'json',
#    u'django-models',
#    u'datatables',
#    u'django-admin',
#    u'django-forms']],
#  [u'2842', [u'sql', u'visual-studio-2013']],
#  [u'2848', [u'jquery', u'dom']],
#  [u'2854',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'css',
#    u'c#',
#    u'html5',
#    u'json',
#    u'dom',
#    u'bootstrap',
#    u'asp',
#    u'iis',
#    u'crystal-reports',
#    u'reportviewer',
#    u'devexpress',
#    u'webforms']],
#  [u'2860', [u'java']],
#  [u'2862', [u'android', u'c#', u'unity3d']],
#  [u'2871', [u'joomla3']],
#  [u'2878', [u'string', u'ios', u'xcode', u'objective-c', u'swift', u'swift2']],
#  [u'2879', [u'string', u'c#', u'windows-forms', u'bitmap']],
#  [u'2880', [u'ionic']],
#  [u'2883', [u'c#', u'wcf', u'json', u'linq']],
#  [u'2890', [u'linux', u'unix']],
#  [u'2894',
#   [u'javascript', u'css', u'nodejs', u'reactjs', u'ecmascript-2015', u'less']],
#  [u'2896',
#   [u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'api',
#    u'java',
#    u'git',
#    u'php',
#    u'css3',
#    u'nodejs',
#    u'cordova',
#    u'github',
#    u'windows',
#    u'sqlite',
#    u'android-studio',
#    u'ionic',
#    u'requirejs',
#    u'genymotion',
#    u'twitter-api',
#    u'ng-cordova']],
#  [u'2904', [u'asp']],
#  [u'2908', [u'java', u'eclipse', u'maven']],
#  [u'2909', [u'xcode', u'codificaci\xf3n', u'c', u'osx', u'tad']],
#  [u'2910', [u'php', u'formularios']],
#  [u'2911', [u'python', u'xml', u'revisi\xf3n-de-c\xf3digo']],
#  [u'2917', [u'asp.net', u'javascript', u'html', u'bootstrap', u'asp']],
#  [u'2920', [u'html', u'css', u'google-chrome', u'internet-explorer']],
#  [u'2931', [u'rails', u'ruby']],
#  [u'2935', [u'c#', u'thread']],
#  [u'2941', [u'socket', u'php', u'c', u'libcurl']],
#  [u'2945', [u'.net', u'c#', u'revisi\xf3n-de-c\xf3digo']],
#  [u'2946', [u'.net', u'c#', u'windows']],
#  [u'2947', [u'.net', u'html']],
#  [u'2948', [u'sql-server']],
#  [u'2950',
#   [u'array', u'python', u'numpy', u'matplotlib', u'revisi\xf3n-de-c\xf3digo']],
#  [u'2953', [u'android', u'android-layout']],
#  [u'2955', [u'javascript', u'android', u'redondeo', u'amcharts']],
#  [u'2957',
#   [u'javascript',
#    u'jquery',
#    u'android',
#    u'html',
#    u'android-layout',
#    u'facebook',
#    u'tinymce']],
#  [u'2958',
#   [u'javascript', u'jquery', u'php', u'html', u'css', u'formularios']],
#  [u'2960', [u'sql', u'azure', u'asp.net-mvc-5']],
#  [u'2967', [u'visual-studio', u'visual-studio-2015']],
#  [u'2969', [u'asp.net', u'google-maps', u'c#', u'asp.net-mvc']],
#  [u'2974',
#   [u'c#',
#    u'lenguaje-agn\xf3stico',
#    u'visual-studio',
#    u'\xe1rboles',
#    u'\xe1rboles-binarios']],
#  [u'2975', [u'android', u'java']],
#  [u'2980',
#   [u'array',
#    u'java',
#    u'algoritmos',
#    u'netbeans',
#    u'excepciones',
#    u'consola',
#    u'swing']],
#  [u'2981', [u'android', u'api', u'php', u'cordova', u'google-app-engine']],
#  [u'2985', [u'ios', u'admob', u'swift', u'json']],
#  [u'2989', [u'php']],
#  [u'2990',
#   [u'asp.net-web-api',
#    u'c#',
#    u'visual-studio',
#    u'seguridad',
#    u'base-de-datos',
#    u'asp.net-mvc-5',
#    u'asp.net-mvc']],
#  [u'2994', [u'r', u'geo-localizacion']],
#  [u'2998', [u'android', u'3d']],
#  [u'3004',
#   [u'string',
#    u'google-maps',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'mysql',
#    u'java',
#    u'php',
#    u'android-layout',
#    u'html5',
#    u'navigationview',
#    u'bootstrap',
#    u'android-studio',
#    u'apache',
#    u'csv',
#    u'gps']],
#  [u'3008',
#   [u'.net',
#    u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'java',
#    u'laravel',
#    u'php',
#    u'ajax',
#    u'select2',
#    u'json',
#    u'servlets',
#    u'postgresql',
#    u'asp.net-mvc',
#    u'reportviewer']],
#  [u'3013',
#   [u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'laravel',
#    u'php',
#    u'ajax',
#    u'laravel-5',
#    u'html5',
#    u'sublimetext',
#    u'sublimetext3',
#    u'windows',
#    u'angular-directivas',
#    u'material-design-lite',
#    u'materialize',
#    u'angularjs-injector',
#    u'handlebars.js']],
#  [u'3014', [u'angularjs', u'http', u'php', u'servicio', u'binding']],
#  [u'3021', [u'java', u'python', u'swing']],
#  [u'3022', [u'ios', u'xcode', u'swift', u'json']],
#  [u'3038',
#   [u'javascript', u'jquery', u'asp.net-mvc', u'asp', u'jqgrid', u'firefox']],
#  [u'3040', [u'sql', u'sql-server']],
#  [u'3042', [u'javascript', u'php', u'nodejs']],
#  [u'3043', [u'windows-forms']],
#  [u'3052', [u'vb.net']],
#  [u'3053', [u'xaml', u'uwp']],
#  [u'3054', [u'join', u'vb.net', u'linq']],
#  [u'3060',
#   [u'asp.net', u'ajax', u'regex', u'c#', u'entity-framework', u'asp.net-mvc']],
#  [u'3065', [u'java', u'base-de-datos']],
#  [u'3067', [u'java']],
#  [u'3068', [u'php']],
#  [u'3073',
#   [u'angularjs',
#    u'java',
#    u'spring',
#    u'html',
#    u'html5',
#    u'spring-mvc',
#    u'aplicaci\xf3n-web',
#    u'paypal',
#    u'prestashop']],
#  [u'3077', [u'delphi', u'lazarus']],
#  [u'3081', [u'c++']],
#  [u'3088',
#   [u'.net', u'oracle', u'c#', u'visual-studio', u'revisi\xf3n-de-c\xf3digo']],
#  [u'3089', [u'bootstrap']],
#  [u'3092', [u'mysql']],
#  [u'3093', [u'soapui']],
#  [u'3094',
#   [u'javascript',
#    u'jquery',
#    u'mysql',
#    u'api',
#    u'php',
#    u'html',
#    u'css',
#    u'email',
#    u'html5',
#    u'css3',
#    u'office365',
#    u'jquery-datepicker']],
#  [u'3110', [u'reescritura-url', u'mod-rewrite']],
#  [u'3115',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'sql',
#    u'ajax',
#    u'html',
#    u'css',
#    u'regex',
#    u'json',
#    u'sql-server',
#    u'vb.net',
#    u'bootstrap',
#    u'jquery-validate']],
#  [u'3116', [u'php']],
#  [u'3118', [u'php', u'facebook']],
#  [u'3128', [u'oracle', u'postgresql']],
#  [u'3130',
#   [u'javascript',
#    u'java',
#    u'laravel',
#    u'php',
#    u'html',
#    u'linux',
#    u'nodejs',
#    u'licencias',
#    u'json',
#    u'datatables',
#    u'fullcalendar',
#    u'setinterval']],
#  [u'3131', [u'java']],
#  [u'3138', [u'python', u'linux', u'django', u'ubuntu', u'pygame']],
#  [u'3142', [u'.net', u'c#']],
#  [u'3144', [u'regex', u'google-hoja-de-calculo']],
#  [u'3151', [u'git', u'git-push']],
#  [u'3152', [u'mysql', u'phpmyadmin']],
#  [u'3158', [u'angularjs', u'javascript', u'pdf']],
#  [u'3159', [u'java']],
#  [u'3162', [u'php', u'wordpress']],
#  [u'3165', [u'doctrine', u'symfony2']],
#  [u'3167', [u'javascript', u'jquery']],
#  [u'3170',
#   [u'android',
#    u'java',
#    u'xml',
#    u'firebase',
#    u'windows10',
#    u'material-design-lite',
#    u'genymotion']],
#  [u'3181', [u'php', u'codeigniter']],
#  [u'3182', [u'spring', u'spring-roo', u'gvnix', u'spring-mvc']],
#  [u'3190', [u'jquery', u'bootstrap']],
#  [u'3199', [u'string', u'c', u'manejo-de-memoria', u'estructuras-de-datos']],
#  [u'3202', [u'android', u'sublimetext']],
#  [u'3203',
#   [u'angularjs',
#    u'javascript',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'xml',
#    u'genexus',
#    u'rest',
#    u'criptograf\xeda',
#    u'firma-digital']],
#  [u'3204', [u'javascript']],
#  [u'3205', [u'yii2']],
#  [u'3217', [u'java', u'xstream']],
#  [u'3221', [u'php', u'css']],
#  [u'3224', [u'php', u'mysqli']],
#  [u'3228', [u'css', u'laravel-5', u'pdf', u'bootstrap']],
#  [u'3229', [u'c#']],
#  [u'3231',
#   [u'javascript',
#    u'jquery',
#    u'java',
#    u'git',
#    u'php',
#    u'html',
#    u'linux',
#    u'eclipse',
#    u'html5',
#    u'github',
#    u'windows',
#    u'configuraci\xf3n',
#    u'mysqli',
#    u'jsp']],
#  [u'3234',
#   [u'javascript',
#    u'git',
#    u'php',
#    u'html',
#    u'css',
#    u'rendimiento',
#    u'optimizaci\xf3n',
#    u'html5',
#    u'c',
#    u'dom',
#    u'bootstrap',
#    u'facebook',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'bootstrap-carousel',
#    u'facebook-api']],
#  [u'3243', [u'python', u'html', u'css', u'django', u'sqlite']],
#  [u'3244', [u'java', u'swing']],
#  [u'3247', [u'python']],
#  [u'3248',
#   [u'rails',
#    u'ruby',
#    u'git',
#    u'php',
#    u'git-commit',
#    u'funciones',
#    u'github',
#    u'git-push',
#    u'wordpress',
#    u'bootstrap',
#    u'codeigniter',
#    u'.htaccess',
#    u'date',
#    u'mvc']],
#  [u'3249',
#   [u'.net',
#    u'java',
#    u'hibernate',
#    u'php',
#    u'eclipse',
#    u'jboss',
#    u'jersey',
#    u'sqlite3',
#    u'apache',
#    u'rest',
#    u'jboss-as-7',
#    u'ejb',
#    u'cil']],
#  [u'3250', [u'asp.net-mvc-5']],
#  [u'3251', [u'java', u'orientaci\xf3n-a-objetos']],
#  [u'3257',
#   [u'rails',
#    u'ruby',
#    u'javascript',
#    u'jquery',
#    u'html',
#    u'css',
#    u'bootstrap',
#    u'gemfile']],
#  [u'3258', [u'javascript']],
#  [u'3259', [u'arduino']],
#  [u'3262', [u'javascript', u'socket', u'java', u'servlets']],
#  [u'3265', [u'javascript']],
#  [u'3275',
#   [u'mysql',
#    u'java',
#    u'css',
#    u'matem\xe1ticas',
#    u'netbeans',
#    u'jdbc',
#    u'eventos',
#    u'javafx']],
#  [u'3278', [u'javascript', u'bootstrap', u'bootstrap-carousel']],
#  [u'3280', [u'google-maps', u'ios', u'xcode', u'swift']],
#  [u'3281',
#   [u'javascript',
#    u'jquery',
#    u'html',
#    u'mongodb',
#    u'base-de-datos',
#    u'express']],
#  [u'3283', [u'php', u'phpmyadmin', u'symfony2']],
#  [u'3284', [u'mysql', u'asterisk']],
#  [u'3287',
#   [u'javascript',
#    u'python',
#    u'django',
#    u'nodejs',
#    u'parse.com',
#    u'express',
#    u'serializaci\xf3n',
#    u'chartkick']],
#  [u'3290', [u'android', u'genexus']],
#  [u'3291', [u'angularjs', u'php', u'json']],
# ...
#    u'.htaccess',
#    u'swing',
#    u'aplicaci\xf3n-web',
#    u'javafx',
#    u'layout',
#    u'gui']],
#  [u'4336', [u'visual-studio-2010']],
#  [u'4348', [u'asp.net', u'c#', u'entity-framework']],
#  [u'4351', [u'sql-server']],
#  [u'4355', [u'r', u'ggplot2', u'plotly']],
#  [u'4357', [u'android', u'cordova', u'aplicaci\xf3n-web', u'polymer']],
#  [u'4360', [u'condiciones', u'sql-server']],
#  [u'4361',
#   [u'.net',
#    u'asp.net',
#    u'google-maps',
#    u'oracle',
#    u'oracle-10g',
#    u'java',
#    u'c#',
#    u'entity-framework',
#    u'windows-forms',
#    u'sql-server',
#    u'visual-studio',
#    u'excel',
#    u'base-de-datos',
#    u'i18n',
#    u'vb.net',
#    u'deployment',
#    u'linq',
#    u'windows-installer',
#    u'iis',
#    u'aplicaci\xf3n-web',
#    u'webservice']],
#  [u'4362', [u'android', u'eventos']],
#  [u'4365', [u'android']],
#  [u'4366', [u'java']],
#  [u'4369', [u'c#']],
#  [u'4370', [u'php', u'html']],
#  [u'4371', [u'r']],
#  [u'4377', [u'java']],
#  [u'4380', [u'nodejs', u'mongodb']],
#  [u'4381',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'sql',
#    u'python',
#    u'php',
#    u'ajax',
#    u'html',
#    u'c#',
#    u'django',
#    u'sql-server',
#    u'bootstrap',
#    u'asp',
#    u'iis']],
#  [u'4382', [u'android']],
#  [u'4383', [u'c++']],
#  [u'4384', [u'java', u'spring', u'mybatis']],
#  [u'4388', [u'php', u'wordpress', u'docker', u'zip']],
#  [u'4389', [u'symfony2']],
#  [u'4392', [u'google-maps', u'android']],
#  [u'4394', [u'java', u'swing']],
#  [u'4402', [u'css', u'html5']],
#  [u'4403', [u'linux']],
#  [u'4404', [u'ensamblador']],
#  [u'4414', [u'javascript', u'mongodb', u'meteor']],
#  [u'4418',
#   [u'javascript',
#    u'android',
#    u'android-intent',
#    u'php',
#    u'html',
#    u'android-layout',
#    u'firebase',
#    u'android-studio',
#    u'svg',
#    u'google-play']],
#  [u'4420', [u'angularjs', u'css', u'datatables']],
#  [u'4421', [u'google-maps', u'wordpress']],
#  [u'4423',
#   [u'java',
#    u'spring',
#    u'spring-mvc',
#    u'spring-security',
#    u'autenticaci\xf3n']],
#  [u'4430', [u'python', u'atom-editor']],
#  [u'4432', [u'c']],
#  [u'4439', [u'android']],
#  [u'4440', [u'php', u'optimizaci\xf3n', u'algoritmos', u'pdf']],
#  [u'4446',
#   [u'javascript', u'laravel', u'php', u'nodejs', u'mongodb', u'mongoose']],
#  [u'4447', [u'c#']],
#  [u'4451',
#   [u'javascript',
#    u'jquery',
#    u'php',
#    u'html',
#    u'email',
#    u'validaci\xf3n',
#    u'formularios',
#    u'codeigniter',
#    u'codeigniter-3']],
#  [u'4453', [u'android']],
#  [u'4456',
#   [u'c++', u'python', u'c#', u'xml', u'c', u'vpn', u'qt', u'qt-creator']],
#  [u'4458', [u'matem\xe1ticas', u'matlab', u'modulaci\xf3n', u'frecuencia']],
#  [u'4465', [u'java']],
#  [u'4466', [u'java', u'firebase']],
#  [u'4468', [u'javascript', u'email', u'facebook']],
#  [u'4474', [u'mysql', u'php']],
#  [u'4479', [u'angularjs', u'javascript', u'html', u'css3']],
#  [u'4486', [u'java', u'javafx']],
#  [u'4487',
#   [u'asp.net',
#    u'javascript',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'php',
#    u'css',
#    u'html5',
#    u'windows-forms',
#    u'css3',
#    u'sql-server',
#    u'vb.net',
#    u'datatables',
#    u'android-studio',
#    u'iis']],
#  [u'4494', [u'asp.net', u'c#']],
#  [u'4499',
#   [u'.net',
#    u'c++',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'c#',
#    u'python-3.x',
#    u'sql-server']],
#  [u'4507', [u'mysql', u'php', u'ajax', u'bootstrap']],
#  [u'4514', [u'php']],
#  [u'4516', [u'mysql']],
#  [u'4520', [u'python', u'python-2.7', u'windows']],
#  [u'4528',
#   [u'android',
#    u'java',
#    u'android-asynctask',
#    u'php',
#    u'linux',
#    u'c',
#    u'android-studio',
#    u'arduino',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'google-play',
#    u'atmel',
#    u'android-widget',
#    u'push-notification',
#    u'pic',
#    u'ccs']],
#  [u'4529', [u'sql', u'tsql', u'trigger']],
#  [u'4530', [u'ios', u'java', u'php', u'apache', u'.htaccess']],
#  [u'4532', [u'android', u'java', u'android-viewpager']],
#  [u'4537', [u'android', u'python']],
#  [u'4538', [u'asp.net', u'javascript', u'html5']],
#  [u'4541', [u'java', u'struts', u'apache', u'tomcat']],
#  [u'4544', [u'c++', u'c']],
#  [u'4545', [u'php', u'aplicaci\xf3n-web']],
#  [u'4548',
#   [u'javascript',
#    u'jquery',
#    u'datetime',
#    u'post',
#    u'php',
#    u'ajax',
#    u'html',
#    u'funciones',
#    u'pdf',
#    u'codeigniter-3',
#    u'eventos',
#    u'asp']],
#  [u'4563', [u'android']],
#  [u'4564', [u'jquery-ui']],
#  [u'4568',
#   [u'google-maps',
#    u'android',
#    u'java',
#    u'android-sqlite',
#    u'sqlite3',
#    u'sqlite',
#    u'android-studio',
#    u'gradle',
#    u'geo-localizacion',
#    u'map']],
#  [u'4571', [u'.htaccess', u'redirecci\xf3n', u'mod-rewrite']],
#  [u'4574', [u'python', u'python-2.7']],
#  [u'4577', [u'android-studio']],
#  [u'4580', [u'mysql', u'java', u'spring', u'jpa']],
#  [u'4582', [u'python-3.x']],
#  [u'4583',
#   [u'google-maps', u'javascript', u'mysql', u'php', u'geo-localizacion']],
#  [u'4584',
#   [u'asp.net',
#    u'javascript',
#    u'sql',
#    u'c#',
#    u'xml',
#    u'dns',
#    u'entity-framework-6',
#    u'iis',
#    u'serializaci\xf3n',
#    u'servidores']],
#  [u'4594', [u'java', u'jasper-reports']],
#  [u'4595',
#   [u'string',
#    u'lista',
#    u'sql',
#    u'java',
#    u'php',
#    u'eclipse',
#    u'sql-server',
#    u'c',
#    u'punteros',
#    u'java-8',
#    u'java-stream',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'map',
#    u'preprocesador']],
#  [u'4598', [u'c#', u'xaml', u'sqlite', u'binding', u'mvvm']],
#  [u'4603', [u'base-de-datos', u'dise\xf1o']],
#  [u'4610',
#   [u'c++',
#    u'google-maps',
#    u'angularjs',
#    u'array',
#    u'lista',
#    u'javascript',
#    u'bash',
#    u'python',
#    u'html',
#    u'css',
#    u'linux',
#    u'nodejs',
#    u'algoritmos',
#    u'pdf',
#    u'base-de-datos',
#    u'windows',
#    u'debian',
#    u'angularjs-2.0',
#    u'aplicaci\xf3n-web',
#    u'iron-router',
#    u'map',
#    u'ensamblador',
#    u'materialize',
#    u'angularjs-injector',
#    u'svg',
#    u'gentoo']],
#  [u'4612',
#   [u'.net',
#    u'javascript',
#    u'jquery',
#    u'mysql',
#    u'datetime',
#    u'timestamp',
#    u'java',
#    u'ajax',
#    u'validaci\xf3n',
#    u'c#',
#    u'formularios',
#    u'netbeans',
#    u'jpa',
#    u'bootstrap',
#    u'jquery-datepicker',
#    u'jsf',
#    u'aplicaci\xf3n-web',
#    u'datepicker',
#    u'date',
#    u'trigger',
#    u'ejb',
#    u'glassfish']],
#  [u'4613', [u'c++', u'visual-studio-2015']],
#  [u'4620', [u'java', u'jackrabbit-oak']],
#  [u'4624', [u'r']],
#  [u'4627', [u'python']],
#  [u'4629', [u'array', u'c']],
#  [u'4632', [u'array', u'java', u'constructor', u'herencia']],
#  [u'4633',
#   [u'array', u'javascript', u'php', u'ajax', u'json', u'vb.net', u'linq']],
#  [u'4634', [u'php', u'apache']],
#  [u'4635', [u'java', u'json', u'scala', u'javadoc']],
#  [u'4637', [u'javascript', u'jquery', u'html']],
#  [u'4646', [u'laravel', u'php', u'laravel-5']],
#  [u'4650', [u'sql', u'sql-server']],
#  [u'4654',
#   [u'javascript',
#    u'php',
#    u'ajax',
#    u'django',
#    u'xml',
#    u'sql-server',
#    u'apache',
#    u'stored-procedure',
#    u'transacciones']],
#  [u'4656', [u'android']],
#  [u'4661',
#   [u'jquery',
#    u'join',
#    u'laravel',
#    u'php',
#    u'ajax',
#    u'css',
#    u'laravel-5',
#    u'select2',
#    u'base-de-datos',
#    u'configuraci\xf3n',
#    u'bootstrap']],
#  [u'4663', [u'c++', u'array', u'ordenamiento']],
#  [u'4669', [u'c++']],
#  [u'4671', [u'android']],
#  [u'4673', [u'c++', u'array', u'c', u'punteros', u'poo']],
#  [u'4674', [u'linux', u'bluetooth']],
#  [u'4676',
#   [u'c++',
#    u'javascript',
#    u'variables',
#    u'html',
#    u'linux',
#    u'funciones',
#    u'html5',
#    u'unix',
#    u'herencia']],
#  [u'4677',
#   [u'angularjs',
#    u'javascript',
#    u'java',
#    u'c#',
#    u'html5',
#    u'encriptacion',
#    u'websphere',
#    u'websphere-mq']],
#  [u'4678', [u'typescript', u'firebase', u'angularjs-2.0']],
#  [u'4680',
#   [u'android',
#    u'mysql',
#    u'sql',
#    u'java',
#    u'php',
#    u'json',
#    u'android-studio',
#    u'symfony2']],
#  [u'4684',
#   [u'android',
#    u'sql',
#    u'java',
#    u'android-intent',
#    u'android-layout',
#    u'permisos',
#    u'base-de-datos',
#    u'android-sqlite',
#    u'sqlite',
#    u'mysqli',
#    u'material-design']],
#  [u'4688', [u'angularjs', u'adword']],
#  [u'4695', [u'asp.net', u'mysql', u'c#']],
#  [u'4696', [u'css']],
#  [u'4697', [u'c++', u'double']],
#  [u'4704', [u'java', u'pdf']],
#  [u'4708',
#   [u'android',
#    u'html',
#    u'css',
#    u'c',
#    u'estructuras-de-datos',
#    u'android-widget']],
#  [u'4710', [u'javascript', u'python', u'ajax', u'django']],
#  [u'4715', [u'android']],
#  [u'4718',
#   [u'angularjs',
#    u'javascript',
#    u'html',
#    u'css',
#    u'html5',
#    u'css3',
#    u'json',
#    u'angular-directivas',
#    u'local-storage',
#    u'push-notification']],
#  [u'4723', [u'numpy', u'python-3.x', u'conda', u'windows10', u'anaconda']],
#  [u'4725',
#   [u'javascript',
#    u'jquery',
#    u'laravel',
#    u'php',
#    u'ajax',
#    u'html',
#    u'laravel-5',
#    u'paypal']],
#  [u'4726', [u'javascript', u'mysql', u'sql', u'php', u'ajax']],
#  [u'4729', [u'android', u'mysql', u'vb.net', u'android-studio']],
#  [u'4736',
#   [u'string', u'javascript', u'jquery', u'ajax', u'html', u'comparaciones']],
#  [u'4748',
#   [u'javascript',
#    u'jquery',
#    u'python',
#    u'html',
#    u'css',
#    u'django',
#    u'tinymce',
#    u'heroku']],
#  [u'4753', [u'java', u'jvm', u'groovy', u'grails', u'herencia']],
#  [u'4754', [u'wordpress']],
#  [u'4756', [u'html', u'css', u'google-chrome']],
#  [u'4757', [u'android', u'android-layout', u'datepicker']],
#  [u'4764', [u'groovy', u'grails']],
#  [u'4766', [u'android', u'firebase']],
#  [u'4770',
#   [u'javascript',
#    u'jquery',
#    u'php',
#    u'html',
#    u'css',
#    u'css3',
#    u'bootstrap',
#    u'bootstrap-carousel']],
#  [u'4771', [u'java', u'date']],
#  [u'4775', [u'php', u'ajax', u'rendimiento', u'nginx', u'zend']],
#  [u'4779',
#   [u'.net',
#    u'sql',
#    u'c#',
#    u'windows-forms',
#    u'sql-server',
#    u'vba',
#    u'vb.net',
#    u'devexpress',
#    u'transacciones']],
#  [u'4781', [u'excel', u'vba', u'base-de-datos']],
#  [u'4782',
#   [u'javascript',
#    u'jquery',
#    u'ajax',
#    u'html',
#    u'html5',
#    u'vba',
#    u'internet-explorer-11']],
#  [u'4783', [u'java']],
#  [u'4786', [u'asp.net', u'sql', u'sql-server', u'bootstrap']],
#  [u'4787', [u'.net', u'string', u'comparaciones']],
#  [u'4788', [u'r']],
#  [u'4790', [u'archivo', u'python', u'python-2.7']],
#  [u'4791', [u'c++']],
#  [u'4798', [u'ios', u'xcode', u'swift', u'firebase']],
#  [u'4799', [u'sql-server']],
#  [u'4805', [u'android', u'java', u'android-intent']],
#  [u'4810', [u'android', u'c#', u'xamarin']],
#  [u'4811',
#   [u'asp.net',
#    u'javascript',
#    u'jquery',
#    u'java',
#    u'ajax',
#    u'css',
#    u'c#',
#    u'html5',
#    u'asp.net-mvc-5',
#    u'bootstrap',
#    u'asp.net-mvc',
#    u'linq',
#    u'entity-framework-6',
#    u'linq-to-sql',
#    u'revisi\xf3n-de-c\xf3digo']],
#  [u'4813', [u'mysql', u'php', u'base-de-datos', u'phpmyadmin']],
#  [u'4814', [u'android']],
#  [u'4815', [u'android', u'java', u'sqlite']],
#  [u'4819', [u'java', u'django']],
#  [u'4822', [u'php', u'validaci\xf3n', u'formularios']],
#  [u'4823', [u'google-maps', u'android', u'java']],
#  [u'4830', [u'java', u'hibernate', u'hql']],
#  [u'4836', [u'android', u'android-studio', u'gradle']],
#  [u'4840', [u'javascript', u'html', u'pdf']],
#  [u'4845', [u'javascript', u'jquery', u'laravel', u'php', u'laravel-5']],
#  [u'4846', [u'php', u'html', u'html5', u'xampp']],
#  [u'4858', [u'ios', u'swift', u'swift2', u'sqlite3']],
#  [u'4859', [u'ios', u'android', u'ide']],
#  [u'4861', [u'python-3.x']],
#  [u'4866', [u'ios', u'android', u'java', u'swift']],
#  [u'4870', [u'c++']],
#  [u'4871', [u'rails', u'ruby', u'linux', u'ubuntu']],
#  [u'4872', [u'sql', u'deployment', u'symfony2']],
#  [u'4874',
#   [u'ios',
#    u'android',
#    u'api',
#    u'java',
#    u'git',
#    u'android-layout',
#    u'xml',
#    u'android-sqlite',
#    u'android-studio',
#    u'gradle',
#    u'google+',
#    u'progressbar',
#    u'bitbucket',
#    u'facebook-api']],
#  [u'4878',
#   [u'android',
#    u'api',
#    u'http',
#    u'php',
#    u'html',
#    u'html5',
#    u'xml',
#    u'json',
#    u'wordpress',
#    u'facebook',
#    u'android-studio']],
#  [u'4879', [u'java', u'eclipse', u'plsql', u'jooq']],
#  [u'4880', [u'ios', u'xcode', u'swift']],
#  [u'4881', [u'jquery', u'php', u'ajax']],
#  [u'4883', [u'git']],
#  [u'4886', [u'laravel-5']],
#  [u'4892', [u'python', u'django']],
#  [u'4894', [u'python', u'django']],
#  [u'4898', [u'linux']],
#  [u'4899', [u'funciones', u'c', u'estructuras-de-datos']],
#  [u'4914', [u'c#', u'json', u'postgresql', u'extjs']],
#  [u'4916', [u'android']],
#  [u'4918', [u'javascript', u'mysql', u'php', u'json']],
#  [u'4923',
#   [u'lista',
#    u'c#',
#    u'wcf',
#    u'entity-framework',
#    u'linq',
#    u'entity-framework-6',
#    u'webservice']],
#  [u'4924', [u'ios', u'android', u'swift2']],
#  [u'4932', [u'java', u'hibernate', u'encriptacion']],
#  [u'4934', [u'php', u'laravel-5']],
#  [u'4937', [u'sql', u'java', u'ms-access-2010', u'csv']],
#  [u'4939', [u'css', u'bootstrap']],
#  [u'4943', [u'android', u'json', u'sqlite']],
#  [u'4948', [u'php', u'bootstrap']],
#  [u'4949', [u'javascript', u'java', u'jsp', u'liferay']],
#  [u'4950', [u'mysql', u'php', u'mysqli', u'iis']],
#  [u'4951', [u'c#', u'windows-forms']],
#  [u'4958', [u'windows', u'kerberos']],
#  [u'4959', [u'jquery', u'spring']],
#  [u'4961', [u'python', u'c', u'qt-creator']],
#  [u'4983', [u'excel', u'vba']],
#  [u'4984', [u'php', u'base-de-datos', u'zend']],
#  [u'4985', [u'c#', u'vb.net', u'cuenta-usuario']],
#  [u'4987', [u'html5']],
#  [u'4989',
#   [u'oracle', u'bash', u'python', u'linux', u'curl', u'aws', u'aws-s3']],
#  [u'4991',
#   [u'array',
#    u'lista',
#    u'javascript',
#    u'variables',
#    u'php',
#    u'poo',
#    u'frecuencia',
#    u'vue.js']],
#  [u'5002', [u'javascript', u'jquery', u'html5']],
#  [u'5004',
#   [u'jquery',
#    u'mysql',
#    u'sql',
#    u'php',
#    u'html',
#    u'html5',
#    u'sql-server',
#    u'base-de-datos',
#    u'phpmyadmin',
#    u'mysqli']],
#  [u'5005',
#   [u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'http',
#    u'java',
#    u'spring',
#    u'php',
#    u'html',
#    u'css',
#    u'doctrine',
#    u'doctrine2',
#    u'ubuntu',
#    u'html5',
#    u'css3',
#    u'pdf',
#    u'apache',
#    u'symfony2',
#    u'rest',
#    u'heroku']],
#  [u'5012', [u'javascript', u'laravel', u'php']],
#  [u'5023', [u'post', u'php']],
#  [u'5024',
#   [u'php',
#    u'formularios',
#    u'base-de-datos',
#    u'codeigniter',
#    u'codeigniter-3']],
#  [u'5027', [u'c#']],
#  [u'5032', [u'java']],
#  [u'5034', [u'c#']],
#  [u'5036', [u'sql']],
#  [u'5049', [u'python', u'php', u'yii', u'flask']],
#  [u'5056', [u'angularjs', u'javascript']],
#  [u'5066', [u'vb.net']],
#  [u'5069', [u'java', u'netbeans', u'postgresql']],
#  [u'5071', [u'windows-forms', u'visual-studio', u'vb.net']],
#  [u'5075', [u'javascript', u'funciones', u'html5']],
#  [u'5076', [u'java', u'estructuras-de-datos']],
#  [u'5087', [u'android', u'android-studio']],
#  [u'5090', [u'php', u'base-de-datos', u'mysqli']],
#  [u'5094', [u'android', u'arduino']],
#  [u'5095', [u'c']],
#  [u'5105', [u'c#']],
#  [u'5107', [u'r']],
#  [u'5109', [u'sql-server']],
#  [u'5118', [u'c#', u'asp.net-mvc-5', u'asp.net-mvc', u'seo']],
#  [u'5126', [u'java', u'apache-poi']],
#  [u'5127', [u'java', u'smartgwt']],
#  [u'5130', [u'python', u'python-2.7']],
#  [u'5133', [u'ensamblador']],
#  [u'5137', [u'php']],
#  [u'5145', [u'python', u'linux', u'windows']],
#  [u'5147', [u'angularjs', u'javascript']],
#  [u'5159', [u'java']],
#  [u'5161', [u'xampp']],
#  [u'5174', [u'c#', u'windows-forms']],
#  [u'5175', [u'oracle', u'ubuntu', u'oracle-11g', u'sqldeveloper']],
#  [u'5176', [u'mongodb']],
#  [u'5179', [u'array', u'php', u'session']],
#  [u'5180', [u'asp.net', u'kendoui', u'c#', u'asp.net-mvc', u'reportviewer']],
#  [u'5194', [u'oracle', u'php', u'base-de-datos', u'pdo']],
#  [u'5197',
#   [u'mysql', u'sql', u'php', u'html', u'pdf', u'revisi\xf3n-de-c\xf3digo']],
#  [u'5199', [u'pdf', u'aplicaci\xf3n-web', u'jspdf', u'csv', u'mpdf']],
#  [u'5200', [u'c++']],
#  [u'5206', [u'javascript', u'mysql', u'sql', u'php', u'pdf', u'phpmyadmin']],
#  [u'5215', [u'c']],
#  [u'5217', [u'r']],
#  [u'5218', [u'c', u'c++98']],
#  [u'5219', [u'android', u'java', u'xml', u'firebase']],
#  [u'5231', [u'mysql', u'java', u'php']],
#  [u'5233', [u'c', u'dev-c++']],
#  [u'5236', [u'php', u'ajax', u'datepicker']],
#  [u'5239', [u'javascript', u'jquery', u'java', u'spring', u'html']],
#  [u'5240', [u'wordpress']],
#  [u'5242', [u'c++', u'java', u'c']],
#  [u'5243', [u'visual-c++']],
#  [u'5244', [u'android']],
#  [u'5248',
#   [u'php', u'django', u'wordpress', u'debian', u'apache', u'.htaccess']],
#  [u'5253', [u'html', u'css']],
#  ...]

# %% [markdown]
# ## EJERCICIO: Relacionar cada usuario con los tags de sus preguntas a través de la relación `:INTERESTED_IN`.

# %%
# %%cypher
# MATCH (tag:Tag)-->(:Question)<--(usuario:User)
# MERGE (usuario)-[:INTERESTED_IN]->(tag);
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ## EJERCICIO: Recomendar a los usuarios _tags_ sobre los que podrían estar interesados en base a _tags_ en los que los usuarios con los que están relacionados con `:RECIPROCATE` están interesados y ellos no, ordenado por número de usuarios interesados en cada _tag_.

# %%
# %%cypher
# MATCH
# (usuario1)-[:RECIPROCATE]->(usuario2),
# (usuario2)-[:INTERESTED_IN]->(tag1),
# (usuario1)-[:INTERESTED_IN]->(tag2)
# WHERE usuario1.Id <> usuario2.Id AND tag1.name <> tag2.name
# RETURN usuario1 AS Usuario, COLLECT(DISTINCT tag2.name) AS Tags_Recomendados, count(usuario2) AS Interesados
# ORDER BY Interesados DESC
# Out:
# 55 rows affected.
# [[{u'Id': u'100'},
#   [u'datetime',
#    u'android',
#    u'bash',
#    u'archivo',
#    u'python',
#    u'linux',
#    u'funciones',
#    u'validaci\xf3n',
#    u'html5',
#    u'formularios',
#    u'python-2.7',
#    u'control-de-versiones',
#    u'mercurial',
#    u'pip',
#    u'ubuntu',
#    u'django',
#    u'cordova',
#    u'python-3.x',
#    u'string',
#    u'lista',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'lua',
#    u'highcharts',
#    u'parse.com',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'ionic',
#    u'celery',
#    u'nginx',
#    u'logrotate',
#    u'configuraci\xf3n',
#    u'excepciones',
#    u'pdf',
#    u'reportlab',
#    u'asincronismo',
#    u'm\xe9todo',
#    u'clase',
#    u'haskell',
#    u'base-de-datos',
#    u'mysql'],
#   6111],
#  [{u'Id': u'342'},
#   [u'java',
#    u'oracle-10g',
#    u'oracle',
#    u'sql',
#    u'knockoutjs',
#    u'git',
#    u'css',
#    u'html',
#    u'c#',
#    u'admob',
#    u'git-commit',
#    u'dukescript',
#    u'regex',
#    u'eclipse',
#    u'jboss',
#    u'depuraci\xf3n',
#    u'json',
#    u'importaci\xf3n',
#    u'3d',
#    u'css3',
#    u'ruby',
#    u'javascript',
#    u'jquery',
#    u'rubygems',
#    u'coffeescript',
#    u'primefaces-calendar',
#    u'oracle-11g',
#    u'webgl',
#    u'scss',
#    u'jsfiddle',
#    u'jboss-as-7',
#    u'jboss-cli',
#    u'jboss-as',
#    u'sqldeveloper',
#    u'java-9',
#    u'plsql',
#    u'swing',
#    u'azul-zulu',
#    u'spring-tool-suite',
#    u'bootstrap',
#    u'windows',
#    u'sqlfiddle',
#    u'primefaces',
#    u'unity3d',
#    u'jdbc',
#    u'jboss-eap',
#    u'jpa',
#    u'seam',
#    u'hql',
#    u'maven',
#    u'plugin',
#    u'netbeans',
#    u'i18n',
#    u'git-push',
#    u'github',
#    u'git-fork',
#    u'html5'],
#   4826],
#  [{u'Id': u'250'},
#   [u'mysql',
#    u'php',
#    u'css',
#    u'ajax',
#    u'html',
#    u'unidades-de-medici\xf3n',
#    u'html5',
#    u'lenguaje-agn\xf3stico',
#    u'cordova',
#    u'xml',
#    u'css3',
#    u'ios',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'phonegap',
#    u'inyecci\xf3n-sql',
#    u'local-storage',
#    u'svg',
#    u'arm',
#    u'intel-atom',
#    u'namespace',
#    u'almacenamiento',
#    u'data-atributos',
#    u'programaci\xf3n-m\xf3vil',
#    u'css-transform',
#    u'd3.js',
#    u'eventos',
#    u'cq5',
#    u'aem',
#    u'jsp',
#    u'promises',
#    u'internacionalizaci\xf3n',
#    u'avd',
#    u'bootstrap',
#    u'seguridad',
#    u'base-de-datos',
#    u'sql'],
#   4735],
#  [{u'Id': u'517'},
#   [u'mysql',
#    u'datetime',
#    u'css',
#    u'html',
#    u'regex',
#    u'html5',
#    u'comparaciones',
#    u'eclipse',
#    u'lenguaje-agn\xf3stico',
#    u'condiciones',
#    u'loops',
#    u'algoritmos',
#    u'importaci\xf3n',
#    u'google-maps',
#    u'string',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'anotaciones',
#    u'tomcat',
#    u'eficiencia',
#    u'infobox',
#    u'combobox',
#    u'volatile',
#    u'oracle-sqldeveloper',
#    u'db2',
#    u'redirecci\xf3n',
#    u'.htaccess',
#    u'swing',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'apache',
#    u'constantes',
#    u'fecha',
#    u'jsp',
#    u'internacionalizaci\xf3n',
#    u'double',
#    u'redondeo',
#    u'bigdecimal',
#    u'java-stream',
#    u'java-8',
#    u'wordpress',
#    u'localizaci\xf3n',
#    u'thread',
#    u'pattern',
#    u'i18n',
#    u'hilos',
#    u'base-de-datos',
#    u'servlets',
#    u'java'],
#   4390],
#  [{u'Id': u'729'},
#   [u'mysql',
#    u'bash',
#    u'git',
#    u'php',
#    u'css',
#    u'linux',
#    u'html',
#    u'regex',
#    u'orientaci\xf3n-a-objetos',
#    u'google-maps',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'magento-1.9',
#    u'gpg',
#    u'ecmascript-2015',
#    u'magento2',
#    u'xpath',
#    u'joomla3',
#    u'yii2'],
#   2437],
#  [{u'Id': u'2004'},
#   [u'python',
#    u'git',
#    u'java',
#    u'hibernate',
#    u'spring',
#    u'html',
#    u'git-commit',
#    u'c#',
#    u'control-de-versiones',
#    u'ubuntu',
#    u'matem\xe1ticas',
#    u'json',
#    u'.net',
#    u'google-maps',
#    u'string',
#    u'javascript',
#    u'svn',
#    u'subversion',
#    u'oauth',
#    u'google-datastore',
#    u'google-app-engine',
#    u'objectify',
#    u'google-chrome',
#    u'spring-mvc',
#    u'jpa',
#    u'maven',
#    u'git-push'],
#   2093],
#  [{u'Id': u'9099'},
#   [u'http',
#    u'post',
#    u'java',
#    u'variables',
#    u'php',
#    u'css',
#    u'html',
#    u'android-layout',
#    u'email',
#    u'html5',
#    u'json',
#    u'swift',
#    u'css3',
#    u'casting',
#    u'string',
#    u'ios',
#    u'xcode',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'android',
#    u'twig',
#    u'jquery-validate',
#    u'cabeceras-http',
#    u'if-else',
#    u'dispatch-async',
#    u'nsdata',
#    u'nsstring',
#    u'appdelegate',
#    u'alamofire',
#    u'boundary',
#    u'segue',
#    u'mpdf',
#    u'validate',
#    u'alamofireimage',
#    u'jquery-seat-chart',
#    u'required',
#    u'lang',
#    u'uitableviewcontroller',
#    u'uitableview',
#    u'sha512',
#    u'app',
#    u'constraints',
#    u'snapkit',
#    u'webview',
#    u'whatsapp',
#    u'uicollectionview',
#    u'wordpress-theme',
#    u'uiview',
#    u'cocoapods',
#    u'encriptacion',
#    u'fecha',
#    u'swift2',
#    u'wordpress',
#    u'asincr\xf3nico'],
#   1749],
#  [{u'Id': u'2230'},
#   [u'sql',
#    u'java',
#    u'php',
#    u'c#',
#    u'android-layout',
#    u'json',
#    u'google-maps',
#    u'string',
#    u'android',
#    u'material-design',
#    u'google-play',
#    u'live-template',
#    u'realm',
#    u'trigger',
#    u'android-jellybean',
#    u'gradle',
#    u'sqlite',
#    u'windows',
#    u'android-studio',
#    u'uwp',
#    u'xaml',
#    u'base-de-datos',
#    u'mysql'],
#   1635],
#  [{u'Id': u'227'},
#   [u'java',
#    u'spring',
#    u'mercurial',
#    u'lenguaje-agn\xf3stico',
#    u'jmc',
#    u'wildfly',
#    u'vscode',
#    u'subrepositorios',
#    u'cabeceras-http',
#    u'rest',
#    u'apache-poi',
#    u'spring-mvc',
#    u'paso-por-referencia',
#    u'paso-por-valor',
#    u'maven',
#    u'java-ee',
#    u'servlets'],
#   1622],
#  [{u'Id': u'2676'},
#   [u'sql',
#    u'java',
#    u'android-asynctask',
#    u'php',
#    u'html',
#    u'optimizaci\xf3n',
#    u'formularios',
#    u'json',
#    u'xml',
#    u'string',
#    u'lista',
#    u'array',
#    u'javascript',
#    u'android',
#    u'pdo',
#    u'glassfish',
#    u'transacciones',
#    u'lambda',
#    u'union',
#    u'markdown',
#    u'pdfmake',
#    u'callback',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'eventos',
#    u'map',
#    u'stored-procedure',
#    u'java-8',
#    u'thread',
#    u'pdf',
#    u'reflexi\xf3n',
#    u'embebido',
#    u'java-ee',
#    u'mysql'],
#   1608],
#  [{u'Id': u'22'},
#   [u'git',
#    u'nodejs',
#    u'perl',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'errores',
#    u'eventos',
#    u'conversi\xf3n-de-tipos',
#    u'pouchdb',
#    u'go',
#    u'seguridad',
#    u'booleano',
#    u'tipos',
#    u'sandbox'],
#   1220],
#  [{u'Id': u'2429'},
#   [u'java',
#    u'git',
#    u'php',
#    u'html',
#    u'ajax',
#    u'html5',
#    u'ordenamiento',
#    u'asp.net',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'errores',
#    u'materialize',
#    u'url',
#    u'login',
#    u'visual-studio-2015',
#    u'apache',
#    u'mono',
#    u'postgresql',
#    u'codeigniter-3',
#    u'codeigniter',
#    u'datatables',
#    u'debian',
#    u'asp.net-mvc',
#    u'excepciones',
#    u'seguridad',
#    u'sql'],
#   1018],
#  [{u'Id': u'187'},
#   [u'bash',
#    u'python',
#    u'hibernate',
#    u'java',
#    u'spring',
#    u'linux',
#    u'clase-abstracta',
#    u'constructor',
#    u'orientaci\xf3n-a-objetos',
#    u'json',
#    u'nodejs',
#    u'javascript',
#    u'generator',
#    u'coroutine',
#    u'yield',
#    u'mongodb',
#    u'c',
#    u'manejo-de-memoria',
#    u'nosql',
#    u'unix',
#    u'depurar',
#    u'hilos',
#    u'mysql'],
#   938],
#  [{u'Id': u'6173'},
#   [u'css',
#    u'html',
#    u'html5',
#    u'css3',
#    u'ios',
#    u'javascript',
#    u'intel-xdk',
#    u'local-storage',
#    u'grid',
#    u'gif',
#    u'desplegable',
#    u'menu',
#    u'redirecci\xf3n',
#    u'animaci\xf3n',
#    u'aplicaci\xf3n-web',
#    u'windows'],
#   874],
#  [{u'Id': u'3234'},
#   [u'git',
#    u'php',
#    u'css',
#    u'html',
#    u'optimizaci\xf3n',
#    u'rendimiento',
#    u'html5',
#    u'javascript',
#    u'facebook-api',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'bootstrap-carousel',
#    u'facebook',
#    u'bootstrap',
#    u'dom',
#    u'c'],
#   820],
#  [{u'Id': u'2163'},
#   [u'mysql',
#    u'post',
#    u'java',
#    u'php',
#    u'html',
#    u'ajax',
#    u'admob',
#    u'json',
#    u'android',
#    u'gridview',
#    u'codeigniter-3',
#    u'codeigniter',
#    u'base-de-datos'],
#   781],
#  [{u'Id': u'353'},
#   [u'python',
#    u'css',
#    u'html',
#    u'ajax',
#    u'django',
#    u'python-3.x',
#    u'nodejs',
#    u'typescript',
#    u'javascript',
#    u'jquery',
#    u'electron',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'material-design-lite',
#    u'pyqt',
#    u'angularjs-2.0',
#    u'babeljs',
#    u'windows',
#    u'conda',
#    u'poo'],
#   773],
#  [{u'Id': u'638'},
#   [u'python',
#    u'git',
#    u'django',
#    u'angularjs',
#    u'javascript',
#    u'ngroute',
#    u'mongoose',
#    u'ngresource',
#    u'restful',
#    u'ui.router',
#    u'node',
#    u'windows10',
#    u'gulp',
#    u'powershell',
#    u'staticfiles',
#    u'rest',
#    u'mongodb',
#    u'djangorestframework'],
#   735],
#  [{u'Id': u'25'},
#   [u'c++11',
#    u'git',
#    u'java',
#    u'c#',
#    u'c\xf3digo-abierto',
#    u'licencias',
#    u'xml',
#    u'nodejs',
#    u'c++',
#    u'array',
#    u'javascript',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'visual-studio-2015',
#    u'groovy'],
#   553],
#  [{u'Id': u'399'},
#   [u'mysql',
#    u'bash',
#    u'http',
#    u'regex',
#    u'go',
#    u'docker',
#    u'makefile',
#    u'ecmascript-2015',
#    u'javascript',
#    u'nodejs',
#    u'puppet',
#    u'vagrant',
#    u'git'],
#   542],
#  [{u'Id': u'2747'},
#   [u'timestamp',
#    u'oracle',
#    u'java',
#    u'html',
#    u'regex',
#    u'html5',
#    u'asp.net',
#    u'angularjs',
#    u'javascript',
#    u'oracle-11g',
#    u'angular-translate',
#    u'md5',
#    u'moodle',
#    u'encriptacion',
#    u'stored-procedure',
#    u'ngcookies',
#    u'iis',
#    u'spring-security',
#    u'spring-mvc',
#    u'visual-studio'],
#   536],
#  [{u'Id': u'24'},
#   [u'android',
#    u'c++11',
#    u'java',
#    u'casting',
#    u'c++',
#    u'string',
#    u'gradle',
#    u'angularjs-2.0',
#    u'angular2-template',
#    u'android-studio',
#    u'c'],
#   507],
#  [{u'Id': u'83'},
#   [u'bash',
#    u'archivo',
#    u'git',
#    u'linux',
#    u'git-commit',
#    u'shell',
#    u'sed',
#    u'awk',
#    u'zsh',
#    u'unix',
#    u'grep',
#    u'ascii'],
#   489],
#  [{u'Id': u'2838'},
#   [u'python',
#    u'ajax',
#    u'html5',
#    u'formularios',
#    u'django',
#    u'json',
#    u'python-3.x',
#    u'javascript',
#    u'django-admin',
#    u'django-forms',
#    u'django-models',
#    u'datatables'],
#   486],
#  [{u'Id': u'9897'},
#   [u'mysql',
#    u'ajax',
#    u'php',
#    u'css',
#    u'html',
#    u'html5',
#    u'css3',
#    u'array',
#    u'javascript',
#    u'jquery',
#    u'session',
#    u'animaci\xf3n',
#    u'mysqli'],
#   485],
#  [{u'Id': u'12625'},
#   [u'ajax',
#    u'php',
#    u'css',
#    u'html',
#    u'html5',
#    u'css3',
#    u'javascript',
#    u'dise\xf1o',
#    u'url',
#    u'bootstrap',
#    u'wordpress',
#    u'plugin'],
#   448],
#  [{u'Id': u'73'},
#   [u'laravel',
#    u'php',
#    u'ajax',
#    u'html',
#    u'html5',
#    u'condiciones',
#    u'javascript',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'css'],
#   432],
#  [{u'Id': u'1839'},
#   [u'c#',
#    u'validaci\xf3n',
#    u'json',
#    u'xml',
#    u'asp.net',
#    u'angularjs',
#    u'javascript',
#    u'jquery',
#    u'facebook-api',
#    u'sailsjs',
#    u'iis',
#    u'nuget',
#    u'razor',
#    u'windows',
#    u'excepciones',
#    u'visual-studio',
#    u'vb.net'],
#   338],
#  [{u'Id': u'2224'},
#   [u'css',
#    u'html',
#    u'c#',
#    u'formularios',
#    u'css3',
#    u'.net',
#    u'javascript',
#    u'jquery',
#    u'reflection',
#    u'operador',
#    u'animaci\xf3n'],
#   312],
#  [{u'Id': u'529'},
#   [u'python', u'json', u'nodejs', u'javascript', u'twitter-api', u'tweepy'],
#   244],
#  [{u'Id': u'2367'}, [u'html5', u'javascript', u'jquery', u'zepto'], 225],
#  [{u'Id': u'191'},
#   [u'mysql',
#    u'java',
#    u'spring',
#    u'json',
#    u'angularjs',
#    u'android',
#    u'recyclerview',
#    u'materialize',
#    u'android-studio',
#    u'reflection'],
#   225],
#  [{u'Id': u'731'},
#   [u'json',
#    u'jquery',
#    u'javascript',
#    u'android',
#    u'xamarin.forms',
#    u'xamarin'],
#   225],
#  [{u'Id': u'400'},
#   [u'spring',
#    u'thymeleaf',
#    u'eclipse',
#    u'json',
#    u'javascript',
#    u'jquery',
#    u'alfresco',
#    u'asincr\xf3nico',
#    u'spring-mvc',
#    u'jpa',
#    u'maven',
#    u'java'],
#   200],
#  [{u'Id': u'23'},
#   [u'momentjs',
#    u'git',
#    u'ajax',
#    u'c#',
#    u'mercurial',
#    u'asp.net-web-api',
#    u'asp.net',
#    u'.net',
#    u'google-maps',
#    u'karma-jasmine',
#    u'jasmine',
#    u'angularjs',
#    u'javascript'],
#   179],
#  [{u'Id': u'225'},
#   [u'css',
#    u'ajax',
#    u'c#',
#    u'html5',
#    u'asp.net-mvc',
#    u'razor',
#    u'asp.net-mvc-5',
#    u'bootstrap',
#    u'jquery',
#    u'asp.net-web-api',
#    u'css3'],
#   153],
#  [{u'Id': u'288'},
#   [u'ordenamiento', u'perl', u'matrices-asociativas', u'booleano', u'tipos'],
#   142],
#  [{u'Id': u'398'},
#   [u'git',
#    u'nodejs',
#    u'windows10',
#    u'registro-windows',
#    u'visual-studio-2015',
#    u'windows',
#    u'directorioactivo',
#    u'visual-studio',
#    u'azure'],
#   124],
#  [{u'Id': u'34'}, [u'css', u'html', u'rails'], 112],
#  [{u'Id': u'95'},
#   [u'java',
#    u'swift',
#    u'objective-c',
#    u'google-newsstand-producer',
#    u'rss',
#    u'javascript',
#    u'android-glide',
#    u'dialogo',
#    u'uiwebview',
#    u'android'],
#   108],
#  [{u'Id': u'547'},
#   [u'c#',
#    u'npm',
#    u'nodejs',
#    u'asp.net-web-api',
#    u'.net',
#    u'javascript',
#    u'powershell',
#    u'datatables',
#    u'sharepoint',
#    u'signalr',
#    u'real-time'],
#   98],
#  [{u'Id': u'120'},
#   [u'sql',
#    u'html',
#    u'javascript',
#    u'ftp',
#    u'as400',
#    u'ms-access-2010',
#    u'xhtml',
#    u'sql-server',
#    u'ssis',
#    u'c#'],
#   88],
#  [{u'Id': u'531'},
#   [u'c#',
#    u'entity-framework',
#    u'windows-forms',
#    u'.net',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'drag-and-drop',
#    u'agarrar-y-soltar',
#    u'irc',
#    u'sql-server'],
#   88],
#  [{u'Id': u'9754'}, [u'.htaccess'], 55],
#  [{u'Id': u'2832'}, [u'post', u'tinymce', u'wordpress'], 38],
#  [{u'Id': u'6497'},
#   [u'php',
#    u'css',
#    u'html',
#    u'funciones',
#    u'formularios',
#    u'google-maps',
#    u'javascript',
#    u'jquery',
#    u'aplicaci\xf3n-web',
#    u'bootstrap-carousel',
#    u'bootstrap',
#    u'wordpress',
#    u'cache'],
#   38],
#  [{u'Id': u'7661'},
#   [u'google-plus', u'google-hoja-de-calculo', u'google-apps-script'],
#   37],
#  [{u'Id': u'65'},
#   [u'css',
#    u'optimizaci\xf3n',
#    u'regex',
#    u'array',
#    u'google-hoja-de-calculo',
#    u'google-forms',
#    u'google-drive',
#    u'bookmarklet',
#    u'gmail',
#    u'formulas',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'javascript',
#    u'google-apps-script'],
#   37],
#  [{u'Id': u'2171'}, [u'winapi', u'windows', u'c'], 26],
#  [{u'Id': u'2509'},
#   [u'git',
#    u'css',
#    u'html',
#    u'html5',
#    u'css3',
#    u'javascript',
#    u'filtros-css',
#    u'revisi\xf3n-de-c\xf3digo',
#    u'babeljs',
#    u'reactjs',
#    u'github',
#    u'angularjs'],
#   22],
#  [{u'Id': u'2722'}, [u'angularjs', u'javascript'], 22],
#  [{u'Id': u'1798'}, [u'git'], 19],
#  [{u'Id': u'555'}, [u'git'], 12],
#  [{u'Id': u'9905'}, [u'javafx'], 7],
#  [{u'Id': u'3275'},
#   [u'mysql',
#    u'java',
#    u'css',
#    u'matem\xe1ticas',
#    u'eventos',
#    u'jdbc',
#    u'netbeans'],
#   7]]
